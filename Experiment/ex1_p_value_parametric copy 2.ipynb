# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import SI_CoRT
import CoRT_builder

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Testing p_value

# %%
n_target = 15
n_source = 10
p = 50
K = 5 
Ka = 3
h = 30 
N = n_target + Ka * n_source
NI = n_target + n_source
lamda_k_source = 1.2 * np.sqrt(np.log(p)/ N)
lamda_1_source = 1.2 * np.sqrt(np.log(p)/ NI) 
lamda_not_source = 1.2 * np.sqrt(np.log(p) / n_target) 
alpha = 0.05
T = 5
s_len = 5
s_vector = [1] * s_len
para_results_storage = []
CoRT_model = CoRT_builder.CoRT(alpha=lamda_not_source)
iteration = 1000

cnt1 = 0
cnt2 = 0
cnt3 = 0
cnt4 = 0

for i in range(iteration):
    target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
    result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, lamda_not_source, lamda_1_source, lamda_k_source, T, s_len)
    if result_dict != None:
        cnt1 += (result_dict['is_signal'] == True)
        cnt2 += (result_dict['is_signal'] == False)
        cnt3 += (result_dict['is_signal'] == True and result_dict['p_value'] <= alpha)
        cnt4 += (result_dict['is_signal'] == False and result_dict['p_value'] <= alpha)
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_values[{i}]: {result_dict['p_value']}")
            print(f"FPR: {cnt4 / cnt2}, TPR: {cnt3 / cnt1}")
            print(f"is_not_signal: {int(cnt2), int(cnt4)}")
            print(f"is_signal: {int(cnt1), int(cnt3)}")
            # print("\n")
            print("===========================================================================")

        para_results_storage.append(result_dict)
# Out:
# is_signal : True, p_values[0]: 0.015103901072926362
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : False, p_values[1]: 0.9364969162918917
# FPR: 0.0, TPR: 1.0
# is_not_signal: (1, 0)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : False, p_values[2]: 0.9817273044406747
# FPR: 0.0, TPR: 1.0
# is_not_signal: (2, 0)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : True, p_values[3]: 0.2438417204885266
# FPR: 0.0, TPR: 0.5
# is_not_signal: (2, 0)
# is_signal: (2, 1)
# ===========================================================================
# is_signal : True, p_values[4]: 0.32957526186491126
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (2, 0)
# is_signal: (3, 1)
# ===========================================================================
# is_signal : True, p_values[5]: 0.17843454753030485
# FPR: 0.0, TPR: 0.25
# is_not_signal: (2, 0)
# is_signal: (4, 1)
# ===========================================================================
# is_signal : True, p_values[6]: 0.5908944168128287
# FPR: 0.0, TPR: 0.2
# is_not_signal: (2, 0)
# is_signal: (5, 1)
# ===========================================================================
# is_signal : True, p_values[7]: 4.943054077166664e-08
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (2, 0)
# is_signal: (6, 2)
# ===========================================================================
# is_signal : True, p_values[8]: 0.013781954732362323
# FPR: 0.0, TPR: 0.42857142857142855
# is_not_signal: (2, 0)
# is_signal: (7, 3)
# ===========================================================================
# is_signal : True, p_values[9]: 0.43832211288054346
# FPR: 0.0, TPR: 0.375
# is_not_signal: (2, 0)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : True, p_values[10]: 0.16252921024728284
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (2, 0)
# is_signal: (9, 3)
# ===========================================================================
# is_signal : True, p_values[11]: 0.8475160605031664
# FPR: 0.0, TPR: 0.3
# is_not_signal: (2, 0)
# is_signal: (10, 3)
# ===========================================================================
# is_signal : False, p_values[12]: 0.8068752742835721
# FPR: 0.0, TPR: 0.3
# is_not_signal: (3, 0)
# is_signal: (10, 3)
# ===========================================================================
# is_signal : True, p_values[13]: 0.2412930611261095
# FPR: 0.0, TPR: 0.2727272727272727
# is_not_signal: (3, 0)
# is_signal: (11, 3)
# ===========================================================================
# is_signal : False, p_values[14]: 0.3692511878089159
# FPR: 0.0, TPR: 0.2727272727272727
# is_not_signal: (4, 0)
# is_signal: (11, 3)
# ===========================================================================
# is_signal : True, p_values[15]: 0.6155781518051191
# FPR: 0.0, TPR: 0.25
# is_not_signal: (4, 0)
# is_signal: (12, 3)
# ===========================================================================
# is_signal : True, p_values[16]: 0.4756618418244852
# FPR: 0.0, TPR: 0.23076923076923078
# is_not_signal: (4, 0)
# is_signal: (13, 3)
# ===========================================================================
# is_signal : False, p_values[17]: 0.416785978740408
# FPR: 0.0, TPR: 0.23076923076923078
# is_not_signal: (5, 0)
# is_signal: (13, 3)
# ===========================================================================
# is_signal : True, p_values[18]: 7.148062028949909e-07
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (5, 0)
# is_signal: (14, 4)
# ===========================================================================
# is_signal : True, p_values[19]: 0.29617641371479286
# FPR: 0.0, TPR: 0.26666666666666666
# is_not_signal: (5, 0)
# is_signal: (15, 4)
# ===========================================================================
# is_signal : True, p_values[20]: 0.6397991922257278
# FPR: 0.0, TPR: 0.25
# is_not_signal: (5, 0)
# is_signal: (16, 4)
# ===========================================================================
# is_signal : True, p_values[21]: 0.8722933613045976
# FPR: 0.0, TPR: 0.23529411764705882
# is_not_signal: (5, 0)
# is_signal: (17, 4)
# ===========================================================================
# is_signal : False, p_values[22]: 0.5186773693414184
# FPR: 0.0, TPR: 0.23529411764705882
# is_not_signal: (6, 0)
# is_signal: (17, 4)
# ===========================================================================
# is_signal : True, p_values[23]: 0.1797335437590737
# FPR: 0.0, TPR: 0.2222222222222222
# is_not_signal: (6, 0)
# is_signal: (18, 4)
# ===========================================================================
# is_signal : False, p_values[24]: 0.4061862384538404
# FPR: 0.0, TPR: 0.2222222222222222
# is_not_signal: (7, 0)
# is_signal: (18, 4)
# ===========================================================================
# is_signal : True, p_values[25]: 0.23298391319118616
# FPR: 0.0, TPR: 0.21052631578947367
# is_not_signal: (7, 0)
# is_signal: (19, 4)
# ===========================================================================
# is_signal : True, p_values[26]: 0.0322407033696257
# FPR: 0.0, TPR: 0.25
# is_not_signal: (7, 0)
# is_signal: (20, 5)
# ===========================================================================
# is_signal : False, p_values[27]: 0.6489344917176534
# FPR: 0.0, TPR: 0.25
# is_not_signal: (8, 0)
# is_signal: (20, 5)
# ===========================================================================
# is_signal : True, p_values[28]: 0.012543059040527549
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (8, 0)
# is_signal: (21, 6)
# ===========================================================================
# is_signal : False, p_values[29]: 0.655396823842078
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (9, 0)
# is_signal: (21, 6)
# ===========================================================================
# is_signal : True, p_values[30]: 0.03077908349158487
# FPR: 0.0, TPR: 0.3181818181818182
# is_not_signal: (9, 0)
# is_signal: (22, 7)
# ===========================================================================
# is_signal : True, p_values[31]: 0.14118412349090106
# FPR: 0.0, TPR: 0.30434782608695654
# is_not_signal: (9, 0)
# is_signal: (23, 7)
# ===========================================================================
# is_signal : True, p_values[32]: 0.0007077009903355691
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (9, 0)
# is_signal: (24, 8)
# ===========================================================================
# is_signal : True, p_values[33]: 0.018082062557714496
# FPR: 0.0, TPR: 0.36
# is_not_signal: (9, 0)
# is_signal: (25, 9)
# ===========================================================================
# is_signal : False, p_values[34]: 0.2826602622157952
# FPR: 0.0, TPR: 0.36
# is_not_signal: (10, 0)
# is_signal: (25, 9)
# ===========================================================================
# is_signal : True, p_values[35]: 0.026678722943323407
# FPR: 0.0, TPR: 0.38461538461538464
# is_not_signal: (10, 0)
# is_signal: (26, 10)
# ===========================================================================
# is_signal : True, p_values[36]: 0.14010859110263874
# FPR: 0.0, TPR: 0.37037037037037035
# is_not_signal: (10, 0)
# is_signal: (27, 10)
# ===========================================================================
# is_signal : True, p_values[37]: 0.8592160320524171
# FPR: 0.0, TPR: 0.35714285714285715
# is_not_signal: (10, 0)
# is_signal: (28, 10)
# ===========================================================================
# is_signal : False, p_values[38]: 0.8935366945818295
# FPR: 0.0, TPR: 0.35714285714285715
# is_not_signal: (11, 0)
# is_signal: (28, 10)
# ===========================================================================
# is_signal : False, p_values[39]: 0.33381692386600553
# FPR: 0.0, TPR: 0.35714285714285715
# is_not_signal: (12, 0)
# is_signal: (28, 10)
# ===========================================================================
# is_signal : True, p_values[40]: 0.21791807563216836
# FPR: 0.0, TPR: 0.3448275862068966
# is_not_signal: (12, 0)
# is_signal: (29, 10)
# ===========================================================================
# is_signal : True, p_values[41]: 0.9344225763340362
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (12, 0)
# is_signal: (30, 10)
# ===========================================================================
# is_signal : True, p_values[42]: 0.07028184184346897
# FPR: 0.0, TPR: 0.3225806451612903
# is_not_signal: (12, 0)
# is_signal: (31, 10)
# ===========================================================================
# is_signal : False, p_values[43]: 0.04919090742531733
# FPR: 0.07692307692307693, TPR: 0.3225806451612903
# is_not_signal: (13, 1)
# is_signal: (31, 10)
# ===========================================================================
# is_signal : True, p_values[44]: 0.3997157619202023
# FPR: 0.07692307692307693, TPR: 0.3125
# is_not_signal: (13, 1)
# is_signal: (32, 10)
# ===========================================================================
# is_signal : False, p_values[45]: 0.8408181535961359
# FPR: 0.07142857142857142, TPR: 0.3125
# is_not_signal: (14, 1)
# is_signal: (32, 10)
# ===========================================================================
# is_signal : False, p_values[46]: 0.41591960824889607
# FPR: 0.06666666666666667, TPR: 0.3125
# is_not_signal: (15, 1)
# is_signal: (32, 10)
# ===========================================================================
# is_signal : True, p_values[47]: 0.7923817494363591
# FPR: 0.06666666666666667, TPR: 0.30303030303030304
# is_not_signal: (15, 1)
# is_signal: (33, 10)
# ===========================================================================
# is_signal : True, p_values[48]: 0.006624031490644056
# FPR: 0.06666666666666667, TPR: 0.3235294117647059
# is_not_signal: (15, 1)
# is_signal: (34, 11)
# ===========================================================================
# is_signal : False, p_values[49]: 0.9906060328801014
# FPR: 0.0625, TPR: 0.3235294117647059
# is_not_signal: (16, 1)
# is_signal: (34, 11)
# ===========================================================================
# is_signal : True, p_values[50]: 0.6623326187298659
# FPR: 0.0625, TPR: 0.3142857142857143
# is_not_signal: (16, 1)
# is_signal: (35, 11)
# ===========================================================================
# is_signal : True, p_values[51]: 0.8378994328681779
# FPR: 0.0625, TPR: 0.3055555555555556
# is_not_signal: (16, 1)
# is_signal: (36, 11)
# ===========================================================================
# is_signal : True, p_values[52]: 0.015050858507940301
# FPR: 0.0625, TPR: 0.32432432432432434
# is_not_signal: (16, 1)
# is_signal: (37, 12)
# ===========================================================================
# is_signal : True, p_values[53]: 0.05473161918798941
# FPR: 0.0625, TPR: 0.3157894736842105
# is_not_signal: (16, 1)
# is_signal: (38, 12)
# ===========================================================================
# is_signal : True, p_values[54]: 0.8030132699429233
# FPR: 0.0625, TPR: 0.3076923076923077
# is_not_signal: (16, 1)
# is_signal: (39, 12)
# ===========================================================================
# is_signal : False, p_values[55]: 0.5175445609413554
# FPR: 0.058823529411764705, TPR: 0.3076923076923077
# is_not_signal: (17, 1)
# is_signal: (39, 12)
# ===========================================================================
# is_signal : True, p_values[56]: 0.05896103291644117
# FPR: 0.058823529411764705, TPR: 0.3
# is_not_signal: (17, 1)
# is_signal: (40, 12)
# ===========================================================================
# is_signal : True, p_values[57]: 0.5300602405965853
# FPR: 0.058823529411764705, TPR: 0.2926829268292683
# is_not_signal: (17, 1)
# is_signal: (41, 12)
# ===========================================================================
# is_signal : False, p_values[58]: 0.2278480081475942
# FPR: 0.05555555555555555, TPR: 0.2926829268292683
# is_not_signal: (18, 1)
# is_signal: (41, 12)
# ===========================================================================
# is_signal : True, p_values[59]: 0.4892506054228997
# FPR: 0.05555555555555555, TPR: 0.2857142857142857
# is_not_signal: (18, 1)
# is_signal: (42, 12)
# ===========================================================================
# is_signal : True, p_values[60]: 5.953888739851365e-05
# FPR: 0.05555555555555555, TPR: 0.3023255813953488
# is_not_signal: (18, 1)
# is_signal: (43, 13)
# ===========================================================================
# is_signal : False, p_values[61]: 0.018363552438064756
# FPR: 0.10526315789473684, TPR: 0.3023255813953488
# is_not_signal: (19, 2)
# is_signal: (43, 13)
# ===========================================================================
# is_signal : True, p_values[62]: 0.34343892679537125
# FPR: 0.10526315789473684, TPR: 0.29545454545454547
# is_not_signal: (19, 2)
# is_signal: (44, 13)
# ===========================================================================
# is_signal : False, p_values[63]: 0.5423973300837244
# FPR: 0.1, TPR: 0.29545454545454547
# is_not_signal: (20, 2)
# is_signal: (44, 13)
# ===========================================================================
# is_signal : False, p_values[64]: 0.8381479135410295
# FPR: 0.09523809523809523, TPR: 0.29545454545454547
# is_not_signal: (21, 2)
# is_signal: (44, 13)
# ===========================================================================
# is_signal : True, p_values[65]: 0.9312136547399336
# FPR: 0.09523809523809523, TPR: 0.28888888888888886
# is_not_signal: (21, 2)
# is_signal: (45, 13)
# ===========================================================================
# is_signal : False, p_values[66]: 0.4685937599929357
# FPR: 0.09090909090909091, TPR: 0.28888888888888886
# is_not_signal: (22, 2)
# is_signal: (45, 13)
# ===========================================================================
# is_signal : False, p_values[67]: 0.8140319722007632
# FPR: 0.08695652173913043, TPR: 0.28888888888888886
# is_not_signal: (23, 2)
# is_signal: (45, 13)
# ===========================================================================
# is_signal : False, p_values[68]: 0.560871356933076
# FPR: 0.08333333333333333, TPR: 0.28888888888888886
# is_not_signal: (24, 2)
# is_signal: (45, 13)
# ===========================================================================
# is_signal : False, p_values[69]: 0.9242962563357622
# FPR: 0.08, TPR: 0.28888888888888886
# is_not_signal: (25, 2)
# is_signal: (45, 13)
# ===========================================================================
# is_signal : False, p_values[70]: 0.18725312958283738
# FPR: 0.07692307692307693, TPR: 0.28888888888888886
# is_not_signal: (26, 2)
# is_signal: (45, 13)
# ===========================================================================
# is_signal : True, p_values[71]: 0.0031445104556133696
# FPR: 0.07692307692307693, TPR: 0.30434782608695654
# is_not_signal: (26, 2)
# is_signal: (46, 14)
# ===========================================================================
# is_signal : True, p_values[72]: 0.004585168039457965
# FPR: 0.07692307692307693, TPR: 0.3191489361702128
# is_not_signal: (26, 2)
# is_signal: (47, 15)
# ===========================================================================
# is_signal : False, p_values[73]: 0.4375145897068282
# FPR: 0.07407407407407407, TPR: 0.3191489361702128
# is_not_signal: (27, 2)
# is_signal: (47, 15)
# ===========================================================================
# is_signal : True, p_values[74]: 0.07331290630743115
# FPR: 0.07407407407407407, TPR: 0.3125
# is_not_signal: (27, 2)
# is_signal: (48, 15)
# ===========================================================================
# is_signal : True, p_values[75]: 0.027984711432644804
# FPR: 0.07407407407407407, TPR: 0.32653061224489793
# is_not_signal: (27, 2)
# is_signal: (49, 16)
# ===========================================================================
# is_signal : True, p_values[76]: 0.0759650143913051
# FPR: 0.07407407407407407, TPR: 0.32
# is_not_signal: (27, 2)
# is_signal: (50, 16)
# ===========================================================================
# is_signal : True, p_values[77]: 0.01741673540462596
# FPR: 0.07407407407407407, TPR: 0.3333333333333333
# is_not_signal: (27, 2)
# is_signal: (51, 17)
# ===========================================================================
# is_signal : False, p_values[78]: 0.8431605845791847
# FPR: 0.07142857142857142, TPR: 0.3333333333333333
# is_not_signal: (28, 2)
# is_signal: (51, 17)
# ===========================================================================
# is_signal : False, p_values[79]: 0.6400559103782468
# FPR: 0.06896551724137931, TPR: 0.3333333333333333
# is_not_signal: (29, 2)
# is_signal: (51, 17)
# ===========================================================================
# is_signal : True, p_values[80]: 0.5873661825594017
# FPR: 0.06896551724137931, TPR: 0.3269230769230769
# is_not_signal: (29, 2)
# is_signal: (52, 17)
# ===========================================================================
# is_signal : False, p_values[81]: 0.3359530502213197
# FPR: 0.06666666666666667, TPR: 0.3269230769230769
# is_not_signal: (30, 2)
# is_signal: (52, 17)
# ===========================================================================
# is_signal : True, p_values[82]: 0.16016948589634383
# FPR: 0.06666666666666667, TPR: 0.32075471698113206
# is_not_signal: (30, 2)
# is_signal: (53, 17)
# ===========================================================================
# is_signal : True, p_values[83]: 0.0024430096448244676
# FPR: 0.06666666666666667, TPR: 0.3333333333333333
# is_not_signal: (30, 2)
# is_signal: (54, 18)
# ===========================================================================
# is_signal : False, p_values[84]: 0.13461279705767426
# FPR: 0.06451612903225806, TPR: 0.3333333333333333
# is_not_signal: (31, 2)
# is_signal: (54, 18)
# ===========================================================================
# is_signal : True, p_values[85]: 0.0031692644750431764
# FPR: 0.06451612903225806, TPR: 0.34545454545454546
# is_not_signal: (31, 2)
# is_signal: (55, 19)
# ===========================================================================
# is_signal : False, p_values[86]: 0.3988157232407716
# FPR: 0.0625, TPR: 0.34545454545454546
# is_not_signal: (32, 2)
# is_signal: (55, 19)
# ===========================================================================
# is_signal : False, p_values[87]: 0.276670504483701
# FPR: 0.06060606060606061, TPR: 0.34545454545454546
# is_not_signal: (33, 2)
# is_signal: (55, 19)
# ===========================================================================
# is_signal : True, p_values[88]: 0.491980119205239
# FPR: 0.06060606060606061, TPR: 0.3392857142857143
# is_not_signal: (33, 2)
# is_signal: (56, 19)
# ===========================================================================
# is_signal : True, p_values[89]: 0.0185900340641163
# FPR: 0.06060606060606061, TPR: 0.3508771929824561
# is_not_signal: (33, 2)
# is_signal: (57, 20)
# ===========================================================================
# is_signal : True, p_values[90]: 0.014075982208877402
# FPR: 0.06060606060606061, TPR: 0.3620689655172414
# is_not_signal: (33, 2)
# is_signal: (58, 21)
# ===========================================================================
# is_signal : False, p_values[91]: 0.8621013309623115
# FPR: 0.058823529411764705, TPR: 0.3620689655172414
# is_not_signal: (34, 2)
# is_signal: (58, 21)
# ===========================================================================
# is_signal : True, p_values[92]: 0.0015023673924214886
# FPR: 0.058823529411764705, TPR: 0.3728813559322034
# is_not_signal: (34, 2)
# is_signal: (59, 22)
# ===========================================================================
# is_signal : True, p_values[93]: 0.20059607489882714
# FPR: 0.058823529411764705, TPR: 0.36666666666666664
# is_not_signal: (34, 2)
# is_signal: (60, 22)
# ===========================================================================
# is_signal : True, p_values[94]: 0.025786714729125304
# FPR: 0.058823529411764705, TPR: 0.3770491803278688
# is_not_signal: (34, 2)
# is_signal: (61, 23)
# ===========================================================================
# is_signal : True, p_values[95]: 0.04268858025442035
# FPR: 0.058823529411764705, TPR: 0.3870967741935484
# is_not_signal: (34, 2)
# is_signal: (62, 24)
# ===========================================================================
# is_signal : True, p_values[96]: 0.010812789868166028
# FPR: 0.058823529411764705, TPR: 0.3968253968253968
# is_not_signal: (34, 2)
# is_signal: (63, 25)
# ===========================================================================
# is_signal : True, p_values[97]: 0.5213493801684594
# FPR: 0.058823529411764705, TPR: 0.390625
# is_not_signal: (34, 2)
# is_signal: (64, 25)
# ===========================================================================
# is_signal : True, p_values[98]: 0.22783863959231998
# FPR: 0.058823529411764705, TPR: 0.38461538461538464
# is_not_signal: (34, 2)
# is_signal: (65, 25)
# ===========================================================================
# is_signal : False, p_values[99]: 0.296047026883735
# FPR: 0.05714285714285714, TPR: 0.38461538461538464
# is_not_signal: (35, 2)
# is_signal: (65, 25)
# ===========================================================================
# is_signal : True, p_values[100]: 0.0009311996959304736
# FPR: 0.05714285714285714, TPR: 0.3939393939393939
# is_not_signal: (35, 2)
# is_signal: (66, 26)
# ===========================================================================
# is_signal : True, p_values[101]: 0.45863031511711716
# FPR: 0.05714285714285714, TPR: 0.3880597014925373
# is_not_signal: (35, 2)
# is_signal: (67, 26)
# ===========================================================================
# is_signal : True, p_values[102]: 0.058992666153357964
# FPR: 0.05714285714285714, TPR: 0.38235294117647056
# is_not_signal: (35, 2)
# is_signal: (68, 26)
# ===========================================================================
# is_signal : True, p_values[103]: 0.23434012371528934
# FPR: 0.05714285714285714, TPR: 0.37681159420289856
# is_not_signal: (35, 2)
# is_signal: (69, 26)
# ===========================================================================
# is_signal : True, p_values[104]: 0.4492106266812129
# FPR: 0.05714285714285714, TPR: 0.37142857142857144
# is_not_signal: (35, 2)
# is_signal: (70, 26)
# ===========================================================================
# is_signal : True, p_values[105]: 5.282643211756977e-10
# FPR: 0.05714285714285714, TPR: 0.38028169014084506
# is_not_signal: (35, 2)
# is_signal: (71, 27)
# ===========================================================================
# is_signal : True, p_values[106]: 0.2918901518464523
# FPR: 0.05714285714285714, TPR: 0.375
# is_not_signal: (35, 2)
# is_signal: (72, 27)
# ===========================================================================
# is_signal : True, p_values[107]: 0.1183048811619849
# FPR: 0.05714285714285714, TPR: 0.3698630136986301
# is_not_signal: (35, 2)
# is_signal: (73, 27)
# ===========================================================================
# is_signal : True, p_values[108]: 0.22235369531317328
# FPR: 0.05714285714285714, TPR: 0.36486486486486486
# is_not_signal: (35, 2)
# is_signal: (74, 27)
# ===========================================================================
# is_signal : True, p_values[109]: 0.006055974332172642
# FPR: 0.05714285714285714, TPR: 0.37333333333333335
# is_not_signal: (35, 2)
# is_signal: (75, 28)
# ===========================================================================
# is_signal : False, p_values[110]: 0.29470776253374864
# FPR: 0.05555555555555555, TPR: 0.37333333333333335
# is_not_signal: (36, 2)
# is_signal: (75, 28)
# ===========================================================================
# is_signal : True, p_values[111]: 0.10930742972478602
# FPR: 0.05555555555555555, TPR: 0.3684210526315789
# is_not_signal: (36, 2)
# is_signal: (76, 28)
# ===========================================================================
# is_signal : True, p_values[112]: 0.343323494500672
# FPR: 0.05555555555555555, TPR: 0.36363636363636365
# is_not_signal: (36, 2)
# is_signal: (77, 28)
# ===========================================================================
# is_signal : True, p_values[113]: 0.4088503418682714
# FPR: 0.05555555555555555, TPR: 0.358974358974359
# is_not_signal: (36, 2)
# is_signal: (78, 28)
# ===========================================================================
# is_signal : False, p_values[114]: 0.801046544849371
# FPR: 0.05405405405405406, TPR: 0.358974358974359
# is_not_signal: (37, 2)
# is_signal: (78, 28)
# ===========================================================================
# is_signal : False, p_values[115]: 0.7787977298377864
# FPR: 0.05263157894736842, TPR: 0.358974358974359
# is_not_signal: (38, 2)
# is_signal: (78, 28)
# ===========================================================================
# is_signal : True, p_values[116]: 0.298296482968587
# FPR: 0.05263157894736842, TPR: 0.35443037974683544
# is_not_signal: (38, 2)
# is_signal: (79, 28)
# ===========================================================================
# is_signal : True, p_values[117]: 0.43323814605314603
# FPR: 0.05263157894736842, TPR: 0.35
# is_not_signal: (38, 2)
# is_signal: (80, 28)
# ===========================================================================
# is_signal : True, p_values[118]: 0.02011771660847117
# FPR: 0.05263157894736842, TPR: 0.35802469135802467
# is_not_signal: (38, 2)
# is_signal: (81, 29)
# ===========================================================================
# is_signal : True, p_values[119]: 0.0073878051619375995
# FPR: 0.05263157894736842, TPR: 0.36585365853658536
# is_not_signal: (38, 2)
# is_signal: (82, 30)
# ===========================================================================
# is_signal : False, p_values[120]: 0.633754297936999
# FPR: 0.05128205128205128, TPR: 0.36585365853658536
# is_not_signal: (39, 2)
# is_signal: (82, 30)
# ===========================================================================
# is_signal : True, p_values[121]: 0.36452568240582356
# FPR: 0.05128205128205128, TPR: 0.3614457831325301
# is_not_signal: (39, 2)
# is_signal: (83, 30)
# ===========================================================================
# is_signal : True, p_values[122]: 0.4095352937378285
# FPR: 0.05128205128205128, TPR: 0.35714285714285715
# is_not_signal: (39, 2)
# is_signal: (84, 30)
# ===========================================================================
# is_signal : True, p_values[123]: 0.6031039121420256
# FPR: 0.05128205128205128, TPR: 0.35294117647058826
# is_not_signal: (39, 2)
# is_signal: (85, 30)
# ===========================================================================
# is_signal : True, p_values[124]: 0.8296550342072183
# FPR: 0.05128205128205128, TPR: 0.3488372093023256
# is_not_signal: (39, 2)
# is_signal: (86, 30)
# ===========================================================================
# is_signal : True, p_values[125]: 0.2509743326527818
# FPR: 0.05128205128205128, TPR: 0.3448275862068966
# is_not_signal: (39, 2)
# is_signal: (87, 30)
# ===========================================================================
# is_signal : False, p_values[126]: 0.703682836035477
# FPR: 0.05, TPR: 0.3448275862068966
# is_not_signal: (40, 2)
# is_signal: (87, 30)
# ===========================================================================
# is_signal : True, p_values[127]: 0.02922697520293349
# FPR: 0.05, TPR: 0.3522727272727273
# is_not_signal: (40, 2)
# is_signal: (88, 31)
# ===========================================================================
# is_signal : False, p_values[128]: 0.67800516347522
# FPR: 0.04878048780487805, TPR: 0.3522727272727273
# is_not_signal: (41, 2)
# is_signal: (88, 31)
# ===========================================================================
# is_signal : True, p_values[129]: 0.008019589638752933
# FPR: 0.04878048780487805, TPR: 0.3595505617977528
# is_not_signal: (41, 2)
# is_signal: (89, 32)
# ===========================================================================
# is_signal : False, p_values[130]: 0.8598028434181616
# FPR: 0.047619047619047616, TPR: 0.3595505617977528
# is_not_signal: (42, 2)
# is_signal: (89, 32)
# ===========================================================================
# is_signal : False, p_values[131]: 0.624636622103226
# FPR: 0.046511627906976744, TPR: 0.3595505617977528
# is_not_signal: (43, 2)
# is_signal: (89, 32)
# ===========================================================================
# is_signal : True, p_values[132]: 0.1751059495269609
# FPR: 0.046511627906976744, TPR: 0.35555555555555557
# is_not_signal: (43, 2)
# is_signal: (90, 32)
# ===========================================================================
# is_signal : True, p_values[133]: 0.06305541067271214
# FPR: 0.046511627906976744, TPR: 0.3516483516483517
# is_not_signal: (43, 2)
# is_signal: (91, 32)
# ===========================================================================
# is_signal : False, p_values[134]: 0.2522960835869297
# FPR: 0.045454545454545456, TPR: 0.3516483516483517
# is_not_signal: (44, 2)
# is_signal: (91, 32)
# ===========================================================================
# is_signal : False, p_values[135]: 0.7213657555179178
# FPR: 0.044444444444444446, TPR: 0.3516483516483517
# is_not_signal: (45, 2)
# is_signal: (91, 32)
# ===========================================================================
# is_signal : False, p_values[136]: 0.5683880765486071
# FPR: 0.043478260869565216, TPR: 0.3516483516483517
# is_not_signal: (46, 2)
# is_signal: (91, 32)
# ===========================================================================
# is_signal : True, p_values[137]: 0.9744792728371559
# FPR: 0.043478260869565216, TPR: 0.34782608695652173
# is_not_signal: (46, 2)
# is_signal: (92, 32)
# ===========================================================================
# is_signal : True, p_values[138]: 0.4210775805126994
# FPR: 0.043478260869565216, TPR: 0.34408602150537637
# is_not_signal: (46, 2)
# is_signal: (93, 32)
# ===========================================================================
# is_signal : True, p_values[139]: 0.6932098886900062
# FPR: 0.043478260869565216, TPR: 0.3404255319148936
# is_not_signal: (46, 2)
# is_signal: (94, 32)
# ===========================================================================
# is_signal : False, p_values[140]: 0.7990535092792117
# FPR: 0.0425531914893617, TPR: 0.3404255319148936
# is_not_signal: (47, 2)
# is_signal: (94, 32)
# ===========================================================================
# is_signal : False, p_values[141]: 0.4956915074998263
# FPR: 0.041666666666666664, TPR: 0.3404255319148936
# is_not_signal: (48, 2)
# is_signal: (94, 32)
# ===========================================================================
# is_signal : True, p_values[142]: 0.10082730594221911
# FPR: 0.041666666666666664, TPR: 0.3368421052631579
# is_not_signal: (48, 2)
# is_signal: (95, 32)
# ===========================================================================
# is_signal : True, p_values[143]: 0.49487561828259297
# FPR: 0.041666666666666664, TPR: 0.3333333333333333
# is_not_signal: (48, 2)
# is_signal: (96, 32)
# ===========================================================================
# is_signal : False, p_values[144]: 0.19568364655556025
# FPR: 0.04081632653061224, TPR: 0.3333333333333333
# is_not_signal: (49, 2)
# is_signal: (96, 32)
# ===========================================================================
# is_signal : True, p_values[145]: 0.1260096208810384
# FPR: 0.04081632653061224, TPR: 0.32989690721649484
# is_not_signal: (49, 2)
# is_signal: (97, 32)
# ===========================================================================
# is_signal : False, p_values[146]: 0.4970944064884815
# FPR: 0.04, TPR: 0.32989690721649484
# is_not_signal: (50, 2)
# is_signal: (97, 32)
# ===========================================================================
# is_signal : True, p_values[147]: 0.2797712451003757
# FPR: 0.04, TPR: 0.32653061224489793
# is_not_signal: (50, 2)
# is_signal: (98, 32)
# ===========================================================================
# is_signal : True, p_values[148]: 0.5863800836970752
# FPR: 0.04, TPR: 0.32323232323232326
# is_not_signal: (50, 2)
# is_signal: (99, 32)
# ===========================================================================
# is_signal : True, p_values[149]: 0.853483907981001
# FPR: 0.04, TPR: 0.32
# is_not_signal: (50, 2)
# is_signal: (100, 32)
# ===========================================================================
# is_signal : False, p_values[150]: 0.3560412568132758
# FPR: 0.0392156862745098, TPR: 0.32
# is_not_signal: (51, 2)
# is_signal: (100, 32)
# ===========================================================================
# is_signal : True, p_values[151]: 0.7497927143126246
# FPR: 0.0392156862745098, TPR: 0.31683168316831684
# is_not_signal: (51, 2)
# is_signal: (101, 32)
# ===========================================================================
# is_signal : True, p_values[152]: 0.07436009208665384
# FPR: 0.0392156862745098, TPR: 0.3137254901960784
# is_not_signal: (51, 2)
# is_signal: (102, 32)
# ===========================================================================
# is_signal : False, p_values[153]: 0.8987547332516389
# FPR: 0.038461538461538464, TPR: 0.3137254901960784
# is_not_signal: (52, 2)
# is_signal: (102, 32)
# ===========================================================================
# is_signal : True, p_values[154]: 0.8490215618332738
# FPR: 0.038461538461538464, TPR: 0.3106796116504854
# is_not_signal: (52, 2)
# is_signal: (103, 32)
# ===========================================================================

# %% [markdown]
# ## Testing True Positive Rate and False Positive Rate

# %%
is_signal_cases = [r for r in para_results_storage if r['is_signal']]
not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
print(f"len not_signal_cases : {len(not_signal_cases)}")
print(f"false_positives: {false_positives}")
fpr = false_positives / len(not_signal_cases)
print(f"FPR: {fpr:.4f} (Target: {alpha})")
print("\n")
true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha)
print(f"len not_signal_cases : {len(is_signal_cases)}")
print(f"true_positives: {true_positives}")
tpr = true_positives / len(is_signal_cases)
print(f"TPR: {tpr:.4f}")
# Out:
# len not_signal_cases : 343
# false_positives: 24
# FPR: 0.0700 (Target: 0.05)
#
#
# len not_signal_cases : 657
# true_positives: 239
# TPR: 0.3638
