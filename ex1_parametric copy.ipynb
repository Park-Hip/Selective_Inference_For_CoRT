# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import SI_CoRT
import CoRT_builder

import warnings
warnings.filterwarnings("ignore")

np.random.seed(42)  # For reproducibility

# %%
import os
os.environ["OMP_NUM_THREADS"] = "3"
os.environ["MKL_NUM_THREADS"] = "3"
os.environ["OPENBLAS_NUM_THREADS"] = "3"
os.environ["VECLIB_MAXIMUM_THREADS"] = "3"
os.environ["NUMEXPR_NUM_THREADS"] = "3"

# %% [markdown]
# ## Testing p_value

# %%
n_target = 40
n_source = 80
p = 200
K = 5
Ka = 3
h = 10
alpha = 0.05
T = 5
s_len = 10
s_vector = [0.0] * s_len

para_results_storage = []
CoRT_model = CoRT_builder.CoRT()
iteration = 1000

cnt1 = 0
cnt2 = 0
cnt3 = 0
cnt4 = 0

for i in range(iteration):
    print(i)
    target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
    result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, T, s_len)
    # print(f"P_value[{i}]: {result_dict['p_value']}")
    if result_dict != None:
        cnt1 += (result_dict['is_signal'] == True)
        cnt2 += (result_dict['is_signal'] == False)
        cnt3 += (result_dict['is_signal'] == True and result_dict['p_value'] <= alpha)
        cnt4 += (result_dict['is_signal'] == False and result_dict['p_value'] <= alpha)
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_values[{i}]: {result_dict['p_value']}")
            print(f"FPR: {cnt4 / cnt2}, TPR: {cnt3 / cnt1}")
            print(f"is_not_signal: {int(cnt2), int(cnt4)}")
            print(f"is_signal: {int(cnt1), int(cnt3)}")
            # print("\n")
            print("===========================================================================")
            
        para_results_storage.append(result_dict)
# Out:
# 0
# Lasso selected no features. Skipping.
# 1
# is_signal : False, p_values[1]: 0.21481765616440193
# FPR: 0.0, TPR: nan
# is_not_signal: (1, 0)
# is_signal: (0, 0)
# ===========================================================================
# 2
# Lasso selected no features. Skipping.
# 3
# is_signal : False, p_values[3]: 0.14179330816363073
# FPR: 0.0, TPR: nan
# is_not_signal: (2, 0)
# is_signal: (0, 0)
# ===========================================================================
# 4
# is_signal : False, p_values[4]: 0.320608622694486
# FPR: 0.0, TPR: nan
# is_not_signal: (3, 0)
# is_signal: (0, 0)
# ===========================================================================
# 5
# Lasso selected no features. Skipping.
# 6
# Lasso selected no features. Skipping.
# 7
# is_signal : False, p_values[7]: 0.6662630213901936
# FPR: 0.0, TPR: nan
# is_not_signal: (4, 0)
# is_signal: (0, 0)
# ===========================================================================
# 8
# Lasso selected no features. Skipping.
# 9
# Lasso selected no features. Skipping.
# 10
# is_signal : False, p_values[10]: 0.8700071472791291
# FPR: 0.0, TPR: nan
# is_not_signal: (5, 0)
# is_signal: (0, 0)
# ===========================================================================
# 11
# Lasso selected no features. Skipping.
# 12
# Lasso selected no features. Skipping.
# 13
# Lasso selected no features. Skipping.
# 14
# Lasso selected no features. Skipping.
# 15
# Lasso selected no features. Skipping.
# 16
# is_signal : False, p_values[16]: 0.2203315409533606
# FPR: 0.0, TPR: nan
# is_not_signal: (6, 0)
# is_signal: (0, 0)
# ===========================================================================
# 17
# is_signal : False, p_values[17]: 0.7431752603188053
# FPR: 0.0, TPR: nan
# is_not_signal: (7, 0)
# is_signal: (0, 0)
# ===========================================================================
# 18
# is_signal : False, p_values[18]: 0.28726997210552857
# FPR: 0.0, TPR: nan
# is_not_signal: (8, 0)
# is_signal: (0, 0)
# ===========================================================================
# 19
# is_signal : False, p_values[19]: 0.008668439541142242
# FPR: 0.1111111111111111, TPR: nan
# is_not_signal: (9, 1)
# is_signal: (0, 0)
# ===========================================================================
# 20
# is_signal : False, p_values[20]: 0.5212200862583083
# FPR: 0.1, TPR: nan
# is_not_signal: (10, 1)
# is_signal: (0, 0)
# ===========================================================================
# 21
# Lasso selected no features. Skipping.
# 22
# is_signal : True, p_values[22]: 0.20092423582418606
# FPR: 0.1, TPR: 0.0
# is_not_signal: (10, 1)
# is_signal: (1, 0)
# ===========================================================================
# 23
# is_signal : False, p_values[23]: 0.46463417485319
# FPR: 0.09090909090909091, TPR: 0.0
# is_not_signal: (11, 1)
# is_signal: (1, 0)
# ===========================================================================
# 24
# Lasso selected no features. Skipping.
# 25
# Lasso selected no features. Skipping.
# 26
# is_signal : False, p_values[26]: 0.722505174318064
# FPR: 0.08333333333333333, TPR: 0.0
# is_not_signal: (12, 1)
# is_signal: (1, 0)
# ===========================================================================
# 27
# is_signal : False, p_values[27]: 0.9181000572855799
# FPR: 0.07692307692307693, TPR: 0.0
# is_not_signal: (13, 1)
# is_signal: (1, 0)
# ===========================================================================
# 28
# is_signal : False, p_values[28]: 0.49512012682265805
# FPR: 0.07142857142857142, TPR: 0.0
# is_not_signal: (14, 1)
# is_signal: (1, 0)
# ===========================================================================
# 29
# is_signal : False, p_values[29]: 0.5327880256699193
# FPR: 0.06666666666666667, TPR: 0.0
# is_not_signal: (15, 1)
# is_signal: (1, 0)
# ===========================================================================
# 30
# is_signal : True, p_values[30]: 0.5896656273541935
# FPR: 0.06666666666666667, TPR: 0.0
# is_not_signal: (15, 1)
# is_signal: (2, 0)
# ===========================================================================
# 31
# is_signal : False, p_values[31]: 0.8652187213330815
# FPR: 0.0625, TPR: 0.0
# is_not_signal: (16, 1)
# is_signal: (2, 0)
# ===========================================================================
# 32
# is_signal : True, p_values[32]: 0.2994044932258341
# FPR: 0.0625, TPR: 0.0
# is_not_signal: (16, 1)
# is_signal: (3, 0)
# ===========================================================================
# 33
# is_signal : False, p_values[33]: 0.2900515947619392
# FPR: 0.058823529411764705, TPR: 0.0
# is_not_signal: (17, 1)
# is_signal: (3, 0)
# ===========================================================================
# 34
# is_signal : False, p_values[34]: 0.611153154827993
# FPR: 0.05555555555555555, TPR: 0.0
# is_not_signal: (18, 1)
# is_signal: (3, 0)
# ===========================================================================
# 35
# Lasso selected no features. Skipping.
# 36
# is_signal : False, p_values[36]: 0.10186933247262356
# FPR: 0.05263157894736842, TPR: 0.0
# is_not_signal: (19, 1)
# is_signal: (3, 0)
# ===========================================================================
# 37
# is_signal : False, p_values[37]: 0.8735097498368997
# FPR: 0.05, TPR: 0.0
# is_not_signal: (20, 1)
# is_signal: (3, 0)
# ===========================================================================
# 38
# Lasso selected no features. Skipping.
# 39
# is_signal : False, p_values[39]: 0.4971809430403652
# FPR: 0.047619047619047616, TPR: 0.0
# is_not_signal: (21, 1)
# is_signal: (3, 0)
# ===========================================================================
# 40
# is_signal : False, p_values[40]: 0.5694348292631739
# FPR: 0.045454545454545456, TPR: 0.0
# is_not_signal: (22, 1)
# is_signal: (3, 0)
# ===========================================================================
# 41
# is_signal : False, p_values[41]: 0.20482798184507858
# FPR: 0.043478260869565216, TPR: 0.0
# is_not_signal: (23, 1)
# is_signal: (3, 0)
# ===========================================================================
# 42
# Lasso selected no features. Skipping.
# 43
# is_signal : False, p_values[43]: 0.6143476950643433
# FPR: 0.041666666666666664, TPR: 0.0
# is_not_signal: (24, 1)
# is_signal: (3, 0)
# ===========================================================================
# 44
# is_signal : True, p_values[44]: 0.8232093915553468
# FPR: 0.041666666666666664, TPR: 0.0
# is_not_signal: (24, 1)
# is_signal: (4, 0)
# ===========================================================================
# 45
# is_signal : False, p_values[45]: 0.11033511705079506
# FPR: 0.04, TPR: 0.0
# is_not_signal: (25, 1)
# is_signal: (4, 0)
# ===========================================================================
# 46
# is_signal : False, p_values[46]: 0.7926460066243768
# FPR: 0.038461538461538464, TPR: 0.0
# is_not_signal: (26, 1)
# is_signal: (4, 0)
# ===========================================================================
# 47
# is_signal : False, p_values[47]: 0.5569730570100647
# FPR: 0.037037037037037035, TPR: 0.0
# is_not_signal: (27, 1)
# is_signal: (4, 0)
# ===========================================================================
# 48
# Lasso selected no features. Skipping.
# 49
# Lasso selected no features. Skipping.
# 50
# is_signal : False, p_values[50]: 0.031781290543924895
# FPR: 0.07142857142857142, TPR: 0.0
# is_not_signal: (28, 2)
# is_signal: (4, 0)
# ===========================================================================
# 51
# Lasso selected no features. Skipping.
# 52
# is_signal : False, p_values[52]: 0.42794257510230876
# FPR: 0.06896551724137931, TPR: 0.0
# is_not_signal: (29, 2)
# is_signal: (4, 0)
# ===========================================================================
# 53
# Lasso selected no features. Skipping.
# 54
# is_signal : False, p_values[54]: 0.6388210397881701
# FPR: 0.06666666666666667, TPR: 0.0
# is_not_signal: (30, 2)
# is_signal: (4, 0)
# ===========================================================================
# 55
# Lasso selected no features. Skipping.
# 56
# is_signal : False, p_values[56]: 0.912734817157547
# FPR: 0.06451612903225806, TPR: 0.0
# is_not_signal: (31, 2)
# is_signal: (4, 0)
# ===========================================================================
# 57
# is_signal : False, p_values[57]: 0.986198416422789
# FPR: 0.0625, TPR: 0.0
# is_not_signal: (32, 2)
# is_signal: (4, 0)
# ===========================================================================
# 58
# is_signal : False, p_values[58]: 0.8458618636968992
# FPR: 0.06060606060606061, TPR: 0.0
# is_not_signal: (33, 2)
# is_signal: (4, 0)
# ===========================================================================
# 59
# Lasso selected no features. Skipping.
# 60
# Lasso selected no features. Skipping.
# 61
# is_signal : False, p_values[61]: 0.3467128084148651
# FPR: 0.058823529411764705, TPR: 0.0
# is_not_signal: (34, 2)
# is_signal: (4, 0)
# ===========================================================================
# 62
# is_signal : False, p_values[62]: 0.29470735443882606
# FPR: 0.05714285714285714, TPR: 0.0
# is_not_signal: (35, 2)
# is_signal: (4, 0)
# ===========================================================================
# 63
# Lasso selected no features. Skipping.
# 64
# is_signal : False, p_values[64]: 0.08747446869842147
# FPR: 0.05555555555555555, TPR: 0.0
# is_not_signal: (36, 2)
# is_signal: (4, 0)
# ===========================================================================
# 65
# Lasso selected no features. Skipping.
# 66
# is_signal : False, p_values[66]: 0.7148931377738055
# FPR: 0.05405405405405406, TPR: 0.0
# is_not_signal: (37, 2)
# is_signal: (4, 0)
# ===========================================================================
# 67
# Lasso selected no features. Skipping.
# 68
# is_signal : False, p_values[68]: 0.06869104620423397
# FPR: 0.05263157894736842, TPR: 0.0
# is_not_signal: (38, 2)
# is_signal: (4, 0)
# ===========================================================================
# 69
# is_signal : False, p_values[69]: 0.9608988839534038
# FPR: 0.05128205128205128, TPR: 0.0
# is_not_signal: (39, 2)
# is_signal: (4, 0)
# ===========================================================================
# 70
# is_signal : False, p_values[70]: 0.17706531009036441
# FPR: 0.05, TPR: 0.0
# is_not_signal: (40, 2)
# is_signal: (4, 0)
# ===========================================================================
# 71
# is_signal : False, p_values[71]: 0.6764233256660491
# FPR: 0.04878048780487805, TPR: 0.0
# is_not_signal: (41, 2)
# is_signal: (4, 0)
# ===========================================================================
# 72
# Lasso selected no features. Skipping.
# 73
# Lasso selected no features. Skipping.
# 74
# Lasso selected no features. Skipping.
# 75
# is_signal : False, p_values[75]: 0.49964555353340234
# FPR: 0.047619047619047616, TPR: 0.0
# is_not_signal: (42, 2)
# is_signal: (4, 0)
# ===========================================================================
# 76
# is_signal : False, p_values[76]: 0.8906820941533173
# FPR: 0.046511627906976744, TPR: 0.0
# is_not_signal: (43, 2)
# is_signal: (4, 0)
# ===========================================================================
# 77
# is_signal : False, p_values[77]: 0.335940209192862
# FPR: 0.045454545454545456, TPR: 0.0
# is_not_signal: (44, 2)
# is_signal: (4, 0)
# ===========================================================================
# 78
# is_signal : False, p_values[78]: 0.5229097592071592
# FPR: 0.044444444444444446, TPR: 0.0
# is_not_signal: (45, 2)
# is_signal: (4, 0)
# ===========================================================================
# 79
# is_signal : False, p_values[79]: 0.7045098019277334
# FPR: 0.043478260869565216, TPR: 0.0
# is_not_signal: (46, 2)
# is_signal: (4, 0)
# ===========================================================================
# 80
# is_signal : False, p_values[80]: 0.5372621763756641
# FPR: 0.0425531914893617, TPR: 0.0
# is_not_signal: (47, 2)
# is_signal: (4, 0)
# ===========================================================================
# 81
# Lasso selected no features. Skipping.
# 82
# is_signal : False, p_values[82]: 0.6985521241882175
# FPR: 0.041666666666666664, TPR: 0.0
# is_not_signal: (48, 2)
# is_signal: (4, 0)
# ===========================================================================
# 83
# Lasso selected no features. Skipping.
# 84
# is_signal : False, p_values[84]: 0.5870775023954474
# FPR: 0.04081632653061224, TPR: 0.0
# is_not_signal: (49, 2)
# is_signal: (4, 0)
# ===========================================================================
# 85
# Lasso selected no features. Skipping.
# 86
# Lasso selected no features. Skipping.
# 87
# Lasso selected no features. Skipping.
# 88
# Lasso selected no features. Skipping.
# 89
# Lasso selected no features. Skipping.
# 90
# Lasso selected no features. Skipping.
# 91
# is_signal : False, p_values[91]: 0.5026298848626175
# FPR: 0.04, TPR: 0.0
# is_not_signal: (50, 2)
# is_signal: (4, 0)
# ===========================================================================
# 92
# Lasso selected no features. Skipping.
# 93
# is_signal : False, p_values[93]: 0.605576052939706
# FPR: 0.0392156862745098, TPR: 0.0
# is_not_signal: (51, 2)
# is_signal: (4, 0)
# ===========================================================================
# 94
# is_signal : False, p_values[94]: 0.18036815672351872
# FPR: 0.038461538461538464, TPR: 0.0
# is_not_signal: (52, 2)
# is_signal: (4, 0)
# ===========================================================================
# 95
# Lasso selected no features. Skipping.
# 96
# is_signal : False, p_values[96]: 0.7736040541225219
# FPR: 0.03773584905660377, TPR: 0.0
# is_not_signal: (53, 2)
# is_signal: (4, 0)
# ===========================================================================
# 97
# Lasso selected no features. Skipping.
# 98
# is_signal : False, p_values[98]: 0.6687979014188787
# FPR: 0.037037037037037035, TPR: 0.0
# is_not_signal: (54, 2)
# is_signal: (4, 0)
# ===========================================================================
# 99
# Lasso selected no features. Skipping.
# 100
# Lasso selected no features. Skipping.
# 101
# is_signal : False, p_values[101]: 0.8703507350352736
# FPR: 0.03636363636363636, TPR: 0.0
# is_not_signal: (55, 2)
# is_signal: (4, 0)
# ===========================================================================
# 102
# is_signal : True, p_values[102]: 0.4851160468844918
# FPR: 0.03636363636363636, TPR: 0.0
# is_not_signal: (55, 2)
# is_signal: (5, 0)
# ===========================================================================
# 103
# is_signal : False, p_values[103]: 0.4321110724053735
# FPR: 0.03571428571428571, TPR: 0.0
# is_not_signal: (56, 2)
# is_signal: (5, 0)
# ===========================================================================
# 104
# is_signal : False, p_values[104]: 0.8010946974976706
# FPR: 0.03508771929824561, TPR: 0.0
# is_not_signal: (57, 2)
# is_signal: (5, 0)
# ===========================================================================
# 105
# Lasso selected no features. Skipping.
# 106
# Lasso selected no features. Skipping.
# 107
# is_signal : False, p_values[107]: 0.7544906664002226
# FPR: 0.034482758620689655, TPR: 0.0
# is_not_signal: (58, 2)
# is_signal: (5, 0)
# ===========================================================================
# 108
# Lasso selected no features. Skipping.
# 109
# is_signal : False, p_values[109]: 0.9427492024779918
# FPR: 0.03389830508474576, TPR: 0.0
# is_not_signal: (59, 2)
# is_signal: (5, 0)
# ===========================================================================
# 110
# is_signal : False, p_values[110]: 0.3394577752907834
# FPR: 0.03333333333333333, TPR: 0.0
# is_not_signal: (60, 2)
# is_signal: (5, 0)
# ===========================================================================
# 111
# Lasso selected no features. Skipping.
# 112
# is_signal : False, p_values[112]: 0.7472805917589407
# FPR: 0.03278688524590164, TPR: 0.0
# is_not_signal: (61, 2)
# is_signal: (5, 0)
# ===========================================================================
# 113
# is_signal : False, p_values[113]: 0.5060031392045934
# FPR: 0.03225806451612903, TPR: 0.0
# is_not_signal: (62, 2)
# is_signal: (5, 0)
# ===========================================================================
# 114
# is_signal : False, p_values[114]: 0.27741497972100154
# FPR: 0.031746031746031744, TPR: 0.0
# is_not_signal: (63, 2)
# is_signal: (5, 0)
# ===========================================================================
# 115
# is_signal : False, p_values[115]: 0.8239605387962814
# FPR: 0.03125, TPR: 0.0
# is_not_signal: (64, 2)
# is_signal: (5, 0)
# ===========================================================================
# 116
# Lasso selected no features. Skipping.
# 117
# is_signal : False, p_values[117]: 0.9500710571933542
# FPR: 0.03076923076923077, TPR: 0.0
# is_not_signal: (65, 2)
# is_signal: (5, 0)
# ===========================================================================
# 118
# Lasso selected no features. Skipping.
# 119
# is_signal : False, p_values[119]: 0.6880221908873967
# FPR: 0.030303030303030304, TPR: 0.0
# is_not_signal: (66, 2)
# is_signal: (5, 0)
# ===========================================================================
# 120
# is_signal : True, p_values[120]: 0.5187195753552666
# FPR: 0.030303030303030304, TPR: 0.0
# is_not_signal: (66, 2)
# is_signal: (6, 0)
# ===========================================================================
# 121
# is_signal : False, p_values[121]: 0.2593713992947735
# FPR: 0.029850746268656716, TPR: 0.0
# is_not_signal: (67, 2)
# is_signal: (6, 0)
# ===========================================================================
# 122
# is_signal : False, p_values[122]: 0.2548276654494347
# FPR: 0.029411764705882353, TPR: 0.0
# is_not_signal: (68, 2)
# is_signal: (6, 0)
# ===========================================================================
# 123
# is_signal : False, p_values[123]: 0.7807917590290187
# FPR: 0.028985507246376812, TPR: 0.0
# is_not_signal: (69, 2)
# is_signal: (6, 0)
# ===========================================================================
# 124
# Lasso selected no features. Skipping.
# 125
# Lasso selected no features. Skipping.
# 126
# is_signal : False, p_values[126]: 0.4524706117564753
# FPR: 0.02857142857142857, TPR: 0.0
# is_not_signal: (70, 2)
# is_signal: (6, 0)
# ===========================================================================
# 127
# is_signal : False, p_values[127]: 0.7178291395326064
# FPR: 0.028169014084507043, TPR: 0.0
# is_not_signal: (71, 2)
# is_signal: (6, 0)
# ===========================================================================
# 128
# is_signal : False, p_values[128]: 0.6907151032288119
# FPR: 0.027777777777777776, TPR: 0.0
# is_not_signal: (72, 2)
# is_signal: (6, 0)
# ===========================================================================
# 129
# is_signal : False, p_values[129]: 0.6352594032240871
# FPR: 0.0273972602739726, TPR: 0.0
# is_not_signal: (73, 2)
# is_signal: (6, 0)
# ===========================================================================
# 130
# Lasso selected no features. Skipping.
# 131
# Lasso selected no features. Skipping.
# 132
# is_signal : False, p_values[132]: 0.7873919894656743
# FPR: 0.02702702702702703, TPR: 0.0
# is_not_signal: (74, 2)
# is_signal: (6, 0)
# ===========================================================================
# 133
# is_signal : False, p_values[133]: 0.10658237625330992
# FPR: 0.02666666666666667, TPR: 0.0
# is_not_signal: (75, 2)
# is_signal: (6, 0)
# ===========================================================================
# 134
# Lasso selected no features. Skipping.
# 135
# is_signal : True, p_values[135]: 0.6346895165681649
# FPR: 0.02666666666666667, TPR: 0.0
# is_not_signal: (75, 2)
# is_signal: (7, 0)
# ===========================================================================
# 136
# Lasso selected no features. Skipping.
# 137
# is_signal : False, p_values[137]: 0.20883273211150868
# FPR: 0.02631578947368421, TPR: 0.0
# is_not_signal: (76, 2)
# is_signal: (7, 0)
# ===========================================================================
# 138
# Lasso selected no features. Skipping.
# 139
# Lasso selected no features. Skipping.
# 140
# Lasso selected no features. Skipping.
# 141
# Lasso selected no features. Skipping.
# 142
# is_signal : False, p_values[142]: 0.7591426705045555
# FPR: 0.025974025974025976, TPR: 0.0
# is_not_signal: (77, 2)
# is_signal: (7, 0)
# ===========================================================================
# 143
# is_signal : False, p_values[143]: 0.45422526472838404
# FPR: 0.02564102564102564, TPR: 0.0
# is_not_signal: (78, 2)
# is_signal: (7, 0)
# ===========================================================================
# 144
# Lasso selected no features. Skipping.
# 145
# is_signal : False, p_values[145]: 0.4706881823647686
# FPR: 0.02531645569620253, TPR: 0.0
# is_not_signal: (79, 2)
# is_signal: (7, 0)
# ===========================================================================
# 146
# Lasso selected no features. Skipping.
# 147
# Lasso selected no features. Skipping.
# 148
# Lasso selected no features. Skipping.
# 149
# is_signal : True, p_values[149]: 0.6522636646439584
# FPR: 0.02531645569620253, TPR: 0.0
# is_not_signal: (79, 2)
# is_signal: (8, 0)
# ===========================================================================
# 150
# is_signal : False, p_values[150]: 0.5831896151890325
# FPR: 0.025, TPR: 0.0
# is_not_signal: (80, 2)
# is_signal: (8, 0)
# ===========================================================================
# 151
# is_signal : True, p_values[151]: 0.45459578928241856
# FPR: 0.025, TPR: 0.0
# is_not_signal: (80, 2)
# is_signal: (9, 0)
# ===========================================================================
# 152
# Lasso selected no features. Skipping.
# 153
# is_signal : False, p_values[153]: 0.24063191928566222
# FPR: 0.024691358024691357, TPR: 0.0
# is_not_signal: (81, 2)
# is_signal: (9, 0)
# ===========================================================================
# 154
# is_signal : False, p_values[154]: 0.4264719091150209
# FPR: 0.024390243902439025, TPR: 0.0
# is_not_signal: (82, 2)
# is_signal: (9, 0)
# ===========================================================================
# 155
# is_signal : False, p_values[155]: 0.11614205143661717
# FPR: 0.024096385542168676, TPR: 0.0
# is_not_signal: (83, 2)
# is_signal: (9, 0)
# ===========================================================================
# 156
# is_signal : False, p_values[156]: 0.41838440314237485
# FPR: 0.023809523809523808, TPR: 0.0
# is_not_signal: (84, 2)
# is_signal: (9, 0)
# ===========================================================================
# 157
# is_signal : False, p_values[157]: 0.8209013521349922
# FPR: 0.023529411764705882, TPR: 0.0
# is_not_signal: (85, 2)
# is_signal: (9, 0)
# ===========================================================================
# 158
# Lasso selected no features. Skipping.
# 159
# is_signal : False, p_values[159]: 0.9960577619684938
# FPR: 0.023255813953488372, TPR: 0.0
# is_not_signal: (86, 2)
# is_signal: (9, 0)
# ===========================================================================
# 160
# is_signal : False, p_values[160]: 0.3932547168544798
# FPR: 0.022988505747126436, TPR: 0.0
# is_not_signal: (87, 2)
# is_signal: (9, 0)
# ===========================================================================
# 161
# is_signal : False, p_values[161]: 0.6203683867455939
# FPR: 0.022727272727272728, TPR: 0.0
# is_not_signal: (88, 2)
# is_signal: (9, 0)
# ===========================================================================
# 162
# is_signal : False, p_values[162]: 0.39174856163448957
# FPR: 0.02247191011235955, TPR: 0.0
# is_not_signal: (89, 2)
# is_signal: (9, 0)
# ===========================================================================
# 163
# is_signal : False, p_values[163]: 0.043902283521623967
# FPR: 0.03333333333333333, TPR: 0.0
# is_not_signal: (90, 3)
# is_signal: (9, 0)
# ===========================================================================
# 164
# is_signal : False, p_values[164]: 0.7362427240725905
# FPR: 0.03296703296703297, TPR: 0.0
# is_not_signal: (91, 3)
# is_signal: (9, 0)
# ===========================================================================
# 165
# is_signal : False, p_values[165]: 0.672865592824147
# FPR: 0.03260869565217391, TPR: 0.0
# is_not_signal: (92, 3)
# is_signal: (9, 0)
# ===========================================================================
# 166
# Lasso selected no features. Skipping.
# 167
# Lasso selected no features. Skipping.
# 168
# is_signal : False, p_values[168]: 0.012145053663815419
# FPR: 0.043010752688172046, TPR: 0.0
# is_not_signal: (93, 4)
# is_signal: (9, 0)
# ===========================================================================
# 169
# Lasso selected no features. Skipping.
# 170
# Lasso selected no features. Skipping.
# 171
# is_signal : False, p_values[171]: 0.6975280117426558
# FPR: 0.0425531914893617, TPR: 0.0
# is_not_signal: (94, 4)
# is_signal: (9, 0)
# ===========================================================================
# 172
# is_signal : False, p_values[172]: 0.02626759132921343
# FPR: 0.05263157894736842, TPR: 0.0
# is_not_signal: (95, 5)
# is_signal: (9, 0)
# ===========================================================================
# 173
# Lasso selected no features. Skipping.
# 174
# is_signal : False, p_values[174]: 0.28025591962287827
# FPR: 0.052083333333333336, TPR: 0.0
# is_not_signal: (96, 5)
# is_signal: (9, 0)
# ===========================================================================
# 175
# is_signal : False, p_values[175]: 0.09383401855859458
# FPR: 0.05154639175257732, TPR: 0.0
# is_not_signal: (97, 5)
# is_signal: (9, 0)
# ===========================================================================
# 176
# Lasso selected no features. Skipping.
# 177
# Lasso selected no features. Skipping.
# 178
# is_signal : True, p_values[178]: 0.19820351825340352
# FPR: 0.05154639175257732, TPR: 0.0
# is_not_signal: (97, 5)
# is_signal: (10, 0)
# ===========================================================================
# 179
# Lasso selected no features. Skipping.
# 180
# is_signal : False, p_values[180]: 0.7561867232753954
# FPR: 0.05102040816326531, TPR: 0.0
# is_not_signal: (98, 5)
# is_signal: (10, 0)
# ===========================================================================
# 181
# is_signal : False, p_values[181]: 0.22249189161900998
# FPR: 0.050505050505050504, TPR: 0.0
# is_not_signal: (99, 5)
# is_signal: (10, 0)
# ===========================================================================
# 182
# is_signal : False, p_values[182]: 0.6605489035690258
# FPR: 0.05, TPR: 0.0
# is_not_signal: (100, 5)
# is_signal: (10, 0)
# ===========================================================================
# 183
# Lasso selected no features. Skipping.
# 184
# is_signal : False, p_values[184]: 0.9277640562240493
# FPR: 0.04950495049504951, TPR: 0.0
# is_not_signal: (101, 5)
# is_signal: (10, 0)
# ===========================================================================
# 185
# Lasso selected no features. Skipping.
# 186
# is_signal : False, p_values[186]: 0.1685729721826706
# FPR: 0.049019607843137254, TPR: 0.0
# is_not_signal: (102, 5)
# is_signal: (10, 0)
# ===========================================================================
# 187
# is_signal : False, p_values[187]: 0.049347583770341236
# FPR: 0.05825242718446602, TPR: 0.0
# is_not_signal: (103, 6)
# is_signal: (10, 0)
# ===========================================================================
# 188
# is_signal : True, p_values[188]: 0.04495010007592006
# FPR: 0.05825242718446602, TPR: 0.09090909090909091
# is_not_signal: (103, 6)
# is_signal: (11, 1)
# ===========================================================================
# 189
# Lasso selected no features. Skipping.
# 190
# is_signal : False, p_values[190]: 0.10755574125147353
# FPR: 0.057692307692307696, TPR: 0.09090909090909091
# is_not_signal: (104, 6)
# is_signal: (11, 1)
# ===========================================================================
# 191
# is_signal : False, p_values[191]: 0.5732612851836905
# FPR: 0.05714285714285714, TPR: 0.09090909090909091
# is_not_signal: (105, 6)
# is_signal: (11, 1)
# ===========================================================================
# 192
# is_signal : False, p_values[192]: 0.7483796601423408
# FPR: 0.05660377358490566, TPR: 0.09090909090909091
# is_not_signal: (106, 6)
# is_signal: (11, 1)
# ===========================================================================
# 193
# is_signal : False, p_values[193]: 0.4518083925287256
# FPR: 0.056074766355140186, TPR: 0.09090909090909091
# is_not_signal: (107, 6)
# is_signal: (11, 1)
# ===========================================================================
# 194
# is_signal : True, p_values[194]: 0.8048139446135965
# FPR: 0.056074766355140186, TPR: 0.08333333333333333
# is_not_signal: (107, 6)
# is_signal: (12, 1)
# ===========================================================================
# 195
# is_signal : False, p_values[195]: 0.972505896986803
# FPR: 0.05555555555555555, TPR: 0.08333333333333333
# is_not_signal: (108, 6)
# is_signal: (12, 1)
# ===========================================================================
# 196
# Lasso selected no features. Skipping.
# 197
# is_signal : False, p_values[197]: 0.8168165966656267
# FPR: 0.05504587155963303, TPR: 0.08333333333333333
# is_not_signal: (109, 6)
# is_signal: (12, 1)
# ===========================================================================
# 198
# is_signal : False, p_values[198]: 0.9165829230934472
# FPR: 0.05454545454545454, TPR: 0.08333333333333333
# is_not_signal: (110, 6)
# is_signal: (12, 1)
# ===========================================================================
# 199
# is_signal : False, p_values[199]: 0.2992070755638416
# FPR: 0.05405405405405406, TPR: 0.08333333333333333
# is_not_signal: (111, 6)
# is_signal: (12, 1)
# ===========================================================================
# 200
# is_signal : False, p_values[200]: 0.3334435625990602
# FPR: 0.05357142857142857, TPR: 0.08333333333333333
# is_not_signal: (112, 6)
# is_signal: (12, 1)
# ===========================================================================
# 201
# is_signal : False, p_values[201]: 0.9782282473630579
# FPR: 0.05309734513274336, TPR: 0.08333333333333333
# is_not_signal: (113, 6)
# is_signal: (12, 1)
# ===========================================================================
# 202
# Lasso selected no features. Skipping.
# 203
# Lasso selected no features. Skipping.
# 204
# is_signal : False, p_values[204]: 0.16571480205932312
# FPR: 0.05263157894736842, TPR: 0.08333333333333333
# is_not_signal: (114, 6)
# is_signal: (12, 1)
# ===========================================================================
# 205
# is_signal : False, p_values[205]: 0.1607953008372054
# FPR: 0.05217391304347826, TPR: 0.08333333333333333
# is_not_signal: (115, 6)
# is_signal: (12, 1)
# ===========================================================================
# 206
# Lasso selected no features. Skipping.
# 207
# Lasso selected no features. Skipping.
# 208
# is_signal : False, p_values[208]: 0.4876506569039265
# FPR: 0.05172413793103448, TPR: 0.08333333333333333
# is_not_signal: (116, 6)
# is_signal: (12, 1)
# ===========================================================================
# 209
# Lasso selected no features. Skipping.
# 210
# is_signal : False, p_values[210]: 0.20872624723713615
# FPR: 0.05128205128205128, TPR: 0.08333333333333333
# is_not_signal: (117, 6)
# is_signal: (12, 1)
# ===========================================================================
# 211
# is_signal : False, p_values[211]: 0.2559078940820283
# FPR: 0.05084745762711865, TPR: 0.08333333333333333
# is_not_signal: (118, 6)
# is_signal: (12, 1)
# ===========================================================================
# 212
# Lasso selected no features. Skipping.
# 213
# Lasso selected no features. Skipping.
# 214
# is_signal : False, p_values[214]: 0.2507890004011939
# FPR: 0.05042016806722689, TPR: 0.08333333333333333
# is_not_signal: (119, 6)
# is_signal: (12, 1)
# ===========================================================================
# 215
# is_signal : False, p_values[215]: 0.4991925920460172
# FPR: 0.05, TPR: 0.08333333333333333
# is_not_signal: (120, 6)
# is_signal: (12, 1)
# ===========================================================================
# 216
# is_signal : False, p_values[216]: 0.19027609528432363
# FPR: 0.049586776859504134, TPR: 0.08333333333333333
# is_not_signal: (121, 6)
# is_signal: (12, 1)
# ===========================================================================
# 217
# is_signal : False, p_values[217]: 0.14298000490790236
# FPR: 0.04918032786885246, TPR: 0.08333333333333333
# is_not_signal: (122, 6)
# is_signal: (12, 1)
# ===========================================================================
# 218
# Lasso selected no features. Skipping.
# 219
# is_signal : False, p_values[219]: 0.2598061702214423
# FPR: 0.04878048780487805, TPR: 0.08333333333333333
# is_not_signal: (123, 6)
# is_signal: (12, 1)
# ===========================================================================
# 220
# is_signal : False, p_values[220]: 0.8894441288489573
# FPR: 0.04838709677419355, TPR: 0.08333333333333333
# is_not_signal: (124, 6)
# is_signal: (12, 1)
# ===========================================================================
# 221
# Lasso selected no features. Skipping.
# 222
# Lasso selected no features. Skipping.
# 223
# is_signal : False, p_values[223]: 0.7833620533930941
# FPR: 0.048, TPR: 0.08333333333333333
# is_not_signal: (125, 6)
# is_signal: (12, 1)
# ===========================================================================
# 224
# is_signal : False, p_values[224]: 0.27548885173804977
# FPR: 0.047619047619047616, TPR: 0.08333333333333333
# is_not_signal: (126, 6)
# is_signal: (12, 1)
# ===========================================================================
# 225
# Lasso selected no features. Skipping.
# 226
# is_signal : False, p_values[226]: 0.6055674963953815
# FPR: 0.047244094488188976, TPR: 0.08333333333333333
# is_not_signal: (127, 6)
# is_signal: (12, 1)
# ===========================================================================
# 227
# is_signal : False, p_values[227]: 0.030378648222407042
# FPR: 0.0546875, TPR: 0.08333333333333333
# is_not_signal: (128, 7)
# is_signal: (12, 1)
# ===========================================================================
# 228
# is_signal : False, p_values[228]: 0.8027288216413605
# FPR: 0.05426356589147287, TPR: 0.08333333333333333
# is_not_signal: (129, 7)
# is_signal: (12, 1)
# ===========================================================================
# 229
# is_signal : True, p_values[229]: 0.7957584720084696
# FPR: 0.05426356589147287, TPR: 0.07692307692307693
# is_not_signal: (129, 7)
# is_signal: (13, 1)
# ===========================================================================
# 230
# Lasso selected no features. Skipping.
# 231
# is_signal : False, p_values[231]: 0.9698608686907668
# FPR: 0.05384615384615385, TPR: 0.07692307692307693
# is_not_signal: (130, 7)
# is_signal: (13, 1)
# ===========================================================================
# 232
# Lasso selected no features. Skipping.
# 233
# is_signal : False, p_values[233]: 0.441905989362326
# FPR: 0.05343511450381679, TPR: 0.07692307692307693
# is_not_signal: (131, 7)
# is_signal: (13, 1)
# ===========================================================================
# 234
# is_signal : False, p_values[234]: 0.8386239982569886
# FPR: 0.05303030303030303, TPR: 0.07692307692307693
# is_not_signal: (132, 7)
# is_signal: (13, 1)
# ===========================================================================
# 235
# is_signal : False, p_values[235]: 0.5598852939719148
# FPR: 0.05263157894736842, TPR: 0.07692307692307693
# is_not_signal: (133, 7)
# is_signal: (13, 1)
# ===========================================================================
# 236
# Lasso selected no features. Skipping.
# 237
# Lasso selected no features. Skipping.
# 238
# is_signal : True, p_values[238]: 0.12620675488664257
# FPR: 0.05263157894736842, TPR: 0.07142857142857142
# is_not_signal: (133, 7)
# is_signal: (14, 1)
# ===========================================================================
# 239
# Lasso selected no features. Skipping.
# 240
# is_signal : False, p_values[240]: 0.5721302020614089
# FPR: 0.05223880597014925, TPR: 0.07142857142857142
# is_not_signal: (134, 7)
# is_signal: (14, 1)
# ===========================================================================
# 241
# is_signal : False, p_values[241]: 0.07063252520713112
# FPR: 0.05185185185185185, TPR: 0.07142857142857142
# is_not_signal: (135, 7)
# is_signal: (14, 1)
# ===========================================================================
# 242
# Lasso selected no features. Skipping.
# 243
# Lasso selected no features. Skipping.
# 244
# Lasso selected no features. Skipping.
# 245
# Lasso selected no features. Skipping.
# 246
# is_signal : False, p_values[246]: 0.19931309486429005
# FPR: 0.051470588235294115, TPR: 0.07142857142857142
# is_not_signal: (136, 7)
# is_signal: (14, 1)
# ===========================================================================
# 247
# is_signal : False, p_values[247]: 0.8230620932702571
# FPR: 0.051094890510948905, TPR: 0.07142857142857142
# is_not_signal: (137, 7)
# is_signal: (14, 1)
# ===========================================================================
# 248
# is_signal : False, p_values[248]: 0.9596216171618247
# FPR: 0.050724637681159424, TPR: 0.07142857142857142
# is_not_signal: (138, 7)
# is_signal: (14, 1)
# ===========================================================================
# 249
# Lasso selected no features. Skipping.
# 250
# Lasso selected no features. Skipping.
# 251
# is_signal : False, p_values[251]: 0.06164648971389693
# FPR: 0.050359712230215826, TPR: 0.07142857142857142
# is_not_signal: (139, 7)
# is_signal: (14, 1)
# ===========================================================================
# 252
# is_signal : False, p_values[252]: 0.19946734483638504
# FPR: 0.05, TPR: 0.07142857142857142
# is_not_signal: (140, 7)
# is_signal: (14, 1)
# ===========================================================================
# 253
# is_signal : False, p_values[253]: 0.5820790006588781
# FPR: 0.04964539007092199, TPR: 0.07142857142857142
# is_not_signal: (141, 7)
# is_signal: (14, 1)
# ===========================================================================
# 254
# Lasso selected no features. Skipping.
# 255
# is_signal : True, p_values[255]: 0.001809602599942746
# FPR: 0.04964539007092199, TPR: 0.13333333333333333
# is_not_signal: (141, 7)
# is_signal: (15, 2)
# ===========================================================================
# 256
# Lasso selected no features. Skipping.
# 257
# is_signal : True, p_values[257]: 0.002597863022561421
# FPR: 0.04964539007092199, TPR: 0.1875
# is_not_signal: (141, 7)
# is_signal: (16, 3)
# ===========================================================================
# 258
# is_signal : False, p_values[258]: 0.8876280795909998
# FPR: 0.04929577464788732, TPR: 0.1875
# is_not_signal: (142, 7)
# is_signal: (16, 3)
# ===========================================================================
# 259
# Lasso selected no features. Skipping.
# 260
# Lasso selected no features. Skipping.
# 261
# is_signal : False, p_values[261]: 0.8705873543473329
# FPR: 0.04895104895104895, TPR: 0.1875
# is_not_signal: (143, 7)
# is_signal: (16, 3)
# ===========================================================================
# 262
# Lasso selected no features. Skipping.
# 263
# is_signal : False, p_values[263]: 0.8405747996264479
# FPR: 0.04861111111111111, TPR: 0.1875
# is_not_signal: (144, 7)
# is_signal: (16, 3)
# ===========================================================================
# 264
# Lasso selected no features. Skipping.
# 265
# is_signal : False, p_values[265]: 0.01079862938065889
# FPR: 0.05517241379310345, TPR: 0.1875
# is_not_signal: (145, 8)
# is_signal: (16, 3)
# ===========================================================================
# 266
# is_signal : False, p_values[266]: 0.09683663154255036
# FPR: 0.0547945205479452, TPR: 0.1875
# is_not_signal: (146, 8)
# is_signal: (16, 3)
# ===========================================================================
# 267
# Lasso selected no features. Skipping.
# 268
# Lasso selected no features. Skipping.
# 269
# is_signal : False, p_values[269]: 0.06870379554130038
# FPR: 0.05442176870748299, TPR: 0.1875
# is_not_signal: (147, 8)
# is_signal: (16, 3)
# ===========================================================================
# 270
# Lasso selected no features. Skipping.
# 271
# is_signal : False, p_values[271]: 0.5668858130764247
# FPR: 0.05405405405405406, TPR: 0.1875
# is_not_signal: (148, 8)
# is_signal: (16, 3)
# ===========================================================================
# 272
# is_signal : False, p_values[272]: 0.5532127226527335
# FPR: 0.053691275167785234, TPR: 0.1875
# is_not_signal: (149, 8)
# is_signal: (16, 3)
# ===========================================================================
# 273
# is_signal : False, p_values[273]: 0.49195143004635056
# FPR: 0.05333333333333334, TPR: 0.1875
# is_not_signal: (150, 8)
# is_signal: (16, 3)
# ===========================================================================
# 274
# Lasso selected no features. Skipping.
# 275
# is_signal : False, p_values[275]: 0.6751263173132179
# FPR: 0.052980132450331126, TPR: 0.1875
# is_not_signal: (151, 8)
# is_signal: (16, 3)
# ===========================================================================
# 276
# Lasso selected no features. Skipping.
# 277
# Lasso selected no features. Skipping.
# 278
# is_signal : False, p_values[278]: 0.8006949235683465
# FPR: 0.05263157894736842, TPR: 0.1875
# is_not_signal: (152, 8)
# is_signal: (16, 3)
# ===========================================================================
# 279
# is_signal : False, p_values[279]: 0.13206991459379516
# FPR: 0.05228758169934641, TPR: 0.1875
# is_not_signal: (153, 8)
# is_signal: (16, 3)
# ===========================================================================
# 280
# Lasso selected no features. Skipping.
# 281
# is_signal : True, p_values[281]: 0.4451580520220106
# FPR: 0.05228758169934641, TPR: 0.17647058823529413
# is_not_signal: (153, 8)
# is_signal: (17, 3)
# ===========================================================================
# 282
# Lasso selected no features. Skipping.
# 283
# Lasso selected no features. Skipping.
# 284
# Lasso selected no features. Skipping.
# 285
# is_signal : False, p_values[285]: 0.9739547387852542
# FPR: 0.05194805194805195, TPR: 0.17647058823529413
# is_not_signal: (154, 8)
# is_signal: (17, 3)
# ===========================================================================
# 286
# Lasso selected no features. Skipping.
# 287
# Lasso selected no features. Skipping.
# 288
# is_signal : False, p_values[288]: 0.2087594388361158
# FPR: 0.05161290322580645, TPR: 0.17647058823529413
# is_not_signal: (155, 8)
# is_signal: (17, 3)
# ===========================================================================
# 289
# is_signal : False, p_values[289]: 0.03911687577286957
# FPR: 0.057692307692307696, TPR: 0.17647058823529413
# is_not_signal: (156, 9)
# is_signal: (17, 3)
# ===========================================================================
# 290
# is_signal : False, p_values[290]: 0.029763920776345792
# FPR: 0.06369426751592357, TPR: 0.17647058823529413
# is_not_signal: (157, 10)
# is_signal: (17, 3)
# ===========================================================================
# 291
# is_signal : False, p_values[291]: 0.5241252571057725
# FPR: 0.06329113924050633, TPR: 0.17647058823529413
# is_not_signal: (158, 10)
# is_signal: (17, 3)
# ===========================================================================
# 292
# Lasso selected no features. Skipping.
# 293
# is_signal : False, p_values[293]: 0.4580585594990723
# FPR: 0.06289308176100629, TPR: 0.17647058823529413
# is_not_signal: (159, 10)
# is_signal: (17, 3)
# ===========================================================================
# 294
# is_signal : True, p_values[294]: 0.5171057134142734
# FPR: 0.06289308176100629, TPR: 0.16666666666666666
# is_not_signal: (159, 10)
# is_signal: (18, 3)
# ===========================================================================
# 295
# is_signal : False, p_values[295]: 0.6075931045763799
# FPR: 0.0625, TPR: 0.16666666666666666
# is_not_signal: (160, 10)
# is_signal: (18, 3)
# ===========================================================================
# 296
# is_signal : False, p_values[296]: 0.12203524619379681
# FPR: 0.062111801242236024, TPR: 0.16666666666666666
# is_not_signal: (161, 10)
# is_signal: (18, 3)
# ===========================================================================
# 297
# is_signal : False, p_values[297]: 0.6626875784905772
# FPR: 0.06172839506172839, TPR: 0.16666666666666666
# is_not_signal: (162, 10)
# is_signal: (18, 3)
# ===========================================================================
# 298
# is_signal : False, p_values[298]: 0.5507653748706303
# FPR: 0.06134969325153374, TPR: 0.16666666666666666
# is_not_signal: (163, 10)
# is_signal: (18, 3)
# ===========================================================================
# 299
# is_signal : False, p_values[299]: 0.6348275270803272
# FPR: 0.06097560975609756, TPR: 0.16666666666666666
# is_not_signal: (164, 10)
# is_signal: (18, 3)
# ===========================================================================
# 300
# is_signal : False, p_values[300]: 0.3060888490221997
# FPR: 0.06060606060606061, TPR: 0.16666666666666666
# is_not_signal: (165, 10)
# is_signal: (18, 3)
# ===========================================================================
# 301
# is_signal : False, p_values[301]: 0.332799306488931
# FPR: 0.060240963855421686, TPR: 0.16666666666666666
# is_not_signal: (166, 10)
# is_signal: (18, 3)
# ===========================================================================
# 302
# Lasso selected no features. Skipping.
# 303
# is_signal : False, p_values[303]: 0.3505641955218638
# FPR: 0.059880239520958084, TPR: 0.16666666666666666
# is_not_signal: (167, 10)
# is_signal: (18, 3)
# ===========================================================================
# 304
# is_signal : False, p_values[304]: 0.7354263998196456
# FPR: 0.05952380952380952, TPR: 0.16666666666666666
# is_not_signal: (168, 10)
# is_signal: (18, 3)
# ===========================================================================
# 305
# is_signal : False, p_values[305]: 0.7360287935705845
# FPR: 0.05917159763313609, TPR: 0.16666666666666666
# is_not_signal: (169, 10)
# is_signal: (18, 3)
# ===========================================================================
# 306
# Lasso selected no features. Skipping.
# 307
# Lasso selected no features. Skipping.
# 308
# is_signal : False, p_values[308]: 0.13782775056037516
# FPR: 0.058823529411764705, TPR: 0.16666666666666666
# is_not_signal: (170, 10)
# is_signal: (18, 3)
# ===========================================================================
# 309
# is_signal : False, p_values[309]: 0.9036124401941056
# FPR: 0.05847953216374269, TPR: 0.16666666666666666
# is_not_signal: (171, 10)
# is_signal: (18, 3)
# ===========================================================================
# 310
# is_signal : False, p_values[310]: 0.8860566839419555
# FPR: 0.05813953488372093, TPR: 0.16666666666666666
# is_not_signal: (172, 10)
# is_signal: (18, 3)
# ===========================================================================
# 311
# Lasso selected no features. Skipping.
# 312
# is_signal : True, p_values[312]: 0.8860578502384482
# FPR: 0.05813953488372093, TPR: 0.15789473684210525
# is_not_signal: (172, 10)
# is_signal: (19, 3)
# ===========================================================================
# 313
# is_signal : False, p_values[313]: 0.1809207263045766
# FPR: 0.057803468208092484, TPR: 0.15789473684210525
# is_not_signal: (173, 10)
# is_signal: (19, 3)
# ===========================================================================
# 314
# Lasso selected no features. Skipping.
# 315
# is_signal : False, p_values[315]: 0.8695870276915443
# FPR: 0.05747126436781609, TPR: 0.15789473684210525
# is_not_signal: (174, 10)
# is_signal: (19, 3)
# ===========================================================================
# 316
# is_signal : False, p_values[316]: 0.7352328506833442
# FPR: 0.05714285714285714, TPR: 0.15789473684210525
# is_not_signal: (175, 10)
# is_signal: (19, 3)
# ===========================================================================
# 317
# is_signal : False, p_values[317]: 0.14940470908850473
# FPR: 0.056818181818181816, TPR: 0.15789473684210525
# is_not_signal: (176, 10)
# is_signal: (19, 3)
# ===========================================================================
# 318
# Lasso selected no features. Skipping.
# 319
# is_signal : False, p_values[319]: 0.4379382117157846
# FPR: 0.05649717514124294, TPR: 0.15789473684210525
# is_not_signal: (177, 10)
# is_signal: (19, 3)
# ===========================================================================
# 320
# is_signal : False, p_values[320]: 0.9122680568317503
# FPR: 0.056179775280898875, TPR: 0.15789473684210525
# is_not_signal: (178, 10)
# is_signal: (19, 3)
# ===========================================================================
# 321
# Lasso selected no features. Skipping.
# 322
# is_signal : False, p_values[322]: 0.3125955789064751
# FPR: 0.055865921787709494, TPR: 0.15789473684210525
# is_not_signal: (179, 10)
# is_signal: (19, 3)
# ===========================================================================
# 323
# is_signal : False, p_values[323]: 0.6774290346900371
# FPR: 0.05555555555555555, TPR: 0.15789473684210525
# is_not_signal: (180, 10)
# is_signal: (19, 3)
# ===========================================================================
# 324
# is_signal : False, p_values[324]: 0.2192684911560411
# FPR: 0.055248618784530384, TPR: 0.15789473684210525
# is_not_signal: (181, 10)
# is_signal: (19, 3)
# ...
# is_signal: (54, 5)
# ===========================================================================
# 897
# is_signal : False, p_values[897]: 0.49741228195242737
# FPR: 0.040983606557377046, TPR: 0.09259259259259259
# is_not_signal: (488, 20)
# is_signal: (54, 5)
# ===========================================================================
# 898
# is_signal : False, p_values[898]: 0.4285263391225888
# FPR: 0.0408997955010225, TPR: 0.09259259259259259
# is_not_signal: (489, 20)
# is_signal: (54, 5)
# ===========================================================================
# 899
# is_signal : False, p_values[899]: 0.6306787025480173
# FPR: 0.04081632653061224, TPR: 0.09259259259259259
# is_not_signal: (490, 20)
# is_signal: (54, 5)
# ===========================================================================
# 900
# is_signal : False, p_values[900]: 0.1824824087921194
# FPR: 0.04073319755600815, TPR: 0.09259259259259259
# is_not_signal: (491, 20)
# is_signal: (54, 5)
# ===========================================================================
# 901
# Lasso selected no features. Skipping.
# 902
# is_signal : False, p_values[902]: 0.7100482924274165
# FPR: 0.04065040650406504, TPR: 0.09259259259259259
# is_not_signal: (492, 20)
# is_signal: (54, 5)
# ===========================================================================
# 903
# Lasso selected no features. Skipping.
# 904
# is_signal : False, p_values[904]: 0.4425834061870458
# FPR: 0.04056795131845842, TPR: 0.09259259259259259
# is_not_signal: (493, 20)
# is_signal: (54, 5)
# ===========================================================================
# 905
# is_signal : True, p_values[905]: 0.08578617057721656
# FPR: 0.04056795131845842, TPR: 0.09090909090909091
# is_not_signal: (493, 20)
# is_signal: (55, 5)
# ===========================================================================
# 906
# Lasso selected no features. Skipping.
# 907
# Lasso selected no features. Skipping.
# 908
# is_signal : False, p_values[908]: 0.4116126941274444
# FPR: 0.04048582995951417, TPR: 0.09090909090909091
# is_not_signal: (494, 20)
# is_signal: (55, 5)
# ===========================================================================
# 909
# Lasso selected no features. Skipping.
# 910
# Lasso selected no features. Skipping.
# 911
# Lasso selected no features. Skipping.
# 912
# is_signal : False, p_values[912]: 0.9620243583242671
# FPR: 0.04040404040404041, TPR: 0.09090909090909091
# is_not_signal: (495, 20)
# is_signal: (55, 5)
# ===========================================================================
# 913
# is_signal : True, p_values[913]: 0.5880640402427624
# FPR: 0.04040404040404041, TPR: 0.08928571428571429
# is_not_signal: (495, 20)
# is_signal: (56, 5)
# ===========================================================================
# 914
# Lasso selected no features. Skipping.
# 915
# is_signal : False, p_values[915]: 0.992623860555213
# FPR: 0.04032258064516129, TPR: 0.08928571428571429
# is_not_signal: (496, 20)
# is_signal: (56, 5)
# ===========================================================================
# 916
# is_signal : False, p_values[916]: 0.8214714760756023
# FPR: 0.04024144869215292, TPR: 0.08928571428571429
# is_not_signal: (497, 20)
# is_signal: (56, 5)
# ===========================================================================
# 917
# is_signal : False, p_values[917]: 0.8134733968234852
# FPR: 0.040160642570281124, TPR: 0.08928571428571429
# is_not_signal: (498, 20)
# is_signal: (56, 5)
# ===========================================================================
# 918
# is_signal : False, p_values[918]: 0.760858759137951
# FPR: 0.04008016032064128, TPR: 0.08928571428571429
# is_not_signal: (499, 20)
# is_signal: (56, 5)
# ===========================================================================
# 919
# is_signal : False, p_values[919]: 0.15599940879939383
# FPR: 0.04, TPR: 0.08928571428571429
# is_not_signal: (500, 20)
# is_signal: (56, 5)
# ===========================================================================
# 920
# Lasso selected no features. Skipping.
# 921
# Lasso selected no features. Skipping.
# 922
# Lasso selected no features. Skipping.
# 923
# is_signal : False, p_values[923]: 0.906158316034745
# FPR: 0.03992015968063872, TPR: 0.08928571428571429
# is_not_signal: (501, 20)
# is_signal: (56, 5)
# ===========================================================================
# 924
# Lasso selected no features. Skipping.
# 925
# is_signal : True, p_values[925]: 0.7399217813691249
# FPR: 0.03992015968063872, TPR: 0.08771929824561403
# is_not_signal: (501, 20)
# is_signal: (57, 5)
# ===========================================================================
# 926
# is_signal : False, p_values[926]: 0.32596487149054054
# FPR: 0.0398406374501992, TPR: 0.08771929824561403
# is_not_signal: (502, 20)
# is_signal: (57, 5)
# ===========================================================================
# 927
# is_signal : False, p_values[927]: 0.16010217652990555
# FPR: 0.039761431411530816, TPR: 0.08771929824561403
# is_not_signal: (503, 20)
# is_signal: (57, 5)
# ===========================================================================
# 928
# is_signal : True, p_values[928]: 0.4883596548618066
# FPR: 0.039761431411530816, TPR: 0.08620689655172414
# is_not_signal: (503, 20)
# is_signal: (58, 5)
# ===========================================================================
# 929
# Lasso selected no features. Skipping.
# 930
# is_signal : False, p_values[930]: 0.7453082578138669
# FPR: 0.03968253968253968, TPR: 0.08620689655172414
# is_not_signal: (504, 20)
# is_signal: (58, 5)
# ===========================================================================
# 931
# is_signal : False, p_values[931]: 0.4417980777103869
# FPR: 0.039603960396039604, TPR: 0.08620689655172414
# is_not_signal: (505, 20)
# is_signal: (58, 5)
# ===========================================================================
# 932
# is_signal : False, p_values[932]: 0.3792944731979753
# FPR: 0.039525691699604744, TPR: 0.08620689655172414
# is_not_signal: (506, 20)
# is_signal: (58, 5)
# ===========================================================================
# 933
# is_signal : False, p_values[933]: 0.48540096969440183
# FPR: 0.03944773175542406, TPR: 0.08620689655172414
# is_not_signal: (507, 20)
# is_signal: (58, 5)
# ===========================================================================
# 934
# Lasso selected no features. Skipping.
# 935
# is_signal : False, p_values[935]: 0.4300884544249937
# FPR: 0.03937007874015748, TPR: 0.08620689655172414
# is_not_signal: (508, 20)
# is_signal: (58, 5)
# ===========================================================================
# 936
# is_signal : True, p_values[936]: 0.16791664996733408
# FPR: 0.03937007874015748, TPR: 0.0847457627118644
# is_not_signal: (508, 20)
# is_signal: (59, 5)
# ===========================================================================
# 937
# is_signal : False, p_values[937]: 0.2149455589546574
# FPR: 0.03929273084479371, TPR: 0.0847457627118644
# is_not_signal: (509, 20)
# is_signal: (59, 5)
# ===========================================================================
# 938
# Lasso selected no features. Skipping.
# 939
# Lasso selected no features. Skipping.
# 940
# is_signal : True, p_values[940]: 0.5649673116705776
# FPR: 0.03929273084479371, TPR: 0.08333333333333333
# is_not_signal: (509, 20)
# is_signal: (60, 5)
# ===========================================================================
# 941
# is_signal : False, p_values[941]: 0.44031283246505837
# FPR: 0.0392156862745098, TPR: 0.08333333333333333
# is_not_signal: (510, 20)
# is_signal: (60, 5)
# ===========================================================================
# 942
# Lasso selected no features. Skipping.
# 943
# is_signal : True, p_values[943]: 0.23679368129268807
# FPR: 0.0392156862745098, TPR: 0.08196721311475409
# is_not_signal: (510, 20)
# is_signal: (61, 5)
# ===========================================================================
# 944
# is_signal : True, p_values[944]: 0.25074673398061087
# FPR: 0.0392156862745098, TPR: 0.08064516129032258
# is_not_signal: (510, 20)
# is_signal: (62, 5)
# ===========================================================================
# 945
# Lasso selected no features. Skipping.
# 946
# Lasso selected no features. Skipping.
# 947
# is_signal : False, p_values[947]: 0.915474239549562
# FPR: 0.03913894324853229, TPR: 0.08064516129032258
# is_not_signal: (511, 20)
# is_signal: (62, 5)
# ===========================================================================
# 948
# is_signal : False, p_values[948]: 0.07011459693155735
# FPR: 0.0390625, TPR: 0.08064516129032258
# is_not_signal: (512, 20)
# is_signal: (62, 5)
# ===========================================================================
# 949
# is_signal : False, p_values[949]: 0.4503281443608735
# FPR: 0.03898635477582846, TPR: 0.08064516129032258
# is_not_signal: (513, 20)
# is_signal: (62, 5)
# ===========================================================================
# 950
# is_signal : False, p_values[950]: 0.23854618883088372
# FPR: 0.038910505836575876, TPR: 0.08064516129032258
# is_not_signal: (514, 20)
# is_signal: (62, 5)
# ===========================================================================
# 951
# Lasso selected no features. Skipping.
# 952
# is_signal : False, p_values[952]: 0.0026340757133538595
# FPR: 0.040776699029126215, TPR: 0.08064516129032258
# is_not_signal: (515, 21)
# is_signal: (62, 5)
# ===========================================================================
# 953
# Lasso selected no features. Skipping.
# 954
# is_signal : False, p_values[954]: 0.45651395360710784
# FPR: 0.040697674418604654, TPR: 0.08064516129032258
# is_not_signal: (516, 21)
# is_signal: (62, 5)
# ===========================================================================
# 955
# is_signal : True, p_values[955]: 0.19690777153956274
# FPR: 0.040697674418604654, TPR: 0.07936507936507936
# is_not_signal: (516, 21)
# is_signal: (63, 5)
# ===========================================================================
# 956
# Lasso selected no features. Skipping.
# 957
# is_signal : False, p_values[957]: 0.17987119565089213
# FPR: 0.04061895551257253, TPR: 0.07936507936507936
# is_not_signal: (517, 21)
# is_signal: (63, 5)
# ===========================================================================
# 958
# Lasso selected no features. Skipping.
# 959
# Lasso selected no features. Skipping.
# 960
# is_signal : True, p_values[960]: 0.4177264958963735
# FPR: 0.04061895551257253, TPR: 0.078125
# is_not_signal: (517, 21)
# is_signal: (64, 5)
# ===========================================================================
# 961
# is_signal : False, p_values[961]: 0.5448044675677295
# FPR: 0.04054054054054054, TPR: 0.078125
# is_not_signal: (518, 21)
# is_signal: (64, 5)
# ===========================================================================
# 962
# is_signal : False, p_values[962]: 0.7212961428529288
# FPR: 0.04046242774566474, TPR: 0.078125
# is_not_signal: (519, 21)
# is_signal: (64, 5)
# ===========================================================================
# 963
# is_signal : False, p_values[963]: 0.119277011067481
# FPR: 0.04038461538461539, TPR: 0.078125
# is_not_signal: (520, 21)
# is_signal: (64, 5)
# ===========================================================================
# 964
# Lasso selected no features. Skipping.
# 965
# is_signal : False, p_values[965]: 0.5949251099177699
# FPR: 0.04030710172744722, TPR: 0.078125
# is_not_signal: (521, 21)
# is_signal: (64, 5)
# ===========================================================================
# 966
# is_signal : False, p_values[966]: 0.8969911535606229
# FPR: 0.040229885057471264, TPR: 0.078125
# is_not_signal: (522, 21)
# is_signal: (64, 5)
# ===========================================================================
# 967
# Lasso selected no features. Skipping.
# 968
# is_signal : False, p_values[968]: 0.5874181042514318
# FPR: 0.040152963671128104, TPR: 0.078125
# is_not_signal: (523, 21)
# is_signal: (64, 5)
# ===========================================================================
# 969
# is_signal : False, p_values[969]: 0.8098664010275786
# FPR: 0.04007633587786259, TPR: 0.078125
# is_not_signal: (524, 21)
# is_signal: (64, 5)
# ===========================================================================
# 970
# is_signal : False, p_values[970]: 0.029193185406148698
# FPR: 0.0419047619047619, TPR: 0.078125
# is_not_signal: (525, 22)
# is_signal: (64, 5)
# ===========================================================================
# 971
# is_signal : False, p_values[971]: 0.81431475787773
# FPR: 0.04182509505703422, TPR: 0.078125
# is_not_signal: (526, 22)
# is_signal: (64, 5)
# ===========================================================================
# 972
# is_signal : False, p_values[972]: 0.7175009313427926
# FPR: 0.04174573055028463, TPR: 0.078125
# is_not_signal: (527, 22)
# is_signal: (64, 5)
# ===========================================================================
# 973
# Lasso selected no features. Skipping.
# 974
# is_signal : False, p_values[974]: 0.8045975522845727
# FPR: 0.041666666666666664, TPR: 0.078125
# is_not_signal: (528, 22)
# is_signal: (64, 5)
# ===========================================================================
# 975
# Lasso selected no features. Skipping.
# 976
# Lasso selected no features. Skipping.
# 977
# is_signal : True, p_values[977]: 0.5720863611100313
# FPR: 0.041666666666666664, TPR: 0.07692307692307693
# is_not_signal: (528, 22)
# is_signal: (65, 5)
# ===========================================================================
# 978
# Lasso selected no features. Skipping.
# 979
# Lasso selected no features. Skipping.
# 980
# Lasso selected no features. Skipping.
# 981
# Lasso selected no features. Skipping.
# 982
# Lasso selected no features. Skipping.
# 983
# is_signal : False, p_values[983]: 0.5069036339050028
# FPR: 0.04158790170132325, TPR: 0.07692307692307693
# is_not_signal: (529, 22)
# is_signal: (65, 5)
# ===========================================================================
# 984
# Lasso selected no features. Skipping.
# 985
# is_signal : False, p_values[985]: 0.2789254300235214
# FPR: 0.04150943396226415, TPR: 0.07692307692307693
# is_not_signal: (530, 22)
# is_signal: (65, 5)
# ===========================================================================
# 986
# Lasso selected no features. Skipping.
# 987
# is_signal : False, p_values[987]: 0.8111854912045888
# FPR: 0.04143126177024482, TPR: 0.07692307692307693
# is_not_signal: (531, 22)
# is_signal: (65, 5)
# ===========================================================================
# 988
# Lasso selected no features. Skipping.
# 989
# is_signal : False, p_values[989]: 0.967769722859193
# FPR: 0.041353383458646614, TPR: 0.07692307692307693
# is_not_signal: (532, 22)
# is_signal: (65, 5)
# ===========================================================================
# 990
# is_signal : False, p_values[990]: 0.44010171838909584
# FPR: 0.04127579737335835, TPR: 0.07692307692307693
# is_not_signal: (533, 22)
# is_signal: (65, 5)
# ===========================================================================
# 991
# Lasso selected no features. Skipping.
# 992
# is_signal : False, p_values[992]: 0.4837563444863068
# FPR: 0.04119850187265917, TPR: 0.07692307692307693
# is_not_signal: (534, 22)
# is_signal: (65, 5)
# ===========================================================================
# 993
# is_signal : False, p_values[993]: 0.9531598427271984
# FPR: 0.041121495327102804, TPR: 0.07692307692307693
# is_not_signal: (535, 22)
# is_signal: (65, 5)
# ===========================================================================
# 994
# is_signal : True, p_values[994]: 0.6370951956229765
# FPR: 0.041121495327102804, TPR: 0.07575757575757576
# is_not_signal: (535, 22)
# is_signal: (66, 5)
# ===========================================================================
# 995
# is_signal : False, p_values[995]: 0.9459670543705823
# FPR: 0.041044776119402986, TPR: 0.07575757575757576
# is_not_signal: (536, 22)
# is_signal: (66, 5)
# ===========================================================================
# 996
# is_signal : False, p_values[996]: 0.17775528703858806
# FPR: 0.040968342644320296, TPR: 0.07575757575757576
# is_not_signal: (537, 22)
# is_signal: (66, 5)
# ===========================================================================
# 997
# is_signal : False, p_values[997]: 0.3635707438183725
# FPR: 0.040892193308550186, TPR: 0.07575757575757576
# is_not_signal: (538, 22)
# is_signal: (66, 5)
# ===========================================================================
# 998
# Lasso selected no features. Skipping.
# 999
# Lasso selected no features. Skipping.

# %%
is_signal_cases = [r for r in para_results_storage if r['is_signal']]
not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
print(f"len not_signal_cases : {len(not_signal_cases)}")
print(f"false_positives: {false_positives}")
fpr = false_positives / len(not_signal_cases)
print(f"FPR: {fpr:.4f} (Target: {alpha})")
print("\n")
true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha)
print(f"len not_signal_cases : {len(is_signal_cases)}")
print(f"true_positives: {true_positives}")
tpr = true_positives / len(is_signal_cases)
print(f"TPR: {tpr:.4f}")
# Out:
# len not_signal_cases : 538
# false_positives: 22
# FPR: 0.0409 (Target: 0.05)
#
#
# len not_signal_cases : 66
# true_positives: 5
# TPR: 0.0758
