# %% [markdown]
# ## Testing p_value

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import SI_CoRT
import CoRT_builder

# %%
n_target = 40
n_source = 80
p = 200
K = 5
Ka = 3
h = 10
alpha = 0.05
T = 5
s_len = 10
s_vector = [0.5] * s_len

para_results_storage = []
CoRT_model = CoRT_builder.CoRT()
iteration = 1000

for i in range(iteration):
    target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
    result_dict = SI_CoRT.SI_over_conditioning(n_target, p, K, target_data, source_data, T, s_len)
    
    if result_dict != None:
        if i % 25 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_value[{i}] = {result_dict['p_value']}")
            print("==========================================================================================")
        para_results_storage.append(result_dict)
# Out:
# is_signal : True, p_value[0] = 0.6129911701680111
# ==========================================================================================
# is_signal : True, p_value[25] = 0.10905491431916324
# ==========================================================================================
# is_signal : True, p_value[50] = 0.13425145626944104
# ==========================================================================================
# is_signal : True, p_value[75] = 0.6464347906209034
# ==========================================================================================
# is_signal : True, p_value[100] = 0.07287272789110129
# ==========================================================================================
# is_signal : True, p_value[125] = 0.029419539622373758
# ==========================================================================================
# is_signal : True, p_value[150] = 0.8203085781006296
# ==========================================================================================
# is_signal : False, p_value[175] = 0.12612142462304213
# ==========================================================================================
# is_signal : False, p_value[200] = 0.1504837467967688
# ==========================================================================================
# is_signal : False, p_value[225] = 0.6390615610807673
# ==========================================================================================
# is_signal : True, p_value[250] = 0.2677737155431943
# ==========================================================================================
# is_signal : True, p_value[275] = 0.8577784544769855
# ==========================================================================================
# is_signal : False, p_value[300] = 0.867440823706892
# ==========================================================================================
# is_signal : True, p_value[325] = 0.558806635055505
# ==========================================================================================
# is_signal : True, p_value[350] = 0.8141713165478364
# ==========================================================================================
# is_signal : True, p_value[375] = 0.2804208217608881
# ==========================================================================================
# is_signal : False, p_value[400] = 0.6269931887762918
# ==========================================================================================
# is_signal : True, p_value[425] = 0.5646250737536216
# ==========================================================================================
# is_signal : False, p_value[450] = 0.3235230953233183
# ==========================================================================================
# is_signal : True, p_value[475] = 0.44359389412084704
# ==========================================================================================
# is_signal : True, p_value[500] = 0.5681959314158876
# ==========================================================================================
# is_signal : True, p_value[525] = 0.5520604059507755
# ==========================================================================================

# %%
is_signal_cases = [r for r in para_results_storage if r['is_signal']]
not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
print(f"len not_signal_cases : {len(not_signal_cases)}")
print(f"false_positives: {false_positives}")
fpr = false_positives / len(not_signal_cases)
print(f"FPR: {fpr:.4f} (Target: {alpha})")
print("\n")
true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha)
print(f"len not_signal_cases : {len(is_signal_cases)}")
print(f"true_positives: {true_positives}")
tpr = true_positives / len(is_signal_cases)
print(f"TPR: {tpr:.4f}")
