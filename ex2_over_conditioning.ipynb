# %% [markdown]
# ## Testing p_value

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import SI_CoRT
import CoRT_builder

# %%
n_target = 40
n_source = 80
p = 200
K = 5
Ka = 3
h = 10
alpha = 0.05
T = 5
s_len = 10
s_vector = [0.8] * s_len

para_results_storage = []
CoRT_model = CoRT_builder.CoRT()
iteration = 1000

for i in range(iteration):
    target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
    result_dict = SI_CoRT.SI_over_conditioning(n_target, p, K, target_data, source_data, T, s_len)
    
    if result_dict != None:
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_value[{i}] = {result_dict['p_value']}")
            print("==========================================================================================")
        para_results_storage.append(result_dict)
# Out:
# is_signal : True, p_value[0] = 0.017755832279947148
# ==========================================================================================
# is_signal : True, p_value[1] = 0.8304112603738804
# ==========================================================================================
# is_signal : True, p_value[2] = 0.5865985509062699
# ==========================================================================================
# is_signal : True, p_value[3] = 0.22469541986923103
# ==========================================================================================
# is_signal : True, p_value[4] = 0.5802762784639828
# ==========================================================================================
# is_signal : True, p_value[5] = 0.46172872498113215
# ==========================================================================================
# is_signal : True, p_value[6] = 0.0018622643752692217
# ==========================================================================================
# is_signal : True, p_value[7] = 0.1333874360359697
# ==========================================================================================
# is_signal : True, p_value[8] = 0.8435861857281639
# ==========================================================================================
# is_signal : True, p_value[9] = 0.23995559498746566
# ==========================================================================================
# is_signal : True, p_value[10] = 0.41392217588179653
# ==========================================================================================
# is_signal : True, p_value[11] = 0.30061272955553897
# ==========================================================================================
# is_signal : True, p_value[12] = 0.6010692952192819
# ==========================================================================================
# is_signal : True, p_value[13] = 0.429939613873724
# ==========================================================================================
# is_signal : True, p_value[14] = 0.7323634467677061
# ==========================================================================================
# is_signal : True, p_value[15] = 0.544675731670378
# ==========================================================================================
# is_signal : True, p_value[16] = 0.4861905587351632
# ==========================================================================================
# is_signal : True, p_value[17] = 0.02936490419805545
# ==========================================================================================
# is_signal : True, p_value[18] = 0.3622625128797501
# ==========================================================================================
# is_signal : True, p_value[19] = 0.3790597443945414
# ==========================================================================================
# is_signal : True, p_value[20] = 0.7640101958975628
# ==========================================================================================
# is_signal : True, p_value[21] = 0.1164951017923259
# ==========================================================================================
# is_signal : True, p_value[22] = 0.12772298653967795
# ==========================================================================================
# is_signal : True, p_value[23] = 0.6099754174319396
# ==========================================================================================
# is_signal : True, p_value[24] = 0.05994588895887554
# ==========================================================================================
# is_signal : True, p_value[25] = 0.4084920852092966
# ==========================================================================================
# is_signal : True, p_value[26] = 0.05066276519207959
# ==========================================================================================
# is_signal : True, p_value[27] = 0.2841306311906296
# ==========================================================================================
# is_signal : True, p_value[28] = 0.9859950213940986
# ==========================================================================================
# is_signal : True, p_value[29] = 0.4901184747060434
# ==========================================================================================
# is_signal : True, p_value[30] = 0.8312235613684169
# ==========================================================================================
# is_signal : True, p_value[31] = 0.29240337621816814
# ==========================================================================================
# is_signal : True, p_value[32] = 0.7504231695610717
# ==========================================================================================
# is_signal : True, p_value[33] = 0.24643411070209487
# ==========================================================================================
# is_signal : True, p_value[34] = 0.6185609451581938
# ==========================================================================================
# is_signal : True, p_value[35] = 0.8889088421576992
# ==========================================================================================
# is_signal : True, p_value[36] = 0.000632657302258401
# ==========================================================================================
# is_signal : True, p_value[37] = 0.4106934858377306
# ==========================================================================================
# is_signal : True, p_value[38] = 0.3461762423621404
# ==========================================================================================
# is_signal : True, p_value[39] = 0.7743844975710005
# ==========================================================================================
# is_signal : True, p_value[40] = 0.6686521929544782
# ==========================================================================================
# is_signal : True, p_value[41] = 0.045781193959406385
# ==========================================================================================
# is_signal : True, p_value[42] = 0.9795351949398506
# ==========================================================================================
# is_signal : True, p_value[43] = 0.545360856829248
# ==========================================================================================
# is_signal : True, p_value[44] = 0.17405015657103817
# ==========================================================================================
# is_signal : True, p_value[45] = 0.5261834767144359
# ==========================================================================================
# is_signal : True, p_value[46] = 0.37707568664591706
# ==========================================================================================
# is_signal : True, p_value[47] = 0.9314467556477959
# ==========================================================================================
# is_signal : True, p_value[48] = 0.4125728011005869
# ==========================================================================================
# is_signal : True, p_value[49] = 0.46960193465534605
# ==========================================================================================
# is_signal : True, p_value[50] = 0.473536483717307
# ==========================================================================================
# is_signal : True, p_value[51] = 0.7122530392039809
# ==========================================================================================
# is_signal : True, p_value[52] = 0.16966737665860943
# ==========================================================================================
# is_signal : True, p_value[53] = 0.9104705606137593
# ==========================================================================================
# is_signal : True, p_value[54] = 0.03339605909394261
# ==========================================================================================
# is_signal : True, p_value[55] = 0.9013927589604847
# ==========================================================================================
# is_signal : True, p_value[56] = 0.5368174505710814
# ==========================================================================================
# is_signal : True, p_value[57] = 0.7642717296797386
# ==========================================================================================
# is_signal : True, p_value[58] = 0.1929938317333916
# ==========================================================================================
# is_signal : True, p_value[59] = 0.2910735498881492
# ==========================================================================================
# is_signal : True, p_value[60] = 0.26030783712563443
# ==========================================================================================
# is_signal : True, p_value[61] = 0.6318611933302289
# ==========================================================================================
# is_signal : True, p_value[62] = 0.7140883659232321
# ==========================================================================================
# is_signal : True, p_value[63] = 0.11486975970160337
# ==========================================================================================
# is_signal : True, p_value[64] = 0.546139222652703
# ==========================================================================================
# is_signal : True, p_value[65] = 0.6889334168702788
# ==========================================================================================
# is_signal : True, p_value[66] = 0.3995645050380554
# ==========================================================================================
# is_signal : True, p_value[67] = 0.8178809936058921
# ==========================================================================================
# is_signal : True, p_value[68] = 0.963821170483818
# ==========================================================================================
# is_signal : True, p_value[69] = 0.37562810185750667
# ==========================================================================================
# is_signal : True, p_value[70] = 0.6063360236067162
# ==========================================================================================
# is_signal : True, p_value[71] = 0.7935323110397239
# ==========================================================================================
# is_signal : True, p_value[72] = 0.43010185548841595
# ==========================================================================================
# is_signal : True, p_value[73] = 0.9443273626977713
# ==========================================================================================
# is_signal : True, p_value[74] = 0.4098408489469878
# ==========================================================================================
# is_signal : True, p_value[75] = 0.96319800823973
# ==========================================================================================
# is_signal : True, p_value[76] = 0.5822689840118437
# ==========================================================================================
# is_signal : True, p_value[77] = 0.8057611280297509
# ==========================================================================================
# is_signal : True, p_value[78] = 0.15382264615672936
# ==========================================================================================
# is_signal : False, p_value[79] = 0.5093062578152786
# ==========================================================================================
# is_signal : True, p_value[80] = 0.6552439727879917
# ==========================================================================================
# is_signal : True, p_value[81] = 0.576917906681625
# ==========================================================================================
# is_signal : True, p_value[82] = 0.6543942155252012
# ==========================================================================================
# is_signal : True, p_value[83] = 0.530533020631651
# ==========================================================================================
# is_signal : True, p_value[84] = 0.9016100437200602
# ==========================================================================================
# is_signal : True, p_value[85] = 0.08925097008801881
# ==========================================================================================
# is_signal : True, p_value[86] = 0.08430679101169014
# ==========================================================================================
# is_signal : True, p_value[87] = 0.41155844068544
# ==========================================================================================
# is_signal : True, p_value[88] = 0.2892428264018583
# ==========================================================================================
# is_signal : True, p_value[89] = 0.159837129270374
# ==========================================================================================
# is_signal : True, p_value[90] = 0.6514808688374584
# ==========================================================================================
# is_signal : True, p_value[91] = 0.7928911045425584
# ==========================================================================================
# is_signal : True, p_value[92] = 0.10935463486588633
# ==========================================================================================
# is_signal : True, p_value[93] = 0.32282480171335326
# ==========================================================================================
# is_signal : True, p_value[94] = 0.23208662069574254
# ==========================================================================================
# is_signal : True, p_value[95] = 0.7719108842548987
# ==========================================================================================
# is_signal : True, p_value[96] = 0.7699659718985936
# ==========================================================================================
# is_signal : True, p_value[97] = 0.5545593220263094
# ==========================================================================================
# is_signal : True, p_value[98] = 0.2125196530354676
# ==========================================================================================
# is_signal : True, p_value[99] = 0.11786203188877309
# ==========================================================================================
# is_signal : True, p_value[100] = 0.18853330544501123
# ==========================================================================================
# is_signal : True, p_value[101] = 0.0007052258677505476
# ==========================================================================================
# is_signal : True, p_value[102] = 0.10315782862842804
# ==========================================================================================
# is_signal : True, p_value[103] = 0.9110750970507662
# ==========================================================================================
# is_signal : True, p_value[104] = 0.004748446426585007
# ==========================================================================================
# is_signal : True, p_value[105] = 0.04918065469634417
# ==========================================================================================
# is_signal : True, p_value[106] = 0.19955556990501533
# ==========================================================================================
# is_signal : True, p_value[107] = 0.9039039467546024
# ==========================================================================================
# is_signal : True, p_value[108] = 0.023430100002703735
# ==========================================================================================
# is_signal : True, p_value[109] = 0.801462418573333
# ==========================================================================================
# is_signal : True, p_value[110] = 0.33773909830643745
# ==========================================================================================
# is_signal : True, p_value[111] = 0.4462201279950389
# ==========================================================================================
# is_signal : True, p_value[112] = 0.5574131700527737
# ==========================================================================================
# is_signal : True, p_value[113] = 0.8118349194817412
# ==========================================================================================
# is_signal : True, p_value[114] = 0.03785664921455001
# ==========================================================================================
# is_signal : True, p_value[115] = 0.041414954203113474
# ==========================================================================================
# is_signal : True, p_value[116] = 0.7641833579474805
# ==========================================================================================
# is_signal : True, p_value[117] = 0.8981353976529959
# ==========================================================================================
# is_signal : True, p_value[118] = 0.6943178991184042
# ==========================================================================================
# is_signal : True, p_value[119] = 0.22779919530497564
# ==========================================================================================
# is_signal : True, p_value[120] = 0.05567388156454817
# ==========================================================================================
# is_signal : True, p_value[121] = 0.6046641687190235
# ==========================================================================================
# is_signal : True, p_value[122] = 0.7326794410156824
# ==========================================================================================
# is_signal : True, p_value[123] = 0.37381227093642466
# ==========================================================================================
# is_signal : True, p_value[124] = 0.7247123038897458
# ==========================================================================================
# is_signal : True, p_value[125] = 0.8065825020083082
# ==========================================================================================
# is_signal : True, p_value[126] = 0.44484086280950164
# ==========================================================================================
# is_signal : True, p_value[127] = 0.2568945228354955
# ==========================================================================================
# is_signal : True, p_value[128] = 0.9576431759474874
# ==========================================================================================
# is_signal : True, p_value[129] = 0.15411445613930574
# ==========================================================================================
# is_signal : True, p_value[130] = 0.7680032189148154
# ==========================================================================================
# is_signal : True, p_value[131] = 0.21091428619394023
# ==========================================================================================
# is_signal : True, p_value[132] = 0.43262900300719853
# ==========================================================================================
# is_signal : True, p_value[133] = 0.44354620313183846
# ==========================================================================================
# is_signal : True, p_value[134] = 0.494268736521863
# ==========================================================================================
# is_signal : True, p_value[135] = 0.7559893326303553
# ==========================================================================================
# is_signal : True, p_value[136] = 0.38424673349032457
# ==========================================================================================
# is_signal : True, p_value[137] = 0.7240075704695526
# ==========================================================================================
# is_signal : True, p_value[138] = 0.2959358632179525
# ==========================================================================================
# is_signal : True, p_value[139] = 0.009054156000953582
# ==========================================================================================
# is_signal : True, p_value[140] = 0.6236610350066193
# ==========================================================================================
# is_signal : True, p_value[141] = 0.5894328957596908
# ==========================================================================================
# is_signal : True, p_value[142] = 0.7912532676448245
# ==========================================================================================
# is_signal : True, p_value[143] = 0.30611358297130453
# ==========================================================================================
# is_signal : True, p_value[144] = 0.08744524040146673
# ==========================================================================================
# is_signal : True, p_value[145] = 0.9830103102909955
# ==========================================================================================
# is_signal : True, p_value[146] = 0.2032824614032056
# ==========================================================================================
# is_signal : True, p_value[147] = 0.012224484963401358
# ==========================================================================================
# is_signal : True, p_value[148] = 0.42016025135291973
# ==========================================================================================
# is_signal : True, p_value[149] = 0.8976693255255142
# ==========================================================================================
# is_signal : True, p_value[150] = 0.6730884844626916
# ==========================================================================================
# is_signal : True, p_value[151] = 0.8751761792809889
# ==========================================================================================
# is_signal : True, p_value[152] = 0.5950205606902794
# ==========================================================================================
# is_signal : True, p_value[153] = 0.26556087154267316
# ==========================================================================================
# is_signal : True, p_value[154] = 0.9373864243183756
# ==========================================================================================
# is_signal : True, p_value[155] = 0.7463680995015147
# ==========================================================================================
# is_signal : True, p_value[156] = 0.9617012725179008
# ==========================================================================================
# is_signal : True, p_value[157] = 0.8780016462246978
# ==========================================================================================
# is_signal : True, p_value[158] = 0.5717951732005015
# ==========================================================================================
# is_signal : True, p_value[159] = 0.9715805346872907
# ==========================================================================================
# is_signal : True, p_value[160] = 0.3332338321630523
# ==========================================================================================
# is_signal : True, p_value[161] = 0.29693364535333794
# ==========================================================================================
# is_signal : True, p_value[162] = 0.6505117088554845
# ==========================================================================================
# is_signal : True, p_value[163] = 0.9274016777058033
# ==========================================================================================
# is_signal : True, p_value[164] = 0.5139361066784789
# ==========================================================================================
# is_signal : True, p_value[165] = 0.460420731668979
# ==========================================================================================
# is_signal : True, p_value[166] = 0.7178260189636971
# ==========================================================================================
# is_signal : True, p_value[167] = 0.423811928515016
# ==========================================================================================
# is_signal : True, p_value[168] = 0.6467191144059945
# ==========================================================================================
# is_signal : True, p_value[169] = 0.697420232267693
# ==========================================================================================
# is_signal : True, p_value[170] = 0.26215716449235327
# ==========================================================================================
# is_signal : True, p_value[171] = 0.3956003341470047
# ==========================================================================================
# is_signal : True, p_value[172] = 0.4294757075830573
# ==========================================================================================
# is_signal : True, p_value[173] = 0.8146399209202988
# ==========================================================================================
# is_signal : True, p_value[174] = 0.023733761475854376
# ==========================================================================================
# is_signal : True, p_value[175] = 0.496073206293111
# ==========================================================================================
# is_signal : True, p_value[176] = 0.6384506296853212
# ==========================================================================================
# is_signal : True, p_value[177] = 0.26741452816295247
# ==========================================================================================
# is_signal : True, p_value[178] = 0.5206463532926873
# ==========================================================================================
# is_signal : True, p_value[179] = 0.07961584093539006
# ==========================================================================================
# is_signal : True, p_value[180] = 0.17649928235034543
# ==========================================================================================
# is_signal : True, p_value[181] = 0.5552834608783503
# ==========================================================================================
# is_signal : True, p_value[182] = 0.9764514645606761
# ==========================================================================================
# is_signal : True, p_value[183] = 0.35687300294248114
# ==========================================================================================
# is_signal : True, p_value[184] = 0.3792169699373556
# ==========================================================================================
# is_signal : False, p_value[185] = 0.5887027910452443
# ==========================================================================================
# c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.584e-11, tolerance: 1.928e-11
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.580e-11, tolerance: 1.928e-11
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.580e-11, tolerance: 1.928e-11
#   model = cd_fast.enet_coordinate_descent(
# is_signal : True, p_value[186] = 0.11474707766227321
# ==========================================================================================
# is_signal : True, p_value[187] = 0.2905018876784558
# ==========================================================================================
# is_signal : True, p_value[188] = 0.9715544408723145
# ==========================================================================================
# is_signal : True, p_value[189] = 0.08944614896858324
# ==========================================================================================
# is_signal : True, p_value[190] = 0.23832514016600895
# ==========================================================================================
# is_signal : True, p_value[191] = 0.4190084663561412
# ==========================================================================================
# is_signal : True, p_value[192] = 0.5147111986422509
# ==========================================================================================
# is_signal : True, p_value[193] = 0.09067425699812648
# ==========================================================================================
# is_signal : True, p_value[194] = 0.16078266924088783
# ==========================================================================================
# is_signal : True, p_value[195] = 0.9768993889265112
# ==========================================================================================
# is_signal : True, p_value[196] = 0.4884468589228131
# ==========================================================================================
# is_signal : True, p_value[197] = 0.9961707758258318
# ==========================================================================================
# is_signal : True, p_value[198] = 0.411324918842071
# ==========================================================================================
# is_signal : True, p_value[199] = 0.9414796633822615
# ==========================================================================================
# is_signal : True, p_value[200] = 0.7703415125448868
# ==========================================================================================
# is_signal : True, p_value[201] = 0.12038849712774202
# ==========================================================================================
# is_signal : True, p_value[202] = 0.6915069869736239
# ==========================================================================================
# is_signal : True, p_value[203] = 0.20529535933584775
# ==========================================================================================
# is_signal : True, p_value[204] = 0.0730383556571097
# ==========================================================================================
# is_signal : True, p_value[205] = 0.369491659459506
# ==========================================================================================
# is_signal : True, p_value[206] = 0.7320083545079306
# ==========================================================================================
# is_signal : True, p_value[207] = 0.8455892338473578
# ==========================================================================================
# is_signal : True, p_value[208] = 0.07204394468813069
# ==========================================================================================
# is_signal : True, p_value[209] = 0.3163840023735227
# ==========================================================================================
# is_signal : True, p_value[210] = 0.9302231428152183
# ==========================================================================================
# is_signal : True, p_value[211] = 0.17965612856589752
# ==========================================================================================
# is_signal : True, p_value[212] = 0.1406922243891955
# ==========================================================================================
# is_signal : True, p_value[213] = 0.9475452287659676
# ==========================================================================================
# is_signal : True, p_value[214] = 0.732164708074425
# ==========================================================================================
# is_signal : True, p_value[215] = 0.2278973654972214
# ==========================================================================================
# is_signal : True, p_value[216] = 0.9761824342570437
# ==========================================================================================
# is_signal : True, p_value[217] = 0.39477858015492506
# ==========================================================================================
# is_signal : True, p_value[218] = 0.6113598335705032
# ==========================================================================================
# is_signal : True, p_value[219] = 0.9240334236750879
# ==========================================================================================
# is_signal : True, p_value[220] = 0.7187137762162319
# ==========================================================================================
# is_signal : True, p_value[221] = 0.05687002288665521
# ==========================================================================================
# is_signal : True, p_value[222] = 0.8507591103715566
# ==========================================================================================
# is_signal : True, p_value[223] = 0.2308837661214335
# ==========================================================================================
# is_signal : True, p_value[224] = 0.828522161958724
# ==========================================================================================
# is_signal : True, p_value[225] = 0.09362726949370925
# ==========================================================================================
# is_signal : True, p_value[226] = 0.04503332731796104
# ==========================================================================================
# is_signal : True, p_value[227] = 0.6419631056767194
# ==========================================================================================
# is_signal : True, p_value[228] = 0.9430927683973891
# ==========================================================================================
# is_signal : True, p_value[229] = 0.7466223003829888
# ==========================================================================================
# is_signal : True, p_value[230] = 0.6061460215945459
# ==========================================================================================
# is_signal : True, p_value[231] = 0.7313045428334635
# ==========================================================================================
# is_signal : True, p_value[232] = 0.6082932737229254
# ==========================================================================================
# is_signal : True, p_value[233] = 0.7492456188331598
# ==========================================================================================
# is_signal : True, p_value[234] = 0.6534390795896738
# ==========================================================================================
# is_signal : True, p_value[235] = 0.8342740710762997
# ==========================================================================================
# is_signal : False, p_value[236] = 0.8323386113021023
# ==========================================================================================
# is_signal : True, p_value[237] = 0.43300429722243783
# ==========================================================================================
# is_signal : True, p_value[238] = 0.7716199973822857
# ==========================================================================================
# is_signal : True, p_value[239] = 0.04025031891324882
# ==========================================================================================
# is_signal : True, p_value[240] = 0.5454220425167742
# ==========================================================================================
# is_signal : True, p_value[241] = 0.4033506380381915
# ==========================================================================================
# is_signal : True, p_value[242] = 0.16776202732874546
# ==========================================================================================
# is_signal : True, p_value[243] = 0.9465374385625704
# ==========================================================================================
# is_signal : True, p_value[244] = 0.8183045885404843
# ==========================================================================================
# is_signal : True, p_value[245] = 0.42882312708543857
# ==========================================================================================
# is_signal : True, p_value[246] = 0.1510681755698297
# ==========================================================================================
# is_signal : True, p_value[247] = 0.1876378340511211
# ==========================================================================================
# is_signal : True, p_value[248] = 0.30337400339590537
# ==========================================================================================
# is_signal : True, p_value[249] = 0.527799101458744
# ==========================================================================================
# is_signal : True, p_value[250] = 0.37935540534673184
# ==========================================================================================
# is_signal : True, p_value[251] = 0.6746536675480475
# ==========================================================================================
# is_signal : True, p_value[252] = 0.20465258452542812
# ==========================================================================================
# is_signal : True, p_value[253] = 0.445948768187994
# ==========================================================================================
# is_signal : True, p_value[254] = 0.6534600386802463
# ==========================================================================================
# is_signal : True, p_value[255] = 0.6375516099804024
# ==========================================================================================
# is_signal : True, p_value[256] = 0.3349872160934647
# ==========================================================================================
# is_signal : True, p_value[257] = 0.15167377612100674
# ==========================================================================================
# is_signal : True, p_value[258] = 0.8041383768957877
# ==========================================================================================
# is_signal : True, p_value[259] = 0.14528656572719068
# ==========================================================================================
# is_signal : True, p_value[260] = 0.08250602016682307
# ==========================================================================================
# is_signal : True, p_value[261] = 0.9132521880867945
# ==========================================================================================
# is_signal : True, p_value[262] = 0.020348363987195084
# ==========================================================================================
# is_signal : True, p_value[263] = 0.04132698777544715
# ==========================================================================================
# is_signal : True, p_value[264] = 0.5751904082173092
# ==========================================================================================
# is_signal : True, p_value[265] = 0.37355356826668973
# ==========================================================================================
# is_signal : True, p_value[266] = 0.9438861560039216
# ==========================================================================================
# is_signal : True, p_value[267] = 0.19939980872392365
# ==========================================================================================
# is_signal : True, p_value[268] = 0.7451668785440404
# ==========================================================================================
# is_signal : True, p_value[269] = 0.07339231393483317
# ==========================================================================================
# is_signal : True, p_value[270] = 0.8775376406087474
# ==========================================================================================
# is_signal : True, p_value[271] = 0.7201453730079203
# ==========================================================================================
# is_signal : True, p_value[272] = 0.37410601826409406
# ==========================================================================================
# is_signal : True, p_value[273] = 0.809141332952902
# ==========================================================================================
# is_signal : True, p_value[274] = 0.6060849141331381
# ==========================================================================================
# is_signal : True, p_value[275] = 0.9242228312231712
# ==========================================================================================
# is_signal : True, p_value[276] = 0.4253344150409515
# ==========================================================================================
# is_signal : True, p_value[277] = 0.5257015320993543
# ==========================================================================================
# is_signal : True, p_value[278] = 0.5519677660376856
# ==========================================================================================
# is_signal : True, p_value[279] = 0.8114383765204666
# ==========================================================================================
# is_signal : True, p_value[280] = 0.9178427549866475
# ==========================================================================================
# is_signal : True, p_value[281] = 0.9352800476208862
# ==========================================================================================
# is_signal : True, p_value[282] = 0.5737493984748938
# ==========================================================================================
# is_signal : True, p_value[283] = 0.17189949190342954
# ==========================================================================================
# is_signal : True, p_value[284] = 0.5667373685312238
# ==========================================================================================
# is_signal : True, p_value[285] = 0.20475786546610708
# ==========================================================================================
# is_signal : True, p_value[286] = 0.10388870015730611
# ==========================================================================================
# is_signal : True, p_value[287] = 0.015696002920612795
# ==========================================================================================
# is_signal : True, p_value[288] = 0.1485526048540855
# ==========================================================================================
# is_signal : True, p_value[289] = 0.5329121261176599
# ==========================================================================================
# is_signal : True, p_value[290] = 0.2082422164894706
# ==========================================================================================
# is_signal : True, p_value[291] = 0.27609031381099797
# ==========================================================================================
# is_signal : True, p_value[292] = 0.961696320675602
# ==========================================================================================
# is_signal : True, p_value[293] = 0.8974136598942735
# ==========================================================================================
# is_signal : True, p_value[294] = 0.41525771591909577
# ==========================================================================================
# is_signal : True, p_value[295] = 0.17365247440077178
# ==========================================================================================
# is_signal : True, p_value[296] = 0.29166320770258514
# ==========================================================================================
# is_signal : True, p_value[297] = 0.7574988154015794
# ==========================================================================================
# is_signal : True, p_value[298] = 0.4766018493963782
# ==========================================================================================
# is_signal : True, p_value[299] = 0.0893230671435814
# ==========================================================================================
# is_signal : True, p_value[300] = 0.8090381747122806
# ==========================================================================================
# is_signal : True, p_value[301] = 0.043448462056137886
# ==========================================================================================
# is_signal : True, p_value[302] = 0.7386570354060593
# ==========================================================================================
# is_signal : True, p_value[303] = 0.9718525731920089
# ==========================================================================================
# is_signal : True, p_value[304] = 0.14073844573628158
# ==========================================================================================
# is_signal : True, p_value[305] = 0.76481584618639
# ==========================================================================================
# is_signal : True, p_value[306] = 0.015023357554470707
# ==========================================================================================
# is_signal : True, p_value[307] = 0.4790469930216792
# ==========================================================================================
# is_signal : True, p_value[308] = 0.8765181054563305
# ==========================================================================================
# is_signal : True, p_value[309] = 0.06554056218180221
# ==========================================================================================
# is_signal : True, p_value[310] = 0.19798700825450286
# ==========================================================================================
# is_signal : True, p_value[311] = 0.06793806794378976
# ==========================================================================================
# is_signal : True, p_value[312] = 0.698461440227931
# ==========================================================================================
# is_signal : True, p_value[313] = 0.8955159563434114
# ==========================================================================================
# is_signal : True, p_value[314] = 0.5079205942794518
# ==========================================================================================
# is_signal : True, p_value[315] = 0.7439556485574164
# ==========================================================================================
# is_signal : True, p_value[316] = 0.28828337833207884
# ==========================================================================================
# is_signal : True, p_value[317] = 0.08746139964022075
# ==========================================================================================
# is_signal : True, p_value[318] = 0.04637301792609614
# ==========================================================================================
# is_signal : True, p_value[319] = 0.9913162418182911
# ==========================================================================================
# is_signal : True, p_value[320] = 0.5053481947525287
# ==========================================================================================
# is_signal : True, p_value[321] = 0.41389762148658105
# ==========================================================================================
# is_signal : True, p_value[322] = 0.22483768493999035
# ==========================================================================================
# is_signal : True, p_value[323] = 0.10575256827415676
# ==========================================================================================
# is_signal : True, p_value[324] = 0.0877870463383219
# ==========================================================================================
# is_signal : True, p_value[325] = 0.6204365925645234
# ==========================================================================================
# is_signal : True, p_value[326] = 0.07118715755944893
# ==========================================================================================
# is_signal : True, p_value[327] = 0.28383220013407073
# ...
# ==========================================================================================
# is_signal : True, p_value[512] = 0.02282776358106981
# ==========================================================================================
# is_signal : True, p_value[513] = 0.26438251439189364
# ==========================================================================================
# is_signal : True, p_value[514] = 0.7181243775871209
# ==========================================================================================
# is_signal : True, p_value[515] = 0.6772435526019132
# ==========================================================================================
# is_signal : True, p_value[516] = 0.08812354139160372
# ==========================================================================================
# is_signal : True, p_value[517] = 0.7189932410490418
# ==========================================================================================
# is_signal : True, p_value[518] = 0.09394394299337934
# ==========================================================================================
# is_signal : True, p_value[519] = 0.11632617520013633
# ==========================================================================================
# is_signal : True, p_value[520] = 0.10601578861775518
# ==========================================================================================
# is_signal : True, p_value[521] = 0.16900124562222585
# ==========================================================================================
# is_signal : True, p_value[522] = 0.3226449446430503
# ==========================================================================================
# is_signal : True, p_value[523] = 0.015220569842256726
# ==========================================================================================
# is_signal : True, p_value[524] = 0.41406344988707594
# ==========================================================================================
# is_signal : True, p_value[525] = 0.8984046963994883
# ==========================================================================================
# is_signal : True, p_value[526] = 0.5774184605805293
# ==========================================================================================
# is_signal : True, p_value[527] = 0.3913416039943874
# ==========================================================================================
# is_signal : True, p_value[528] = 0.7485876643913423
# ==========================================================================================
# is_signal : True, p_value[529] = 0.14913361260534663
# ==========================================================================================
# is_signal : True, p_value[530] = 0.8027032914012358
# ==========================================================================================
# is_signal : True, p_value[531] = 0.16098544860012812
# ==========================================================================================
# is_signal : True, p_value[532] = 0.6303070540677871
# ==========================================================================================
# is_signal : True, p_value[533] = 0.5872504597529854
# ==========================================================================================
# is_signal : True, p_value[534] = 0.8760242120710674
# ==========================================================================================
# is_signal : True, p_value[535] = 0.26683735047587853
# ==========================================================================================
# is_signal : True, p_value[536] = 0.46731152575763657
# ==========================================================================================
# is_signal : True, p_value[537] = 0.9902204837939239
# ==========================================================================================
# is_signal : True, p_value[538] = 0.15313826046825718
# ==========================================================================================
# is_signal : True, p_value[539] = 0.6001370944561972
# ==========================================================================================
# is_signal : True, p_value[540] = 0.0641943551686075
# ==========================================================================================
# is_signal : True, p_value[541] = 0.8663569028591034
# ==========================================================================================
# is_signal : True, p_value[542] = 0.019781481015751945
# ==========================================================================================
# is_signal : True, p_value[543] = 0.6922514023048281
# ==========================================================================================
# is_signal : True, p_value[544] = 0.4177748445684146
# ==========================================================================================
# is_signal : True, p_value[545] = 0.02886036629502933
# ==========================================================================================
# is_signal : True, p_value[546] = 0.13071045908062806
# ==========================================================================================
# is_signal : True, p_value[547] = 0.029834588499822345
# ==========================================================================================
# is_signal : True, p_value[548] = 0.6648548065217434
# ==========================================================================================
# is_signal : True, p_value[549] = 0.9406474774300908
# ==========================================================================================
# is_signal : True, p_value[550] = 0.09660156868987935
# ==========================================================================================
# is_signal : True, p_value[551] = 0.8345110403439597
# ==========================================================================================
# is_signal : True, p_value[552] = 0.7314203454216557
# ==========================================================================================
# is_signal : True, p_value[553] = 0.12800605441565427
# ==========================================================================================
# is_signal : True, p_value[554] = 0.20330573392200457
# ==========================================================================================
# is_signal : True, p_value[555] = 0.10486181658278637
# ==========================================================================================
# is_signal : True, p_value[556] = 0.3526756070783923
# ==========================================================================================
# is_signal : True, p_value[557] = 0.8495557893184115
# ==========================================================================================
# is_signal : True, p_value[558] = 0.03645615613363986
# ==========================================================================================
# is_signal : True, p_value[559] = 0.5763816480522376
# ==========================================================================================
# is_signal : True, p_value[560] = 0.21930597718385506
# ==========================================================================================
# is_signal : True, p_value[561] = 0.9400089727025859
# ==========================================================================================
# is_signal : True, p_value[562] = 0.08574858532689134
# ==========================================================================================
# is_signal : True, p_value[563] = 0.7139973401875044
# ==========================================================================================
# is_signal : True, p_value[564] = 0.33581600916736504
# ==========================================================================================
# is_signal : True, p_value[565] = 0.05952313774734597
# ==========================================================================================
# is_signal : True, p_value[566] = 0.006140986281776506
# ==========================================================================================
# is_signal : True, p_value[567] = 0.580989181875286
# ==========================================================================================
# is_signal : True, p_value[568] = 0.3111180262771762
# ==========================================================================================
# is_signal : True, p_value[569] = 0.062116250029892406
# ==========================================================================================
# is_signal : True, p_value[570] = 0.7192043946955888
# ==========================================================================================
# is_signal : True, p_value[571] = 0.2822708640144236
# ==========================================================================================
# is_signal : True, p_value[572] = 0.35485415539637377
# ==========================================================================================
# is_signal : True, p_value[573] = 0.12020661999630174
# ==========================================================================================
# is_signal : True, p_value[574] = 0.3446793646882378
# ==========================================================================================
# is_signal : True, p_value[575] = 0.5365889123843912
# ==========================================================================================
# is_signal : True, p_value[576] = 0.34705282895778145
# ==========================================================================================
# is_signal : True, p_value[577] = 0.4451829561103734
# ==========================================================================================
# is_signal : True, p_value[578] = 0.0006293735488729651
# ==========================================================================================
# is_signal : True, p_value[579] = 0.01816413849196718
# ==========================================================================================
# is_signal : True, p_value[580] = 0.9145054142957395
# ==========================================================================================
# is_signal : True, p_value[581] = 0.568621862222757
# ==========================================================================================
# is_signal : True, p_value[582] = 0.15777270675361255
# ==========================================================================================
# is_signal : True, p_value[583] = 0.6161711602999776
# ==========================================================================================
# is_signal : True, p_value[584] = 0.8106857532694447
# ==========================================================================================
# is_signal : True, p_value[585] = 0.9010822778744147
# ==========================================================================================
# is_signal : True, p_value[586] = 0.9127339901256666
# ==========================================================================================
# is_signal : True, p_value[587] = 0.6125529799872648
# ==========================================================================================
# is_signal : True, p_value[588] = 0.039915444464364465
# ==========================================================================================
# is_signal : True, p_value[589] = 0.8526388383597464
# ==========================================================================================
# is_signal : True, p_value[590] = 0.4950484075824122
# ==========================================================================================
# is_signal : True, p_value[591] = 0.35152663549131247
# ==========================================================================================
# is_signal : True, p_value[592] = 0.7927364525145724
# ==========================================================================================
# is_signal : True, p_value[593] = 0.6916695509155003
# ==========================================================================================
# is_signal : True, p_value[594] = 0.16538572297269202
# ==========================================================================================
# is_signal : True, p_value[595] = 0.43886612825149646
# ==========================================================================================
# is_signal : True, p_value[596] = 0.5110990511694173
# ==========================================================================================
# is_signal : True, p_value[597] = 0.38811789972280253
# ==========================================================================================
# is_signal : False, p_value[598] = 0.31867219459102736
# ==========================================================================================
# is_signal : True, p_value[599] = 0.7568239010566524
# ==========================================================================================
# is_signal : True, p_value[600] = 0.3436775779331707
# ==========================================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 18
#      16 for i in range(iteration):
#      17     target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
# ---> 18     result_dict = SI_CoRT.SI_over_conditioning(n_target, p, K, target_data, source_data, T, s_len)
#      20     if result_dict != None:
#      21         if i % 1 == 0:
#
# File c:\Users\Hiep\OneDrive\Desktop\test\Selective_Inference_For_CoRT\SI_CoRT.py:94, in SI_over_conditioning(n_target, p, K, target_data, source_data, T, s_len)
#      90 a_global = (np.eye(n_target) - b_global @ etaj.T) @ y_target
#      92 folds = utils.split_target(T, X_target, y_target, n_target)
# ---> 94 L_base_agu, R_base_agu = over_conditioning.get_Z_base_aug(p, etajTy, folds, source_data, a_global, b_global, K, T)
#      95 L_val, R_val = over_conditioning.get_Z_val(p, folds, T, K, a_global, b_global, etajTy, source_data)
#      96 L_CoRT, R_CoRT, Az = over_conditioning.get_Z_CoRT(p, X_combined, similar_source_index, a_global, b_global, source_data, etajTy)
#
# File c:\Users\Hiep\OneDrive\Desktop\test\Selective_Inference_For_CoRT\over_conditioning.py:36, in get_Z_base_aug(p, z_obs, folds, source_data, a_global, b_global, K, T)
#      33 source_data_k = source_data[k]
#      35 X_aug, a_aug, b_aug = utils.get_affine_params(X_target_train, train_indices, a_global, b_global, source_data_k)
# ---> 36 L_aug, R_aug = solve_interval.compute_lasso_interval(p, X_aug, a_aug, b_aug, z_obs)
#      38 L_final = max(L_final, L_aug)
#      39 R_final = min(R_final, R_aug)
#
# File c:\Users\Hiep\OneDrive\Desktop\test\Selective_Inference_For_CoRT\solve_interval.py:72, in compute_lasso_interval(p_original, X, a, b, z, similar_source_index, source_data)
#      69 s_M = np.sign(clf.coef_[active_indices]).reshape(-1,1)
#      71 P_M = X_M @ np.linalg.pinv(X_M.T @ X_M) @ X_M.T
# ---> 72 u = np.linalg.pinv(X_M.T @ X_M) @ (X_M.T @ a - lamda * s_M)
#      73 v = np.linalg.pinv(X_M.T @ X_M) @ (X_M.T @ b)
#      74 p = (1 / lamda) * X_Mc.T @ (np.eye(n) - P_M) @ a + X_Mc.T @ X_M @ np.linalg.pinv(X_M.T @ X_M) @ s_M
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\linalg\_linalg.py:2256, in pinv(a, rcond, hermitian, rtol)
#    2254     return wrap(res)
#    2255 a = a.conjugate()
# -> 2256 u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    2258 # discard small singular values
#    2259 cutoff = rcond[..., newaxis] * amax(s, axis=-1, keepdims=True)
#
# File c:\Users\Hiep\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\linalg\_linalg.py:1841, in svd(a, full_matrices, compute_uv, hermitian)
#    1837 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
#    1838 with errstate(call=_raise_linalgerror_svd_nonconvergence,
#    1839               invalid='call', over='ignore', divide='ignore',
#    1840               under='ignore'):
# -> 1841     u, s, vh = gufunc(a, signature=signature)
#    1842 u = u.astype(result_t, copy=False)
#    1843 s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
is_signal_cases = [r for r in para_results_storage if r['is_signal']]
not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
print(f"len not_signal_cases : {len(not_signal_cases)}")
print(f"false_positives: {false_positives}")
fpr = false_positives / len(not_signal_cases)
print(f"FPR: {fpr:.4f} (Target: {alpha})")
print("\n")
true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha)
print(f"len not_signal_cases : {len(is_signal_cases)}")
print(f"true_positives: {true_positives}")
tpr = true_positives / len(is_signal_cases)
print(f"TPR: {tpr:.4f}")
# Out:
# len not_signal_cases : 6
# false_positives: 0
# FPR: 0.0000 (Target: 0.05)
#
#
# len not_signal_cases : 595
# true_positives: 43
# TPR: 0.0723
