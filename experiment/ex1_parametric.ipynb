# %%
import numpy as np
import SI_CoRT
import CoRT_builder

# %% [markdown]
# ## Testing p_value

# %%
n_target = 50
n_source = 20
p = 100
K = 5 
Ka = 3
h = 30 
N = n_target + Ka * n_source
lamda_big = np.sqrt(np.log(p)/N) * 2
lamda_small = np.sqrt(np.log(p)/n_target) * 2
alpha = 0.05
T = 5
s_len = 5
s_vector = [0.4] * s_len
para_results_storage = []
CoRT_model = CoRT_builder.CoRT(alpha=lamda_small)
iteration = 1000

for i in range(iteration):
    target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
    result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, lamda_big, lamda_small, T, s_len)
    if result_dict != None:
        if i % 25 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_value[{i}] = {result_dict['p_value']}")
            print("==========================================================================================")
        para_results_storage.append(result_dict)
# Out:
# is_signal : True, p_value[0] = 0.5440588956438036
# ==========================================================================================
# is_signal : True, p_value[25] = 0.44240691007638966
# ==========================================================================================
# is_signal : True, p_value[50] = 0.5132564137350908
# ==========================================================================================
# is_signal : False, p_value[75] = 0.8824149814279936
# ==========================================================================================
# is_signal : True, p_value[100] = 0.008298071590296496
# ==========================================================================================
# is_signal : True, p_value[125] = 0.04289247015677944
# ==========================================================================================
# is_signal : True, p_value[150] = 0.00024573208241851496
# ==========================================================================================
# is_signal : True, p_value[175] = 0.25747950317377644
# ==========================================================================================
# is_signal : True, p_value[200] = 0.09321667744859961
# ==========================================================================================
# is_signal : True, p_value[225] = 0.12350714517466299
# ==========================================================================================
# is_signal : True, p_value[250] = 0.01637171940395432
# ==========================================================================================
# is_signal : True, p_value[275] = 0.051464918518913993
# ==========================================================================================
# is_signal : True, p_value[300] = 0.0006510852478545104
# ==========================================================================================
# is_signal : True, p_value[325] = 1.8937061982748915e-05
# ==========================================================================================
# is_signal : True, p_value[350] = 0.008148172551708077
# ==========================================================================================
# is_signal : True, p_value[375] = 0.004895415995995744
# ==========================================================================================
# is_signal : True, p_value[400] = 0.15848443496624176
# ==========================================================================================
# is_signal : True, p_value[425] = 0.7533743563607783
# ==========================================================================================
# is_signal : True, p_value[450] = 0.0073493424208974645
# ==========================================================================================
# is_signal : True, p_value[475] = 4.1685699536664345e-07
# ==========================================================================================
# is_signal : True, p_value[500] = 2.165499714124053e-05
# ==========================================================================================
# is_signal : True, p_value[525] = 0.02249084789357969
# ==========================================================================================
# is_signal : True, p_value[550] = 0.4210659579218581
# ==========================================================================================
# is_signal : True, p_value[575] = 0.6897175411075207
# ==========================================================================================
# is_signal : False, p_value[600] = 0.9012098424596111
# ==========================================================================================
# is_signal : True, p_value[625] = 0.0015892970769506576
# ==========================================================================================
# is_signal : True, p_value[650] = 0.014024142984054189
# ==========================================================================================
# is_signal : True, p_value[675] = 0.0039786837300581634
# ==========================================================================================
# is_signal : True, p_value[700] = 0.10989284697104185
# ==========================================================================================
# is_signal : True, p_value[725] = 0.04063680686817972
# ==========================================================================================
# is_signal : False, p_value[750] = 0.9444428197332517
# ==========================================================================================
# is_signal : True, p_value[775] = 0.038127052717982
# ==========================================================================================
# is_signal : True, p_value[800] = 0.8513973977048095
# ==========================================================================================
# is_signal : True, p_value[825] = 0.11800704330411382
# ==========================================================================================
# is_signal : True, p_value[850] = 0.002033028000084647
# ==========================================================================================
# is_signal : True, p_value[875] = 0.8939643912067895
# ==========================================================================================
# is_signal : True, p_value[900] = 0.0013537445337126197
# ==========================================================================================
# is_signal : True, p_value[925] = 0.039774248138697565
# ==========================================================================================
# is_signal : True, p_value[950] = 2.9445274707384783e-07
# ==========================================================================================
# is_signal : True, p_value[975] = 0.006323376350636067
# ==========================================================================================

# %% [markdown]
# ## Testing True Positive Rate and False Positive Rate

# %%
is_signal_cases = [r for r in para_results_storage if r['is_signal']]
not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
fpr = false_positives / len(not_signal_cases)
print(f"FPR: {fpr:.4f} (Target: {alpha})")

true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha)
tpr = true_positives / len(is_signal_cases)
print(f"TPR: {tpr:.4f}")
# Out:
# FPR: 0.0404 (Target: 0.05)
# TPR: 0.4784
