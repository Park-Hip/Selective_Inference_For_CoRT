# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
# Đặt giới hạn số luồng xử lý cho mỗi thư viện tính toán về 1
os.environ["OMP_NUM_THREADS"] = "4"
os.environ["MKL_NUM_THREADS"] = "4"
os.environ["OPENBLAS_NUM_THREADS"] = "4"
os.environ["VECLIB_MAXIMUM_THREADS"] = "4"
os.environ["NUMEXPR_NUM_THREADS"] = "4"

# %%
import matplotlib.pyplot as plt
import numpy as np
import ex1_parametric
import os
import CoRT_builder
import SI_CoRT
import datetime
import json

# %%
n_target = 40
n_source = 80
p = 200
K = 7
h = 10
alpha = 0.05
T = 5
s_len = 10
s_vector = [0.5] * s_len

Ka_list = [1, 3, 5, 7]

iteration = 125

for Ka in Ka_list:
    print(f"-- Ka = {Ka} --")
    para_results_storage = []
    CoRT_model = CoRT_builder.CoRT()
    cnt1 = 0
    cnt2 = 0
    cnt3 = 0
    cnt4 = 0

    for i in range(iteration):
        target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
        result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, T, s_len)

        if result_dict != None:
            cnt1 += (result_dict['is_signal'] == True)
            cnt2 += (result_dict['is_signal'] == False)
            cnt3 += (result_dict['is_signal'] == True and result_dict['p_value'] <= alpha)
            cnt4 += (result_dict['is_signal'] == False and result_dict['p_value'] <= alpha)
            
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_values[{i}]: {result_dict['p_value']}")
            print(f"FPR: {cnt4 / cnt2}, TPR: {cnt3 / cnt1}")
            print(f"is_not_signal: {int(cnt2), int(cnt4)}")
            print(f"is_signal: {int(cnt1), int(cnt3)}")
            print("===========================================================================")
                
            para_results_storage.append(result_dict)
    is_signal_cases = [r for r in para_results_storage if r['is_signal']]
    not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

    false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
    fpr = false_positives / len(not_signal_cases) if len(not_signal_cases) != 0 else -1
    true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha) 
    tpr = true_positives / len(is_signal_cases) if len(is_signal_cases) != 0 else -1

    configs = {
        "n_source": n_source,
        "p":  p,
        "K": K,
        "Ka": Ka,
        "h": h,
        "alpha": alpha,
        "T":  T,
        "s_len": s_len,
        "s_vector": s_vector,
        "n_target": n_target,
        "iteration": iteration,
    }

    results = {
        "configs": configs,
        "time": datetime.datetime.now().ctime(),
        "fpr": fpr,
        "tpr": tpr,
        "is_signal_cases": len(is_signal_cases),
        "not_signal_cases": len(not_signal_cases),
        "false_positives": false_positives,
        "true_positives": true_positives
    }

    filename = 'records_4/TPR_parametric_vis_records.json'
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            try:
                records = json.load(f)
            except Exception as e:
                print(e)
                records = []
    else:
        records = []

    records.append(results)

    with open(filename, 'w') as f:
        json.dump(records, f, indent=4)
# Out:
# -- Ka = 1 --
# is_signal : True, p_values[0]: 0.0019015568088861842
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : True, p_values[1]: 0.5727297187422749
# FPR: nan, TPR: 0.5
# is_not_signal: (0, 0)
# is_signal: (2, 1)
# ===========================================================================
# is_signal : False, p_values[2]: 0.34840706019775014
# FPR: 0.0, TPR: 0.5
# is_not_signal: (1, 0)
# is_signal: (2, 1)
# ===========================================================================
# is_signal : False, p_values[3]: 0.32888453768373754
# FPR: 0.0, TPR: 0.5
# is_not_signal: (2, 0)
# is_signal: (2, 1)
# ===========================================================================
# is_signal : False, p_values[4]: 0.4778782706114637
# FPR: 0.0, TPR: 0.5
# is_not_signal: (3, 0)
# is_signal: (2, 1)
# ===========================================================================
# is_signal : True, p_values[5]: 0.4749640477001455
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (3, 0)
# is_signal: (3, 1)
# ===========================================================================
# is_signal : False, p_values[6]: 0.392292304149577
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (4, 0)
# is_signal: (3, 1)
# ===========================================================================
# is_signal : False, p_values[7]: 0.04854417671866099
# FPR: 0.2, TPR: 0.3333333333333333
# is_not_signal: (5, 1)
# is_signal: (3, 1)
# ===========================================================================
# is_signal : True, p_values[8]: 0.7781285033413526
# FPR: 0.2, TPR: 0.25
# is_not_signal: (5, 1)
# is_signal: (4, 1)
# ===========================================================================
# is_signal : False, p_values[9]: 0.7349772553367396
# FPR: 0.16666666666666666, TPR: 0.25
# is_not_signal: (6, 1)
# is_signal: (4, 1)
# ===========================================================================
# is_signal : False, p_values[10]: 0.9378521012444568
# FPR: 0.14285714285714285, TPR: 0.25
# is_not_signal: (7, 1)
# is_signal: (4, 1)
# ===========================================================================
# is_signal : True, p_values[11]: 0.8510573691039123
# FPR: 0.14285714285714285, TPR: 0.2
# is_not_signal: (7, 1)
# is_signal: (5, 1)
# ===========================================================================
# is_signal : True, p_values[12]: 0.013734182816377598
# FPR: 0.14285714285714285, TPR: 0.3333333333333333
# is_not_signal: (7, 1)
# is_signal: (6, 2)
# ===========================================================================
# is_signal : True, p_values[13]: 0.879486173575449
# FPR: 0.14285714285714285, TPR: 0.2857142857142857
# is_not_signal: (7, 1)
# is_signal: (7, 2)
# ===========================================================================
# is_signal : True, p_values[14]: 0.4296497045563079
# FPR: 0.14285714285714285, TPR: 0.25
# is_not_signal: (7, 1)
# is_signal: (8, 2)
# ===========================================================================
# is_signal : True, p_values[15]: 0.13651709720005234
# FPR: 0.14285714285714285, TPR: 0.2222222222222222
# is_not_signal: (7, 1)
# is_signal: (9, 2)
# ===========================================================================
# is_signal : False, p_values[16]: 0.6385023325246864
# FPR: 0.125, TPR: 0.2222222222222222
# is_not_signal: (8, 1)
# is_signal: (9, 2)
# ===========================================================================
# is_signal : True, p_values[17]: 0.13722346909600253
# FPR: 0.125, TPR: 0.2
# is_not_signal: (8, 1)
# is_signal: (10, 2)
# ===========================================================================
# is_signal : True, p_values[18]: 0.1996998039488506
# FPR: 0.125, TPR: 0.18181818181818182
# is_not_signal: (8, 1)
# is_signal: (11, 2)
# ===========================================================================
# is_signal : True, p_values[19]: 0.4718750122360311
# FPR: 0.125, TPR: 0.16666666666666666
# is_not_signal: (8, 1)
# is_signal: (12, 2)
# ===========================================================================
# is_signal : False, p_values[20]: 0.31124996476591116
# FPR: 0.1111111111111111, TPR: 0.16666666666666666
# is_not_signal: (9, 1)
# is_signal: (12, 2)
# ===========================================================================
# is_signal : True, p_values[21]: 0.044955543884094964
# FPR: 0.1111111111111111, TPR: 0.23076923076923078
# is_not_signal: (9, 1)
# is_signal: (13, 3)
# ===========================================================================
# is_signal : False, p_values[22]: 0.14708356051350904
# FPR: 0.1, TPR: 0.23076923076923078
# is_not_signal: (10, 1)
# is_signal: (13, 3)
# ===========================================================================
# is_signal : True, p_values[23]: 0.004310489833992524
# FPR: 0.1, TPR: 0.2857142857142857
# is_not_signal: (10, 1)
# is_signal: (14, 4)
# ===========================================================================
# is_signal : False, p_values[24]: 0.9496705770717452
# FPR: 0.09090909090909091, TPR: 0.2857142857142857
# is_not_signal: (11, 1)
# is_signal: (14, 4)
# ===========================================================================
# is_signal : True, p_values[25]: 0.7721514337215895
# FPR: 0.09090909090909091, TPR: 0.26666666666666666
# is_not_signal: (11, 1)
# is_signal: (15, 4)
# ===========================================================================
# is_signal : True, p_values[26]: 0.20032585861806607
# FPR: 0.09090909090909091, TPR: 0.25
# is_not_signal: (11, 1)
# is_signal: (16, 4)
# ===========================================================================
# is_signal : False, p_values[27]: 0.907796964036712
# FPR: 0.08333333333333333, TPR: 0.25
# is_not_signal: (12, 1)
# is_signal: (16, 4)
# ===========================================================================
# is_signal : False, p_values[28]: 0.49115182097038623
# FPR: 0.07692307692307693, TPR: 0.25
# is_not_signal: (13, 1)
# is_signal: (16, 4)
# ===========================================================================
# is_signal : True, p_values[29]: 0.3695433126811499
# FPR: 0.07692307692307693, TPR: 0.23529411764705882
# is_not_signal: (13, 1)
# is_signal: (17, 4)
# ===========================================================================
# is_signal : False, p_values[30]: 0.45308078901653553
# FPR: 0.07142857142857142, TPR: 0.23529411764705882
# is_not_signal: (14, 1)
# is_signal: (17, 4)
# ===========================================================================
# is_signal : True, p_values[31]: 0.02201852151638206
# FPR: 0.07142857142857142, TPR: 0.2777777777777778
# is_not_signal: (14, 1)
# is_signal: (18, 5)
# ===========================================================================
# is_signal : True, p_values[32]: 0.06697109965686472
# FPR: 0.07142857142857142, TPR: 0.2631578947368421
# is_not_signal: (14, 1)
# is_signal: (19, 5)
# ===========================================================================
# is_signal : False, p_values[33]: 0.29369360368575104
# FPR: 0.06666666666666667, TPR: 0.2631578947368421
# is_not_signal: (15, 1)
# is_signal: (19, 5)
# ===========================================================================
# is_signal : False, p_values[34]: 0.10377977573588483
# FPR: 0.0625, TPR: 0.2631578947368421
# is_not_signal: (16, 1)
# is_signal: (19, 5)
# ===========================================================================
# is_signal : True, p_values[35]: 0.16727647252481678
# FPR: 0.0625, TPR: 0.25
# is_not_signal: (16, 1)
# is_signal: (20, 5)
# ===========================================================================
# is_signal : True, p_values[36]: 0.1454037951648465
# FPR: 0.0625, TPR: 0.23809523809523808
# is_not_signal: (16, 1)
# is_signal: (21, 5)
# ===========================================================================
# is_signal : False, p_values[37]: 0.30374093339507063
# FPR: 0.058823529411764705, TPR: 0.23809523809523808
# is_not_signal: (17, 1)
# is_signal: (21, 5)
# ===========================================================================
# is_signal : False, p_values[38]: 0.9343334043586531
# FPR: 0.05555555555555555, TPR: 0.23809523809523808
# is_not_signal: (18, 1)
# is_signal: (21, 5)
# ===========================================================================
# is_signal : True, p_values[39]: 0.02930727013134331
# FPR: 0.05555555555555555, TPR: 0.2727272727272727
# is_not_signal: (18, 1)
# is_signal: (22, 6)
# ===========================================================================
# is_signal : False, p_values[40]: 0.061108214834456026
# FPR: 0.05263157894736842, TPR: 0.2727272727272727
# is_not_signal: (19, 1)
# is_signal: (22, 6)
# ===========================================================================
# is_signal : False, p_values[41]: 0.26347306961219974
# FPR: 0.05, TPR: 0.2727272727272727
# is_not_signal: (20, 1)
# is_signal: (22, 6)
# ===========================================================================
# is_signal : True, p_values[42]: 0.40691047542235353
# FPR: 0.05, TPR: 0.2608695652173913
# is_not_signal: (20, 1)
# is_signal: (23, 6)
# ===========================================================================
# is_signal : False, p_values[43]: 0.6510328856727143
# FPR: 0.047619047619047616, TPR: 0.2608695652173913
# is_not_signal: (21, 1)
# is_signal: (23, 6)
# ===========================================================================
# is_signal : False, p_values[44]: 0.5920132812586197
# FPR: 0.045454545454545456, TPR: 0.2608695652173913
# is_not_signal: (22, 1)
# is_signal: (23, 6)
# ===========================================================================
# is_signal : True, p_values[45]: 0.007040306738402052
# FPR: 0.045454545454545456, TPR: 0.2916666666666667
# is_not_signal: (22, 1)
# is_signal: (24, 7)
# ===========================================================================
# is_signal : False, p_values[46]: 0.5993705153607645
# FPR: 0.043478260869565216, TPR: 0.2916666666666667
# is_not_signal: (23, 1)
# is_signal: (24, 7)
# ===========================================================================
# is_signal : False, p_values[47]: 0.4191819424782474
# FPR: 0.041666666666666664, TPR: 0.2916666666666667
# is_not_signal: (24, 1)
# is_signal: (24, 7)
# ===========================================================================
# is_signal : False, p_values[48]: 0.955237338538763
# FPR: 0.04, TPR: 0.2916666666666667
# is_not_signal: (25, 1)
# is_signal: (24, 7)
# ===========================================================================
# is_signal : False, p_values[49]: 0.4768532939943983
# FPR: 0.038461538461538464, TPR: 0.2916666666666667
# is_not_signal: (26, 1)
# is_signal: (24, 7)
# ===========================================================================
# is_signal : False, p_values[50]: 0.5866980569790484
# FPR: 0.037037037037037035, TPR: 0.2916666666666667
# is_not_signal: (27, 1)
# is_signal: (24, 7)
# ===========================================================================
# is_signal : True, p_values[51]: 0.01366361492427545
# FPR: 0.037037037037037035, TPR: 0.32
# is_not_signal: (27, 1)
# is_signal: (25, 8)
# ===========================================================================
# is_signal : False, p_values[52]: 0.31585091295499806
# FPR: 0.03571428571428571, TPR: 0.32
# is_not_signal: (28, 1)
# is_signal: (25, 8)
# ===========================================================================
# is_signal : False, p_values[53]: 0.24428932098323533
# FPR: 0.034482758620689655, TPR: 0.32
# is_not_signal: (29, 1)
# is_signal: (25, 8)
# ===========================================================================
# is_signal : False, p_values[54]: 0.3565282563276629
# FPR: 0.03333333333333333, TPR: 0.32
# is_not_signal: (30, 1)
# is_signal: (25, 8)
# ===========================================================================
# is_signal : False, p_values[55]: 0.8672486305342404
# FPR: 0.03225806451612903, TPR: 0.32
# is_not_signal: (31, 1)
# is_signal: (25, 8)
# ===========================================================================
# is_signal : False, p_values[56]: 0.04447912197858209
# FPR: 0.0625, TPR: 0.32
# is_not_signal: (32, 2)
# is_signal: (25, 8)
# ===========================================================================
# is_signal : True, p_values[57]: 0.31705865501392455
# FPR: 0.0625, TPR: 0.3076923076923077
# is_not_signal: (32, 2)
# is_signal: (26, 8)
# ===========================================================================
# is_signal : True, p_values[58]: 0.7848486698371082
# FPR: 0.0625, TPR: 0.2962962962962963
# is_not_signal: (32, 2)
# is_signal: (27, 8)
# ===========================================================================
# is_signal : False, p_values[59]: 0.9131718554435414
# FPR: 0.06060606060606061, TPR: 0.2962962962962963
# is_not_signal: (33, 2)
# is_signal: (27, 8)
# ===========================================================================
# is_signal : True, p_values[60]: 0.18991322382266088
# FPR: 0.06060606060606061, TPR: 0.2857142857142857
# is_not_signal: (33, 2)
# is_signal: (28, 8)
# ===========================================================================
# is_signal : False, p_values[61]: 0.32537217640665617
# FPR: 0.058823529411764705, TPR: 0.2857142857142857
# is_not_signal: (34, 2)
# is_signal: (28, 8)
# ===========================================================================
# is_signal : True, p_values[62]: 0.9187536325586961
# FPR: 0.058823529411764705, TPR: 0.27586206896551724
# is_not_signal: (34, 2)
# is_signal: (29, 8)
# ===========================================================================
# is_signal : False, p_values[63]: 0.7091780055150881
# FPR: 0.05714285714285714, TPR: 0.27586206896551724
# is_not_signal: (35, 2)
# is_signal: (29, 8)
# ===========================================================================
# is_signal : True, p_values[64]: 0.016957732592634972
# FPR: 0.05714285714285714, TPR: 0.3
# is_not_signal: (35, 2)
# is_signal: (30, 9)
# ===========================================================================
# is_signal : False, p_values[65]: 0.952700466564665
# FPR: 0.05555555555555555, TPR: 0.3
# is_not_signal: (36, 2)
# is_signal: (30, 9)
# ===========================================================================
# is_signal : True, p_values[66]: 0.6068152069555981
# FPR: 0.05555555555555555, TPR: 0.2903225806451613
# is_not_signal: (36, 2)
# is_signal: (31, 9)
# ===========================================================================
# is_signal : False, p_values[67]: 0.5508871764243032
# FPR: 0.05405405405405406, TPR: 0.2903225806451613
# is_not_signal: (37, 2)
# is_signal: (31, 9)
# ===========================================================================
# is_signal : True, p_values[68]: 0.5556303895478613
# FPR: 0.05405405405405406, TPR: 0.28125
# is_not_signal: (37, 2)
# is_signal: (32, 9)
# ===========================================================================
# is_signal : False, p_values[69]: 0.919667574690367
# FPR: 0.05263157894736842, TPR: 0.28125
# is_not_signal: (38, 2)
# is_signal: (32, 9)
# ===========================================================================
# is_signal : True, p_values[70]: 0.2831180202434677
# FPR: 0.05263157894736842, TPR: 0.2727272727272727
# is_not_signal: (38, 2)
# is_signal: (33, 9)
# ===========================================================================
# is_signal : False, p_values[71]: 0.2193624251987399
# FPR: 0.05128205128205128, TPR: 0.2727272727272727
# is_not_signal: (39, 2)
# is_signal: (33, 9)
# ===========================================================================
# is_signal : False, p_values[72]: 0.5185355828048961
# FPR: 0.05, TPR: 0.2727272727272727
# is_not_signal: (40, 2)
# is_signal: (33, 9)
# ===========================================================================
# is_signal : True, p_values[73]: 0.0008200133076163137
# FPR: 0.05, TPR: 0.29411764705882354
# is_not_signal: (40, 2)
# is_signal: (34, 10)
# ===========================================================================
# is_signal : True, p_values[74]: 0.004792730765396562
# FPR: 0.05, TPR: 0.3142857142857143
# is_not_signal: (40, 2)
# is_signal: (35, 11)
# ===========================================================================
# is_signal : False, p_values[75]: 0.6846766023533647
# FPR: 0.04878048780487805, TPR: 0.3142857142857143
# is_not_signal: (41, 2)
# is_signal: (35, 11)
# ===========================================================================
# is_signal : True, p_values[76]: 0.40016741941628453
# FPR: 0.04878048780487805, TPR: 0.3055555555555556
# is_not_signal: (41, 2)
# is_signal: (36, 11)
# ===========================================================================
# is_signal : True, p_values[77]: 0.6057949962556124
# FPR: 0.04878048780487805, TPR: 0.2972972972972973
# is_not_signal: (41, 2)
# is_signal: (37, 11)
# ===========================================================================
# is_signal : True, p_values[78]: 0.023580658233554437
# FPR: 0.04878048780487805, TPR: 0.3157894736842105
# is_not_signal: (41, 2)
# is_signal: (38, 12)
# ===========================================================================
# is_signal : True, p_values[79]: 0.865041947086274
# FPR: 0.04878048780487805, TPR: 0.3076923076923077
# is_not_signal: (41, 2)
# is_signal: (39, 12)
# ===========================================================================
# is_signal : True, p_values[80]: 0.7745686706129871
# FPR: 0.04878048780487805, TPR: 0.3
# is_not_signal: (41, 2)
# is_signal: (40, 12)
# ===========================================================================
# is_signal : True, p_values[81]: 0.7420326840529224
# FPR: 0.04878048780487805, TPR: 0.2926829268292683
# is_not_signal: (41, 2)
# is_signal: (41, 12)
# ===========================================================================
# is_signal : True, p_values[82]: 0.000645857879559591
# FPR: 0.04878048780487805, TPR: 0.30952380952380953
# is_not_signal: (41, 2)
# is_signal: (42, 13)
# ===========================================================================
# is_signal : False, p_values[83]: 0.01077969850041004
# FPR: 0.07142857142857142, TPR: 0.30952380952380953
# is_not_signal: (42, 3)
# is_signal: (42, 13)
# ===========================================================================
# is_signal : False, p_values[84]: 0.34607312024546516
# FPR: 0.06976744186046512, TPR: 0.30952380952380953
# is_not_signal: (43, 3)
# is_signal: (42, 13)
# ===========================================================================
# is_signal : False, p_values[85]: 0.7048365101848201
# FPR: 0.06818181818181818, TPR: 0.30952380952380953
# is_not_signal: (44, 3)
# is_signal: (42, 13)
# ===========================================================================
# is_signal : False, p_values[86]: 0.28833616926335337
# FPR: 0.06666666666666667, TPR: 0.30952380952380953
# is_not_signal: (45, 3)
# is_signal: (42, 13)
# ===========================================================================
# is_signal : True, p_values[87]: 0.5531082225278888
# FPR: 0.06666666666666667, TPR: 0.3023255813953488
# is_not_signal: (45, 3)
# is_signal: (43, 13)
# ===========================================================================
# is_signal : False, p_values[88]: 0.5294888283735103
# FPR: 0.06521739130434782, TPR: 0.3023255813953488
# is_not_signal: (46, 3)
# is_signal: (43, 13)
# ===========================================================================
# is_signal : True, p_values[89]: 0.8181830919397616
# FPR: 0.06521739130434782, TPR: 0.29545454545454547
# is_not_signal: (46, 3)
# is_signal: (44, 13)
# ===========================================================================
# is_signal : True, p_values[90]: 0.06713302786464856
# FPR: 0.06521739130434782, TPR: 0.28888888888888886
# is_not_signal: (46, 3)
# is_signal: (45, 13)
# ===========================================================================
# is_signal : True, p_values[91]: 0.1003122977954044
# FPR: 0.06521739130434782, TPR: 0.2826086956521739
# is_not_signal: (46, 3)
# is_signal: (46, 13)
# ===========================================================================
# is_signal : True, p_values[92]: 0.2484191151476204
# FPR: 0.06521739130434782, TPR: 0.2765957446808511
# is_not_signal: (46, 3)
# is_signal: (47, 13)
# ===========================================================================
# is_signal : True, p_values[93]: 0.2651924214518036
# FPR: 0.06521739130434782, TPR: 0.2708333333333333
# is_not_signal: (46, 3)
# is_signal: (48, 13)
# ===========================================================================
# is_signal : False, p_values[94]: 0.9014663589368573
# FPR: 0.06382978723404255, TPR: 0.2708333333333333
# is_not_signal: (47, 3)
# is_signal: (48, 13)
# ===========================================================================
# is_signal : False, p_values[95]: 0.29345947950387097
# FPR: 0.0625, TPR: 0.2708333333333333
# is_not_signal: (48, 3)
# is_signal: (48, 13)
# ===========================================================================
# is_signal : True, p_values[96]: 0.08711809187459799
# FPR: 0.0625, TPR: 0.2653061224489796
# is_not_signal: (48, 3)
# is_signal: (49, 13)
# ===========================================================================
# is_signal : True, p_values[97]: 0.0732811069602743
# FPR: 0.0625, TPR: 0.26
# is_not_signal: (48, 3)
# is_signal: (50, 13)
# ===========================================================================
# is_signal : False, p_values[98]: 0.7848682684525236
# FPR: 0.061224489795918366, TPR: 0.26
# is_not_signal: (49, 3)
# is_signal: (50, 13)
# ===========================================================================
# is_signal : True, p_values[99]: 0.9281264501038449
# FPR: 0.061224489795918366, TPR: 0.2549019607843137
# is_not_signal: (49, 3)
# is_signal: (51, 13)
# ===========================================================================
# is_signal : True, p_values[100]: 0.03110202567397928
# FPR: 0.061224489795918366, TPR: 0.2692307692307692
# is_not_signal: (49, 3)
# is_signal: (52, 14)
# ===========================================================================
# is_signal : True, p_values[101]: 0.5075408209004811
# FPR: 0.061224489795918366, TPR: 0.2641509433962264
# is_not_signal: (49, 3)
# is_signal: (53, 14)
# ===========================================================================
# is_signal : True, p_values[102]: 0.22848743123033155
# FPR: 0.061224489795918366, TPR: 0.25925925925925924
# is_not_signal: (49, 3)
# is_signal: (54, 14)
# ===========================================================================
# is_signal : True, p_values[103]: 0.5680931050896187
# FPR: 0.061224489795918366, TPR: 0.2545454545454545
# is_not_signal: (49, 3)
# is_signal: (55, 14)
# ===========================================================================
# is_signal : False, p_values[104]: 0.47571286211410724
# FPR: 0.06, TPR: 0.2545454545454545
# is_not_signal: (50, 3)
# is_signal: (55, 14)
# ===========================================================================
# is_signal : True, p_values[105]: 0.1531506639777568
# FPR: 0.06, TPR: 0.25
# is_not_signal: (50, 3)
# is_signal: (56, 14)
# ===========================================================================
# is_signal : True, p_values[106]: 0.0035385160907712124
# FPR: 0.06, TPR: 0.2631578947368421
# is_not_signal: (50, 3)
# is_signal: (57, 15)
# ===========================================================================
# is_signal : False, p_values[107]: 0.17105805035122057
# FPR: 0.058823529411764705, TPR: 0.2631578947368421
# is_not_signal: (51, 3)
# is_signal: (57, 15)
# ===========================================================================
# is_signal : True, p_values[108]: 0.08202290763595863
# FPR: 0.058823529411764705, TPR: 0.25862068965517243
# is_not_signal: (51, 3)
# is_signal: (58, 15)
# ===========================================================================
# is_signal : False, p_values[109]: 0.010330021392309041
# FPR: 0.07692307692307693, TPR: 0.25862068965517243
# is_not_signal: (52, 4)
# is_signal: (58, 15)
# ===========================================================================
# is_signal : True, p_values[110]: 0.04036249468014574
# FPR: 0.07692307692307693, TPR: 0.2711864406779661
# is_not_signal: (52, 4)
# is_signal: (59, 16)
# ===========================================================================
# is_signal : False, p_values[111]: 0.6239947220024993
# FPR: 0.07547169811320754, TPR: 0.2711864406779661
# is_not_signal: (53, 4)
# is_signal: (59, 16)
# ===========================================================================
# is_signal : False, p_values[112]: 0.6935578951083552
# FPR: 0.07407407407407407, TPR: 0.2711864406779661
# is_not_signal: (54, 4)
# is_signal: (59, 16)
# ===========================================================================
# is_signal : False, p_values[113]: 0.281322976711338
# FPR: 0.07272727272727272, TPR: 0.2711864406779661
# is_not_signal: (55, 4)
# is_signal: (59, 16)
# ===========================================================================
# is_signal : False, p_values[114]: 0.6310931314672353
# FPR: 0.07142857142857142, TPR: 0.2711864406779661
# is_not_signal: (56, 4)
# is_signal: (59, 16)
# ===========================================================================
# is_signal : True, p_values[115]: 0.030050631813061442
# FPR: 0.07142857142857142, TPR: 0.2833333333333333
# is_not_signal: (56, 4)
# is_signal: (60, 17)
# ===========================================================================
# is_signal : True, p_values[116]: 0.020668596207541017
# FPR: 0.07142857142857142, TPR: 0.29508196721311475
# is_not_signal: (56, 4)
# is_signal: (61, 18)
# ===========================================================================
# is_signal : True, p_values[117]: 0.0820483316691415
# FPR: 0.07142857142857142, TPR: 0.2903225806451613
# is_not_signal: (56, 4)
# is_signal: (62, 18)
# ===========================================================================
# is_signal : True, p_values[118]: 0.00332910511730557
# FPR: 0.07142857142857142, TPR: 0.30158730158730157
# is_not_signal: (56, 4)
# is_signal: (63, 19)
# ===========================================================================
# is_signal : True, p_values[119]: 0.013932320114519139
# FPR: 0.07142857142857142, TPR: 0.3125
# is_not_signal: (56, 4)
# is_signal: (64, 20)
# ===========================================================================
# is_signal : True, p_values[120]: 0.23699344191807803
# FPR: 0.07142857142857142, TPR: 0.3076923076923077
# is_not_signal: (56, 4)
# is_signal: (65, 20)
# ===========================================================================
# is_signal : False, p_values[121]: 0.05516725821124525
# FPR: 0.07017543859649122, TPR: 0.3076923076923077
# is_not_signal: (57, 4)
# is_signal: (65, 20)
# ===========================================================================
# is_signal : False, p_values[122]: 0.16610998560300905
# FPR: 0.06896551724137931, TPR: 0.3076923076923077
# is_not_signal: (58, 4)
# is_signal: (65, 20)
# ===========================================================================
# is_signal : True, p_values[123]: 0.057325473491784386
# FPR: 0.06896551724137931, TPR: 0.30303030303030304
# is_not_signal: (58, 4)
# is_signal: (66, 20)
# ===========================================================================
# is_signal : True, p_values[124]: 0.9936926831756175
# FPR: 0.06896551724137931, TPR: 0.29850746268656714
# is_not_signal: (58, 4)
# is_signal: (67, 20)
# ===========================================================================
# -- Ka = 3 --
# is_signal : True, p_values[0]: 0.08219550507492321
# FPR: nan, TPR: 0.0
# is_not_signal: (0, 0)
# is_signal: (1, 0)
# ===========================================================================
# is_signal : True, p_values[1]: 0.5337243672638717
# FPR: nan, TPR: 0.0
# is_not_signal: (0, 0)
# is_signal: (2, 0)
# ===========================================================================
# is_signal : True, p_values[2]: 0.06850776499256234
# FPR: nan, TPR: 0.0
# is_not_signal: (0, 0)
# is_signal: (3, 0)
# ===========================================================================
# is_signal : True, p_values[3]: 0.19323568825838094
# FPR: nan, TPR: 0.0
# is_not_signal: (0, 0)
# is_signal: (4, 0)
# ===========================================================================
# is_signal : True, p_values[4]: 0.020659989872143812
# FPR: nan, TPR: 0.2
# is_not_signal: (0, 0)
# is_signal: (5, 1)
# ===========================================================================
# is_signal : False, p_values[5]: 0.25102578658109403
# FPR: 0.0, TPR: 0.2
# is_not_signal: (1, 0)
# is_signal: (5, 1)
# ===========================================================================
# is_signal : False, p_values[6]: 0.2284108032778409
# FPR: 0.0, TPR: 0.2
# is_not_signal: (2, 0)
# is_signal: (5, 1)
# ===========================================================================
# is_signal : True, p_values[7]: 0.005040609093022463
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (2, 0)
# is_signal: (6, 2)
# ===========================================================================
# is_signal : False, p_values[8]: 0.21412529100985214
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (3, 0)
# is_signal: (6, 2)
# ===========================================================================
# is_signal : False, p_values[9]: 0.07940540630076079
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (4, 0)
# is_signal: (6, 2)
# ===========================================================================
# is_signal : True, p_values[10]: 0.16795562453040122
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (4, 0)
# is_signal: (7, 2)
# ===========================================================================
# is_signal : False, p_values[11]: 0.5108032418811452
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (5, 0)
# is_signal: (7, 2)
# ===========================================================================
# is_signal : False, p_values[12]: 0.9781822935023772
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (6, 0)
# is_signal: (7, 2)
# ===========================================================================
# is_signal : False, p_values[13]: 0.3692783871874329
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (7, 0)
# is_signal: (7, 2)
# ===========================================================================
# is_signal : False, p_values[14]: 0.6712552433065785
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (8, 0)
# is_signal: (7, 2)
# ===========================================================================
# is_signal : True, p_values[15]: 0.02277098671518469
# FPR: 0.0, TPR: 0.375
# is_not_signal: (8, 0)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : True, p_values[16]: 4.29021361926496e-05
# FPR: 0.0, TPR: 0.4444444444444444
# is_not_signal: (8, 0)
# is_signal: (9, 4)
# ===========================================================================
# is_signal : False, p_values[17]: 0.3750485700343691
# FPR: 0.0, TPR: 0.4444444444444444
# is_not_signal: (9, 0)
# is_signal: (9, 4)
# ===========================================================================
# is_signal : True, p_values[18]: 0.362791938190665
# FPR: 0.0, TPR: 0.4
# is_not_signal: (9, 0)
# is_signal: (10, 4)
# ===========================================================================
# is_signal : True, p_values[19]: 0.16017010410208707
# FPR: 0.0, TPR: 0.36363636363636365
# is_not_signal: (9, 0)
# is_signal: (11, 4)
# ===========================================================================
# is_signal : False, p_values[20]: 0.9682722365826457
# FPR: 0.0, TPR: 0.36363636363636365
# is_not_signal: (10, 0)
# is_signal: (11, 4)
# ===========================================================================
# is_signal : False, p_values[21]: 0.5640421774470661
# FPR: 0.0, TPR: 0.36363636363636365
# is_not_signal: (11, 0)
# is_signal: (11, 4)
# ===========================================================================
# is_signal : True, p_values[22]: 0.00852685789735495
# FPR: 0.0, TPR: 0.4166666666666667
# is_not_signal: (11, 0)
# is_signal: (12, 5)
# ===========================================================================
# is_signal : False, p_values[23]: 0.5576594294234709
# FPR: 0.0, TPR: 0.4166666666666667
# is_not_signal: (12, 0)
# is_signal: (12, 5)
# ===========================================================================
# is_signal : True, p_values[24]: 0.036484942551530355
# FPR: 0.0, TPR: 0.46153846153846156
# is_not_signal: (12, 0)
# is_signal: (13, 6)
# ===========================================================================
# is_signal : True, p_values[25]: 0.08889268016568468
# FPR: 0.0, TPR: 0.42857142857142855
# is_not_signal: (12, 0)
# is_signal: (14, 6)
# ===========================================================================
# is_signal : True, p_values[26]: 0.7346098376441492
# FPR: 0.0, TPR: 0.4
# is_not_signal: (12, 0)
# is_signal: (15, 6)
# ===========================================================================
# is_signal : False, p_values[27]: 0.6117636003290543
# FPR: 0.0, TPR: 0.4
# is_not_signal: (13, 0)
# is_signal: (15, 6)
# ===========================================================================
# is_signal : False, p_values[28]: 0.9905404688821088
# FPR: 0.0, TPR: 0.4
# is_not_signal: (14, 0)
# is_signal: (15, 6)
# ===========================================================================
# is_signal : True, p_values[29]: 0.9601039919602811
# FPR: 0.0, TPR: 0.375
# is_not_signal: (14, 0)
# is_signal: (16, 6)
# ===========================================================================
# is_signal : True, p_values[30]: 0.8084303549724746
# FPR: 0.0, TPR: 0.35294117647058826
# is_not_signal: (14, 0)
# is_signal: (17, 6)
# ===========================================================================
# is_signal : True, p_values[31]: 0.8155732363579407
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (14, 0)
# is_signal: (18, 6)
# ===========================================================================
# is_signal : True, p_values[32]: 0.00031037882494744444
# FPR: 0.0, TPR: 0.3684210526315789
# is_not_signal: (14, 0)
# is_signal: (19, 7)
# ===========================================================================
# is_signal : True, p_values[33]: 0.02138676443853291
# FPR: 0.0, TPR: 0.4
# is_not_signal: (14, 0)
# is_signal: (20, 8)
# ===========================================================================
# is_signal : True, p_values[34]: 0.1108260012923563
# FPR: 0.0, TPR: 0.38095238095238093
# is_not_signal: (14, 0)
# is_signal: (21, 8)
# ===========================================================================
# is_signal : True, p_values[35]: 0.005096448567631975
# FPR: 0.0, TPR: 0.4090909090909091
# is_not_signal: (14, 0)
# is_signal: (22, 9)
# ===========================================================================
# is_signal : False, p_values[36]: 0.6705517262144468
# FPR: 0.0, TPR: 0.4090909090909091
# is_not_signal: (15, 0)
# is_signal: (22, 9)
# ===========================================================================
# is_signal : False, p_values[37]: 0.9071301715209072
# FPR: 0.0, TPR: 0.4090909090909091
# is_not_signal: (16, 0)
# is_signal: (22, 9)
# ===========================================================================
# is_signal : False, p_values[38]: 0.6850690057755889
# FPR: 0.0, TPR: 0.4090909090909091
# is_not_signal: (17, 0)
# is_signal: (22, 9)
# ===========================================================================
# is_signal : False, p_values[39]: 0.5863624563119869
# FPR: 0.0, TPR: 0.4090909090909091
# is_not_signal: (18, 0)
# is_signal: (22, 9)
# ===========================================================================
# is_signal : False, p_values[40]: 0.1359070856541718
# FPR: 0.0, TPR: 0.4090909090909091
# is_not_signal: (19, 0)
# is_signal: (22, 9)
# ===========================================================================
# is_signal : True, p_values[41]: 0.07992543917519096
# FPR: 0.0, TPR: 0.391304347826087
# is_not_signal: (19, 0)
# is_signal: (23, 9)
# ===========================================================================
# is_signal : False, p_values[42]: 0.34265543011259586
# FPR: 0.0, TPR: 0.391304347826087
# is_not_signal: (20, 0)
# is_signal: (23, 9)
# ===========================================================================
# is_signal : True, p_values[43]: 0.2052413804573541
# FPR: 0.0, TPR: 0.375
# is_not_signal: (20, 0)
# is_signal: (24, 9)
# ===========================================================================
# is_signal : True, p_values[44]: 0.8716941584908503
# FPR: 0.0, TPR: 0.36
# is_not_signal: (20, 0)
# is_signal: (25, 9)
# ===========================================================================
# is_signal : True, p_values[45]: 0.12153980214645556
# FPR: 0.0, TPR: 0.34615384615384615
# is_not_signal: (20, 0)
# is_signal: (26, 9)
# ===========================================================================
# is_signal : True, p_values[46]: 0.0006488965360421464
# FPR: 0.0, TPR: 0.37037037037037035
# is_not_signal: (20, 0)
# is_signal: (27, 10)
# ===========================================================================
# is_signal : True, p_values[47]: 0.5537701354988255
# FPR: 0.0, TPR: 0.35714285714285715
# is_not_signal: (20, 0)
# is_signal: (28, 10)
# ===========================================================================
# is_signal : True, p_values[48]: 0.9361160990284182
# FPR: 0.0, TPR: 0.3448275862068966
# is_not_signal: (20, 0)
# is_signal: (29, 10)
# ===========================================================================
# is_signal : True, p_values[49]: 0.057513354127382524
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (20, 0)
# is_signal: (30, 10)
# ===========================================================================
# is_signal : False, p_values[50]: 0.8047437844917245
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (21, 0)
# is_signal: (30, 10)
# ===========================================================================
# is_signal : True, p_values[51]: 0.10006634039402196
# FPR: 0.0, TPR: 0.3225806451612903
# is_not_signal: (21, 0)
# is_signal: (31, 10)
# ===========================================================================
# is_signal : True, p_values[52]: 0.2318119516275528
# FPR: 0.0, TPR: 0.3125
# is_not_signal: (21, 0)
# is_signal: (32, 10)
# ===========================================================================
# is_signal : False, p_values[53]: 0.8918262257099479
# FPR: 0.0, TPR: 0.3125
# is_not_signal: (22, 0)
# is_signal: (32, 10)
# ===========================================================================
# is_signal : True, p_values[54]: 0.00047926378818587156
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (22, 0)
# is_signal: (33, 11)
# ===========================================================================
# is_signal : False, p_values[55]: 0.6990462833854778
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (23, 0)
# is_signal: (33, 11)
# ===========================================================================
# is_signal : True, p_values[56]: 0.6410293991071084
# FPR: 0.0, TPR: 0.3235294117647059
# is_not_signal: (23, 0)
# is_signal: (34, 11)
# ===========================================================================
# is_signal : False, p_values[57]: 0.6852964391613451
# FPR: 0.0, TPR: 0.3235294117647059
# is_not_signal: (24, 0)
# is_signal: (34, 11)
# ===========================================================================
# is_signal : True, p_values[58]: 0.23818548590302638
# FPR: 0.0, TPR: 0.3142857142857143
# is_not_signal: (24, 0)
# is_signal: (35, 11)
# ===========================================================================
# is_signal : True, p_values[59]: 0.005827135928987946
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (24, 0)
# is_signal: (36, 12)
# ===========================================================================
# is_signal : False, p_values[60]: 0.8466867172698238
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (25, 0)
# is_signal: (36, 12)
# ===========================================================================
# is_signal : False, p_values[61]: 0.4756708182499675
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (26, 0)
# is_signal: (36, 12)
# ===========================================================================
# is_signal : True, p_values[62]: 0.16443430093708175
# FPR: 0.0, TPR: 0.32432432432432434
# is_not_signal: (26, 0)
# is_signal: (37, 12)
# ===========================================================================
# is_signal : True, p_values[63]: 0.01201682644671451
# FPR: 0.0, TPR: 0.34210526315789475
# is_not_signal: (26, 0)
# is_signal: (38, 13)
# ===========================================================================
# is_signal : True, p_values[64]: 0.17946078381055391
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (26, 0)
# is_signal: (39, 13)
# ===========================================================================
# is_signal : True, p_values[65]: 0.0017698425001592502
# FPR: 0.0, TPR: 0.35
# is_not_signal: (26, 0)
# is_signal: (40, 14)
# ===========================================================================
# is_signal : True, p_values[66]: 0.5319738042937402
# FPR: 0.0, TPR: 0.34146341463414637
# is_not_signal: (26, 0)
# is_signal: (41, 14)
# ===========================================================================
# is_signal : True, p_values[67]: 0.2084441775460446
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (26, 0)
# is_signal: (42, 14)
# ===========================================================================
# is_signal : True, p_values[68]: 0.8227256812333392
# FPR: 0.0, TPR: 0.32558139534883723
# is_not_signal: (26, 0)
# is_signal: (43, 14)
# ===========================================================================
# is_signal : False, p_values[69]: 0.29859146219976174
# FPR: 0.0, TPR: 0.32558139534883723
# is_not_signal: (27, 0)
# is_signal: (43, 14)
# ===========================================================================
# is_signal : True, p_values[70]: 0.12824423769884474
# FPR: 0.0, TPR: 0.3181818181818182
# is_not_signal: (27, 0)
# is_signal: (44, 14)
# ===========================================================================
# is_signal : True, p_values[71]: 0.31296163062523524
# FPR: 0.0, TPR: 0.3111111111111111
# is_not_signal: (27, 0)
# is_signal: (45, 14)
# ===========================================================================
# is_signal : False, p_values[72]: 0.5417856076633962
# FPR: 0.0, TPR: 0.3111111111111111
# is_not_signal: (28, 0)
# is_signal: (45, 14)
# ===========================================================================
# is_signal : True, p_values[73]: 0.06050022805073373
# FPR: 0.0, TPR: 0.30434782608695654
# is_not_signal: (28, 0)
# is_signal: (46, 14)
# ===========================================================================
# is_signal : True, p_values[74]: 0.7009988900352793
# FPR: 0.0, TPR: 0.2978723404255319
# is_not_signal: (28, 0)
# is_signal: (47, 14)
# ===========================================================================
# is_signal : True, p_values[75]: 0.40670916576133503
# FPR: 0.0, TPR: 0.2916666666666667
# is_not_signal: (28, 0)
# is_signal: (48, 14)
# ===========================================================================
# is_signal : True, p_values[76]: 0.7321679570541114
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (28, 0)
# is_signal: (49, 14)
# ===========================================================================
# is_signal : True, p_values[77]: 1.8153968305694026e-05
# FPR: 0.0, TPR: 0.3
# is_not_signal: (28, 0)
# is_signal: (50, 15)
# ===========================================================================
# is_signal : True, p_values[78]: 0.7465559466909596
# FPR: 0.0, TPR: 0.29411764705882354
# is_not_signal: (28, 0)
# is_signal: (51, 15)
# ===========================================================================
# is_signal : False, p_values[79]: 0.16875169430007736
# FPR: 0.0, TPR: 0.29411764705882354
# is_not_signal: (29, 0)
# is_signal: (51, 15)
# ===========================================================================
# is_signal : False, p_values[80]: 0.2813621767632774
# FPR: 0.0, TPR: 0.29411764705882354
# is_not_signal: (30, 0)
# is_signal: (51, 15)
# ===========================================================================
# is_signal : False, p_values[81]: 0.41594169175208634
# FPR: 0.0, TPR: 0.29411764705882354
# is_not_signal: (31, 0)
# is_signal: (51, 15)
# ===========================================================================
# is_signal : True, p_values[82]: 0.21832986746935096
# FPR: 0.0, TPR: 0.28846153846153844
# is_not_signal: (31, 0)
# is_signal: (52, 15)
# ===========================================================================
# is_signal : True, p_values[83]: 0.15904984509888673
# FPR: 0.0, TPR: 0.2830188679245283
# is_not_signal: (31, 0)
# is_signal: (53, 15)
# ===========================================================================
# is_signal : True, p_values[84]: 0.09766601776227299
# FPR: 0.0, TPR: 0.2777777777777778
# is_not_signal: (31, 0)
# is_signal: (54, 15)
# ===========================================================================
# is_signal : False, p_values[85]: 0.7391363063490333
# FPR: 0.0, TPR: 0.2777777777777778
# is_not_signal: (32, 0)
# is_signal: (54, 15)
# ===========================================================================
# is_signal : True, p_values[86]: 0.04525854995279386
# FPR: 0.0, TPR: 0.2909090909090909
# is_not_signal: (32, 0)
# is_signal: (55, 16)
# ===========================================================================
# is_signal : True, p_values[87]: 0.18823686533308912
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (32, 0)
# is_signal: (56, 16)
# ===========================================================================
# is_signal : False, p_values[88]: 0.718223246596936
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (33, 0)
# is_signal: (56, 16)
# ===========================================================================
# is_signal : False, p_values[89]: 0.9926292801030051
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (34, 0)
# is_signal: (56, 16)
# ===========================================================================
# is_signal : True, p_values[90]: 0.19858475985777002
# FPR: 0.0, TPR: 0.2807017543859649
# is_not_signal: (34, 0)
# is_signal: (57, 16)
# ===========================================================================
# is_signal : False, p_values[91]: 0.2739927053612305
# FPR: 0.0, TPR: 0.2807017543859649
# is_not_signal: (35, 0)
# is_signal: (57, 16)
# ===========================================================================
# is_signal : True, p_values[92]: 0.11126330408332975
# FPR: 0.0, TPR: 0.27586206896551724
# is_not_signal: (35, 0)
# is_signal: (58, 16)
# ===========================================================================
# is_signal : False, p_values[93]: 0.7014186150668328
# FPR: 0.0, TPR: 0.27586206896551724
# is_not_signal: (36, 0)
# is_signal: (58, 16)
# ===========================================================================
# is_signal : False, p_values[94]: 0.7773064727630115
# FPR: 0.0, TPR: 0.27586206896551724
# is_not_signal: (37, 0)
# is_signal: (58, 16)
# ===========================================================================
# is_signal : False, p_values[95]: 0.2744991733193215
# FPR: 0.0, TPR: 0.27586206896551724
# is_not_signal: (38, 0)
# is_signal: (58, 16)
# ===========================================================================
# is_signal : True, p_values[96]: 0.23811219263314742
# FPR: 0.0, TPR: 0.2711864406779661
# is_not_signal: (38, 0)
# is_signal: (59, 16)
# ===========================================================================
# is_signal : False, p_values[97]: 0.8465465588321018
# FPR: 0.0, TPR: 0.2711864406779661
# is_not_signal: (39, 0)
# is_signal: (59, 16)
# ===========================================================================
# is_signal : True, p_values[98]: 0.03531209027197494
# FPR: 0.0, TPR: 0.2833333333333333
# is_not_signal: (39, 0)
# is_signal: (60, 17)
# ===========================================================================
# is_signal : False, p_values[99]: 0.8257565963333426
# FPR: 0.0, TPR: 0.2833333333333333
# is_not_signal: (40, 0)
# is_signal: (60, 17)
# ===========================================================================
# is_signal : True, p_values[100]: 0.11871933965145011
# FPR: 0.0, TPR: 0.2786885245901639
# is_not_signal: (40, 0)
# is_signal: (61, 17)
# ===========================================================================
# is_signal : True, p_values[101]: 0.05666325024672778
# FPR: 0.0, TPR: 0.27419354838709675
# is_not_signal: (40, 0)
# is_signal: (62, 17)
# ===========================================================================
# is_signal : True, p_values[102]: 0.06251878033340341
# FPR: 0.0, TPR: 0.2698412698412698
# is_not_signal: (40, 0)
# is_signal: (63, 17)
# ===========================================================================
# is_signal : True, p_values[103]: 0.029181713068483574
# FPR: 0.0, TPR: 0.28125
# is_not_signal: (40, 0)
# is_signal: (64, 18)
# ===========================================================================
# is_signal : True, p_values[104]: 0.020073674158479375
# FPR: 0.0, TPR: 0.2923076923076923
# is_not_signal: (40, 0)
# is_signal: (65, 19)
# ===========================================================================
# is_signal : True, p_values[105]: 0.0802660667846365
# FPR: 0.0, TPR: 0.2878787878787879
# is_not_signal: (40, 0)
# is_signal: (66, 19)
# ===========================================================================
# is_signal : False, p_values[106]: 0.8817906150326633
# FPR: 0.0, TPR: 0.2878787878787879
# is_not_signal: (41, 0)
# is_signal: (66, 19)
# ===========================================================================
# is_signal : True, p_values[107]: 0.005057887675234617
# FPR: 0.0, TPR: 0.29850746268656714
# is_not_signal: (41, 0)
# is_signal: (67, 20)
# ===========================================================================
# is_signal : True, p_values[108]: 0.0006391047960849837
# FPR: 0.0, TPR: 0.3088235294117647
# is_not_signal: (41, 0)
# is_signal: (68, 21)
# ===========================================================================
# is_signal : True, p_values[109]: 0.32052388985481967
# FPR: 0.0, TPR: 0.30434782608695654
# is_not_signal: (41, 0)
# is_signal: (69, 21)
# ===========================================================================
# is_signal : True, p_values[110]: 0.012416513399220641
# FPR: 0.0, TPR: 0.3142857142857143
# is_not_signal: (41, 0)
# is_signal: (70, 22)
# ===========================================================================
# is_signal : True, p_values[111]: 0.5019475440556592
# FPR: 0.0, TPR: 0.30985915492957744
# is_not_signal: (41, 0)
# is_signal: (71, 22)
# ===========================================================================
# is_signal : True, p_values[112]: 0.0012553504043879224
# FPR: 0.0, TPR: 0.3194444444444444
# is_not_signal: (41, 0)
# is_signal: (72, 23)
# ===========================================================================
# is_signal : True, p_values[113]: 0.45650707575312477
# FPR: 0.0, TPR: 0.3150684931506849
# is_not_signal: (41, 0)
# is_signal: (73, 23)
# ===========================================================================
# is_signal : True, p_values[114]: 0.5803411345354101
# FPR: 0.0, TPR: 0.3108108108108108
# is_not_signal: (41, 0)
# is_signal: (74, 23)
# ===========================================================================
# is_signal : True, p_values[115]: 0.1620100810129973
# FPR: 0.0, TPR: 0.30666666666666664
# is_not_signal: (41, 0)
# is_signal: (75, 23)
# ===========================================================================
# is_signal : True, p_values[116]: 0.002928797620003192
# FPR: 0.0, TPR: 0.3157894736842105
# is_not_signal: (41, 0)
# is_signal: (76, 24)
# ===========================================================================
# is_signal : True, p_values[117]: 0.4205491268620587
# FPR: 0.0, TPR: 0.3116883116883117
# is_not_signal: (41, 0)
# is_signal: (77, 24)
# ===========================================================================
# is_signal : True, p_values[118]: 0.11429180932274373
# FPR: 0.0, TPR: 0.3076923076923077
# is_not_signal: (41, 0)
# is_signal: (78, 24)
# ===========================================================================
# is_signal : False, p_values[119]: 0.7867867919633889
# FPR: 0.0, TPR: 0.3076923076923077
# is_not_signal: (42, 0)
# is_signal: (78, 24)
# ===========================================================================
# is_signal : False, p_values[120]: 0.5163656235326756
# FPR: 0.0, TPR: 0.3076923076923077
# is_not_signal: (43, 0)
# is_signal: (78, 24)
# ===========================================================================
# is_signal : True, p_values[121]: 0.01024998819886143
# FPR: 0.0, TPR: 0.31645569620253167
# is_not_signal: (43, 0)
# is_signal: (79, 25)
# ===========================================================================
# is_signal : False, p_values[122]: 0.10108037581086218
# FPR: 0.0, TPR: 0.31645569620253167
# is_not_signal: (44, 0)
# is_signal: (79, 25)
# ===========================================================================
# is_signal : False, p_values[123]: 0.8011159077378132
# FPR: 0.0, TPR: 0.31645569620253167
# is_not_signal: (45, 0)
# is_signal: (79, 25)
# ===========================================================================
# is_signal : True, p_values[124]: 0.0010446068577323582
# FPR: 0.0, TPR: 0.325
# is_not_signal: (45, 0)
# is_signal: (80, 26)
# ===========================================================================
# -- Ka = 5 --
# is_signal : True, p_values[0]: 0.2895376360408884
# FPR: nan, TPR: 0.0
# is_not_signal: (0, 0)
# is_signal: (1, 0)
# ===========================================================================
# is_signal : False, p_values[1]: 0.3653513318745835
# FPR: 0.0, TPR: 0.0
# is_not_signal: (1, 0)
# is_signal: (1, 0)
# ===========================================================================
# is_signal : False, p_values[2]: 0.5583366818506171
# FPR: 0.0, TPR: 0.0
# is_not_signal: (2, 0)
# is_signal: (1, 0)
# ===========================================================================
# is_signal : True, p_values[3]: 0.09229500796152607
# FPR: 0.0, TPR: 0.0
# is_not_signal: (2, 0)
# is_signal: (2, 0)
# ===========================================================================
# is_signal : True, p_values[4]: 0.000125870511579195
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (2, 0)
# is_signal: (3, 1)
# ===========================================================================
# is_signal : True, p_values[5]: 0.00018177289985205338
# FPR: 0.0, TPR: 0.5
# is_not_signal: (2, 0)
# is_signal: (4, 2)
# ===========================================================================
# is_signal : True, p_values[6]: 0.0022090110806824654
# FPR: 0.0, TPR: 0.6
# is_not_signal: (2, 0)
# is_signal: (5, 3)
# ===========================================================================
# is_signal : True, p_values[7]: 0.003365608841915579
# FPR: 0.0, TPR: 0.6666666666666666
# is_not_signal: (2, 0)
# is_signal: (6, 4)
# ===========================================================================
# is_signal : True, p_values[8]: 0.058241552666428796
# FPR: 0.0, TPR: 0.5714285714285714
# is_not_signal: (2, 0)
# is_signal: (7, 4)
# ===========================================================================
# is_signal : False, p_values[9]: 0.7945306724636306
# FPR: 0.0, TPR: 0.5714285714285714
# is_not_signal: (3, 0)
# is_signal: (7, 4)
# ===========================================================================
# is_signal : True, p_values[10]: 0.9999068177195325
# FPR: 0.0, TPR: 0.5
# is_not_signal: (3, 0)
# is_signal: (8, 4)
# ===========================================================================
# is_signal : True, p_values[11]: 0.06487359418324759
# FPR: 0.0, TPR: 0.4444444444444444
# is_not_signal: (3, 0)
# is_signal: (9, 4)
# ===========================================================================
# is_signal : True, p_values[12]: 0.00448719088442012
# FPR: 0.0, TPR: 0.5
# is_not_signal: (3, 0)
# is_signal: (10, 5)
# ===========================================================================
# is_signal : True, p_values[13]: 0.08064714896778842
# FPR: 0.0, TPR: 0.45454545454545453
# is_not_signal: (3, 0)
# is_signal: (11, 5)
# ===========================================================================
# is_signal : True, p_values[14]: 0.8423092462952393
# FPR: 0.0, TPR: 0.4166666666666667
# is_not_signal: (3, 0)
# is_signal: (12, 5)
# ===========================================================================
# is_signal : True, p_values[15]: 0.017479044529294416
# FPR: 0.0, TPR: 0.46153846153846156
# is_not_signal: (3, 0)
# is_signal: (13, 6)
# ===========================================================================
# is_signal : True, p_values[16]: 0.3777372616786196
# FPR: 0.0, TPR: 0.42857142857142855
# is_not_signal: (3, 0)
# is_signal: (14, 6)
# ===========================================================================
# is_signal : True, p_values[17]: 0.4811369472723039
# FPR: 0.0, TPR: 0.4
# is_not_signal: (3, 0)
# is_signal: (15, 6)
# ===========================================================================
# is_signal : True, p_values[18]: 0.3208782426688534
# FPR: 0.0, TPR: 0.375
# is_not_signal: (3, 0)
# is_signal: (16, 6)
# ===========================================================================
# is_signal : True, p_values[19]: 0.4642331839338636
# FPR: 0.0, TPR: 0.35294117647058826
# is_not_signal: (3, 0)
# is_signal: (17, 6)
# ===========================================================================
# is_signal : True, p_values[20]: 0.2515003762178379
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (3, 0)
# is_signal: (18, 6)
# ===========================================================================
# is_signal : True, p_values[21]: 0.42511374348113523
# FPR: 0.0, TPR: 0.3157894736842105
# is_not_signal: (3, 0)
# is_signal: (19, 6)
# ===========================================================================
# is_signal : True, p_values[22]: 0.1910641977234386
# FPR: 0.0, TPR: 0.3
# is_not_signal: (3, 0)
# is_signal: (20, 6)
# ===========================================================================
# is_signal : False, p_values[23]: 0.2552429629117106
# FPR: 0.0, TPR: 0.3
# is_not_signal: (4, 0)
# is_signal: (20, 6)
# ===========================================================================
# is_signal : True, p_values[24]: 0.14909037825088473
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (4, 0)
# is_signal: (21, 6)
# ===========================================================================
# is_signal : False, p_values[25]: 0.5777394133295737
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (5, 0)
# is_signal: (21, 6)
# ===========================================================================
# is_signal : True, p_values[26]: 0.08620777746215999
# FPR: 0.0, TPR: 0.2727272727272727
# is_not_signal: (5, 0)
# is_signal: (22, 6)
# ===========================================================================
# is_signal : True, p_values[27]: 0.42870080968392565
# FPR: 0.0, TPR: 0.2608695652173913
# is_not_signal: (5, 0)
# is_signal: (23, 6)
# ===========================================================================
# is_signal : True, p_values[28]: 0.4252579635939147
# FPR: 0.0, TPR: 0.25
# is_not_signal: (5, 0)
# is_signal: (24, 6)
# ===========================================================================
# is_signal : False, p_values[29]: 0.5234722441029356
# FPR: 0.0, TPR: 0.25
# is_not_signal: (6, 0)
# is_signal: (24, 6)
# ===========================================================================
# is_signal : False, p_values[30]: 0.9146330939258291
# FPR: 0.0, TPR: 0.25
# is_not_signal: (7, 0)
# is_signal: (24, 6)
# ===========================================================================
# is_signal : True, p_values[31]: 0.00014573495635447932
# FPR: 0.0, TPR: 0.28
# is_not_signal: (7, 0)
# is_signal: (25, 7)
# ===========================================================================
# is_signal : True, p_values[32]: 0.11189198251641302
# FPR: 0.0, TPR: 0.2692307692307692
# is_not_signal: (7, 0)
# is_signal: (26, 7)
# ===========================================================================
# is_signal : True, p_values[33]: 0.020223009566328717
# FPR: 0.0, TPR: 0.2962962962962963
# is_not_signal: (7, 0)
# is_signal: (27, 8)
# ===========================================================================
# is_signal : True, p_values[34]: 0.31415236294896964
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (7, 0)
# is_signal: (28, 8)
# ===========================================================================
# is_signal : True, p_values[35]: 0.03991667550507128
# FPR: 0.0, TPR: 0.3103448275862069
# is_not_signal: (7, 0)
# is_signal: (29, 9)
# ===========================================================================
# is_signal : True, p_values[36]: 0.8892546418857197
# FPR: 0.0, TPR: 0.3
# is_not_signal: (7, 0)
# is_signal: (30, 9)
# ===========================================================================
# is_signal : False, p_values[37]: 0.7168388038657127
# FPR: 0.0, TPR: 0.3
# is_not_signal: (8, 0)
# is_signal: (30, 9)
# ===========================================================================
# is_signal : True, p_values[38]: 0.21257158928294384
# FPR: 0.0, TPR: 0.2903225806451613
# is_not_signal: (8, 0)
# is_signal: (31, 9)
# ===========================================================================
# is_signal : True, p_values[39]: 0.8596934474156307
# FPR: 0.0, TPR: 0.28125
# is_not_signal: (8, 0)
# is_signal: (32, 9)
# ===========================================================================
# is_signal : False, p_values[40]: 0.2233011702307304
# FPR: 0.0, TPR: 0.28125
# is_not_signal: (9, 0)
# is_signal: (32, 9)
# ===========================================================================
# is_signal : True, p_values[41]: 0.3051727045476716
# FPR: 0.0, TPR: 0.2727272727272727
# is_not_signal: (9, 0)
# is_signal: (33, 9)
# ===========================================================================
# is_signal : False, p_values[42]: 0.7519335796512424
# FPR: 0.0, TPR: 0.2727272727272727
# is_not_signal: (10, 0)
# is_signal: (33, 9)
# ===========================================================================
# is_signal : True, p_values[43]: 0.02172196876169741
# FPR: 0.0, TPR: 0.29411764705882354
# is_not_signal: (10, 0)
# is_signal: (34, 10)
# ===========================================================================
# is_signal : True, p_values[44]: 0.12100267574824235
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (10, 0)
# is_signal: (35, 10)
# ===========================================================================
# is_signal : False, p_values[45]: 0.5334340662077938
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (11, 0)
# is_signal: (35, 10)
# ===========================================================================
# is_signal : True, p_values[46]: 0.14457329687184314
# FPR: 0.0, TPR: 0.2777777777777778
# is_not_signal: (11, 0)
# is_signal: (36, 10)
# ===========================================================================

# %%
n_target = 40
n_source = 80
p = 200
K = 7
h = 10
alpha = 0.05
T = 5
s_len = 10
s_vector = [0.0] * s_len

Ka_list = [1, 3, 5, 7]

iteration = 200

for Ka in Ka_list:
    print(f"-- Ka = {Ka} --")
    para_results_storage = []
    CoRT_model = CoRT_builder.CoRT()
    cnt1 = 0
    cnt2 = 0
    cnt3 = 0
    cnt4 = 0

    for i in range(iteration):
        target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
        result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, T, s_len)

        if result_dict != None:
            cnt1 += (result_dict['is_signal'] == True)
            cnt2 += (result_dict['is_signal'] == False)
            cnt3 += (result_dict['is_signal'] == True and result_dict['p_value'] <= alpha)
            cnt4 += (result_dict['is_signal'] == False and result_dict['p_value'] <= alpha)
            
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_values[{i}]: {result_dict['p_value']}")
            print(f"FPR: {cnt4 / cnt2}, TPR: {cnt3 / cnt1}")
            print(f"is_not_signal: {int(cnt2), int(cnt4)}")
            print(f"is_signal: {int(cnt1), int(cnt3)}")
            print("===========================================================================")
                
            para_results_storage.append(result_dict)
    is_signal_cases = [r for r in para_results_storage if r['is_signal']]
    not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

    false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
    fpr = false_positives / len(not_signal_cases) if len(not_signal_cases) != 0 else -1
    true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha) 
    tpr = true_positives / len(is_signal_cases) if len(is_signal_cases) != 0 else -1

    configs = {
        "n_source": n_source,
        "p":  p,
        "K": K,
        "Ka": Ka,
        "h": h,
        "alpha": alpha,
        "T":  T,
        "s_len": s_len,
        "s_vector": s_vector,
        "n_target": n_target,
        "iteration": iteration,
    }

    results = {
        "configs": configs,
        "time": datetime.datetime.now().ctime(),
        "fpr": fpr,
        "tpr": tpr,
        "is_signal_cases": len(is_signal_cases),
        "not_signal_cases": len(not_signal_cases),
        "false_positives": false_positives,
        "true_positives": true_positives
    }

    filename = 'records_4/FPR_parametric_vis_records.json'
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            try:
                records = json.load(f)
            except Exception as e:
                print(e)
                records = []
    else:
        records = []

    records.append(results)

    with open(filename, 'w') as f:
        json.dump(records, f, indent=4)

# %%
n_target = 40
n_source = 80
p = 200
K = 5
Ka = 3
h = 10
alpha = 0.05
T = 5
s_len = 10

iteration = 125

signal_list = [0.25, 0.5, 0.75, 1.0]

for signal in signal_list:
    print(f"-- signal = {signal} --")
    para_results_storage = []
    CoRT_model = CoRT_builder.CoRT()
    s_vector = [signal] * s_len
    cnt1 = 0
    cnt2 = 0
    cnt3 = 0
    cnt4 = 0

    for i in range(iteration):
        target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
        result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, T, s_len)

        if result_dict != None:
            cnt1 += (result_dict['is_signal'] == True)
            cnt2 += (result_dict['is_signal'] == False)
            cnt3 += (result_dict['is_signal'] == True and result_dict['p_value'] <= alpha)
            cnt4 += (result_dict['is_signal'] == False and result_dict['p_value'] <= alpha)
            
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_values[{i}]: {result_dict['p_value']}")
            print(f"FPR: {cnt4 / cnt2}, TPR: {cnt3 / cnt1}")
            print(f"is_not_signal: {int(cnt2), int(cnt4)}")
            print(f"is_signal: {int(cnt1), int(cnt3)}")
            print("===========================================================================")
                
            para_results_storage.append(result_dict)
    is_signal_cases = [r for r in para_results_storage if r['is_signal']]
    not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

    false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
    fpr = false_positives / len(not_signal_cases) if len(not_signal_cases) != 0 else -1
    true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha) 
    tpr = true_positives / len(is_signal_cases) if len(is_signal_cases) != 0 else -1

    configs = {
        "n_source": n_source,
        "p":  p,
        "K": K,
        "Ka": Ka,
        "h": h,
        "alpha": alpha,
        "T":  T,
        "s_len": s_len,
        "s_vector": s_vector,
        "n_target": n_target,
        "iteration": iteration,
    }

    results = {
        "configs": configs,
        "time": datetime.datetime.now().ctime(),
        "fpr": fpr,
        "tpr": tpr,
        "is_signal_cases": len(is_signal_cases),
        "not_signal_cases": len(not_signal_cases),
        "false_positives": false_positives,
        "true_positives": true_positives
    }

    filename = 'records_2/TPR_FPR_parametric_vis_records.json'
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            try:
                records = json.load(f)
            except Exception as e:
                print(e)
                records = []
    else:
        records = []

    records.append(results)

    with open(filename, 'w') as f:
        json.dump(records, f, indent=4)
# Out:
# -- signal = 0.25 --
# is_signal : True, p_values[0]: 0.7259099348921859
# FPR: nan, TPR: 0.0
# is_not_signal: (0, 0)
# is_signal: (1, 0)
# ===========================================================================
# is_signal : True, p_values[1]: 0.9918976032697618
# FPR: nan, TPR: 0.0
# is_not_signal: (0, 0)
# is_signal: (2, 0)
# ===========================================================================
# is_signal : False, p_values[2]: 0.6313945348902924
# FPR: 0.0, TPR: 0.0
# is_not_signal: (1, 0)
# is_signal: (2, 0)
# ===========================================================================

# %%
n_target = 40
n_source = 80
p = 200
K = 5
Ka = 3
h = 10
alpha = 0.05
T = 5
s_len = 10
s_vector = [0.5] * s_len

h_list = [2, 6, 10, 14]

iteration = 125

for h in h_list:
    print(f"-- h = {h} --")
    para_results_storage = []
    CoRT_model = CoRT_builder.CoRT()
    cnt1 = 0
    cnt2 = 0
    cnt3 = 0
    cnt4 = 0

    for i in range(iteration):
        target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
        result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, T, s_len)

        if result_dict != None:
            cnt1 += (result_dict['is_signal'] == True)
            cnt2 += (result_dict['is_signal'] == False)
            cnt3 += (result_dict['is_signal'] == True and result_dict['p_value'] <= alpha)
            cnt4 += (result_dict['is_signal'] == False and result_dict['p_value'] <= alpha)
            
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_values[{i}]: {result_dict['p_value']}")
            print(f"FPR: {cnt4 / cnt2}, TPR: {cnt3 / cnt1}")
            print(f"is_not_signal: {int(cnt2), int(cnt4)}")
            print(f"is_signal: {int(cnt1), int(cnt3)}")
            print("===========================================================================")
                
            para_results_storage.append(result_dict)
    is_signal_cases = [r for r in para_results_storage if r['is_signal']]
    not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

    false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
    fpr = false_positives / len(not_signal_cases) if len(not_signal_cases) != 0 else -1
    true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha) 
    tpr = true_positives / len(is_signal_cases) if len(is_signal_cases) != 0 else -1

    configs = {
        "n_source": n_source,
        "p":  p,
        "K": K,
        "Ka": Ka,
        "h": h,
        "alpha": alpha,
        "T":  T,
        "s_len": s_len,
        "s_vector": s_vector,
        "n_target": n_target,
        "iteration": iteration,
    }

    results = {
        "configs": configs,
        "time": datetime.datetime.now().ctime(),
        "fpr": fpr,
        "tpr": tpr,
        "is_signal_cases": len(is_signal_cases),
        "not_signal_cases": len(not_signal_cases),
        "false_positives": false_positives,
        "true_positives": true_positives
    }

    filename = 'records_3/TPR_parametric_vis_records.json'
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            try:
                records = json.load(f)
            except Exception as e:
                print(e)
                records = []
    else:
        records = []

    records.append(results)

    with open(filename, 'w') as f:
        json.dump(records, f, indent=4)
# Out:
# -- h = 2 --
# is_signal : True, p_values[0]: 0.5978730619390638
# FPR: nan, TPR: 0.0
# is_not_signal: (0, 0)
# is_signal: (1, 0)
# ===========================================================================
# is_signal : True, p_values[1]: 0.00016150605554621962
# FPR: nan, TPR: 0.5
# is_not_signal: (0, 0)
# is_signal: (2, 1)
# ===========================================================================
# is_signal : True, p_values[2]: 0.00044722221179807896
# FPR: nan, TPR: 0.6666666666666666
# is_not_signal: (0, 0)
# is_signal: (3, 2)
# ===========================================================================
# is_signal : True, p_values[3]: 0.08230066639181934
# FPR: nan, TPR: 0.5
# is_not_signal: (0, 0)
# is_signal: (4, 2)
# ===========================================================================
# is_signal : True, p_values[4]: 0.9636221223414148
# FPR: nan, TPR: 0.4
# is_not_signal: (0, 0)
# is_signal: (5, 2)
# ===========================================================================
# is_signal : True, p_values[5]: 0.020865001474632498
# FPR: nan, TPR: 0.5
# is_not_signal: (0, 0)
# is_signal: (6, 3)
# ===========================================================================
# is_signal : True, p_values[6]: 0.1381752657297598
# FPR: nan, TPR: 0.42857142857142855
# is_not_signal: (0, 0)
# is_signal: (7, 3)
# ===========================================================================
# is_signal : True, p_values[7]: 0.00780355550823046
# FPR: nan, TPR: 0.5
# is_not_signal: (0, 0)
# is_signal: (8, 4)
# ===========================================================================
# is_signal : True, p_values[8]: 0.9900410275160346
# FPR: nan, TPR: 0.4444444444444444
# is_not_signal: (0, 0)
# is_signal: (9, 4)
# ===========================================================================
# is_signal : True, p_values[9]: 0.14878196352431083
# FPR: nan, TPR: 0.4
# is_not_signal: (0, 0)
# is_signal: (10, 4)
# ===========================================================================
# is_signal : True, p_values[10]: 0.0007129813760136651
# FPR: nan, TPR: 0.45454545454545453
# is_not_signal: (0, 0)
# is_signal: (11, 5)
# ===========================================================================
# is_signal : False, p_values[11]: 0.4752126698287574
# FPR: 0.0, TPR: 0.45454545454545453
# is_not_signal: (1, 0)
# is_signal: (11, 5)
# ===========================================================================
# is_signal : True, p_values[12]: 0.0590183919669112
# FPR: 0.0, TPR: 0.4166666666666667
# is_not_signal: (1, 0)
# is_signal: (12, 5)
# ===========================================================================
# is_signal : True, p_values[13]: 0.22048736209392045
# FPR: 0.0, TPR: 0.38461538461538464
# is_not_signal: (1, 0)
# is_signal: (13, 5)
# ===========================================================================
# is_signal : True, p_values[14]: 0.32498827377468376
# FPR: 0.0, TPR: 0.35714285714285715
# is_not_signal: (1, 0)
# is_signal: (14, 5)
# ===========================================================================
# is_signal : True, p_values[15]: 0.8210782807898322
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (1, 0)
# is_signal: (15, 5)
# ===========================================================================
# is_signal : True, p_values[16]: 0.11547747322236046
# FPR: 0.0, TPR: 0.3125
# is_not_signal: (1, 0)
# is_signal: (16, 5)
# ===========================================================================
# is_signal : True, p_values[17]: 0.020569396187747085
# FPR: 0.0, TPR: 0.35294117647058826
# is_not_signal: (1, 0)
# is_signal: (17, 6)
# ===========================================================================
# is_signal : True, p_values[18]: 0.0757447921020308
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (1, 0)
# is_signal: (18, 6)
# ===========================================================================
# is_signal : True, p_values[19]: 0.005389441296138227
# FPR: 0.0, TPR: 0.3684210526315789
# is_not_signal: (1, 0)
# is_signal: (19, 7)
# ===========================================================================
# is_signal : True, p_values[20]: 0.0023660670979313743
# FPR: 0.0, TPR: 0.4
# is_not_signal: (1, 0)
# is_signal: (20, 8)
# ===========================================================================
# is_signal : True, p_values[21]: 0.9319424929045895
# FPR: 0.0, TPR: 0.38095238095238093
# is_not_signal: (1, 0)
# is_signal: (21, 8)
# ===========================================================================
# is_signal : True, p_values[22]: 0.11627120834609063
# FPR: 0.0, TPR: 0.36363636363636365
# is_not_signal: (1, 0)
# is_signal: (22, 8)
# ===========================================================================
# is_signal : True, p_values[23]: 0.015787170445653694
# FPR: 0.0, TPR: 0.391304347826087
# is_not_signal: (1, 0)
# is_signal: (23, 9)
# ===========================================================================
# is_signal : True, p_values[24]: 0.0008864033517803076
# FPR: 0.0, TPR: 0.4166666666666667
# is_not_signal: (1, 0)
# is_signal: (24, 10)
# ===========================================================================
# is_signal : True, p_values[25]: 0.01809655691231401
# FPR: 0.0, TPR: 0.44
# is_not_signal: (1, 0)
# is_signal: (25, 11)
# ===========================================================================
# is_signal : True, p_values[26]: 0.41577315173384954
# FPR: 0.0, TPR: 0.4230769230769231
# is_not_signal: (1, 0)
# is_signal: (26, 11)
# ===========================================================================
# is_signal : True, p_values[27]: 0.657342779788183
# FPR: 0.0, TPR: 0.4074074074074074
# is_not_signal: (1, 0)
# is_signal: (27, 11)
# ===========================================================================
# is_signal : True, p_values[28]: 0.00982402939836992
# FPR: 0.0, TPR: 0.42857142857142855
# is_not_signal: (1, 0)
# is_signal: (28, 12)
# ===========================================================================
# is_signal : True, p_values[29]: 0.0013801012412119212
# FPR: 0.0, TPR: 0.4482758620689655
# is_not_signal: (1, 0)
# is_signal: (29, 13)
# ===========================================================================
# is_signal : True, p_values[30]: 0.10642299891853303
# FPR: 0.0, TPR: 0.43333333333333335
# is_not_signal: (1, 0)
# is_signal: (30, 13)
# ===========================================================================
# is_signal : True, p_values[31]: 0.0007328460267065541
# FPR: 0.0, TPR: 0.45161290322580644
# is_not_signal: (1, 0)
# is_signal: (31, 14)
# ===========================================================================
# is_signal : True, p_values[32]: 0.023641536713911566
# FPR: 0.0, TPR: 0.46875
# is_not_signal: (1, 0)
# is_signal: (32, 15)
# ===========================================================================
# is_signal : True, p_values[33]: 0.13101523140846905
# FPR: 0.0, TPR: 0.45454545454545453
# is_not_signal: (1, 0)
# is_signal: (33, 15)
# ===========================================================================
# is_signal : True, p_values[34]: 0.6839570607359473
# FPR: 0.0, TPR: 0.4411764705882353
# is_not_signal: (1, 0)
# is_signal: (34, 15)
# ===========================================================================
# is_signal : False, p_values[35]: 0.3607240297971784
# FPR: 0.0, TPR: 0.4411764705882353
# is_not_signal: (2, 0)
# is_signal: (34, 15)
# ===========================================================================
# is_signal : True, p_values[36]: 0.00014512605393481438
# FPR: 0.0, TPR: 0.45714285714285713
# is_not_signal: (2, 0)
# is_signal: (35, 16)
# ===========================================================================
# is_signal : True, p_values[37]: 0.07000828211902076
# FPR: 0.0, TPR: 0.4444444444444444
# is_not_signal: (2, 0)
# is_signal: (36, 16)
# ===========================================================================
# is_signal : True, p_values[38]: 0.015911477451076128
# FPR: 0.0, TPR: 0.4594594594594595
# is_not_signal: (2, 0)
# is_signal: (37, 17)
# ===========================================================================
# is_signal : True, p_values[39]: 0.0003533775613592537
# FPR: 0.0, TPR: 0.47368421052631576
# is_not_signal: (2, 0)
# is_signal: (38, 18)
# ===========================================================================
# is_signal : True, p_values[40]: 0.11244059069228829
# FPR: 0.0, TPR: 0.46153846153846156
# is_not_signal: (2, 0)
# is_signal: (39, 18)
# ===========================================================================
# is_signal : True, p_values[41]: 0.04014859595708775
# FPR: 0.0, TPR: 0.475
# is_not_signal: (2, 0)
# is_signal: (40, 19)
# ===========================================================================
# is_signal : True, p_values[42]: 0.0004366164826333083
# FPR: 0.0, TPR: 0.4878048780487805
# is_not_signal: (2, 0)
# is_signal: (41, 20)
# ===========================================================================
# is_signal : True, p_values[43]: 0.013420589974192532
# FPR: 0.0, TPR: 0.5
# is_not_signal: (2, 0)
# is_signal: (42, 21)
# ===========================================================================
# is_signal : False, p_values[44]: 0.20293046338105847
# FPR: 0.0, TPR: 0.5
# is_not_signal: (3, 0)
# is_signal: (42, 21)
# ===========================================================================
# is_signal : False, p_values[45]: 0.7311470374299507
# FPR: 0.0, TPR: 0.5
# is_not_signal: (4, 0)
# is_signal: (42, 21)
# ===========================================================================
# is_signal : True, p_values[46]: 0.09744463256635183
# FPR: 0.0, TPR: 0.4883720930232558
# is_not_signal: (4, 0)
# is_signal: (43, 21)
# ===========================================================================
# is_signal : False, p_values[47]: 0.9462385055764392
# FPR: 0.0, TPR: 0.4883720930232558
# is_not_signal: (5, 0)
# is_signal: (43, 21)
# ===========================================================================
# is_signal : True, p_values[48]: 0.0911672352988529
# FPR: 0.0, TPR: 0.4772727272727273
# is_not_signal: (5, 0)
# is_signal: (44, 21)
# ===========================================================================
# is_signal : True, p_values[49]: 0.6995702186058439
# FPR: 0.0, TPR: 0.4666666666666667
# is_not_signal: (5, 0)
# is_signal: (45, 21)
# ===========================================================================
# is_signal : True, p_values[50]: 0.009814875344334223
# FPR: 0.0, TPR: 0.4782608695652174
# is_not_signal: (5, 0)
# is_signal: (46, 22)
# ===========================================================================
# is_signal : True, p_values[51]: 0.07832204225696979
# FPR: 0.0, TPR: 0.46808510638297873
# is_not_signal: (5, 0)
# is_signal: (47, 22)
# ===========================================================================
# is_signal : True, p_values[52]: 0.0001256915339615613
# FPR: 0.0, TPR: 0.4791666666666667
# is_not_signal: (5, 0)
# is_signal: (48, 23)
# ===========================================================================
# is_signal : True, p_values[53]: 0.0025674630261671954
# FPR: 0.0, TPR: 0.4897959183673469
# is_not_signal: (5, 0)
# is_signal: (49, 24)
# ===========================================================================
# is_signal : True, p_values[54]: 0.12819641862878894
# FPR: 0.0, TPR: 0.48
# is_not_signal: (5, 0)
# is_signal: (50, 24)
# ===========================================================================
# is_signal : False, p_values[55]: 0.2042263920620516
# FPR: 0.0, TPR: 0.48
# is_not_signal: (6, 0)
# is_signal: (50, 24)
# ===========================================================================
# is_signal : True, p_values[56]: 0.8892120079157407
# FPR: 0.0, TPR: 0.47058823529411764
# is_not_signal: (6, 0)
# is_signal: (51, 24)
# ===========================================================================
# is_signal : False, p_values[57]: 0.8046543341789528
# FPR: 0.0, TPR: 0.47058823529411764
# is_not_signal: (7, 0)
# is_signal: (51, 24)
# ===========================================================================
# is_signal : False, p_values[58]: 0.2367736745534378
# FPR: 0.0, TPR: 0.47058823529411764
# is_not_signal: (8, 0)
# is_signal: (51, 24)
# ===========================================================================
# is_signal : True, p_values[59]: 0.008738501636165305
# FPR: 0.0, TPR: 0.4807692307692308
# is_not_signal: (8, 0)
# is_signal: (52, 25)
# ===========================================================================
# is_signal : False, p_values[60]: 0.052471440041393105
# FPR: 0.0, TPR: 0.4807692307692308
# is_not_signal: (9, 0)
# is_signal: (52, 25)
# ===========================================================================
# is_signal : True, p_values[61]: 0.021243396331852942
# FPR: 0.0, TPR: 0.49056603773584906
# is_not_signal: (9, 0)
# is_signal: (53, 26)
# ===========================================================================
# is_signal : True, p_values[62]: 0.04283168748609315
# FPR: 0.0, TPR: 0.5
# is_not_signal: (9, 0)
# is_signal: (54, 27)
# ===========================================================================
# is_signal : True, p_values[63]: 0.052998632893304136
# FPR: 0.0, TPR: 0.4909090909090909
# is_not_signal: (9, 0)
# is_signal: (55, 27)
# ===========================================================================
# is_signal : True, p_values[64]: 0.6238606360218467
# FPR: 0.0, TPR: 0.48214285714285715
# is_not_signal: (9, 0)
# is_signal: (56, 27)
# ===========================================================================
# is_signal : True, p_values[65]: 0.10192981850183336
# FPR: 0.0, TPR: 0.47368421052631576
# is_not_signal: (9, 0)
# is_signal: (57, 27)
# ===========================================================================
# is_signal : False, p_values[66]: 0.91980910223783
# FPR: 0.0, TPR: 0.47368421052631576
# is_not_signal: (10, 0)
# is_signal: (57, 27)
# ===========================================================================
# is_signal : True, p_values[67]: 0.6959099593236775
# FPR: 0.0, TPR: 0.46551724137931033
# is_not_signal: (10, 0)
# is_signal: (58, 27)
# ===========================================================================
# -- h = 6 --
# is_signal : True, p_values[0]: 0.0037112320188383173
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : False, p_values[1]: 0.2426103537654849
# FPR: 0.0, TPR: 1.0
# is_not_signal: (1, 0)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : True, p_values[2]: 0.029154555449124025
# FPR: 0.0, TPR: 1.0
# is_not_signal: (1, 0)
# is_signal: (2, 2)
# ===========================================================================
# is_signal : True, p_values[3]: 0.0019572336769127967
# FPR: 0.0, TPR: 1.0
# is_not_signal: (1, 0)
# is_signal: (3, 3)
# ===========================================================================
# is_signal : True, p_values[4]: 0.0510428734532638
# FPR: 0.0, TPR: 0.75
# is_not_signal: (1, 0)
# is_signal: (4, 3)
# ===========================================================================
# is_signal : True, p_values[5]: 0.2909287422561259
# FPR: 0.0, TPR: 0.6
# is_not_signal: (1, 0)
# is_signal: (5, 3)
# ===========================================================================
# is_signal : True, p_values[6]: 0.05912697996931841
# FPR: 0.0, TPR: 0.5
# is_not_signal: (1, 0)
# is_signal: (6, 3)
# ===========================================================================
# is_signal : True, p_values[7]: 0.011920311461916714
# FPR: 0.0, TPR: 0.5714285714285714
# is_not_signal: (1, 0)
# is_signal: (7, 4)
# ===========================================================================
# is_signal : True, p_values[8]: 0.009333019096587318
# FPR: 0.0, TPR: 0.625
# is_not_signal: (1, 0)
# is_signal: (8, 5)
# ===========================================================================
# is_signal : True, p_values[9]: 0.7114347507969443
# FPR: 0.0, TPR: 0.5555555555555556
# is_not_signal: (1, 0)
# is_signal: (9, 5)
# ===========================================================================
# is_signal : True, p_values[10]: 0.1076171886699356
# FPR: 0.0, TPR: 0.5
# is_not_signal: (1, 0)
# is_signal: (10, 5)
# ===========================================================================
# is_signal : True, p_values[11]: 0.008760345538680804
# FPR: 0.0, TPR: 0.5454545454545454
# is_not_signal: (1, 0)
# is_signal: (11, 6)
# ===========================================================================
# is_signal : True, p_values[12]: 0.9027018038428417
# FPR: 0.0, TPR: 0.5
# is_not_signal: (1, 0)
# is_signal: (12, 6)
# ===========================================================================
# is_signal : True, p_values[13]: 0.14501068429820763
# FPR: 0.0, TPR: 0.46153846153846156
# is_not_signal: (1, 0)
# is_signal: (13, 6)
# ===========================================================================
# is_signal : True, p_values[14]: 0.016381390965066186
# FPR: 0.0, TPR: 0.5
# is_not_signal: (1, 0)
# is_signal: (14, 7)
# ===========================================================================
# is_signal : True, p_values[15]: 0.5219855072932692
# FPR: 0.0, TPR: 0.4666666666666667
# is_not_signal: (1, 0)
# is_signal: (15, 7)
# ===========================================================================
# is_signal : True, p_values[16]: 0.008695173922327985
# FPR: 0.0, TPR: 0.5
# is_not_signal: (1, 0)
# is_signal: (16, 8)
# ===========================================================================
# is_signal : True, p_values[17]: 0.479366094453732
# FPR: 0.0, TPR: 0.47058823529411764
# is_not_signal: (1, 0)
# is_signal: (17, 8)
# ===========================================================================
# is_signal : True, p_values[18]: 0.16231362217834042
# FPR: 0.0, TPR: 0.4444444444444444
# is_not_signal: (1, 0)
# is_signal: (18, 8)
# ===========================================================================
# is_signal : True, p_values[19]: 0.01785878775371945
# FPR: 0.0, TPR: 0.47368421052631576
# is_not_signal: (1, 0)
# is_signal: (19, 9)
# ===========================================================================
# is_signal : False, p_values[20]: 0.0907875210675426
# FPR: 0.0, TPR: 0.47368421052631576
# is_not_signal: (2, 0)
# is_signal: (19, 9)
# ===========================================================================
# is_signal : True, p_values[21]: 0.007634388862799642
# FPR: 0.0, TPR: 0.5
# is_not_signal: (2, 0)
# is_signal: (20, 10)
# ===========================================================================
# is_signal : False, p_values[22]: 0.5855751013453663
# FPR: 0.0, TPR: 0.5
# is_not_signal: (3, 0)
# is_signal: (20, 10)
# ===========================================================================
# is_signal : True, p_values[23]: 0.5777437265203923
# FPR: 0.0, TPR: 0.47619047619047616
# is_not_signal: (3, 0)
# is_signal: (21, 10)
# ===========================================================================
# is_signal : False, p_values[24]: 0.9838003210734556
# FPR: 0.0, TPR: 0.47619047619047616
# is_not_signal: (4, 0)
# is_signal: (21, 10)
# ===========================================================================
# is_signal : True, p_values[25]: 0.10649858859912295
# FPR: 0.0, TPR: 0.45454545454545453
# is_not_signal: (4, 0)
# is_signal: (22, 10)
# ===========================================================================
# is_signal : True, p_values[26]: 0.16132927721129767
# FPR: 0.0, TPR: 0.43478260869565216
# is_not_signal: (4, 0)
# is_signal: (23, 10)
# ===========================================================================
# is_signal : False, p_values[27]: 0.8841559928089673
# FPR: 0.0, TPR: 0.43478260869565216
# is_not_signal: (5, 0)
# is_signal: (23, 10)
# ===========================================================================
# is_signal : False, p_values[28]: 0.5391246943730377
# FPR: 0.0, TPR: 0.43478260869565216
# is_not_signal: (6, 0)
# is_signal: (23, 10)
# ===========================================================================
# is_signal : True, p_values[29]: 0.18653256318444747
# FPR: 0.0, TPR: 0.4166666666666667
# is_not_signal: (6, 0)
# is_signal: (24, 10)
# ===========================================================================
# is_signal : True, p_values[30]: 0.7555916336859301
# FPR: 0.0, TPR: 0.4
# is_not_signal: (6, 0)
# is_signal: (25, 10)
# ===========================================================================
# is_signal : True, p_values[31]: 0.5453879899383073
# FPR: 0.0, TPR: 0.38461538461538464
# is_not_signal: (6, 0)
# is_signal: (26, 10)
# ===========================================================================
# is_signal : True, p_values[32]: 0.28299752610812867
# FPR: 0.0, TPR: 0.37037037037037035
# is_not_signal: (6, 0)
# is_signal: (27, 10)
# ===========================================================================
# is_signal : False, p_values[33]: 0.3871909049726422
# FPR: 0.0, TPR: 0.37037037037037035
# is_not_signal: (7, 0)
# is_signal: (27, 10)
# ===========================================================================
# is_signal : True, p_values[34]: 0.009120648893357506
# FPR: 0.0, TPR: 0.39285714285714285
# is_not_signal: (7, 0)
# is_signal: (28, 11)
# ===========================================================================
# is_signal : True, p_values[35]: 0.0032647542599844644
# FPR: 0.0, TPR: 0.41379310344827586
# is_not_signal: (7, 0)
# is_signal: (29, 12)
# ===========================================================================
# is_signal : True, p_values[36]: 0.05835767862287889
# FPR: 0.0, TPR: 0.4
# is_not_signal: (7, 0)
# is_signal: (30, 12)
# ===========================================================================
# is_signal : True, p_values[37]: 0.005793427031803714
# FPR: 0.0, TPR: 0.41935483870967744
# is_not_signal: (7, 0)
# is_signal: (31, 13)
# ===========================================================================
# is_signal : True, p_values[38]: 0.0275817639633421
# FPR: 0.0, TPR: 0.4375
# is_not_signal: (7, 0)
# is_signal: (32, 14)
# ===========================================================================
# is_signal : True, p_values[39]: 0.699230920435432
# FPR: 0.0, TPR: 0.42424242424242425
# is_not_signal: (7, 0)
# is_signal: (33, 14)
# ===========================================================================
# is_signal : True, p_values[40]: 0.28897815835316065
# FPR: 0.0, TPR: 0.4117647058823529
# is_not_signal: (7, 0)
# is_signal: (34, 14)
# ===========================================================================
# is_signal : False, p_values[41]: 0.8344120346771505
# FPR: 0.0, TPR: 0.4117647058823529
# is_not_signal: (8, 0)
# is_signal: (34, 14)
# ===========================================================================
# is_signal : True, p_values[42]: 0.535743105833679
# FPR: 0.0, TPR: 0.4
# is_not_signal: (8, 0)
# is_signal: (35, 14)
# ===========================================================================
# is_signal : True, p_values[43]: 0.7183443231896915
# FPR: 0.0, TPR: 0.3888888888888889
# is_not_signal: (8, 0)
# is_signal: (36, 14)
# ===========================================================================
# is_signal : True, p_values[44]: 0.06526490235441687
# FPR: 0.0, TPR: 0.3783783783783784
# is_not_signal: (8, 0)
# is_signal: (37, 14)
# ===========================================================================
# is_signal : True, p_values[45]: 0.06188210504965197
# FPR: 0.0, TPR: 0.3684210526315789
# is_not_signal: (8, 0)
# is_signal: (38, 14)
# ===========================================================================
# is_signal : True, p_values[46]: 0.02635775590456187
# FPR: 0.0, TPR: 0.38461538461538464
# is_not_signal: (8, 0)
# is_signal: (39, 15)
# ===========================================================================
# is_signal : False, p_values[47]: 0.03678115186378071
# FPR: 0.1111111111111111, TPR: 0.38461538461538464
# is_not_signal: (9, 1)
# is_signal: (39, 15)
# ===========================================================================
# is_signal : True, p_values[48]: 0.6438117587450566
# FPR: 0.1111111111111111, TPR: 0.375
# is_not_signal: (9, 1)
# is_signal: (40, 15)
# ===========================================================================
# is_signal : True, p_values[49]: 0.23839467734869685
# FPR: 0.1111111111111111, TPR: 0.36585365853658536
# is_not_signal: (9, 1)
# is_signal: (41, 15)
# ===========================================================================
# is_signal : False, p_values[50]: 0.5819747011423697
# FPR: 0.1, TPR: 0.36585365853658536
# is_not_signal: (10, 1)
# is_signal: (41, 15)
# ===========================================================================
# is_signal : True, p_values[51]: 0.17335594658980918
# FPR: 0.1, TPR: 0.35714285714285715
# is_not_signal: (10, 1)
# is_signal: (42, 15)
# ===========================================================================
# is_signal : False, p_values[52]: 0.7746551966257488
# FPR: 0.09090909090909091, TPR: 0.35714285714285715
# is_not_signal: (11, 1)
# is_signal: (42, 15)
# ===========================================================================
# is_signal : False, p_values[53]: 0.47743738167419
# FPR: 0.08333333333333333, TPR: 0.35714285714285715
# is_not_signal: (12, 1)
# is_signal: (42, 15)
# ===========================================================================
# is_signal : False, p_values[54]: 0.5953076963496092
# FPR: 0.07692307692307693, TPR: 0.35714285714285715
# is_not_signal: (13, 1)
# is_signal: (42, 15)
# ===========================================================================
# is_signal : False, p_values[55]: 0.8221516330934009
# FPR: 0.07142857142857142, TPR: 0.35714285714285715
# is_not_signal: (14, 1)
# is_signal: (42, 15)
# ===========================================================================
# is_signal : False, p_values[56]: 0.7912455540484877
# FPR: 0.06666666666666667, TPR: 0.35714285714285715
# is_not_signal: (15, 1)
# is_signal: (42, 15)
# ===========================================================================
# is_signal : True, p_values[57]: 0.04272303759795048
# FPR: 0.06666666666666667, TPR: 0.37209302325581395
# is_not_signal: (15, 1)
# is_signal: (43, 16)
# ===========================================================================
# is_signal : True, p_values[58]: 0.028340051676774062
# FPR: 0.06666666666666667, TPR: 0.38636363636363635
# is_not_signal: (15, 1)
# is_signal: (44, 17)
# ===========================================================================
# is_signal : True, p_values[59]: 0.0569092707961107
# FPR: 0.06666666666666667, TPR: 0.37777777777777777
# is_not_signal: (15, 1)
# is_signal: (45, 17)
# ===========================================================================
# is_signal : True, p_values[60]: 0.5195598131968405
# FPR: 0.06666666666666667, TPR: 0.3695652173913043
# is_not_signal: (15, 1)
# is_signal: (46, 17)
# ===========================================================================
# is_signal : False, p_values[61]: 0.1760905119296231
# FPR: 0.0625, TPR: 0.3695652173913043
# is_not_signal: (16, 1)
# is_signal: (46, 17)
# ===========================================================================
# is_signal : False, p_values[62]: 0.4100431381894507
# FPR: 0.058823529411764705, TPR: 0.3695652173913043
# is_not_signal: (17, 1)
# is_signal: (46, 17)
# ===========================================================================
# is_signal : True, p_values[63]: 0.21051539626914478
# FPR: 0.058823529411764705, TPR: 0.3617021276595745
# is_not_signal: (17, 1)
# is_signal: (47, 17)
# ===========================================================================
# is_signal : True, p_values[64]: 0.05907883394146526
# FPR: 0.058823529411764705, TPR: 0.3541666666666667
# is_not_signal: (17, 1)
# is_signal: (48, 17)
# ===========================================================================
# is_signal : False, p_values[65]: 0.24719543410948383
# FPR: 0.05555555555555555, TPR: 0.3541666666666667
# is_not_signal: (18, 1)
# is_signal: (48, 17)
# ===========================================================================
# is_signal : False, p_values[66]: 0.1962156979949281
# FPR: 0.05263157894736842, TPR: 0.3541666666666667
# is_not_signal: (19, 1)
# is_signal: (48, 17)
# ===========================================================================
# is_signal : True, p_values[67]: 0.9984064004550257
# FPR: 0.05263157894736842, TPR: 0.3469387755102041
# is_not_signal: (19, 1)
# is_signal: (49, 17)
# ===========================================================================
# -- h = 10 --
# is_signal : True, p_values[0]: 0.1396657953606157
# FPR: nan, TPR: 0.0
# is_not_signal: (0, 0)
# is_signal: (1, 0)
# ===========================================================================
# is_signal : False, p_values[1]: 0.29542361642019144
# FPR: 0.0, TPR: 0.0
# is_not_signal: (1, 0)
# is_signal: (1, 0)
# ===========================================================================
# is_signal : True, p_values[2]: 0.005468614503543215
# FPR: 0.0, TPR: 0.5
# is_not_signal: (1, 0)
# is_signal: (2, 1)
# ===========================================================================
# is_signal : True, p_values[3]: 0.38219326845969187
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (1, 0)
# is_signal: (3, 1)
# ===========================================================================
# is_signal : True, p_values[4]: 0.9431724384293868
# FPR: 0.0, TPR: 0.25
# is_not_signal: (1, 0)
# is_signal: (4, 1)
# ===========================================================================
# is_signal : True, p_values[5]: 0.002024823209731168
# FPR: 0.0, TPR: 0.4
# is_not_signal: (1, 0)
# is_signal: (5, 2)
# ===========================================================================
# is_signal : False, p_values[6]: 0.44476832057317345
# FPR: 0.0, TPR: 0.4
# is_not_signal: (2, 0)
# is_signal: (5, 2)
# ===========================================================================
# is_signal : True, p_values[7]: 0.5277047255806064
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (2, 0)
# is_signal: (6, 2)
# ===========================================================================
# is_signal : True, p_values[8]: 0.04374960412852093
# FPR: 0.0, TPR: 0.42857142857142855
# is_not_signal: (2, 0)
# is_signal: (7, 3)
# ===========================================================================
# is_signal : True, p_values[9]: 0.08815000021624164
# FPR: 0.0, TPR: 0.375
# is_not_signal: (2, 0)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : False, p_values[10]: 0.9902889295826633
# FPR: 0.0, TPR: 0.375
# is_not_signal: (3, 0)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : False, p_values[11]: 0.8891891302345672
# FPR: 0.0, TPR: 0.375
# is_not_signal: (4, 0)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : False, p_values[12]: 0.1634385298541135
# FPR: 0.0, TPR: 0.375
# is_not_signal: (5, 0)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : True, p_values[13]: 0.0037487973526235934
# FPR: 0.0, TPR: 0.4444444444444444
# is_not_signal: (5, 0)
# is_signal: (9, 4)
# ===========================================================================
# is_signal : True, p_values[14]: 0.08740213235647445
# FPR: 0.0, TPR: 0.4
# is_not_signal: (5, 0)
# is_signal: (10, 4)
# ===========================================================================
# is_signal : True, p_values[15]: 0.0041964063009797365
# FPR: 0.0, TPR: 0.45454545454545453
# is_not_signal: (5, 0)
# is_signal: (11, 5)
# ===========================================================================
# is_signal : True, p_values[16]: 0.043707054317284076
# FPR: 0.0, TPR: 0.5
# is_not_signal: (5, 0)
# is_signal: (12, 6)
# ===========================================================================
# is_signal : True, p_values[17]: 0.6713675480485722
# FPR: 0.0, TPR: 0.46153846153846156
# is_not_signal: (5, 0)
# is_signal: (13, 6)
# ===========================================================================
# is_signal : False, p_values[18]: 0.6457683965415152
# FPR: 0.0, TPR: 0.46153846153846156
# is_not_signal: (6, 0)
# is_signal: (13, 6)
# ===========================================================================
# is_signal : False, p_values[19]: 0.434052744476436
# FPR: 0.0, TPR: 0.46153846153846156
# is_not_signal: (7, 0)
# is_signal: (13, 6)
# ===========================================================================
# is_signal : True, p_values[20]: 0.0019519066324828601
# FPR: 0.0, TPR: 0.5
# is_not_signal: (7, 0)
# is_signal: (14, 7)
# ===========================================================================
# is_signal : True, p_values[21]: 0.00011809645050492765
# FPR: 0.0, TPR: 0.5333333333333333
# is_not_signal: (7, 0)
# is_signal: (15, 8)
# ===========================================================================
# is_signal : False, p_values[22]: 0.6338927263872338
# FPR: 0.0, TPR: 0.5333333333333333
# is_not_signal: (8, 0)
# is_signal: (15, 8)
# ===========================================================================
# is_signal : True, p_values[23]: 0.12305855380535874
# FPR: 0.0, TPR: 0.5
# is_not_signal: (8, 0)
# is_signal: (16, 8)
# ===========================================================================
# is_signal : True, p_values[24]: 0.011428613176577326
# FPR: 0.0, TPR: 0.5294117647058824
# is_not_signal: (8, 0)
# is_signal: (17, 9)
# ===========================================================================
# is_signal : True, p_values[25]: 0.2162024967701185
# FPR: 0.0, TPR: 0.5
# is_not_signal: (8, 0)
# is_signal: (18, 9)
# ===========================================================================
# is_signal : True, p_values[26]: 0.2424377943368241
# FPR: 0.0, TPR: 0.47368421052631576
# is_not_signal: (8, 0)
# is_signal: (19, 9)
# ===========================================================================
# is_signal : True, p_values[27]: 0.09760143002746582
# FPR: 0.0, TPR: 0.45
# is_not_signal: (8, 0)
# is_signal: (20, 9)
# ===========================================================================
# is_signal : True, p_values[28]: 6.012763674661613e-06
# FPR: 0.0, TPR: 0.47619047619047616
# is_not_signal: (8, 0)
# is_signal: (21, 10)
# ===========================================================================
# is_signal : True, p_values[29]: 0.557917091753228
# FPR: 0.0, TPR: 0.45454545454545453
# is_not_signal: (8, 0)
# is_signal: (22, 10)
# ===========================================================================
# is_signal : True, p_values[30]: 0.1316153468126052
# FPR: 0.0, TPR: 0.43478260869565216
# is_not_signal: (8, 0)
# is_signal: (23, 10)
# ===========================================================================
# is_signal : True, p_values[31]: 0.17860347551314038
# FPR: 0.0, TPR: 0.4166666666666667
# is_not_signal: (8, 0)
# is_signal: (24, 10)
# ===========================================================================
# is_signal : True, p_values[32]: 0.009165601664187978
# FPR: 0.0, TPR: 0.44
# is_not_signal: (8, 0)
# is_signal: (25, 11)
# ===========================================================================
# is_signal : True, p_values[33]: 0.00015624234064408294
# FPR: 0.0, TPR: 0.46153846153846156
# is_not_signal: (8, 0)
# is_signal: (26, 12)
# ===========================================================================
# is_signal : True, p_values[34]: 0.43965499460162316
# FPR: 0.0, TPR: 0.4444444444444444
# is_not_signal: (8, 0)
# is_signal: (27, 12)
# ===========================================================================
# is_signal : True, p_values[35]: 0.0025787120479538483
# FPR: 0.0, TPR: 0.4642857142857143
# is_not_signal: (8, 0)
# is_signal: (28, 13)
# ===========================================================================
# is_signal : True, p_values[36]: 0.13845842270446035
# FPR: 0.0, TPR: 0.4482758620689655
# is_not_signal: (8, 0)
# is_signal: (29, 13)
# ===========================================================================
# is_signal : False, p_values[37]: 0.8825082139366299
# FPR: 0.0, TPR: 0.4482758620689655
# is_not_signal: (9, 0)
# is_signal: (29, 13)
# ===========================================================================
# is_signal : True, p_values[38]: 0.6162989864794813
# FPR: 0.0, TPR: 0.43333333333333335
# is_not_signal: (9, 0)
# is_signal: (30, 13)
# ===========================================================================
# is_signal : True, p_values[39]: 0.18286669803541192
# FPR: 0.0, TPR: 0.41935483870967744
# is_not_signal: (9, 0)
# is_signal: (31, 13)
# ===========================================================================
# is_signal : True, p_values[40]: 0.1373910238933091
# FPR: 0.0, TPR: 0.40625
# is_not_signal: (9, 0)
# is_signal: (32, 13)
# ===========================================================================
# is_signal : True, p_values[41]: 0.1124044678283217
# FPR: 0.0, TPR: 0.3939393939393939
# is_not_signal: (9, 0)
# is_signal: (33, 13)
# ===========================================================================
# is_signal : True, p_values[42]: 0.9745479801136301
# FPR: 0.0, TPR: 0.38235294117647056
# is_not_signal: (9, 0)
# is_signal: (34, 13)
# ===========================================================================
# is_signal : True, p_values[43]: 0.03141542293041736
# FPR: 0.0, TPR: 0.4
# is_not_signal: (9, 0)
# is_signal: (35, 14)
# ===========================================================================
# is_signal : True, p_values[44]: 0.15052349001194953
# FPR: 0.0, TPR: 0.3888888888888889
# is_not_signal: (9, 0)
# is_signal: (36, 14)
# ===========================================================================
# is_signal : True, p_values[45]: 0.018480455626109567
# FPR: 0.0, TPR: 0.40540540540540543
# is_not_signal: (9, 0)
# is_signal: (37, 15)
# ===========================================================================
# is_signal : True, p_values[46]: 0.07074173137985058
# FPR: 0.0, TPR: 0.39473684210526316
# is_not_signal: (9, 0)
# is_signal: (38, 15)
# ===========================================================================
# is_signal : True, p_values[47]: 0.0010618790039615819
# FPR: 0.0, TPR: 0.41025641025641024
# is_not_signal: (9, 0)
# is_signal: (39, 16)
# ===========================================================================
# is_signal : True, p_values[48]: 0.02106144486032671
# FPR: 0.0, TPR: 0.425
# is_not_signal: (9, 0)
# is_signal: (40, 17)
# ===========================================================================
# is_signal : True, p_values[49]: 0.02303996703305589
# FPR: 0.0, TPR: 0.43902439024390244
# is_not_signal: (9, 0)
# is_signal: (41, 18)
# ===========================================================================
# is_signal : False, p_values[50]: 0.30087204857077626
# FPR: 0.0, TPR: 0.43902439024390244
# is_not_signal: (10, 0)
# is_signal: (41, 18)
# ===========================================================================
# is_signal : True, p_values[51]: 0.4197747142891679
# FPR: 0.0, TPR: 0.42857142857142855
# is_not_signal: (10, 0)
# is_signal: (42, 18)
# ===========================================================================
# is_signal : False, p_values[52]: 0.729657480467502
# FPR: 0.0, TPR: 0.42857142857142855
# is_not_signal: (11, 0)
# is_signal: (42, 18)
# ===========================================================================
# is_signal : True, p_values[53]: 0.03763509658845233
# FPR: 0.0, TPR: 0.4418604651162791
# is_not_signal: (11, 0)
# is_signal: (43, 19)
# ===========================================================================
# is_signal : True, p_values[54]: 0.20176297248815775
# FPR: 0.0, TPR: 0.4318181818181818
# is_not_signal: (11, 0)
# is_signal: (44, 19)
# ===========================================================================
# is_signal : True, p_values[55]: 0.009987970073862838
# FPR: 0.0, TPR: 0.4444444444444444
# is_not_signal: (11, 0)
# is_signal: (45, 20)
# ===========================================================================
# is_signal : True, p_values[56]: 0.0053646816250664435
# FPR: 0.0, TPR: 0.45652173913043476
# is_not_signal: (11, 0)
# is_signal: (46, 21)
# ===========================================================================
# is_signal : True, p_values[57]: 0.08786299544872561
# FPR: 0.0, TPR: 0.44680851063829785
# is_not_signal: (11, 0)
# is_signal: (47, 21)
# ===========================================================================
# is_signal : False, p_values[58]: 0.7075318104028094
# FPR: 0.0, TPR: 0.44680851063829785
# is_not_signal: (12, 0)
# is_signal: (47, 21)
# ===========================================================================
# is_signal : True, p_values[59]: 0.08209024068367712
# FPR: 0.0, TPR: 0.4375
# is_not_signal: (12, 0)
# is_signal: (48, 21)
# ===========================================================================
# is_signal : True, p_values[60]: 0.38600991027320736
# FPR: 0.0, TPR: 0.42857142857142855
# is_not_signal: (12, 0)
# is_signal: (49, 21)
# ===========================================================================
# is_signal : True, p_values[61]: 0.023071536968180578
# FPR: 0.0, TPR: 0.44
# is_not_signal: (12, 0)
# is_signal: (50, 22)
# ===========================================================================
# is_signal : True, p_values[62]: 0.23980317292890072
# FPR: 0.0, TPR: 0.43137254901960786
# is_not_signal: (12, 0)
# is_signal: (51, 22)
# ===========================================================================
# is_signal : True, p_values[63]: 0.00028571115239638524
# FPR: 0.0, TPR: 0.4423076923076923
# is_not_signal: (12, 0)
# is_signal: (52, 23)
# ===========================================================================
# is_signal : False, p_values[64]: 0.9920774525737792
# FPR: 0.0, TPR: 0.4423076923076923
# is_not_signal: (13, 0)
# is_signal: (52, 23)
# ===========================================================================
# is_signal : True, p_values[65]: 0.005422603209371837
# FPR: 0.0, TPR: 0.4528301886792453
# is_not_signal: (13, 0)
# is_signal: (53, 24)
# ===========================================================================
# is_signal : True, p_values[66]: 0.0035443067295481702
# FPR: 0.0, TPR: 0.46296296296296297
# is_not_signal: (13, 0)
# is_signal: (54, 25)
# ===========================================================================
# is_signal : True, p_values[67]: 0.9150589026533772
# FPR: 0.0, TPR: 0.45454545454545453
# is_not_signal: (13, 0)
# is_signal: (55, 25)
# ===========================================================================
# -- h = 14 --
# is_signal : True, p_values[0]: 0.007379589459037147
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : True, p_values[1]: 0.007286712691874041
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (2, 2)
# ===========================================================================
# is_signal : True, p_values[2]: 0.03255003558611161
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (3, 3)
# ===========================================================================
# is_signal : True, p_values[3]: 0.0024157317715883544
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (4, 4)
# ===========================================================================
# is_signal : True, p_values[4]: 0.011910989842871126
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (5, 5)
# ===========================================================================
# is_signal : True, p_values[5]: 0.02351669452782866
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (6, 6)
# ===========================================================================
# is_signal : True, p_values[6]: 8.923302699253996e-05
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (7, 7)
# ===========================================================================
# is_signal : True, p_values[7]: 0.8990257764345329
# FPR: nan, TPR: 0.875
# is_not_signal: (0, 0)
# is_signal: (8, 7)
# ===========================================================================
# is_signal : True, p_values[8]: 0.16088786015592163
# FPR: nan, TPR: 0.7777777777777778
# is_not_signal: (0, 0)
# is_signal: (9, 7)
# ===========================================================================
# is_signal : True, p_values[9]: 0.10232620189732868
# FPR: nan, TPR: 0.7
# is_not_signal: (0, 0)
# is_signal: (10, 7)
# ===========================================================================
# is_signal : True, p_values[10]: 0.00030993005751302454
# FPR: nan, TPR: 0.7272727272727273
# is_not_signal: (0, 0)
# is_signal: (11, 8)
# ===========================================================================
# is_signal : True, p_values[11]: 0.46490089361633047
# FPR: nan, TPR: 0.6666666666666666
# is_not_signal: (0, 0)
# is_signal: (12, 8)
# ===========================================================================
# is_signal : True, p_values[12]: 0.03030063408560648
# FPR: nan, TPR: 0.6923076923076923
# is_not_signal: (0, 0)
# is_signal: (13, 9)
# ===========================================================================
# is_signal : True, p_values[13]: 0.008831851187018156
# FPR: nan, TPR: 0.7142857142857143
# is_not_signal: (0, 0)
# is_signal: (14, 10)
# ===========================================================================
# is_signal : True, p_values[14]: 0.004237996446226871
# FPR: nan, TPR: 0.7333333333333333
# is_not_signal: (0, 0)
# is_signal: (15, 11)
# ===========================================================================
# is_signal : True, p_values[15]: 0.007886131725721243
# FPR: nan, TPR: 0.75
# is_not_signal: (0, 0)
# is_signal: (16, 12)
# ===========================================================================
# is_signal : True, p_values[16]: 0.2809899551872281
# FPR: nan, TPR: 0.7058823529411765
# is_not_signal: (0, 0)
# is_signal: (17, 12)
# ===========================================================================
# is_signal : True, p_values[17]: 0.03158204569990008
# FPR: nan, TPR: 0.7222222222222222
# is_not_signal: (0, 0)
# is_signal: (18, 13)
# ===========================================================================
# is_signal : True, p_values[18]: 0.27127905047226364
# FPR: nan, TPR: 0.6842105263157895
# is_not_signal: (0, 0)
# is_signal: (19, 13)
# ===========================================================================
# is_signal : True, p_values[19]: 0.01533006490765932
# FPR: nan, TPR: 0.7
# is_not_signal: (0, 0)
# is_signal: (20, 14)
# ===========================================================================
# is_signal : False, p_values[20]: 0.5368284073587427
# FPR: 0.0, TPR: 0.7
# is_not_signal: (1, 0)
# is_signal: (20, 14)
# ===========================================================================
# is_signal : True, p_values[21]: 0.06032064130941995
# FPR: 0.0, TPR: 0.6666666666666666
# is_not_signal: (1, 0)
# is_signal: (21, 14)
# ===========================================================================
# is_signal : True, p_values[22]: 0.17739809352415192
# FPR: 0.0, TPR: 0.6363636363636364
# is_not_signal: (1, 0)
# is_signal: (22, 14)
# ===========================================================================
# is_signal : True, p_values[23]: 0.5781454304024741
# FPR: 0.0, TPR: 0.6086956521739131
# is_not_signal: (1, 0)
# is_signal: (23, 14)
# ===========================================================================
# is_signal : True, p_values[24]: 8.52066989729202e-05
# FPR: 0.0, TPR: 0.625
# is_not_signal: (1, 0)
# is_signal: (24, 15)
# ===========================================================================
# is_signal : True, p_values[25]: 0.5503103242853895
# FPR: 0.0, TPR: 0.6
# is_not_signal: (1, 0)
# is_signal: (25, 15)
# ===========================================================================
# is_signal : True, p_values[26]: 0.2751539710210585
# FPR: 0.0, TPR: 0.5769230769230769
# is_not_signal: (1, 0)
# is_signal: (26, 15)
# ===========================================================================
# is_signal : True, p_values[27]: 0.0011603392229463287
# FPR: 0.0, TPR: 0.5925925925925926
# is_not_signal: (1, 0)
# is_signal: (27, 16)
# ===========================================================================
# is_signal : True, p_values[28]: 0.40770780504109705
# FPR: 0.0, TPR: 0.5714285714285714
# is_not_signal: (1, 0)
# is_signal: (28, 16)
# ===========================================================================
# is_signal : True, p_values[29]: 0.5375821594186289
# FPR: 0.0, TPR: 0.5517241379310345
# is_not_signal: (1, 0)
# is_signal: (29, 16)
# ===========================================================================
# is_signal : False, p_values[30]: 0.7789139266753282
# FPR: 0.0, TPR: 0.5517241379310345
# is_not_signal: (2, 0)
# is_signal: (29, 16)
# ===========================================================================
# is_signal : True, p_values[31]: 0.0002874755185257699
# FPR: 0.0, TPR: 0.5666666666666667
# is_not_signal: (2, 0)
# is_signal: (30, 17)
# ===========================================================================
# is_signal : True, p_values[32]: 0.7689253716820886
# FPR: 0.0, TPR: 0.5483870967741935
# is_not_signal: (2, 0)
# is_signal: (31, 17)
# ===========================================================================
# is_signal : True, p_values[33]: 0.19232713029753837
# FPR: 0.0, TPR: 0.53125
# is_not_signal: (2, 0)
# is_signal: (32, 17)
# ===========================================================================
# is_signal : False, p_values[34]: 0.28118648099693
# FPR: 0.0, TPR: 0.53125
# is_not_signal: (3, 0)
# is_signal: (32, 17)
# ===========================================================================
# is_signal : True, p_values[35]: 0.010019486342649599
# FPR: 0.0, TPR: 0.5454545454545454
# is_not_signal: (3, 0)
# is_signal: (33, 18)
# ===========================================================================
# is_signal : True, p_values[36]: 0.0039567506206715465
# FPR: 0.0, TPR: 0.5588235294117647
# is_not_signal: (3, 0)
# is_signal: (34, 19)
# ===========================================================================
# is_signal : False, p_values[37]: 0.2613513504248208
# FPR: 0.0, TPR: 0.5588235294117647
# is_not_signal: (4, 0)
# is_signal: (34, 19)
# ===========================================================================
# is_signal : True, p_values[38]: 0.0061540145653751705
# FPR: 0.0, TPR: 0.5714285714285714
# is_not_signal: (4, 0)
# is_signal: (35, 20)
# ===========================================================================
# is_signal : True, p_values[39]: 0.004520364127175993
# FPR: 0.0, TPR: 0.5833333333333334
# is_not_signal: (4, 0)
# is_signal: (36, 21)
# ===========================================================================
# is_signal : True, p_values[40]: 0.09415493328772624
# FPR: 0.0, TPR: 0.5675675675675675
# is_not_signal: (4, 0)
# is_signal: (37, 21)
# ===========================================================================
# is_signal : True, p_values[41]: 0.0019399845228040464
# FPR: 0.0, TPR: 0.5789473684210527
# is_not_signal: (4, 0)
# is_signal: (38, 22)
# ===========================================================================
# is_signal : True, p_values[42]: 0.19430871550511505
# FPR: 0.0, TPR: 0.5641025641025641
# is_not_signal: (4, 0)
# is_signal: (39, 22)
# ===========================================================================
# is_signal : True, p_values[43]: 0.5482015099808426
# FPR: 0.0, TPR: 0.55
# is_not_signal: (4, 0)
# is_signal: (40, 22)
# ===========================================================================
# is_signal : True, p_values[44]: 0.00037997338325706343
# FPR: 0.0, TPR: 0.5609756097560976
# is_not_signal: (4, 0)
# is_signal: (41, 23)
# ===========================================================================
# is_signal : True, p_values[45]: 0.31096174739571814
# FPR: 0.0, TPR: 0.5476190476190477
# is_not_signal: (4, 0)
# is_signal: (42, 23)
# ===========================================================================
# is_signal : True, p_values[46]: 0.8455861630392374
# FPR: 0.0, TPR: 0.5348837209302325
# is_not_signal: (4, 0)
# is_signal: (43, 23)
# ===========================================================================
# is_signal : True, p_values[47]: 0.5143523268879835
# FPR: 0.0, TPR: 0.5227272727272727
# is_not_signal: (4, 0)
# is_signal: (44, 23)
# ===========================================================================
# is_signal : True, p_values[48]: 0.00042920447662155676
# FPR: 0.0, TPR: 0.5333333333333333
# is_not_signal: (4, 0)
# is_signal: (45, 24)
# ===========================================================================
# is_signal : True, p_values[49]: 0.24383044219458322
# FPR: 0.0, TPR: 0.5217391304347826
# is_not_signal: (4, 0)
# is_signal: (46, 24)
# ===========================================================================
# is_signal : False, p_values[50]: 0.7211248574077742
# FPR: 0.0, TPR: 0.5217391304347826
# is_not_signal: (5, 0)
# is_signal: (46, 24)
# ===========================================================================
# is_signal : True, p_values[51]: 0.416747622338369
# FPR: 0.0, TPR: 0.5106382978723404
# is_not_signal: (5, 0)
# is_signal: (47, 24)
# ===========================================================================
# is_signal : True, p_values[52]: 0.41658604983802666
# FPR: 0.0, TPR: 0.5
# is_not_signal: (5, 0)
# is_signal: (48, 24)
# ===========================================================================
# is_signal : False, p_values[53]: 0.6660345834591932
# FPR: 0.0, TPR: 0.5
# is_not_signal: (6, 0)
# is_signal: (48, 24)
# ===========================================================================
# is_signal : True, p_values[54]: 0.7798523548038623
# FPR: 0.0, TPR: 0.4897959183673469
# is_not_signal: (6, 0)
# is_signal: (49, 24)
# ===========================================================================
# is_signal : True, p_values[55]: 0.001112209147532302
# FPR: 0.0, TPR: 0.5
# is_not_signal: (6, 0)
# is_signal: (50, 25)
# ===========================================================================
# is_signal : True, p_values[56]: 0.012437626433519833
# FPR: 0.0, TPR: 0.5098039215686274
# is_not_signal: (6, 0)
# is_signal: (51, 26)
# ===========================================================================
# is_signal : True, p_values[57]: 0.3509682811925224
# FPR: 0.0, TPR: 0.5
# is_not_signal: (6, 0)
# is_signal: (52, 26)
# ===========================================================================
# is_signal : True, p_values[58]: 0.0006353781836036737
# FPR: 0.0, TPR: 0.5094339622641509
# is_not_signal: (6, 0)
# is_signal: (53, 27)
# ===========================================================================
# is_signal : True, p_values[59]: 0.005983658296457297
# FPR: 0.0, TPR: 0.5185185185185185
# is_not_signal: (6, 0)
# is_signal: (54, 28)
# ===========================================================================
# is_signal : True, p_values[60]: 0.0544559457429324
# FPR: 0.0, TPR: 0.509090909090909
# is_not_signal: (6, 0)
# is_signal: (55, 28)
# ===========================================================================
# is_signal : True, p_values[61]: 0.5478930420477074
# FPR: 0.0, TPR: 0.5
# is_not_signal: (6, 0)
# is_signal: (56, 28)
# ===========================================================================
# is_signal : True, p_values[62]: 0.0009310695412535964
# FPR: 0.0, TPR: 0.5087719298245614
# is_not_signal: (6, 0)
# is_signal: (57, 29)
# ===========================================================================
# is_signal : True, p_values[63]: 0.7308669421495129
# FPR: 0.0, TPR: 0.5
# is_not_signal: (6, 0)
# is_signal: (58, 29)
# ===========================================================================
# is_signal : False, p_values[64]: 0.47021242133589586
# FPR: 0.0, TPR: 0.5
# is_not_signal: (7, 0)
# is_signal: (58, 29)
# ===========================================================================
# is_signal : True, p_values[65]: 0.01219645354377405
# FPR: 0.0, TPR: 0.5084745762711864
# is_not_signal: (7, 0)
# is_signal: (59, 30)
# ===========================================================================
# is_signal : True, p_values[66]: 0.10807357038485998
# FPR: 0.0, TPR: 0.5
# is_not_signal: (7, 0)
# is_signal: (60, 30)
# ===========================================================================
# is_signal : True, p_values[67]: 0.0034239998771350626
# FPR: 0.0, TPR: 0.5081967213114754
# is_not_signal: (7, 0)
# is_signal: (61, 31)
# ===========================================================================

# %%
n_target = 40
n_source = 80
p = 200
K = 5
Ka = 3
h = 10
alpha = 0.05
T = 5
s_len = 10
s_vector = [0.0] * s_len

h_list = [2, 6, 10, 14]

iteration = 125

for h in h_list:
    print(f"-- h = {h} --")
    para_results_storage = []
    CoRT_model = CoRT_builder.CoRT()
    cnt1 = 0
    cnt2 = 0
    cnt3 = 0
    cnt4 = 0

    for i in range(iteration):
        target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
        result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, T, s_len)

        if result_dict != None:
            cnt1 += (result_dict['is_signal'] == True)
            cnt2 += (result_dict['is_signal'] == False)
            cnt3 += (result_dict['is_signal'] == True and result_dict['p_value'] <= alpha)
            cnt4 += (result_dict['is_signal'] == False and result_dict['p_value'] <= alpha)
            
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_values[{i}]: {result_dict['p_value']}")
            print(f"FPR: {cnt4 / cnt2}, TPR: {cnt3 / cnt1}")
            print(f"is_not_signal: {int(cnt2), int(cnt4)}")
            print(f"is_signal: {int(cnt1), int(cnt3)}")
            print("===========================================================================")
                
            para_results_storage.append(result_dict)
    is_signal_cases = [r for r in para_results_storage if r['is_signal']]
    not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

    false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
    fpr = false_positives / len(not_signal_cases) if len(not_signal_cases) != 0 else -1
    true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha) 
    tpr = true_positives / len(is_signal_cases) if len(is_signal_cases) != 0 else -1

    configs = {
        "n_source": n_source,
        "p":  p,
        "K": K,
        "Ka": Ka,
        "h": h,
        "alpha": alpha,
        "T":  T,
        "s_len": s_len,
        "s_vector": s_vector,
        "n_target": n_target,
        "iteration": iteration,
    }

    results = {
        "configs": configs,
        "time": datetime.datetime.now().ctime(),
        "fpr": fpr,
        "tpr": tpr,
        "is_signal_cases": len(is_signal_cases),
        "not_signal_cases": len(not_signal_cases),
        "false_positives": false_positives,
        "true_positives": true_positives
    }

    filename = 'records_3/FPR_parametric_vis_records.json'
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            try:
                records = json.load(f)
            except Exception as e:
                print(e)
                records = []
    else:
        records = []

    records.append(results)

    with open(filename, 'w') as f:
        json.dump(records, f, indent=4)

# %%
n_source = 80
p = 200
K = 5
Ka = 3
h = 10
alpha = 0.05
T = 5
s_len = 10
s_vector = [0.5] * s_len
iteration = 125

n_target_list = [40, 50, 60, 70]

for n_target in n_target_list:
    print(f"-- n_target = {n_target} --")
    para_results_storage = []
    CoRT_model = CoRT_builder.CoRT()
    cnt1 = 0
    cnt2 = 0
    cnt3 = 0
    cnt4 = 0

    for i in range(iteration):
        target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
        result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, T, s_len)

        if result_dict != None:
            cnt1 += (result_dict['is_signal'] == True)
            cnt2 += (result_dict['is_signal'] == False)
            cnt3 += (result_dict['is_signal'] == True and result_dict['p_value'] <= alpha)
            cnt4 += (result_dict['is_signal'] == False and result_dict['p_value'] <= alpha)
            
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_values[{i}]: {result_dict['p_value']}")
            print(f"FPR: {cnt4 / cnt2}, TPR: {cnt3 / cnt1}")
            print(f"is_not_signal: {int(cnt2), int(cnt4)}")
            print(f"is_signal: {int(cnt1), int(cnt3)}")
            print("===========================================================================")
                
            para_results_storage.append(result_dict)
    is_signal_cases = [r for r in para_results_storage if r['is_signal']]
    not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

    false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
    fpr = false_positives / len(not_signal_cases) if len(not_signal_cases) != 0 else -1
    true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha) 
    tpr = true_positives / len(is_signal_cases) if len(is_signal_cases) != 0 else -1

    configs = {
        "n_source": n_source,
        "p":  p,
        "K": K,
        "Ka": Ka,
        "h": h,
        "alpha": alpha,
        "T":  T,
        "s_len": s_len,
        "s_vector": s_vector,
        "n_target": n_target,
        "iteration": iteration,
    }

    results = {
        "configs": configs,
        "time": datetime.datetime.now().ctime(),
        "fpr": fpr,
        "tpr": tpr,
        "is_signal_cases": len(is_signal_cases),
        "not_signal_cases": len(not_signal_cases),
        "false_positives": false_positives,
        "true_positives": true_positives
    }

    filename = 'records/TPR_parametric_vis_records.json'
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            try:
                records = json.load(f)
            except Exception as e:
                print(e)
                records = []
    else:
        records = []

    records.append(results)

    with open(filename, 'w') as f:
        json.dump(records, f, indent=4)
# Out:
# -- n_target = 40 --
# is_signal : True, p_values[0]: 0.025216784408720286
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : True, p_values[1]: 0.0005257392710020984
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (2, 2)
# ===========================================================================
# is_signal : True, p_values[2]: 0.9754311824384709
# FPR: nan, TPR: 0.6666666666666666
# is_not_signal: (0, 0)
# is_signal: (3, 2)
# ===========================================================================
# is_signal : True, p_values[3]: 0.8104150162581802
# FPR: nan, TPR: 0.5
# is_not_signal: (0, 0)
# is_signal: (4, 2)
# ===========================================================================
# is_signal : True, p_values[4]: 0.8135991566647497
# FPR: nan, TPR: 0.4
# is_not_signal: (0, 0)
# is_signal: (5, 2)
# ===========================================================================
# is_signal : True, p_values[5]: 0.0008888253547786966
# FPR: nan, TPR: 0.5
# is_not_signal: (0, 0)
# is_signal: (6, 3)
# ===========================================================================
# is_signal : True, p_values[6]: 0.37540965171909074
# FPR: nan, TPR: 0.42857142857142855
# is_not_signal: (0, 0)
# is_signal: (7, 3)
# ===========================================================================
# is_signal : True, p_values[7]: 0.2904178016731907
# FPR: nan, TPR: 0.375
# is_not_signal: (0, 0)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : False, p_values[8]: 0.3375079357037829
# FPR: 0.0, TPR: 0.375
# is_not_signal: (1, 0)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : True, p_values[9]: 0.33862610531118525
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (1, 0)
# is_signal: (9, 3)
# ===========================================================================
# is_signal : True, p_values[10]: 0.667958815232952
# FPR: 0.0, TPR: 0.3
# is_not_signal: (1, 0)
# is_signal: (10, 3)
# ===========================================================================
# is_signal : True, p_values[11]: 0.44301475482551544
# FPR: 0.0, TPR: 0.2727272727272727
# is_not_signal: (1, 0)
# is_signal: (11, 3)
# ===========================================================================
# is_signal : True, p_values[12]: 0.6367325478617364
# FPR: 0.0, TPR: 0.25
# is_not_signal: (1, 0)
# is_signal: (12, 3)
# ===========================================================================
# is_signal : True, p_values[13]: 0.8351820286906592
# FPR: 0.0, TPR: 0.23076923076923078
# is_not_signal: (1, 0)
# is_signal: (13, 3)
# ===========================================================================
# is_signal : True, p_values[14]: 0.11413058103900943
# FPR: 0.0, TPR: 0.21428571428571427
# is_not_signal: (1, 0)
# is_signal: (14, 3)
# ===========================================================================
# is_signal : True, p_values[15]: 0.5558424757416303
# FPR: 0.0, TPR: 0.2
# is_not_signal: (1, 0)
# is_signal: (15, 3)
# ===========================================================================
# is_signal : True, p_values[16]: 0.5248941465718531
# FPR: 0.0, TPR: 0.1875
# is_not_signal: (1, 0)
# is_signal: (16, 3)
# ===========================================================================
# is_signal : True, p_values[17]: 0.0025104915262972945
# FPR: 0.0, TPR: 0.23529411764705882
# is_not_signal: (1, 0)
# is_signal: (17, 4)
# ===========================================================================
# is_signal : True, p_values[18]: 0.09663134387705874
# FPR: 0.0, TPR: 0.2222222222222222
# is_not_signal: (1, 0)
# is_signal: (18, 4)
# ===========================================================================
# R_aug, z2: 0.09553923815551595, 0.09553933834700927
# is_signal : True, p_values[19]: 0.05965167912810669
# FPR: 0.0, TPR: 0.21052631578947367
# is_not_signal: (1, 0)
# is_signal: (19, 4)
# ===========================================================================
# is_signal : True, p_values[20]: 0.03186618958500664
# FPR: 0.0, TPR: 0.25
# is_not_signal: (1, 0)
# is_signal: (20, 5)
# ===========================================================================
# is_signal : True, p_values[21]: 0.060048615338200446
# FPR: 0.0, TPR: 0.23809523809523808
# is_not_signal: (1, 0)
# is_signal: (21, 5)
# ===========================================================================
# is_signal : True, p_values[22]: 0.03987350442386638
# FPR: 0.0, TPR: 0.2727272727272727
# is_not_signal: (1, 0)
# is_signal: (22, 6)
# ===========================================================================
# is_signal : True, p_values[23]: 0.3590314201574777
# FPR: 0.0, TPR: 0.2608695652173913
# is_not_signal: (1, 0)
# is_signal: (23, 6)
# ===========================================================================
# is_signal : False, p_values[24]: 0.9647099735724256
# FPR: 0.0, TPR: 0.2608695652173913
# is_not_signal: (2, 0)
# is_signal: (23, 6)
# ===========================================================================
# is_signal : True, p_values[25]: 0.06582839463627209
# FPR: 0.0, TPR: 0.25
# is_not_signal: (2, 0)
# is_signal: (24, 6)
# ===========================================================================
# is_signal : True, p_values[26]: 0.005620056909725873
# FPR: 0.0, TPR: 0.28
# is_not_signal: (2, 0)
# is_signal: (25, 7)
# ===========================================================================
# is_signal : True, p_values[27]: 0.34293557645736605
# FPR: 0.0, TPR: 0.2692307692307692
# is_not_signal: (2, 0)
# is_signal: (26, 7)
# ===========================================================================
# is_signal : True, p_values[28]: 0.19436128581955373
# FPR: 0.0, TPR: 0.25925925925925924
# is_not_signal: (2, 0)
# is_signal: (27, 7)
# ===========================================================================
# is_signal : False, p_values[29]: 0.3844449135374161
# FPR: 0.0, TPR: 0.25925925925925924
# is_not_signal: (3, 0)
# is_signal: (27, 7)
# ===========================================================================
# is_signal : True, p_values[30]: 0.5002980151969826
# FPR: 0.0, TPR: 0.25
# is_not_signal: (3, 0)
# is_signal: (28, 7)
# ===========================================================================
# is_signal : True, p_values[31]: 0.007818144016599764
# FPR: 0.0, TPR: 0.27586206896551724
# is_not_signal: (3, 0)
# is_signal: (29, 8)
# ===========================================================================
# is_signal : False, p_values[32]: 0.12525409151296943
# FPR: 0.0, TPR: 0.27586206896551724
# is_not_signal: (4, 0)
# is_signal: (29, 8)
# ===========================================================================
# is_signal : True, p_values[33]: 0.22622101110760628
# FPR: 0.0, TPR: 0.26666666666666666
# is_not_signal: (4, 0)
# is_signal: (30, 8)
# ===========================================================================
# is_signal : True, p_values[34]: 0.0034477964578934284
# FPR: 0.0, TPR: 0.2903225806451613
# is_not_signal: (4, 0)
# is_signal: (31, 9)
# ===========================================================================
# is_signal : True, p_values[35]: 0.0025636556019234093
# FPR: 0.0, TPR: 0.3125
# is_not_signal: (4, 0)
# is_signal: (32, 10)
# ===========================================================================
# is_signal : False, p_values[36]: 0.32508870491257463
# FPR: 0.0, TPR: 0.3125
# is_not_signal: (5, 0)
# is_signal: (32, 10)
# ===========================================================================
# is_signal : False, p_values[37]: 0.04699957402938943
# FPR: 0.16666666666666666, TPR: 0.3125
# is_not_signal: (6, 1)
# is_signal: (32, 10)
# ===========================================================================
# is_signal : True, p_values[38]: 0.005769619389696698
# FPR: 0.16666666666666666, TPR: 0.3333333333333333
# is_not_signal: (6, 1)
# is_signal: (33, 11)
# ===========================================================================
# is_signal : True, p_values[39]: 0.0711291878131245
# FPR: 0.16666666666666666, TPR: 0.3235294117647059
# is_not_signal: (6, 1)
# is_signal: (34, 11)
# ===========================================================================
# is_signal : True, p_values[40]: 0.6972866805572329
# FPR: 0.16666666666666666, TPR: 0.3142857142857143
# is_not_signal: (6, 1)
# is_signal: (35, 11)
# ===========================================================================
# is_signal : True, p_values[41]: 0.5673355141357865
# FPR: 0.16666666666666666, TPR: 0.3055555555555556
# is_not_signal: (6, 1)
# is_signal: (36, 11)
# ===========================================================================
# is_signal : True, p_values[42]: 0.23409159503924204
# FPR: 0.16666666666666666, TPR: 0.2972972972972973
# is_not_signal: (6, 1)
# is_signal: (37, 11)
# ===========================================================================
# is_signal : True, p_values[43]: 0.6793590136730968
# FPR: 0.16666666666666666, TPR: 0.2894736842105263
# is_not_signal: (6, 1)
# is_signal: (38, 11)
# ===========================================================================
# is_signal : True, p_values[44]: 0.00610450221441505
# FPR: 0.16666666666666666, TPR: 0.3076923076923077
# is_not_signal: (6, 1)
# is_signal: (39, 12)
# ===========================================================================
# is_signal : False, p_values[45]: 0.5275722659339049
# FPR: 0.14285714285714285, TPR: 0.3076923076923077
# is_not_signal: (7, 1)
# is_signal: (39, 12)
# ===========================================================================
# is_signal : True, p_values[46]: 0.7100596409104586
# FPR: 0.14285714285714285, TPR: 0.3
# is_not_signal: (7, 1)
# is_signal: (40, 12)
# ===========================================================================
# is_signal : True, p_values[47]: 0.17089448325604528
# FPR: 0.14285714285714285, TPR: 0.2926829268292683
# is_not_signal: (7, 1)
# is_signal: (41, 12)
# ===========================================================================
# is_signal : True, p_values[48]: 0.4543610839605812
# FPR: 0.14285714285714285, TPR: 0.2857142857142857
# is_not_signal: (7, 1)
# is_signal: (42, 12)
# ===========================================================================
# is_signal : True, p_values[49]: 0.01762263290586136
# FPR: 0.14285714285714285, TPR: 0.3023255813953488
# is_not_signal: (7, 1)
# is_signal: (43, 13)
# ===========================================================================
# is_signal : True, p_values[50]: 0.0066074300663663725
# FPR: 0.14285714285714285, TPR: 0.3181818181818182
# is_not_signal: (7, 1)
# is_signal: (44, 14)
# ===========================================================================
# is_signal : True, p_values[51]: 0.007121536034888114
# FPR: 0.14285714285714285, TPR: 0.3333333333333333
# is_not_signal: (7, 1)
# is_signal: (45, 15)
# ===========================================================================
# is_signal : True, p_values[52]: 0.0016487640155469913
# FPR: 0.14285714285714285, TPR: 0.34782608695652173
# is_not_signal: (7, 1)
# is_signal: (46, 16)
# ===========================================================================
# is_signal : True, p_values[53]: 0.10518475273140056
# FPR: 0.14285714285714285, TPR: 0.3404255319148936
# is_not_signal: (7, 1)
# is_signal: (47, 16)
# ===========================================================================
# is_signal : True, p_values[54]: 0.3744992258935173
# FPR: 0.14285714285714285, TPR: 0.3333333333333333
# is_not_signal: (7, 1)
# is_signal: (48, 16)
# ===========================================================================
# is_signal : False, p_values[55]: 0.19927665344737153
# FPR: 0.125, TPR: 0.3333333333333333
# is_not_signal: (8, 1)
# is_signal: (48, 16)
# ===========================================================================
# is_signal : True, p_values[56]: 0.06467281666106782
# FPR: 0.125, TPR: 0.32653061224489793
# is_not_signal: (8, 1)
# is_signal: (49, 16)
# ===========================================================================
# is_signal : True, p_values[57]: 0.10436587822080516
# FPR: 0.125, TPR: 0.32
# is_not_signal: (8, 1)
# is_signal: (50, 16)
# ===========================================================================
# is_signal : True, p_values[58]: 0.00279340447648059
# FPR: 0.125, TPR: 0.3333333333333333
# is_not_signal: (8, 1)
# is_signal: (51, 17)
# ===========================================================================
# is_signal : True, p_values[59]: 0.243730568401517
# FPR: 0.125, TPR: 0.3269230769230769
# is_not_signal: (8, 1)
# is_signal: (52, 17)
# ===========================================================================
# is_signal : True, p_values[60]: 0.010016033533876915
# FPR: 0.125, TPR: 0.33962264150943394
# is_not_signal: (8, 1)
# is_signal: (53, 18)
# ===========================================================================
# is_signal : True, p_values[61]: 0.09548273744513143
# FPR: 0.125, TPR: 0.3333333333333333
# is_not_signal: (8, 1)
# is_signal: (54, 18)
# ===========================================================================
# is_signal : True, p_values[62]: 0.13951325351017516
# FPR: 0.125, TPR: 0.32727272727272727
# is_not_signal: (8, 1)
# is_signal: (55, 18)
# ===========================================================================
# is_signal : False, p_values[63]: 0.3318780576862669
# FPR: 0.1111111111111111, TPR: 0.32727272727272727
# is_not_signal: (9, 1)
# is_signal: (55, 18)
# ===========================================================================
# is_signal : True, p_values[64]: 0.018784463008104383
# FPR: 0.1111111111111111, TPR: 0.3392857142857143
# is_not_signal: (9, 1)
# is_signal: (56, 19)
# ===========================================================================
# is_signal : True, p_values[65]: 0.6356249259577635
# FPR: 0.1111111111111111, TPR: 0.3333333333333333
# is_not_signal: (9, 1)
# is_signal: (57, 19)
# ===========================================================================
# -- n_target = 50 --
# is_signal : True, p_values[0]: 0.013968570940678177
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : True, p_values[1]: 0.0004250819249778864
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (2, 2)
# ===========================================================================
# is_signal : False, p_values[2]: 0.9677572239013333
# FPR: 0.0, TPR: 1.0
# is_not_signal: (1, 0)
# is_signal: (2, 2)
# ===========================================================================
# is_signal : True, p_values[3]: 0.26640100856646953
# FPR: 0.0, TPR: 0.6666666666666666
# is_not_signal: (1, 0)
# is_signal: (3, 2)
# ===========================================================================
# is_signal : True, p_values[4]: 0.049932689827304616
# FPR: 0.0, TPR: 0.75
# is_not_signal: (1, 0)
# is_signal: (4, 3)
# ===========================================================================
# is_signal : False, p_values[5]: 0.18550359807232747
# FPR: 0.0, TPR: 0.75
# is_not_signal: (2, 0)
# is_signal: (4, 3)
# ===========================================================================
# is_signal : True, p_values[6]: 0.005704263054201872
# FPR: 0.0, TPR: 0.8
# is_not_signal: (2, 0)
# is_signal: (5, 4)
# ===========================================================================
# is_signal : True, p_values[7]: 0.05483624153543658
# FPR: 0.0, TPR: 0.6666666666666666
# is_not_signal: (2, 0)
# is_signal: (6, 4)
# ===========================================================================
# is_signal : True, p_values[8]: 0.620229673945733
# FPR: 0.0, TPR: 0.5714285714285714
# is_not_signal: (2, 0)
# is_signal: (7, 4)
# ===========================================================================
# is_signal : True, p_values[9]: 0.02827946745948469
# FPR: 0.0, TPR: 0.625
# is_not_signal: (2, 0)
# is_signal: (8, 5)
# ===========================================================================
# is_signal : True, p_values[10]: 0.4258226575829079
# FPR: 0.0, TPR: 0.5555555555555556
# is_not_signal: (2, 0)
# is_signal: (9, 5)
# ===========================================================================
# is_signal : True, p_values[11]: 0.0006218056550405146
# FPR: 0.0, TPR: 0.6
# is_not_signal: (2, 0)
# is_signal: (10, 6)
# ===========================================================================
# is_signal : True, p_values[12]: 0.0809122483962886
# FPR: 0.0, TPR: 0.5454545454545454
# is_not_signal: (2, 0)
# is_signal: (11, 6)
# ===========================================================================
# is_signal : True, p_values[13]: 0.015543061988932058
# FPR: 0.0, TPR: 0.5833333333333334
# is_not_signal: (2, 0)
# is_signal: (12, 7)
# ===========================================================================
# is_signal : True, p_values[14]: 7.908594596108135e-05
# FPR: 0.0, TPR: 0.6153846153846154
# is_not_signal: (2, 0)
# is_signal: (13, 8)
# ===========================================================================
# is_signal : True, p_values[15]: 0.08317984193827797
# FPR: 0.0, TPR: 0.5714285714285714
# is_not_signal: (2, 0)
# is_signal: (14, 8)
# ===========================================================================
# is_signal : True, p_values[16]: 0.000334957875292256
# FPR: 0.0, TPR: 0.6
# is_not_signal: (2, 0)
# is_signal: (15, 9)
# ===========================================================================
# is_signal : True, p_values[17]: 0.036196681110585556
# FPR: 0.0, TPR: 0.625
# is_not_signal: (2, 0)
# is_signal: (16, 10)
# ===========================================================================
# is_signal : True, p_values[18]: 0.0012107416818764804
# FPR: 0.0, TPR: 0.6470588235294118
# is_not_signal: (2, 0)
# is_signal: (17, 11)
# ===========================================================================
# is_signal : True, p_values[19]: 0.2040635976773686
# FPR: 0.0, TPR: 0.6111111111111112
# is_not_signal: (2, 0)
# is_signal: (18, 11)
# ===========================================================================
# is_signal : True, p_values[20]: 0.3847282213266104
# FPR: 0.0, TPR: 0.5789473684210527
# is_not_signal: (2, 0)
# is_signal: (19, 11)
# ===========================================================================

# %%
n_source = 80
p = 200
K = 5
Ka = 3
h = 10
alpha = 0.05
T = 5
s_len = 10
s_vector = [0.0] * s_len
iteration = 125

n_target_list = [40, 50, 60, 70]

for n_target in n_target_list:
    print(f"-- n_target = {n_target} --")
    para_results_storage = []
    CoRT_model = CoRT_builder.CoRT()
    cnt1 = 0
    cnt2 = 0
    cnt3 = 0
    cnt4 = 0

    for i in range(iteration):
        target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
        result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, T, s_len)

        if result_dict != None:
            cnt1 += (result_dict['is_signal'] == True)
            cnt2 += (result_dict['is_signal'] == False)
            cnt3 += (result_dict['is_signal'] == True and result_dict['p_value'] <= alpha)
            cnt4 += (result_dict['is_signal'] == False and result_dict['p_value'] <= alpha)
            
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_values[{i}]: {result_dict['p_value']}")
            print(f"FPR: {cnt4 / cnt2}, TPR: {cnt3 / cnt1}")
            print(f"is_not_signal: {int(cnt2), int(cnt4)}")
            print(f"is_signal: {int(cnt1), int(cnt3)}")
            print("===========================================================================")
                
            para_results_storage.append(result_dict)
    is_signal_cases = [r for r in para_results_storage if r['is_signal']]
    not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

    false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
    fpr = false_positives / len(not_signal_cases) if len(not_signal_cases) != 0 else -1
    true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha) 
    tpr = true_positives / len(is_signal_cases) if len(is_signal_cases) != 0 else -1

    configs = {
        "n_source": n_source,
        "p":  p,
        "K": K,
        "Ka": Ka,
        "h": h,
        "alpha": alpha,
        "T":  T,
        "s_len": s_len,
        "s_vector": s_vector,
        "n_target": n_target,
        "iteration": iteration,
    }

    results = {
        "configs": configs,
        "time": datetime.datetime.now().ctime(),
        "fpr": fpr,
        "tpr": tpr,
        "is_signal_cases": len(is_signal_cases),
        "not_signal_cases": len(not_signal_cases),
        "false_positives": false_positives,
        "true_positives": true_positives
    }

    filename = 'records/FPR_parametric_vis_records.json'
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            try:
                records = json.load(f)
            except Exception as e:
                print(e)
                records = []
    else:
        records = []

    records.append(results)

    with open(filename, 'w') as f:
        json.dump(records, f, indent=4)
