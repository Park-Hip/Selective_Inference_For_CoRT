# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
# Đặt giới hạn số luồng xử lý cho mỗi thư viện tính toán về 1
os.environ["OMP_NUM_THREADS"] = "6"
os.environ["MKL_NUM_THREADS"] = "6"
os.environ["OPENBLAS_NUM_THREADS"] = "6"
os.environ["VECLIB_MAXIMUM_THREADS"] = "6"
os.environ["NUMEXPR_NUM_THREADS"] = "6"

# %%
import matplotlib.pyplot as plt
import numpy as np
import ex1_parametric
import os
import CoRT_builder
import SI_CoRT
import datetime
import json

# %%
n_target = 40
n_source = 80
p = 200
K = 7
h = 10
alpha = 0.05
T = 5
s_len = 10
s_vector = [0.5] * s_len

Ka_list = [1, 3, 5, 7]

iteration = 125

for Ka in Ka_list:
    print(f"-- Ka = {Ka} --")
    para_results_storage = []
    CoRT_model = CoRT_builder.CoRT()
    cnt1 = 0
    cnt2 = 0
    cnt3 = 0
    cnt4 = 0

    for i in range(iteration):
        target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
        result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, T, s_len)

        if result_dict != None:
            cnt1 += (result_dict['is_signal'] == True)
            cnt2 += (result_dict['is_signal'] == False)
            cnt3 += (result_dict['is_signal'] == True and result_dict['p_value'] <= alpha)
            cnt4 += (result_dict['is_signal'] == False and result_dict['p_value'] <= alpha)
            
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_values[{i}]: {result_dict['p_value']}")
            print(f"FPR: {cnt4 / cnt2}, TPR: {cnt3 / cnt1}")
            print(f"is_not_signal: {int(cnt2), int(cnt4)}")
            print(f"is_signal: {int(cnt1), int(cnt3)}")
            print("===========================================================================")
                
            para_results_storage.append(result_dict)
    is_signal_cases = [r for r in para_results_storage if r['is_signal']]
    not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

    false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
    fpr = false_positives / len(not_signal_cases) if len(not_signal_cases) != 0 else -1
    true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha) 
    tpr = true_positives / len(is_signal_cases) if len(is_signal_cases) != 0 else -1

    configs = {
        "n_source": n_source,
        "p":  p,
        "K": K,
        "Ka": Ka,
        "h": h,
        "alpha": alpha,
        "T":  T,
        "s_len": s_len,
        "s_vector": s_vector,
        "n_target": n_target,
        "iteration": iteration,
    }

    results = {
        "configs": configs,
        "time": datetime.datetime.now().ctime(),
        "fpr": fpr,
        "tpr": tpr,
        "is_signal_cases": len(is_signal_cases),
        "not_signal_cases": len(not_signal_cases),
        "false_positives": false_positives,
        "true_positives": true_positives
    }

    filename = 'records_4/TPR_parametric_vis_records.json'
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            try:
                records = json.load(f)
            except Exception as e:
                print(e)
                records = []
    else:
        records = []

    records.append(results)

    with open(filename, 'w') as f:
        json.dump(records, f, indent=4)
# Out:
# -- Ka = 1 --
# is_signal : True, p_values[0]: 0.4814538966869638
# FPR: nan, TPR: 0.0
# is_not_signal: (0, 0)
# is_signal: (1, 0)
# ===========================================================================
# is_signal : False, p_values[1]: 0.9156920492879593
# FPR: 0.0, TPR: 0.0
# is_not_signal: (1, 0)
# is_signal: (1, 0)
# ===========================================================================
# is_signal : True, p_values[2]: 0.34246479138029534
# FPR: 0.0, TPR: 0.0
# is_not_signal: (1, 0)
# is_signal: (2, 0)
# ===========================================================================
# is_signal : False, p_values[3]: 0.23546102400901192
# FPR: 0.0, TPR: 0.0
# is_not_signal: (2, 0)
# is_signal: (2, 0)
# ===========================================================================
# is_signal : True, p_values[4]: 0.6523748358397985
# FPR: 0.0, TPR: 0.0
# is_not_signal: (2, 0)
# is_signal: (3, 0)
# ===========================================================================
# is_signal : False, p_values[5]: 0.6383239414749108
# FPR: 0.0, TPR: 0.0
# is_not_signal: (3, 0)
# is_signal: (3, 0)
# ===========================================================================
# is_signal : False, p_values[6]: 0.9443871265253037
# FPR: 0.0, TPR: 0.0
# is_not_signal: (4, 0)
# is_signal: (3, 0)
# ===========================================================================
# is_signal : True, p_values[7]: 0.0007925358518167674
# FPR: 0.0, TPR: 0.25
# is_not_signal: (4, 0)
# is_signal: (4, 1)
# ===========================================================================
# is_signal : False, p_values[8]: 0.011783164814851598
# FPR: 0.2, TPR: 0.25
# is_not_signal: (5, 1)
# is_signal: (4, 1)
# ===========================================================================
# is_signal : False, p_values[9]: 0.8853422680833355
# FPR: 0.16666666666666666, TPR: 0.25
# is_not_signal: (6, 1)
# is_signal: (4, 1)
# ===========================================================================
# is_signal : True, p_values[10]: 1.0303616290863826e-05
# FPR: 0.16666666666666666, TPR: 0.4
# is_not_signal: (6, 1)
# is_signal: (5, 2)
# ===========================================================================
# is_signal : True, p_values[11]: 0.8030220713716538
# FPR: 0.16666666666666666, TPR: 0.3333333333333333
# is_not_signal: (6, 1)
# is_signal: (6, 2)
# ===========================================================================
# is_signal : False, p_values[12]: 0.06676245592063884
# FPR: 0.14285714285714285, TPR: 0.3333333333333333
# is_not_signal: (7, 1)
# is_signal: (6, 2)
# ===========================================================================
# is_signal : False, p_values[13]: 0.9021005228427238
# FPR: 0.125, TPR: 0.3333333333333333
# is_not_signal: (8, 1)
# is_signal: (6, 2)
# ===========================================================================
# is_signal : True, p_values[14]: 0.5128077022420617
# FPR: 0.125, TPR: 0.2857142857142857
# is_not_signal: (8, 1)
# is_signal: (7, 2)
# ===========================================================================
# is_signal : True, p_values[15]: 0.014013477382908616
# FPR: 0.125, TPR: 0.375
# is_not_signal: (8, 1)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : False, p_values[16]: 0.5940374559202896
# FPR: 0.1111111111111111, TPR: 0.375
# is_not_signal: (9, 1)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : True, p_values[17]: 0.08273465770728594
# FPR: 0.1111111111111111, TPR: 0.3333333333333333
# is_not_signal: (9, 1)
# is_signal: (9, 3)
# ===========================================================================
# is_signal : True, p_values[18]: 0.7900732626844253
# FPR: 0.1111111111111111, TPR: 0.3
# is_not_signal: (9, 1)
# is_signal: (10, 3)
# ===========================================================================
# is_signal : True, p_values[19]: 0.9163605947436604
# FPR: 0.1111111111111111, TPR: 0.2727272727272727
# is_not_signal: (9, 1)
# is_signal: (11, 3)
# ===========================================================================
# is_signal : True, p_values[20]: 0.09907188934828876
# FPR: 0.1111111111111111, TPR: 0.25
# is_not_signal: (9, 1)
# is_signal: (12, 3)
# ===========================================================================
# is_signal : False, p_values[21]: 0.4333272055456103
# FPR: 0.1, TPR: 0.25
# is_not_signal: (10, 1)
# is_signal: (12, 3)
# ===========================================================================
# is_signal : False, p_values[22]: 0.6903318986933586
# FPR: 0.09090909090909091, TPR: 0.25
# is_not_signal: (11, 1)
# is_signal: (12, 3)
# ===========================================================================
# is_signal : False, p_values[23]: 0.0320609539585589
# FPR: 0.16666666666666666, TPR: 0.25
# is_not_signal: (12, 2)
# is_signal: (12, 3)
# ===========================================================================
# is_signal : True, p_values[24]: 0.015977183941004457
# FPR: 0.16666666666666666, TPR: 0.3076923076923077
# is_not_signal: (12, 2)
# is_signal: (13, 4)
# ===========================================================================
# is_signal : True, p_values[25]: 0.6019962562051647
# FPR: 0.16666666666666666, TPR: 0.2857142857142857
# is_not_signal: (12, 2)
# is_signal: (14, 4)
# ===========================================================================
# is_signal : True, p_values[26]: 0.3986706548020037
# FPR: 0.16666666666666666, TPR: 0.26666666666666666
# is_not_signal: (12, 2)
# is_signal: (15, 4)
# ===========================================================================
# is_signal : True, p_values[27]: 0.00020517611205665733
# FPR: 0.16666666666666666, TPR: 0.3125
# is_not_signal: (12, 2)
# is_signal: (16, 5)
# ===========================================================================
# is_signal : True, p_values[28]: 0.7686356549754219
# FPR: 0.16666666666666666, TPR: 0.29411764705882354
# is_not_signal: (12, 2)
# is_signal: (17, 5)
# ===========================================================================
# is_signal : True, p_values[29]: 0.10228282015335756
# FPR: 0.16666666666666666, TPR: 0.2777777777777778
# is_not_signal: (12, 2)
# is_signal: (18, 5)
# ===========================================================================
# is_signal : False, p_values[30]: 0.9148282009190212
# FPR: 0.15384615384615385, TPR: 0.2777777777777778
# is_not_signal: (13, 2)
# is_signal: (18, 5)
# ===========================================================================
# is_signal : False, p_values[31]: 0.956103666377753
# FPR: 0.14285714285714285, TPR: 0.2777777777777778
# is_not_signal: (14, 2)
# is_signal: (18, 5)
# ===========================================================================
# is_signal : False, p_values[32]: 0.6432427032184507
# FPR: 0.13333333333333333, TPR: 0.2777777777777778
# is_not_signal: (15, 2)
# is_signal: (18, 5)
# ===========================================================================
# is_signal : False, p_values[33]: 0.5298911898091332
# FPR: 0.125, TPR: 0.2777777777777778
# is_not_signal: (16, 2)
# is_signal: (18, 5)
# ===========================================================================
# is_signal : False, p_values[34]: 0.7632757686988829
# FPR: 0.11764705882352941, TPR: 0.2777777777777778
# is_not_signal: (17, 2)
# is_signal: (18, 5)
# ===========================================================================
# is_signal : True, p_values[35]: 0.0017080046144023566
# FPR: 0.11764705882352941, TPR: 0.3157894736842105
# is_not_signal: (17, 2)
# is_signal: (19, 6)
# ===========================================================================
# is_signal : False, p_values[36]: 0.12948642997169335
# FPR: 0.1111111111111111, TPR: 0.3157894736842105
# is_not_signal: (18, 2)
# is_signal: (19, 6)
# ===========================================================================
# is_signal : True, p_values[37]: 0.03508565459916307
# FPR: 0.1111111111111111, TPR: 0.35
# is_not_signal: (18, 2)
# is_signal: (20, 7)
# ===========================================================================
# is_signal : True, p_values[38]: 0.0009508001835451146
# FPR: 0.1111111111111111, TPR: 0.38095238095238093
# is_not_signal: (18, 2)
# is_signal: (21, 8)
# ===========================================================================
# is_signal : True, p_values[39]: 0.029559829259593138
# FPR: 0.1111111111111111, TPR: 0.4090909090909091
# is_not_signal: (18, 2)
# is_signal: (22, 9)
# ===========================================================================
# is_signal : False, p_values[40]: 0.377628225466714
# FPR: 0.10526315789473684, TPR: 0.4090909090909091
# is_not_signal: (19, 2)
# is_signal: (22, 9)
# ===========================================================================
# is_signal : False, p_values[41]: 0.08090399272408215
# FPR: 0.1, TPR: 0.4090909090909091
# is_not_signal: (20, 2)
# is_signal: (22, 9)
# ===========================================================================
# is_signal : True, p_values[42]: 0.4100276182534865
# FPR: 0.1, TPR: 0.391304347826087
# is_not_signal: (20, 2)
# is_signal: (23, 9)
# ===========================================================================
# is_signal : True, p_values[43]: 0.017111152635041756
# FPR: 0.1, TPR: 0.4166666666666667
# is_not_signal: (20, 2)
# is_signal: (24, 10)
# ===========================================================================
# is_signal : True, p_values[44]: 0.47284999348334594
# FPR: 0.1, TPR: 0.4
# is_not_signal: (20, 2)
# is_signal: (25, 10)
# ===========================================================================
# is_signal : False, p_values[45]: 0.003252868886138153
# FPR: 0.14285714285714285, TPR: 0.4
# is_not_signal: (21, 3)
# is_signal: (25, 10)
# ===========================================================================
# is_signal : False, p_values[46]: 0.4738966949686361
# FPR: 0.13636363636363635, TPR: 0.4
# is_not_signal: (22, 3)
# is_signal: (25, 10)
# ===========================================================================
# is_signal : False, p_values[47]: 0.730715453410956
# FPR: 0.13043478260869565, TPR: 0.4
# is_not_signal: (23, 3)
# is_signal: (25, 10)
# ===========================================================================
# is_signal : True, p_values[48]: 3.258149691583711e-05
# FPR: 0.13043478260869565, TPR: 0.4230769230769231
# is_not_signal: (23, 3)
# is_signal: (26, 11)
# ===========================================================================
# is_signal : True, p_values[49]: 0.1781198925302019
# FPR: 0.13043478260869565, TPR: 0.4074074074074074
# is_not_signal: (23, 3)
# is_signal: (27, 11)
# ===========================================================================
# is_signal : False, p_values[50]: 0.5704719008248794
# FPR: 0.125, TPR: 0.4074074074074074
# is_not_signal: (24, 3)
# is_signal: (27, 11)
# ===========================================================================
# is_signal : True, p_values[51]: 0.0013263817369839304
# FPR: 0.125, TPR: 0.42857142857142855
# is_not_signal: (24, 3)
# is_signal: (28, 12)
# ===========================================================================
# is_signal : True, p_values[52]: 0.0012919974793323538
# FPR: 0.125, TPR: 0.4482758620689655
# is_not_signal: (24, 3)
# is_signal: (29, 13)
# ===========================================================================
# is_signal : True, p_values[53]: 0.9255531365520723
# FPR: 0.125, TPR: 0.43333333333333335
# is_not_signal: (24, 3)
# is_signal: (30, 13)
# ===========================================================================
# is_signal : False, p_values[54]: 0.3391454709967467
# FPR: 0.12, TPR: 0.43333333333333335
# is_not_signal: (25, 3)
# is_signal: (30, 13)
# ===========================================================================
# is_signal : True, p_values[55]: 0.7864657841580646
# FPR: 0.12, TPR: 0.41935483870967744
# is_not_signal: (25, 3)
# is_signal: (31, 13)
# ===========================================================================
# is_signal : True, p_values[56]: 0.48191200035503534
# FPR: 0.12, TPR: 0.40625
# is_not_signal: (25, 3)
# is_signal: (32, 13)
# ===========================================================================
# is_signal : False, p_values[57]: 0.9289501804092672
# FPR: 0.11538461538461539, TPR: 0.40625
# is_not_signal: (26, 3)
# is_signal: (32, 13)
# ===========================================================================
# is_signal : True, p_values[58]: 0.21757029200971906
# FPR: 0.11538461538461539, TPR: 0.3939393939393939
# is_not_signal: (26, 3)
# is_signal: (33, 13)
# ===========================================================================
# is_signal : False, p_values[59]: 0.6875521770309413
# FPR: 0.1111111111111111, TPR: 0.3939393939393939
# is_not_signal: (27, 3)
# is_signal: (33, 13)
# ===========================================================================
# is_signal : False, p_values[60]: 0.7121415355539477
# FPR: 0.10714285714285714, TPR: 0.3939393939393939
# is_not_signal: (28, 3)
# is_signal: (33, 13)
# ===========================================================================
# is_signal : True, p_values[61]: 0.2529223058734691
# FPR: 0.10714285714285714, TPR: 0.38235294117647056
# is_not_signal: (28, 3)
# is_signal: (34, 13)
# ===========================================================================
# is_signal : True, p_values[62]: 0.4323349426816239
# FPR: 0.10714285714285714, TPR: 0.37142857142857144
# is_not_signal: (28, 3)
# is_signal: (35, 13)
# ===========================================================================
# is_signal : True, p_values[63]: 0.04135796231228934
# FPR: 0.10714285714285714, TPR: 0.3888888888888889
# is_not_signal: (28, 3)
# is_signal: (36, 14)
# ===========================================================================
# is_signal : False, p_values[64]: 0.8746948647871206
# FPR: 0.10344827586206896, TPR: 0.3888888888888889
# is_not_signal: (29, 3)
# is_signal: (36, 14)
# ===========================================================================
# is_signal : False, p_values[65]: 0.9757300199939192
# FPR: 0.1, TPR: 0.3888888888888889
# is_not_signal: (30, 3)
# is_signal: (36, 14)
# ===========================================================================
# is_signal : False, p_values[66]: 0.38248636947457354
# FPR: 0.0967741935483871, TPR: 0.3888888888888889
# is_not_signal: (31, 3)
# is_signal: (36, 14)
# ===========================================================================
# is_signal : False, p_values[67]: 0.3148636602492409
# FPR: 0.09375, TPR: 0.3888888888888889
# is_not_signal: (32, 3)
# is_signal: (36, 14)
# ===========================================================================
# is_signal : True, p_values[68]: 0.0002587564136878322
# FPR: 0.09375, TPR: 0.40540540540540543
# is_not_signal: (32, 3)
# is_signal: (37, 15)
# ===========================================================================
# is_signal : False, p_values[69]: 0.7534206784589096
# FPR: 0.09090909090909091, TPR: 0.40540540540540543
# is_not_signal: (33, 3)
# is_signal: (37, 15)
# ===========================================================================
# is_signal : True, p_values[70]: 0.3846836604893076
# FPR: 0.09090909090909091, TPR: 0.39473684210526316
# is_not_signal: (33, 3)
# is_signal: (38, 15)
# ===========================================================================
# is_signal : False, p_values[71]: 0.7589629046292751
# FPR: 0.08823529411764706, TPR: 0.39473684210526316
# is_not_signal: (34, 3)
# is_signal: (38, 15)
# ===========================================================================
# is_signal : False, p_values[72]: 0.22642584104964447
# FPR: 0.08571428571428572, TPR: 0.39473684210526316
# is_not_signal: (35, 3)
# is_signal: (38, 15)
# ===========================================================================
# is_signal : True, p_values[73]: 0.0658236549795193
# FPR: 0.08571428571428572, TPR: 0.38461538461538464
# is_not_signal: (35, 3)
# is_signal: (39, 15)
# ===========================================================================
# is_signal : True, p_values[74]: 0.08966463595389362
# FPR: 0.08571428571428572, TPR: 0.375
# is_not_signal: (35, 3)
# is_signal: (40, 15)
# ===========================================================================
# is_signal : False, p_values[75]: 0.19979355906548324
# FPR: 0.08333333333333333, TPR: 0.375
# is_not_signal: (36, 3)
# is_signal: (40, 15)
# ===========================================================================
# is_signal : True, p_values[76]: 0.147910455882962
# FPR: 0.08333333333333333, TPR: 0.36585365853658536
# is_not_signal: (36, 3)
# is_signal: (41, 15)
# ===========================================================================
# is_signal : False, p_values[77]: 0.3249556429444459
# FPR: 0.08108108108108109, TPR: 0.36585365853658536
# is_not_signal: (37, 3)
# is_signal: (41, 15)
# ===========================================================================
# is_signal : True, p_values[78]: 0.15535061172764442
# FPR: 0.08108108108108109, TPR: 0.35714285714285715
# is_not_signal: (37, 3)
# is_signal: (42, 15)
# ===========================================================================
# is_signal : True, p_values[79]: 0.0005338029498096087
# FPR: 0.08108108108108109, TPR: 0.37209302325581395
# is_not_signal: (37, 3)
# is_signal: (43, 16)
# ===========================================================================
# is_signal : True, p_values[80]: 0.9850729680958039
# FPR: 0.08108108108108109, TPR: 0.36363636363636365
# is_not_signal: (37, 3)
# is_signal: (44, 16)
# ===========================================================================
# is_signal : False, p_values[81]: 0.34176071886549597
# FPR: 0.07894736842105263, TPR: 0.36363636363636365
# is_not_signal: (38, 3)
# is_signal: (44, 16)
# ===========================================================================
# is_signal : True, p_values[82]: 0.004260697169902639
# FPR: 0.07894736842105263, TPR: 0.37777777777777777
# is_not_signal: (38, 3)
# is_signal: (45, 17)
# ===========================================================================
# is_signal : True, p_values[83]: 0.023633538569480448
# FPR: 0.07894736842105263, TPR: 0.391304347826087
# is_not_signal: (38, 3)
# is_signal: (46, 18)
# ===========================================================================
# is_signal : True, p_values[84]: 0.12243983133114661
# FPR: 0.07894736842105263, TPR: 0.3829787234042553
# is_not_signal: (38, 3)
# is_signal: (47, 18)
# ===========================================================================
# is_signal : False, p_values[85]: 0.017356968535904686
# FPR: 0.10256410256410256, TPR: 0.3829787234042553
# is_not_signal: (39, 4)
# is_signal: (47, 18)
# ===========================================================================
# is_signal : True, p_values[86]: 0.13701401824098308
# FPR: 0.10256410256410256, TPR: 0.375
# is_not_signal: (39, 4)
# is_signal: (48, 18)
# ===========================================================================
# is_signal : False, p_values[87]: 0.21962350568387035
# FPR: 0.1, TPR: 0.375
# is_not_signal: (40, 4)
# is_signal: (48, 18)
# ===========================================================================
# is_signal : True, p_values[88]: 0.04523149349433749
# FPR: 0.1, TPR: 0.3877551020408163
# is_not_signal: (40, 4)
# is_signal: (49, 19)
# ===========================================================================
# is_signal : True, p_values[89]: 0.10053364055138847
# FPR: 0.1, TPR: 0.38
# is_not_signal: (40, 4)
# is_signal: (50, 19)
# ===========================================================================
# is_signal : False, p_values[90]: 0.06785219368596837
# FPR: 0.0975609756097561, TPR: 0.38
# is_not_signal: (41, 4)
# is_signal: (50, 19)
# ===========================================================================
# is_signal : True, p_values[91]: 0.016469173094290798
# FPR: 0.0975609756097561, TPR: 0.39215686274509803
# is_not_signal: (41, 4)
# is_signal: (51, 20)
# ===========================================================================
# is_signal : True, p_values[92]: 0.11048393763376332
# FPR: 0.0975609756097561, TPR: 0.38461538461538464
# is_not_signal: (41, 4)
# is_signal: (52, 20)
# ===========================================================================
# is_signal : True, p_values[93]: 0.10912081119509649
# FPR: 0.0975609756097561, TPR: 0.37735849056603776
# is_not_signal: (41, 4)
# is_signal: (53, 20)
# ===========================================================================
# is_signal : True, p_values[94]: 0.03509193072577464
# FPR: 0.0975609756097561, TPR: 0.3888888888888889
# is_not_signal: (41, 4)
# is_signal: (54, 21)
# ===========================================================================
# is_signal : False, p_values[95]: 0.17950805235453807
# FPR: 0.09523809523809523, TPR: 0.3888888888888889
# is_not_signal: (42, 4)
# is_signal: (54, 21)
# ===========================================================================
# is_signal : True, p_values[96]: 0.023158712516117324
# FPR: 0.09523809523809523, TPR: 0.4
# is_not_signal: (42, 4)
# is_signal: (55, 22)
# ===========================================================================
# is_signal : False, p_values[97]: 0.35710683737393306
# FPR: 0.09302325581395349, TPR: 0.4
# is_not_signal: (43, 4)
# is_signal: (55, 22)
# ===========================================================================
# is_signal : True, p_values[98]: 0.023103941463178887
# FPR: 0.09302325581395349, TPR: 0.4107142857142857
# is_not_signal: (43, 4)
# is_signal: (56, 23)
# ===========================================================================
# is_signal : True, p_values[99]: 0.08251466993474434
# FPR: 0.09302325581395349, TPR: 0.40350877192982454
# is_not_signal: (43, 4)
# is_signal: (57, 23)
# ===========================================================================
# is_signal : True, p_values[100]: 0.019531249133444867
# FPR: 0.09302325581395349, TPR: 0.41379310344827586
# is_not_signal: (43, 4)
# is_signal: (58, 24)
# ===========================================================================
# is_signal : True, p_values[101]: 0.4459868441839594
# FPR: 0.09302325581395349, TPR: 0.4067796610169492
# is_not_signal: (43, 4)
# is_signal: (59, 24)
# ===========================================================================
# is_signal : False, p_values[102]: 0.7747288310604752
# FPR: 0.09090909090909091, TPR: 0.4067796610169492
# is_not_signal: (44, 4)
# is_signal: (59, 24)
# ===========================================================================
# is_signal : False, p_values[103]: 0.48625474272017805
# FPR: 0.08888888888888889, TPR: 0.4067796610169492
# is_not_signal: (45, 4)
# is_signal: (59, 24)
# ===========================================================================
# is_signal : False, p_values[104]: 0.42989910167270134
# FPR: 0.08695652173913043, TPR: 0.4067796610169492
# is_not_signal: (46, 4)
# is_signal: (59, 24)
# ===========================================================================
# is_signal : False, p_values[105]: 0.4449790818607679
# FPR: 0.0851063829787234, TPR: 0.4067796610169492
# is_not_signal: (47, 4)
# is_signal: (59, 24)
# ===========================================================================
# is_signal : True, p_values[106]: 0.10228110309152937
# FPR: 0.0851063829787234, TPR: 0.4
# is_not_signal: (47, 4)
# is_signal: (60, 24)
# ===========================================================================
# is_signal : False, p_values[107]: 0.19547923215884966
# FPR: 0.08333333333333333, TPR: 0.4
# is_not_signal: (48, 4)
# is_signal: (60, 24)
# ===========================================================================
# is_signal : True, p_values[108]: 0.00012643243946670968
# FPR: 0.08333333333333333, TPR: 0.4098360655737705
# is_not_signal: (48, 4)
# is_signal: (61, 25)
# ===========================================================================
# is_signal : True, p_values[109]: 0.4292058211023083
# FPR: 0.08333333333333333, TPR: 0.4032258064516129
# is_not_signal: (48, 4)
# is_signal: (62, 25)
# ===========================================================================
# is_signal : False, p_values[110]: 0.030812011935889207
# FPR: 0.10204081632653061, TPR: 0.4032258064516129
# is_not_signal: (49, 5)
# is_signal: (62, 25)
# ===========================================================================
# is_signal : False, p_values[111]: 0.015775443514252512
# FPR: 0.12, TPR: 0.4032258064516129
# is_not_signal: (50, 6)
# is_signal: (62, 25)
# ===========================================================================
# is_signal : True, p_values[112]: 0.0002406615153175305
# FPR: 0.12, TPR: 0.4126984126984127
# is_not_signal: (50, 6)
# is_signal: (63, 26)
# ===========================================================================
# is_signal : False, p_values[113]: 0.2734963522249628
# FPR: 0.11764705882352941, TPR: 0.4126984126984127
# is_not_signal: (51, 6)
# is_signal: (63, 26)
# ===========================================================================
# is_signal : True, p_values[114]: 0.576122771952698
# FPR: 0.11764705882352941, TPR: 0.40625
# is_not_signal: (51, 6)
# is_signal: (64, 26)
# ===========================================================================
# is_signal : True, p_values[115]: 0.29626307175885513
# FPR: 0.11764705882352941, TPR: 0.4
# is_not_signal: (51, 6)
# is_signal: (65, 26)
# ===========================================================================
# is_signal : True, p_values[116]: 0.9696058400750368
# FPR: 0.11764705882352941, TPR: 0.3939393939393939
# is_not_signal: (51, 6)
# is_signal: (66, 26)
# ===========================================================================
# is_signal : False, p_values[117]: 0.4845302294052695
# FPR: 0.11538461538461539, TPR: 0.3939393939393939
# is_not_signal: (52, 6)
# is_signal: (66, 26)
# ===========================================================================
# is_signal : True, p_values[118]: 0.01931593623625408
# FPR: 0.11538461538461539, TPR: 0.40298507462686567
# is_not_signal: (52, 6)
# is_signal: (67, 27)
# ===========================================================================
# is_signal : False, p_values[119]: 0.8296086102129092
# FPR: 0.11320754716981132, TPR: 0.40298507462686567
# is_not_signal: (53, 6)
# is_signal: (67, 27)
# ===========================================================================
# is_signal : True, p_values[120]: 0.0020646955078404425
# FPR: 0.11320754716981132, TPR: 0.4117647058823529
# is_not_signal: (53, 6)
# is_signal: (68, 28)
# ===========================================================================
# is_signal : True, p_values[121]: 0.0030294980399392527
# FPR: 0.11320754716981132, TPR: 0.42028985507246375
# is_not_signal: (53, 6)
# is_signal: (69, 29)
# ===========================================================================
# is_signal : True, p_values[122]: 0.6901318722477526
# FPR: 0.11320754716981132, TPR: 0.4142857142857143
# is_not_signal: (53, 6)
# is_signal: (70, 29)
# ===========================================================================
# is_signal : False, p_values[123]: 0.3496992607111034
# FPR: 0.1111111111111111, TPR: 0.4142857142857143
# is_not_signal: (54, 6)
# is_signal: (70, 29)
# ===========================================================================
# is_signal : True, p_values[124]: 6.394992541259706e-05
# FPR: 0.1111111111111111, TPR: 0.4225352112676056
# is_not_signal: (54, 6)
# is_signal: (71, 30)
# ===========================================================================
# -- Ka = 3 --
# is_signal : False, p_values[0]: 0.3444693051023935
# FPR: 0.0, TPR: nan
# is_not_signal: (1, 0)
# is_signal: (0, 0)
# ===========================================================================
# is_signal : True, p_values[1]: 0.06414593596148399
# FPR: 0.0, TPR: 0.0
# is_not_signal: (1, 0)
# is_signal: (1, 0)
# ===========================================================================
# is_signal : True, p_values[2]: 0.015227264118226384
# FPR: 0.0, TPR: 0.5
# is_not_signal: (1, 0)
# is_signal: (2, 1)
# ===========================================================================
# is_signal : True, p_values[3]: 0.33608471963175707
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (1, 0)
# is_signal: (3, 1)
# ===========================================================================
# is_signal : True, p_values[4]: 0.43367098680979327
# FPR: 0.0, TPR: 0.25
# is_not_signal: (1, 0)
# is_signal: (4, 1)
# ===========================================================================
# is_signal : False, p_values[5]: 0.47389697520698565
# FPR: 0.0, TPR: 0.25
# is_not_signal: (2, 0)
# is_signal: (4, 1)
# ===========================================================================
# is_signal : True, p_values[6]: 0.07083906445105778
# FPR: 0.0, TPR: 0.2
# is_not_signal: (2, 0)
# is_signal: (5, 1)
# ===========================================================================
# is_signal : True, p_values[7]: 0.18858842341784157
# FPR: 0.0, TPR: 0.16666666666666666
# is_not_signal: (2, 0)
# is_signal: (6, 1)
# ===========================================================================
# is_signal : False, p_values[8]: 0.055713876417116136
# FPR: 0.0, TPR: 0.16666666666666666
# is_not_signal: (3, 0)
# is_signal: (6, 1)
# ===========================================================================
# is_signal : False, p_values[9]: 0.2848579938050325
# FPR: 0.0, TPR: 0.16666666666666666
# is_not_signal: (4, 0)
# is_signal: (6, 1)
# ===========================================================================
# is_signal : True, p_values[10]: 0.48625166340957393
# FPR: 0.0, TPR: 0.14285714285714285
# is_not_signal: (4, 0)
# is_signal: (7, 1)
# ===========================================================================
# is_signal : False, p_values[11]: 0.8712169220082834
# FPR: 0.0, TPR: 0.14285714285714285
# is_not_signal: (5, 0)
# is_signal: (7, 1)
# ===========================================================================
# is_signal : True, p_values[12]: 0.02063526254856303
# FPR: 0.0, TPR: 0.25
# is_not_signal: (5, 0)
# is_signal: (8, 2)
# ===========================================================================
# is_signal : False, p_values[13]: 0.9521730394734645
# FPR: 0.0, TPR: 0.25
# is_not_signal: (6, 0)
# is_signal: (8, 2)
# ===========================================================================
# is_signal : True, p_values[14]: 0.47588292177809133
# FPR: 0.0, TPR: 0.2222222222222222
# is_not_signal: (6, 0)
# is_signal: (9, 2)
# ===========================================================================
# is_signal : True, p_values[15]: 0.13899347062149617
# FPR: 0.0, TPR: 0.2
# is_not_signal: (6, 0)
# is_signal: (10, 2)
# ===========================================================================
# is_signal : True, p_values[16]: 0.000411326113481694
# FPR: 0.0, TPR: 0.2727272727272727
# is_not_signal: (6, 0)
# is_signal: (11, 3)
# ===========================================================================
# is_signal : False, p_values[17]: 0.10236830301412152
# FPR: 0.0, TPR: 0.2727272727272727
# is_not_signal: (7, 0)
# is_signal: (11, 3)
# ===========================================================================
# is_signal : True, p_values[18]: 0.10512112822459863
# FPR: 0.0, TPR: 0.25
# is_not_signal: (7, 0)
# is_signal: (12, 3)
# ===========================================================================
# is_signal : False, p_values[19]: 0.2341787106247345
# FPR: 0.0, TPR: 0.25
# is_not_signal: (8, 0)
# is_signal: (12, 3)
# ===========================================================================
# is_signal : False, p_values[20]: 0.3993585509479829
# FPR: 0.0, TPR: 0.25
# is_not_signal: (9, 0)
# is_signal: (12, 3)
# ===========================================================================
# is_signal : True, p_values[21]: 0.0051646301929011455
# FPR: 0.0, TPR: 0.3076923076923077
# is_not_signal: (9, 0)
# is_signal: (13, 4)
# ===========================================================================
# is_signal : False, p_values[22]: 0.5246653720058521
# FPR: 0.0, TPR: 0.3076923076923077
# is_not_signal: (10, 0)
# is_signal: (13, 4)
# ===========================================================================
# is_signal : True, p_values[23]: 0.11842678498599887
# FPR: 0.0, TPR: 0.2857142857142857
# is_not_signal: (10, 0)
# is_signal: (14, 4)
# ===========================================================================
# is_signal : True, p_values[24]: 7.942340371358755e-05
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (10, 0)
# is_signal: (15, 5)
# ===========================================================================
# is_signal : False, p_values[25]: 0.3845038143750555
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (11, 0)
# is_signal: (15, 5)
# ===========================================================================
# is_signal : False, p_values[26]: 0.1063632884655251
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (12, 0)
# is_signal: (15, 5)
# ===========================================================================
# is_signal : True, p_values[27]: 0.636133822887589
# FPR: 0.0, TPR: 0.3125
# is_not_signal: (12, 0)
# is_signal: (16, 5)
# ===========================================================================
# is_signal : True, p_values[28]: 0.444432992791321
# FPR: 0.0, TPR: 0.29411764705882354
# is_not_signal: (12, 0)
# is_signal: (17, 5)
# ===========================================================================
# is_signal : False, p_values[29]: 0.29562970211902684
# FPR: 0.0, TPR: 0.29411764705882354
# is_not_signal: (13, 0)
# is_signal: (17, 5)
# ===========================================================================
# is_signal : True, p_values[30]: 0.4142651425549105
# FPR: 0.0, TPR: 0.2777777777777778
# is_not_signal: (13, 0)
# is_signal: (18, 5)
# ===========================================================================
# is_signal : True, p_values[31]: 0.020396818419629655
# FPR: 0.0, TPR: 0.3157894736842105
# is_not_signal: (13, 0)
# is_signal: (19, 6)
# ===========================================================================
# is_signal : False, p_values[32]: 0.6119154253920424
# FPR: 0.0, TPR: 0.3157894736842105
# is_not_signal: (14, 0)
# is_signal: (19, 6)
# ===========================================================================
# is_signal : True, p_values[33]: 0.03165953618481305
# FPR: 0.0, TPR: 0.35
# is_not_signal: (14, 0)
# is_signal: (20, 7)
# ===========================================================================
# is_signal : False, p_values[34]: 0.18252242795973111
# FPR: 0.0, TPR: 0.35
# is_not_signal: (15, 0)
# is_signal: (20, 7)
# ===========================================================================
# is_signal : False, p_values[35]: 0.2040902526327793
# FPR: 0.0, TPR: 0.35
# is_not_signal: (16, 0)
# is_signal: (20, 7)
# ===========================================================================
# is_signal : True, p_values[36]: 0.014703304334572379
# FPR: 0.0, TPR: 0.38095238095238093
# is_not_signal: (16, 0)
# is_signal: (21, 8)
# ===========================================================================
# is_signal : True, p_values[37]: 0.10381573589836372
# FPR: 0.0, TPR: 0.36363636363636365
# is_not_signal: (16, 0)
# is_signal: (22, 8)
# ===========================================================================
# is_signal : True, p_values[38]: 0.011371093461613701
# FPR: 0.0, TPR: 0.391304347826087
# is_not_signal: (16, 0)
# is_signal: (23, 9)
# ===========================================================================
# is_signal : True, p_values[39]: 0.0006165346708778027
# FPR: 0.0, TPR: 0.4166666666666667
# is_not_signal: (16, 0)
# is_signal: (24, 10)
# ===========================================================================
# is_signal : True, p_values[40]: 0.32935112430120417
# FPR: 0.0, TPR: 0.4
# is_not_signal: (16, 0)
# is_signal: (25, 10)
# ===========================================================================
# is_signal : False, p_values[41]: 0.9748177259623175
# FPR: 0.0, TPR: 0.4
# is_not_signal: (17, 0)
# is_signal: (25, 10)
# ===========================================================================
# is_signal : True, p_values[42]: 0.18201675549352153
# FPR: 0.0, TPR: 0.38461538461538464
# is_not_signal: (17, 0)
# is_signal: (26, 10)
# ===========================================================================
# is_signal : False, p_values[43]: 0.1039607257523399
# FPR: 0.0, TPR: 0.38461538461538464
# is_not_signal: (18, 0)
# is_signal: (26, 10)
# ===========================================================================
# is_signal : False, p_values[44]: 0.03792989229661494
# FPR: 0.05263157894736842, TPR: 0.38461538461538464
# is_not_signal: (19, 1)
# is_signal: (26, 10)
# ===========================================================================
# is_signal : True, p_values[45]: 0.7417033263459132
# FPR: 0.05263157894736842, TPR: 0.37037037037037035
# is_not_signal: (19, 1)
# is_signal: (27, 10)
# ===========================================================================
# is_signal : True, p_values[46]: 0.2804666522677637
# FPR: 0.05263157894736842, TPR: 0.35714285714285715
# is_not_signal: (19, 1)
# is_signal: (28, 10)
# ===========================================================================
# is_signal : True, p_values[47]: 0.18299819653130842
# FPR: 0.05263157894736842, TPR: 0.3448275862068966
# is_not_signal: (19, 1)
# is_signal: (29, 10)
# ===========================================================================
# is_signal : True, p_values[48]: 0.6312310974669147
# FPR: 0.05263157894736842, TPR: 0.3333333333333333
# is_not_signal: (19, 1)
# is_signal: (30, 10)
# ===========================================================================
# is_signal : True, p_values[49]: 0.3300682625943913
# FPR: 0.05263157894736842, TPR: 0.3225806451612903
# is_not_signal: (19, 1)
# is_signal: (31, 10)
# ===========================================================================
# is_signal : False, p_values[50]: 0.08781725071824081
# FPR: 0.05, TPR: 0.3225806451612903
# is_not_signal: (20, 1)
# is_signal: (31, 10)
# ===========================================================================
# is_signal : False, p_values[51]: 0.9688881686501322
# FPR: 0.047619047619047616, TPR: 0.3225806451612903
# is_not_signal: (21, 1)
# is_signal: (31, 10)
# ===========================================================================
# is_signal : False, p_values[52]: 0.82769880591696
# FPR: 0.045454545454545456, TPR: 0.3225806451612903
# is_not_signal: (22, 1)
# is_signal: (31, 10)
# ===========================================================================
# is_signal : False, p_values[53]: 0.1654067396158776
# FPR: 0.043478260869565216, TPR: 0.3225806451612903
# is_not_signal: (23, 1)
# is_signal: (31, 10)
# ===========================================================================
# is_signal : True, p_values[54]: 0.9837509178146392
# FPR: 0.043478260869565216, TPR: 0.3125
# is_not_signal: (23, 1)
# is_signal: (32, 10)
# ===========================================================================
# is_signal : False, p_values[55]: 0.036159405556976124
# FPR: 0.08333333333333333, TPR: 0.3125
# is_not_signal: (24, 2)
# is_signal: (32, 10)
# ===========================================================================
# is_signal : True, p_values[56]: 0.12152455005322137
# FPR: 0.08333333333333333, TPR: 0.30303030303030304
# is_not_signal: (24, 2)
# is_signal: (33, 10)
# ===========================================================================
# is_signal : False, p_values[57]: 0.04483695430530576
# FPR: 0.12, TPR: 0.30303030303030304
# is_not_signal: (25, 3)
# is_signal: (33, 10)
# ===========================================================================
# is_signal : False, p_values[58]: 0.3076736326391246
# FPR: 0.11538461538461539, TPR: 0.30303030303030304
# is_not_signal: (26, 3)
# is_signal: (33, 10)
# ===========================================================================
# is_signal : True, p_values[59]: 0.2291806729999473
# FPR: 0.11538461538461539, TPR: 0.29411764705882354
# is_not_signal: (26, 3)
# is_signal: (34, 10)
# ===========================================================================
# is_signal : True, p_values[60]: 0.0009413076302834524
# FPR: 0.11538461538461539, TPR: 0.3142857142857143
# is_not_signal: (26, 3)
# is_signal: (35, 11)
# ===========================================================================
# is_signal : True, p_values[61]: 0.3245566007914536
# FPR: 0.11538461538461539, TPR: 0.3055555555555556
# is_not_signal: (26, 3)
# is_signal: (36, 11)
# ===========================================================================
# is_signal : True, p_values[62]: 0.031006656655788604
# FPR: 0.11538461538461539, TPR: 0.32432432432432434
# is_not_signal: (26, 3)
# is_signal: (37, 12)
# ===========================================================================
# is_signal : True, p_values[63]: 0.16130812509968728
# FPR: 0.11538461538461539, TPR: 0.3157894736842105
# is_not_signal: (26, 3)
# is_signal: (38, 12)
# ===========================================================================
# is_signal : True, p_values[64]: 0.11305403187294531
# FPR: 0.11538461538461539, TPR: 0.3076923076923077
# is_not_signal: (26, 3)
# is_signal: (39, 12)
# ===========================================================================
# is_signal : True, p_values[65]: 0.5742110113065174
# FPR: 0.11538461538461539, TPR: 0.3
# is_not_signal: (26, 3)
# is_signal: (40, 12)
# ===========================================================================
# is_signal : True, p_values[66]: 0.37170457265196105
# FPR: 0.11538461538461539, TPR: 0.2926829268292683
# is_not_signal: (26, 3)
# is_signal: (41, 12)
# ===========================================================================
# is_signal : True, p_values[67]: 0.29094604039108635
# FPR: 0.11538461538461539, TPR: 0.2857142857142857
# is_not_signal: (26, 3)
# is_signal: (42, 12)
# ===========================================================================
# is_signal : True, p_values[68]: 0.08054176156411766
# FPR: 0.11538461538461539, TPR: 0.27906976744186046
# is_not_signal: (26, 3)
# is_signal: (43, 12)
# ===========================================================================
# is_signal : True, p_values[69]: 0.006415111338862208
# FPR: 0.11538461538461539, TPR: 0.29545454545454547
# is_not_signal: (26, 3)
# is_signal: (44, 13)
# ===========================================================================
# is_signal : False, p_values[70]: 0.27458876733385607
# FPR: 0.1111111111111111, TPR: 0.29545454545454547
# is_not_signal: (27, 3)
# is_signal: (44, 13)
# ===========================================================================
# is_signal : True, p_values[71]: 0.008006794307870508
# FPR: 0.1111111111111111, TPR: 0.3111111111111111
# is_not_signal: (27, 3)
# is_signal: (45, 14)
# ===========================================================================
# is_signal : False, p_values[72]: 0.903214625655994
# FPR: 0.10714285714285714, TPR: 0.3111111111111111
# is_not_signal: (28, 3)
# is_signal: (45, 14)
# ===========================================================================
# is_signal : False, p_values[73]: 0.8806249607188108
# FPR: 0.10344827586206896, TPR: 0.3111111111111111
# is_not_signal: (29, 3)
# is_signal: (45, 14)
# ===========================================================================
# is_signal : True, p_values[74]: 0.02009973096786294
# FPR: 0.10344827586206896, TPR: 0.32608695652173914
# is_not_signal: (29, 3)
# is_signal: (46, 15)
# ===========================================================================
# is_signal : True, p_values[75]: 0.6017546335513067
# FPR: 0.10344827586206896, TPR: 0.3191489361702128
# is_not_signal: (29, 3)
# is_signal: (47, 15)
# ===========================================================================
# is_signal : False, p_values[76]: 0.3535695937738538
# FPR: 0.1, TPR: 0.3191489361702128
# is_not_signal: (30, 3)
# is_signal: (47, 15)
# ===========================================================================
# is_signal : True, p_values[77]: 0.002401047095390135
# FPR: 0.1, TPR: 0.3333333333333333
# is_not_signal: (30, 3)
# is_signal: (48, 16)
# ===========================================================================
# is_signal : False, p_values[78]: 0.8160050064072493
# FPR: 0.0967741935483871, TPR: 0.3333333333333333
# is_not_signal: (31, 3)
# is_signal: (48, 16)
# ===========================================================================
# is_signal : True, p_values[79]: 0.37670130760707465
# FPR: 0.0967741935483871, TPR: 0.32653061224489793
# is_not_signal: (31, 3)
# is_signal: (49, 16)
# ===========================================================================
# is_signal : True, p_values[80]: 0.964624874156536
# FPR: 0.0967741935483871, TPR: 0.32
# is_not_signal: (31, 3)
# is_signal: (50, 16)
# ===========================================================================
# is_signal : True, p_values[81]: 0.3619331312092489
# FPR: 0.0967741935483871, TPR: 0.3137254901960784
# is_not_signal: (31, 3)
# is_signal: (51, 16)
# ===========================================================================
# is_signal : True, p_values[82]: 0.3366769729913215
# FPR: 0.0967741935483871, TPR: 0.3076923076923077
# is_not_signal: (31, 3)
# is_signal: (52, 16)
# ===========================================================================
# is_signal : True, p_values[83]: 0.029427002392454986
# FPR: 0.0967741935483871, TPR: 0.32075471698113206
# is_not_signal: (31, 3)
# is_signal: (53, 17)
# ===========================================================================
# is_signal : True, p_values[84]: 0.8941793553774635
# FPR: 0.0967741935483871, TPR: 0.3148148148148148
# is_not_signal: (31, 3)
# is_signal: (54, 17)
# ===========================================================================
# is_signal : True, p_values[85]: 0.02206648973751902
# FPR: 0.0967741935483871, TPR: 0.32727272727272727
# is_not_signal: (31, 3)
# is_signal: (55, 18)
# ===========================================================================
# is_signal : True, p_values[86]: 0.6343352064787462
# FPR: 0.0967741935483871, TPR: 0.32142857142857145
# is_not_signal: (31, 3)
# is_signal: (56, 18)
# ===========================================================================
# is_signal : False, p_values[87]: 0.15671492766251416
# FPR: 0.09375, TPR: 0.32142857142857145
# is_not_signal: (32, 3)
# is_signal: (56, 18)
# ===========================================================================
# is_signal : True, p_values[88]: 0.1675211580966806
# FPR: 0.09375, TPR: 0.3157894736842105
# is_not_signal: (32, 3)
# is_signal: (57, 18)
# ===========================================================================
# is_signal : True, p_values[89]: 0.002363771628296308
# FPR: 0.09375, TPR: 0.3275862068965517
# is_not_signal: (32, 3)
# is_signal: (58, 19)
# ===========================================================================
# is_signal : True, p_values[90]: 0.0003190202109973829
# FPR: 0.09375, TPR: 0.3389830508474576
# is_not_signal: (32, 3)
# is_signal: (59, 20)
# ===========================================================================
# is_signal : True, p_values[91]: 0.9222089778143358
# FPR: 0.09375, TPR: 0.3333333333333333
# is_not_signal: (32, 3)
# is_signal: (60, 20)
# ===========================================================================
# is_signal : True, p_values[92]: 0.5947841474263358
# FPR: 0.09375, TPR: 0.32786885245901637
# is_not_signal: (32, 3)
# is_signal: (61, 20)
# ===========================================================================
# is_signal : True, p_values[93]: 0.004100593961702906
# FPR: 0.09375, TPR: 0.3387096774193548
# is_not_signal: (32, 3)
# is_signal: (62, 21)
# ===========================================================================
# is_signal : True, p_values[94]: 0.30755495093983864
# FPR: 0.09375, TPR: 0.3333333333333333
# is_not_signal: (32, 3)
# is_signal: (63, 21)
# ===========================================================================
# is_signal : False, p_values[95]: 0.5629479760234823
# FPR: 0.09090909090909091, TPR: 0.3333333333333333
# is_not_signal: (33, 3)
# is_signal: (63, 21)
# ===========================================================================
# is_signal : False, p_values[96]: 0.8778899604918716
# FPR: 0.08823529411764706, TPR: 0.3333333333333333
# is_not_signal: (34, 3)
# is_signal: (63, 21)
# ===========================================================================
# is_signal : False, p_values[97]: 0.6048631257890845
# FPR: 0.08571428571428572, TPR: 0.3333333333333333
# is_not_signal: (35, 3)
# is_signal: (63, 21)
# ===========================================================================
# is_signal : True, p_values[98]: 0.008083231658787226
# FPR: 0.08571428571428572, TPR: 0.34375
# is_not_signal: (35, 3)
# is_signal: (64, 22)
# ===========================================================================
# is_signal : True, p_values[99]: 0.0486794651048768
# FPR: 0.08571428571428572, TPR: 0.35384615384615387
# is_not_signal: (35, 3)
# is_signal: (65, 23)
# ===========================================================================
# is_signal : True, p_values[100]: 0.6395537084416837
# FPR: 0.08571428571428572, TPR: 0.3484848484848485
# is_not_signal: (35, 3)
# is_signal: (66, 23)
# ===========================================================================
# is_signal : False, p_values[101]: 0.6268215779642945
# FPR: 0.08333333333333333, TPR: 0.3484848484848485
# is_not_signal: (36, 3)
# is_signal: (66, 23)
# ===========================================================================
# is_signal : False, p_values[102]: 0.41328986364135256
# ...
# is_signal : False, p_values[112]: 0.3372108555602948
# FPR: 0.07317073170731707, TPR: 0.3472222222222222
# is_not_signal: (41, 3)
# is_signal: (72, 25)
# ===========================================================================
# is_signal : False, p_values[113]: 0.6060294848601568
# FPR: 0.07142857142857142, TPR: 0.3472222222222222
# is_not_signal: (42, 3)
# is_signal: (72, 25)
# ===========================================================================
# is_signal : False, p_values[114]: 0.4632425456488155
# FPR: 0.06976744186046512, TPR: 0.3472222222222222
# is_not_signal: (43, 3)
# is_signal: (72, 25)
# ===========================================================================
# is_signal : True, p_values[115]: 0.016549468444080593
# FPR: 0.06976744186046512, TPR: 0.3561643835616438
# is_not_signal: (43, 3)
# is_signal: (73, 26)
# ===========================================================================
# is_signal : False, p_values[116]: 0.19660868812204013
# FPR: 0.06818181818181818, TPR: 0.3561643835616438
# is_not_signal: (44, 3)
# is_signal: (73, 26)
# ===========================================================================
# is_signal : True, p_values[117]: 0.4690711599577096
# FPR: 0.06818181818181818, TPR: 0.35135135135135137
# is_not_signal: (44, 3)
# is_signal: (74, 26)
# ===========================================================================
# is_signal : True, p_values[118]: 0.16328410735282683
# FPR: 0.06818181818181818, TPR: 0.3466666666666667
# is_not_signal: (44, 3)
# is_signal: (75, 26)
# ===========================================================================
# is_signal : True, p_values[119]: 0.04628681660680558
# FPR: 0.06818181818181818, TPR: 0.35526315789473684
# is_not_signal: (44, 3)
# is_signal: (76, 27)
# ===========================================================================
# is_signal : True, p_values[120]: 0.6448291384553824
# FPR: 0.06818181818181818, TPR: 0.35064935064935066
# is_not_signal: (44, 3)
# is_signal: (77, 27)
# ===========================================================================
# is_signal : True, p_values[121]: 0.547214470149782
# FPR: 0.06818181818181818, TPR: 0.34615384615384615
# is_not_signal: (44, 3)
# is_signal: (78, 27)
# ===========================================================================
# is_signal : True, p_values[122]: 0.0010507086280221057
# FPR: 0.06818181818181818, TPR: 0.35443037974683544
# is_not_signal: (44, 3)
# is_signal: (79, 28)
# ===========================================================================
# is_signal : True, p_values[123]: 0.02160327972049502
# FPR: 0.06818181818181818, TPR: 0.3625
# is_not_signal: (44, 3)
# is_signal: (80, 29)
# ===========================================================================
# is_signal : True, p_values[124]: 0.13444353653675792
# FPR: 0.06818181818181818, TPR: 0.35802469135802467
# is_not_signal: (44, 3)
# is_signal: (81, 29)
# ===========================================================================
# -- Ka = 5 --
# is_signal : True, p_values[0]: 0.0029411749965943187
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : False, p_values[1]: 0.03272754129368881
# FPR: 1.0, TPR: 1.0
# is_not_signal: (1, 1)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : False, p_values[2]: 0.45620833054177046
# FPR: 0.5, TPR: 1.0
# is_not_signal: (2, 1)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : False, p_values[3]: 0.41916377001459226
# FPR: 0.3333333333333333, TPR: 1.0
# is_not_signal: (3, 1)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : True, p_values[4]: 0.19041385749470394
# FPR: 0.3333333333333333, TPR: 0.5
# is_not_signal: (3, 1)
# is_signal: (2, 1)
# ===========================================================================
# is_signal : True, p_values[5]: 0.3079378814490681
# FPR: 0.3333333333333333, TPR: 0.3333333333333333
# is_not_signal: (3, 1)
# is_signal: (3, 1)
# ===========================================================================
# is_signal : True, p_values[6]: 0.01682409945941869
# FPR: 0.3333333333333333, TPR: 0.5
# is_not_signal: (3, 1)
# is_signal: (4, 2)
# ===========================================================================
# is_signal : True, p_values[7]: 0.7947877945936315
# FPR: 0.3333333333333333, TPR: 0.4
# is_not_signal: (3, 1)
# is_signal: (5, 2)
# ===========================================================================
# is_signal : True, p_values[8]: 0.4941644112181438
# FPR: 0.3333333333333333, TPR: 0.3333333333333333
# is_not_signal: (3, 1)
# is_signal: (6, 2)
# ===========================================================================
# is_signal : True, p_values[9]: 0.04589257038221853
# FPR: 0.3333333333333333, TPR: 0.42857142857142855
# is_not_signal: (3, 1)
# is_signal: (7, 3)
# ===========================================================================
# is_signal : False, p_values[10]: 0.14595375121939666
# FPR: 0.25, TPR: 0.42857142857142855
# is_not_signal: (4, 1)
# is_signal: (7, 3)
# ===========================================================================
# is_signal : False, p_values[11]: 0.36710975418982705
# FPR: 0.2, TPR: 0.42857142857142855
# is_not_signal: (5, 1)
# is_signal: (7, 3)
# ===========================================================================
# is_signal : False, p_values[12]: 0.4782502771608958
# FPR: 0.16666666666666666, TPR: 0.42857142857142855
# is_not_signal: (6, 1)
# is_signal: (7, 3)
# ===========================================================================
# is_signal : False, p_values[13]: 0.8843902837959506
# FPR: 0.14285714285714285, TPR: 0.42857142857142855
# is_not_signal: (7, 1)
# is_signal: (7, 3)
# ===========================================================================
# is_signal : True, p_values[14]: 0.27633650263427023
# FPR: 0.14285714285714285, TPR: 0.375
# is_not_signal: (7, 1)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : False, p_values[15]: 0.540107810105997
# FPR: 0.125, TPR: 0.375
# is_not_signal: (8, 1)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : True, p_values[16]: 0.5992672200286314
# FPR: 0.125, TPR: 0.3333333333333333
# is_not_signal: (8, 1)
# is_signal: (9, 3)
# ===========================================================================
# is_signal : True, p_values[17]: 0.1570797595395137
# FPR: 0.125, TPR: 0.3
# is_not_signal: (8, 1)
# is_signal: (10, 3)
# ===========================================================================
# is_signal : True, p_values[18]: 0.3453016840034752
# FPR: 0.125, TPR: 0.2727272727272727
# is_not_signal: (8, 1)
# is_signal: (11, 3)
# ===========================================================================
# is_signal : True, p_values[19]: 0.04006629802854263
# FPR: 0.125, TPR: 0.3333333333333333
# is_not_signal: (8, 1)
# is_signal: (12, 4)
# ===========================================================================
# is_signal : True, p_values[20]: 0.037966839372816585
# FPR: 0.125, TPR: 0.38461538461538464
# is_not_signal: (8, 1)
# is_signal: (13, 5)
# ===========================================================================
# is_signal : True, p_values[21]: 0.12592530784301234
# FPR: 0.125, TPR: 0.35714285714285715
# is_not_signal: (8, 1)
# is_signal: (14, 5)
# ===========================================================================
# is_signal : False, p_values[22]: 0.7627742968126694
# FPR: 0.1111111111111111, TPR: 0.35714285714285715
# is_not_signal: (9, 1)
# is_signal: (14, 5)
# ===========================================================================
# is_signal : False, p_values[23]: 0.9018895853998605
# FPR: 0.1, TPR: 0.35714285714285715
# is_not_signal: (10, 1)
# is_signal: (14, 5)
# ===========================================================================
# is_signal : True, p_values[24]: 0.0015567278916027202
# FPR: 0.1, TPR: 0.4
# is_not_signal: (10, 1)
# is_signal: (15, 6)
# ===========================================================================
# is_signal : False, p_values[25]: 0.19985100160418737
# FPR: 0.09090909090909091, TPR: 0.4
# is_not_signal: (11, 1)
# is_signal: (15, 6)
# ===========================================================================
# is_signal : False, p_values[26]: 0.3780848975111149
# FPR: 0.08333333333333333, TPR: 0.4
# is_not_signal: (12, 1)
# is_signal: (15, 6)
# ===========================================================================
# is_signal : True, p_values[27]: 0.4219538117050324
# FPR: 0.08333333333333333, TPR: 0.375
# is_not_signal: (12, 1)
# is_signal: (16, 6)
# ===========================================================================
# is_signal : True, p_values[28]: 0.18163150339744896
# FPR: 0.08333333333333333, TPR: 0.35294117647058826
# is_not_signal: (12, 1)
# is_signal: (17, 6)
# ===========================================================================
# is_signal : True, p_values[29]: 0.012416069206277306
# FPR: 0.08333333333333333, TPR: 0.3888888888888889
# is_not_signal: (12, 1)
# is_signal: (18, 7)
# ===========================================================================
# is_signal : True, p_values[30]: 0.6756374646570139
# FPR: 0.08333333333333333, TPR: 0.3684210526315789
# is_not_signal: (12, 1)
# is_signal: (19, 7)
# ===========================================================================
# is_signal : True, p_values[31]: 0.09376457181721054
# FPR: 0.08333333333333333, TPR: 0.35
# is_not_signal: (12, 1)
# is_signal: (20, 7)
# ===========================================================================
# is_signal : True, p_values[32]: 0.011960401892187531
# FPR: 0.08333333333333333, TPR: 0.38095238095238093
# is_not_signal: (12, 1)
# is_signal: (21, 8)
# ===========================================================================
# is_signal : True, p_values[33]: 0.00046284852591590536
# FPR: 0.08333333333333333, TPR: 0.4090909090909091
# is_not_signal: (12, 1)
# is_signal: (22, 9)
# ===========================================================================
# is_signal : False, p_values[34]: 0.5495637460561686
# FPR: 0.07692307692307693, TPR: 0.4090909090909091
# is_not_signal: (13, 1)
# is_signal: (22, 9)
# ===========================================================================
# is_signal : True, p_values[35]: 0.09814269085419183
# FPR: 0.07692307692307693, TPR: 0.391304347826087
# is_not_signal: (13, 1)
# is_signal: (23, 9)
# ===========================================================================
# is_signal : False, p_values[36]: 0.9528706027936098
# FPR: 0.07142857142857142, TPR: 0.391304347826087
# is_not_signal: (14, 1)
# is_signal: (23, 9)
# ===========================================================================
# is_signal : False, p_values[37]: 0.4503990953495104
# FPR: 0.06666666666666667, TPR: 0.391304347826087
# is_not_signal: (15, 1)
# is_signal: (23, 9)
# ===========================================================================
# is_signal : True, p_values[38]: 0.19804908196537827
# FPR: 0.06666666666666667, TPR: 0.375
# is_not_signal: (15, 1)
# is_signal: (24, 9)
# ===========================================================================
# is_signal : False, p_values[39]: 0.8661162401917906
# FPR: 0.0625, TPR: 0.375
# is_not_signal: (16, 1)
# is_signal: (24, 9)
# ===========================================================================
# is_signal : True, p_values[40]: 0.09676289926779644
# FPR: 0.0625, TPR: 0.36
# is_not_signal: (16, 1)
# is_signal: (25, 9)
# ===========================================================================
# is_signal : True, p_values[41]: 0.026120752697744245
# FPR: 0.0625, TPR: 0.38461538461538464
# is_not_signal: (16, 1)
# is_signal: (26, 10)
# ===========================================================================
# is_signal : True, p_values[42]: 0.029354337908115653
# FPR: 0.0625, TPR: 0.4074074074074074
# is_not_signal: (16, 1)
# is_signal: (27, 11)
# ===========================================================================
# is_signal : False, p_values[43]: 0.17980259181711944
# FPR: 0.058823529411764705, TPR: 0.4074074074074074
# is_not_signal: (17, 1)
# is_signal: (27, 11)
# ===========================================================================
# is_signal : False, p_values[44]: 0.8647493979854306
# FPR: 0.05555555555555555, TPR: 0.4074074074074074
# is_not_signal: (18, 1)
# is_signal: (27, 11)
# ===========================================================================
# is_signal : False, p_values[45]: 0.9232129486090707
# FPR: 0.05263157894736842, TPR: 0.4074074074074074
# is_not_signal: (19, 1)
# is_signal: (27, 11)
# ===========================================================================
# is_signal : True, p_values[46]: 0.04895682706879782
# FPR: 0.05263157894736842, TPR: 0.42857142857142855
# is_not_signal: (19, 1)
# is_signal: (28, 12)
# ===========================================================================
# is_signal : True, p_values[47]: 0.11010139259301076
# FPR: 0.05263157894736842, TPR: 0.41379310344827586
# is_not_signal: (19, 1)
# is_signal: (29, 12)
# ===========================================================================
# is_signal : True, p_values[48]: 0.017005123661994227
# FPR: 0.05263157894736842, TPR: 0.43333333333333335
# is_not_signal: (19, 1)
# is_signal: (30, 13)
# ===========================================================================
# is_signal : True, p_values[49]: 0.8278121051097539
# FPR: 0.05263157894736842, TPR: 0.41935483870967744
# is_not_signal: (19, 1)
# is_signal: (31, 13)
# ===========================================================================
# is_signal : True, p_values[50]: 0.23760094899290954
# FPR: 0.05263157894736842, TPR: 0.40625
# is_not_signal: (19, 1)
# is_signal: (32, 13)
# ===========================================================================
# is_signal : False, p_values[51]: 0.964338539094367
# FPR: 0.05, TPR: 0.40625
# is_not_signal: (20, 1)
# is_signal: (32, 13)
# ===========================================================================
# is_signal : False, p_values[52]: 0.9532986674613289
# FPR: 0.047619047619047616, TPR: 0.40625
# is_not_signal: (21, 1)
# is_signal: (32, 13)
# ===========================================================================
# is_signal : False, p_values[53]: 0.5958965675269268
# FPR: 0.045454545454545456, TPR: 0.40625
# is_not_signal: (22, 1)
# is_signal: (32, 13)
# ===========================================================================
# is_signal : True, p_values[54]: 0.10686599299665903
# FPR: 0.045454545454545456, TPR: 0.3939393939393939
# is_not_signal: (22, 1)
# is_signal: (33, 13)
# ===========================================================================
# is_signal : True, p_values[55]: 0.554385523580697
# FPR: 0.045454545454545456, TPR: 0.38235294117647056
# is_not_signal: (22, 1)
# is_signal: (34, 13)
# ===========================================================================
# is_signal : True, p_values[56]: 0.39485767150719536
# FPR: 0.045454545454545456, TPR: 0.37142857142857144
# is_not_signal: (22, 1)
# is_signal: (35, 13)
# ===========================================================================
# is_signal : True, p_values[57]: 0.46484038684017914
# FPR: 0.045454545454545456, TPR: 0.3611111111111111
# is_not_signal: (22, 1)
# is_signal: (36, 13)
# ===========================================================================
# is_signal : False, p_values[58]: 0.11274274651181558
# FPR: 0.043478260869565216, TPR: 0.3611111111111111
# is_not_signal: (23, 1)
# is_signal: (36, 13)
# ===========================================================================
# is_signal : True, p_values[59]: 0.09114220691067107
# FPR: 0.043478260869565216, TPR: 0.35135135135135137
# is_not_signal: (23, 1)
# is_signal: (37, 13)
# ===========================================================================
# is_signal : False, p_values[60]: 0.17910291792066513
# FPR: 0.041666666666666664, TPR: 0.35135135135135137
# is_not_signal: (24, 1)
# is_signal: (37, 13)
# ===========================================================================
# is_signal : True, p_values[61]: 0.7213865775538635
# FPR: 0.041666666666666664, TPR: 0.34210526315789475
# is_not_signal: (24, 1)
# is_signal: (38, 13)
# ===========================================================================

# %%
n_target = 40
n_source = 80
p = 200
K = 7
h = 10
alpha = 0.05
T = 5
s_len = 10
s_vector = [0.0] * s_len

Ka_list = [1, 3, 5, 7]

iteration = 200

for Ka in Ka_list:
    print(f"-- Ka = {Ka} --")
    para_results_storage = []
    CoRT_model = CoRT_builder.CoRT()
    cnt1 = 0
    cnt2 = 0
    cnt3 = 0
    cnt4 = 0

    for i in range(iteration):
        target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
        result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, T, s_len)

        if result_dict != None:
            cnt1 += (result_dict['is_signal'] == True)
            cnt2 += (result_dict['is_signal'] == False)
            cnt3 += (result_dict['is_signal'] == True and result_dict['p_value'] <= alpha)
            cnt4 += (result_dict['is_signal'] == False and result_dict['p_value'] <= alpha)
            
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_values[{i}]: {result_dict['p_value']}")
            print(f"FPR: {cnt4 / cnt2}, TPR: {cnt3 / cnt1}")
            print(f"is_not_signal: {int(cnt2), int(cnt4)}")
            print(f"is_signal: {int(cnt1), int(cnt3)}")
            print("===========================================================================")
                
            para_results_storage.append(result_dict)
    is_signal_cases = [r for r in para_results_storage if r['is_signal']]
    not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

    false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
    fpr = false_positives / len(not_signal_cases) if len(not_signal_cases) != 0 else -1
    true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha) 
    tpr = true_positives / len(is_signal_cases) if len(is_signal_cases) != 0 else -1

    configs = {
        "n_source": n_source,
        "p":  p,
        "K": K,
        "Ka": Ka,
        "h": h,
        "alpha": alpha,
        "T":  T,
        "s_len": s_len,
        "s_vector": s_vector,
        "n_target": n_target,
        "iteration": iteration,
    }

    results = {
        "configs": configs,
        "time": datetime.datetime.now().ctime(),
        "fpr": fpr,
        "tpr": tpr,
        "is_signal_cases": len(is_signal_cases),
        "not_signal_cases": len(not_signal_cases),
        "false_positives": false_positives,
        "true_positives": true_positives
    }

    filename = 'records_4/FPR_parametric_vis_records.json'
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            try:
                records = json.load(f)
            except Exception as e:
                print(e)
                records = []
    else:
        records = []

    records.append(results)

    with open(filename, 'w') as f:
        json.dump(records, f, indent=4)

# %%
n_target = 40
n_source = 80
p = 200
K = 5
Ka = 3
h = 10
alpha = 0.05
T = 5
s_len = 10

iteration = 125

signal_list = [0.25, 0.5, 0.75, 1.0]

for signal in signal_list:
    print(f"-- signal = {signal} --")
    para_results_storage = []
    CoRT_model = CoRT_builder.CoRT()
    s_vector = [signal] * s_len
    cnt1 = 0
    cnt2 = 0
    cnt3 = 0
    cnt4 = 0

    for i in range(iteration):
        target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
        result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, T, s_len)

        if result_dict != None:
            cnt1 += (result_dict['is_signal'] == True)
            cnt2 += (result_dict['is_signal'] == False)
            cnt3 += (result_dict['is_signal'] == True and result_dict['p_value'] <= alpha)
            cnt4 += (result_dict['is_signal'] == False and result_dict['p_value'] <= alpha)
            
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_values[{i}]: {result_dict['p_value']}")
            print(f"FPR: {cnt4 / cnt2}, TPR: {cnt3 / cnt1}")
            print(f"is_not_signal: {int(cnt2), int(cnt4)}")
            print(f"is_signal: {int(cnt1), int(cnt3)}")
            print("===========================================================================")
                
            para_results_storage.append(result_dict)
    is_signal_cases = [r for r in para_results_storage if r['is_signal']]
    not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

    false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
    fpr = false_positives / len(not_signal_cases) if len(not_signal_cases) != 0 else -1
    true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha) 
    tpr = true_positives / len(is_signal_cases) if len(is_signal_cases) != 0 else -1

    configs = {
        "n_source": n_source,
        "p":  p,
        "K": K,
        "Ka": Ka,
        "h": h,
        "alpha": alpha,
        "T":  T,
        "s_len": s_len,
        "s_vector": s_vector,
        "n_target": n_target,
        "iteration": iteration,
    }

    results = {
        "configs": configs,
        "time": datetime.datetime.now().ctime(),
        "fpr": fpr,
        "tpr": tpr,
        "is_signal_cases": len(is_signal_cases),
        "not_signal_cases": len(not_signal_cases),
        "false_positives": false_positives,
        "true_positives": true_positives
    }

    filename = 'records_2/TPR_FPR_parametric_vis_records.json'
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            try:
                records = json.load(f)
            except Exception as e:
                print(e)
                records = []
    else:
        records = []

    records.append(results)

    with open(filename, 'w') as f:
        json.dump(records, f, indent=4)
# Out:
# -- signal = 0.25 --
# is_signal : True, p_values[0]: 0.7259099348921859
# FPR: nan, TPR: 0.0
# is_not_signal: (0, 0)
# is_signal: (1, 0)
# ===========================================================================
# is_signal : True, p_values[1]: 0.9918976032697618
# FPR: nan, TPR: 0.0
# is_not_signal: (0, 0)
# is_signal: (2, 0)
# ===========================================================================
# is_signal : False, p_values[2]: 0.6313945348902924
# FPR: 0.0, TPR: 0.0
# is_not_signal: (1, 0)
# is_signal: (2, 0)
# ===========================================================================

# %%
n_target = 40
n_source = 80
p = 200
K = 5
Ka = 3
h = 10
alpha = 0.05
T = 5
s_len = 10
s_vector = [0.5] * s_len

h_list = [2, 6, 10, 14]

iteration = 125

for h in h_list:
    print(f"-- h = {h} --")
    para_results_storage = []
    CoRT_model = CoRT_builder.CoRT()
    cnt1 = 0
    cnt2 = 0
    cnt3 = 0
    cnt4 = 0

    for i in range(iteration):
        target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
        result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, T, s_len)

        if result_dict != None:
            cnt1 += (result_dict['is_signal'] == True)
            cnt2 += (result_dict['is_signal'] == False)
            cnt3 += (result_dict['is_signal'] == True and result_dict['p_value'] <= alpha)
            cnt4 += (result_dict['is_signal'] == False and result_dict['p_value'] <= alpha)
            
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_values[{i}]: {result_dict['p_value']}")
            print(f"FPR: {cnt4 / cnt2}, TPR: {cnt3 / cnt1}")
            print(f"is_not_signal: {int(cnt2), int(cnt4)}")
            print(f"is_signal: {int(cnt1), int(cnt3)}")
            print("===========================================================================")
                
            para_results_storage.append(result_dict)
    is_signal_cases = [r for r in para_results_storage if r['is_signal']]
    not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

    false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
    fpr = false_positives / len(not_signal_cases) if len(not_signal_cases) != 0 else -1
    true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha) 
    tpr = true_positives / len(is_signal_cases) if len(is_signal_cases) != 0 else -1

    configs = {
        "n_source": n_source,
        "p":  p,
        "K": K,
        "Ka": Ka,
        "h": h,
        "alpha": alpha,
        "T":  T,
        "s_len": s_len,
        "s_vector": s_vector,
        "n_target": n_target,
        "iteration": iteration,
    }

    results = {
        "configs": configs,
        "time": datetime.datetime.now().ctime(),
        "fpr": fpr,
        "tpr": tpr,
        "is_signal_cases": len(is_signal_cases),
        "not_signal_cases": len(not_signal_cases),
        "false_positives": false_positives,
        "true_positives": true_positives
    }

    filename = 'records_3/TPR_parametric_vis_records.json'
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            try:
                records = json.load(f)
            except Exception as e:
                print(e)
                records = []
    else:
        records = []

    records.append(results)

    with open(filename, 'w') as f:
        json.dump(records, f, indent=4)
# Out:
# -- h = 2 --
# is_signal : True, p_values[0]: 0.5978730619390638
# FPR: nan, TPR: 0.0
# is_not_signal: (0, 0)
# is_signal: (1, 0)
# ===========================================================================
# is_signal : True, p_values[1]: 0.00016150605554621962
# FPR: nan, TPR: 0.5
# is_not_signal: (0, 0)
# is_signal: (2, 1)
# ===========================================================================
# is_signal : True, p_values[2]: 0.00044722221179807896
# FPR: nan, TPR: 0.6666666666666666
# is_not_signal: (0, 0)
# is_signal: (3, 2)
# ===========================================================================
# is_signal : True, p_values[3]: 0.08230066639181934
# FPR: nan, TPR: 0.5
# is_not_signal: (0, 0)
# is_signal: (4, 2)
# ===========================================================================
# is_signal : True, p_values[4]: 0.9636221223414148
# FPR: nan, TPR: 0.4
# is_not_signal: (0, 0)
# is_signal: (5, 2)
# ===========================================================================
# is_signal : True, p_values[5]: 0.020865001474632498
# FPR: nan, TPR: 0.5
# is_not_signal: (0, 0)
# is_signal: (6, 3)
# ===========================================================================
# is_signal : True, p_values[6]: 0.1381752657297598
# FPR: nan, TPR: 0.42857142857142855
# is_not_signal: (0, 0)
# is_signal: (7, 3)
# ===========================================================================
# is_signal : True, p_values[7]: 0.00780355550823046
# FPR: nan, TPR: 0.5
# is_not_signal: (0, 0)
# is_signal: (8, 4)
# ===========================================================================
# is_signal : True, p_values[8]: 0.9900410275160346
# FPR: nan, TPR: 0.4444444444444444
# is_not_signal: (0, 0)
# is_signal: (9, 4)
# ===========================================================================
# is_signal : True, p_values[9]: 0.14878196352431083
# FPR: nan, TPR: 0.4
# is_not_signal: (0, 0)
# is_signal: (10, 4)
# ===========================================================================
# is_signal : True, p_values[10]: 0.0007129813760136651
# FPR: nan, TPR: 0.45454545454545453
# is_not_signal: (0, 0)
# is_signal: (11, 5)
# ===========================================================================
# is_signal : False, p_values[11]: 0.4752126698287574
# FPR: 0.0, TPR: 0.45454545454545453
# is_not_signal: (1, 0)
# is_signal: (11, 5)
# ===========================================================================
# is_signal : True, p_values[12]: 0.0590183919669112
# FPR: 0.0, TPR: 0.4166666666666667
# is_not_signal: (1, 0)
# is_signal: (12, 5)
# ===========================================================================
# is_signal : True, p_values[13]: 0.22048736209392045
# FPR: 0.0, TPR: 0.38461538461538464
# is_not_signal: (1, 0)
# is_signal: (13, 5)
# ===========================================================================
# is_signal : True, p_values[14]: 0.32498827377468376
# FPR: 0.0, TPR: 0.35714285714285715
# is_not_signal: (1, 0)
# is_signal: (14, 5)
# ===========================================================================
# is_signal : True, p_values[15]: 0.8210782807898322
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (1, 0)
# is_signal: (15, 5)
# ===========================================================================
# is_signal : True, p_values[16]: 0.11547747322236046
# FPR: 0.0, TPR: 0.3125
# is_not_signal: (1, 0)
# is_signal: (16, 5)
# ===========================================================================
# is_signal : True, p_values[17]: 0.020569396187747085
# FPR: 0.0, TPR: 0.35294117647058826
# is_not_signal: (1, 0)
# is_signal: (17, 6)
# ===========================================================================
# is_signal : True, p_values[18]: 0.0757447921020308
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (1, 0)
# is_signal: (18, 6)
# ===========================================================================
# is_signal : True, p_values[19]: 0.005389441296138227
# FPR: 0.0, TPR: 0.3684210526315789
# is_not_signal: (1, 0)
# is_signal: (19, 7)
# ===========================================================================
# is_signal : True, p_values[20]: 0.0023660670979313743
# FPR: 0.0, TPR: 0.4
# is_not_signal: (1, 0)
# is_signal: (20, 8)
# ===========================================================================
# is_signal : True, p_values[21]: 0.9319424929045895
# FPR: 0.0, TPR: 0.38095238095238093
# is_not_signal: (1, 0)
# is_signal: (21, 8)
# ===========================================================================
# is_signal : True, p_values[22]: 0.11627120834609063
# FPR: 0.0, TPR: 0.36363636363636365
# is_not_signal: (1, 0)
# is_signal: (22, 8)
# ===========================================================================
# is_signal : True, p_values[23]: 0.015787170445653694
# FPR: 0.0, TPR: 0.391304347826087
# is_not_signal: (1, 0)
# is_signal: (23, 9)
# ===========================================================================
# is_signal : True, p_values[24]: 0.0008864033517803076
# FPR: 0.0, TPR: 0.4166666666666667
# is_not_signal: (1, 0)
# is_signal: (24, 10)
# ===========================================================================
# is_signal : True, p_values[25]: 0.01809655691231401
# FPR: 0.0, TPR: 0.44
# is_not_signal: (1, 0)
# is_signal: (25, 11)
# ===========================================================================
# is_signal : True, p_values[26]: 0.41577315173384954
# FPR: 0.0, TPR: 0.4230769230769231
# is_not_signal: (1, 0)
# is_signal: (26, 11)
# ===========================================================================
# is_signal : True, p_values[27]: 0.657342779788183
# FPR: 0.0, TPR: 0.4074074074074074
# is_not_signal: (1, 0)
# is_signal: (27, 11)
# ===========================================================================
# is_signal : True, p_values[28]: 0.00982402939836992
# FPR: 0.0, TPR: 0.42857142857142855
# is_not_signal: (1, 0)
# is_signal: (28, 12)
# ===========================================================================
# is_signal : True, p_values[29]: 0.0013801012412119212
# FPR: 0.0, TPR: 0.4482758620689655
# is_not_signal: (1, 0)
# is_signal: (29, 13)
# ===========================================================================
# is_signal : True, p_values[30]: 0.10642299891853303
# FPR: 0.0, TPR: 0.43333333333333335
# is_not_signal: (1, 0)
# is_signal: (30, 13)
# ===========================================================================
# is_signal : True, p_values[31]: 0.0007328460267065541
# FPR: 0.0, TPR: 0.45161290322580644
# is_not_signal: (1, 0)
# is_signal: (31, 14)
# ===========================================================================
# is_signal : True, p_values[32]: 0.023641536713911566
# FPR: 0.0, TPR: 0.46875
# is_not_signal: (1, 0)
# is_signal: (32, 15)
# ===========================================================================
# is_signal : True, p_values[33]: 0.13101523140846905
# FPR: 0.0, TPR: 0.45454545454545453
# is_not_signal: (1, 0)
# is_signal: (33, 15)
# ===========================================================================
# is_signal : True, p_values[34]: 0.6839570607359473
# FPR: 0.0, TPR: 0.4411764705882353
# is_not_signal: (1, 0)
# is_signal: (34, 15)
# ===========================================================================
# is_signal : False, p_values[35]: 0.3607240297971784
# FPR: 0.0, TPR: 0.4411764705882353
# is_not_signal: (2, 0)
# is_signal: (34, 15)
# ===========================================================================
# is_signal : True, p_values[36]: 0.00014512605393481438
# FPR: 0.0, TPR: 0.45714285714285713
# is_not_signal: (2, 0)
# is_signal: (35, 16)
# ===========================================================================
# is_signal : True, p_values[37]: 0.07000828211902076
# FPR: 0.0, TPR: 0.4444444444444444
# is_not_signal: (2, 0)
# is_signal: (36, 16)
# ===========================================================================
# is_signal : True, p_values[38]: 0.015911477451076128
# FPR: 0.0, TPR: 0.4594594594594595
# is_not_signal: (2, 0)
# is_signal: (37, 17)
# ===========================================================================
# is_signal : True, p_values[39]: 0.0003533775613592537
# FPR: 0.0, TPR: 0.47368421052631576
# is_not_signal: (2, 0)
# is_signal: (38, 18)
# ===========================================================================
# is_signal : True, p_values[40]: 0.11244059069228829
# FPR: 0.0, TPR: 0.46153846153846156
# is_not_signal: (2, 0)
# is_signal: (39, 18)
# ===========================================================================
# is_signal : True, p_values[41]: 0.04014859595708775
# FPR: 0.0, TPR: 0.475
# is_not_signal: (2, 0)
# is_signal: (40, 19)
# ===========================================================================
# is_signal : True, p_values[42]: 0.0004366164826333083
# FPR: 0.0, TPR: 0.4878048780487805
# is_not_signal: (2, 0)
# is_signal: (41, 20)
# ===========================================================================
# is_signal : True, p_values[43]: 0.013420589974192532
# FPR: 0.0, TPR: 0.5
# is_not_signal: (2, 0)
# is_signal: (42, 21)
# ===========================================================================
# is_signal : False, p_values[44]: 0.20293046338105847
# FPR: 0.0, TPR: 0.5
# is_not_signal: (3, 0)
# is_signal: (42, 21)
# ===========================================================================
# is_signal : False, p_values[45]: 0.7311470374299507
# FPR: 0.0, TPR: 0.5
# is_not_signal: (4, 0)
# is_signal: (42, 21)
# ===========================================================================
# is_signal : True, p_values[46]: 0.09744463256635183
# FPR: 0.0, TPR: 0.4883720930232558
# is_not_signal: (4, 0)
# is_signal: (43, 21)
# ===========================================================================
# is_signal : False, p_values[47]: 0.9462385055764392
# FPR: 0.0, TPR: 0.4883720930232558
# is_not_signal: (5, 0)
# is_signal: (43, 21)
# ===========================================================================
# is_signal : True, p_values[48]: 0.0911672352988529
# FPR: 0.0, TPR: 0.4772727272727273
# is_not_signal: (5, 0)
# is_signal: (44, 21)
# ===========================================================================
# is_signal : True, p_values[49]: 0.6995702186058439
# FPR: 0.0, TPR: 0.4666666666666667
# is_not_signal: (5, 0)
# is_signal: (45, 21)
# ===========================================================================
# is_signal : True, p_values[50]: 0.009814875344334223
# FPR: 0.0, TPR: 0.4782608695652174
# is_not_signal: (5, 0)
# is_signal: (46, 22)
# ===========================================================================
# is_signal : True, p_values[51]: 0.07832204225696979
# FPR: 0.0, TPR: 0.46808510638297873
# is_not_signal: (5, 0)
# is_signal: (47, 22)
# ===========================================================================
# is_signal : True, p_values[52]: 0.0001256915339615613
# FPR: 0.0, TPR: 0.4791666666666667
# is_not_signal: (5, 0)
# is_signal: (48, 23)
# ===========================================================================
# is_signal : True, p_values[53]: 0.0025674630261671954
# FPR: 0.0, TPR: 0.4897959183673469
# is_not_signal: (5, 0)
# is_signal: (49, 24)
# ===========================================================================
# is_signal : True, p_values[54]: 0.12819641862878894
# FPR: 0.0, TPR: 0.48
# is_not_signal: (5, 0)
# is_signal: (50, 24)
# ===========================================================================
# is_signal : False, p_values[55]: 0.2042263920620516
# FPR: 0.0, TPR: 0.48
# is_not_signal: (6, 0)
# is_signal: (50, 24)
# ===========================================================================
# is_signal : True, p_values[56]: 0.8892120079157407
# FPR: 0.0, TPR: 0.47058823529411764
# is_not_signal: (6, 0)
# is_signal: (51, 24)
# ===========================================================================
# is_signal : False, p_values[57]: 0.8046543341789528
# FPR: 0.0, TPR: 0.47058823529411764
# is_not_signal: (7, 0)
# is_signal: (51, 24)
# ===========================================================================
# is_signal : False, p_values[58]: 0.2367736745534378
# FPR: 0.0, TPR: 0.47058823529411764
# is_not_signal: (8, 0)
# is_signal: (51, 24)
# ===========================================================================
# is_signal : True, p_values[59]: 0.008738501636165305
# FPR: 0.0, TPR: 0.4807692307692308
# is_not_signal: (8, 0)
# is_signal: (52, 25)
# ===========================================================================
# is_signal : False, p_values[60]: 0.052471440041393105
# FPR: 0.0, TPR: 0.4807692307692308
# is_not_signal: (9, 0)
# is_signal: (52, 25)
# ===========================================================================
# is_signal : True, p_values[61]: 0.021243396331852942
# FPR: 0.0, TPR: 0.49056603773584906
# is_not_signal: (9, 0)
# is_signal: (53, 26)
# ===========================================================================
# is_signal : True, p_values[62]: 0.04283168748609315
# FPR: 0.0, TPR: 0.5
# is_not_signal: (9, 0)
# is_signal: (54, 27)
# ===========================================================================
# is_signal : True, p_values[63]: 0.052998632893304136
# FPR: 0.0, TPR: 0.4909090909090909
# is_not_signal: (9, 0)
# is_signal: (55, 27)
# ===========================================================================
# is_signal : True, p_values[64]: 0.6238606360218467
# FPR: 0.0, TPR: 0.48214285714285715
# is_not_signal: (9, 0)
# is_signal: (56, 27)
# ===========================================================================
# is_signal : True, p_values[65]: 0.10192981850183336
# FPR: 0.0, TPR: 0.47368421052631576
# is_not_signal: (9, 0)
# is_signal: (57, 27)
# ===========================================================================
# is_signal : False, p_values[66]: 0.91980910223783
# FPR: 0.0, TPR: 0.47368421052631576
# is_not_signal: (10, 0)
# is_signal: (57, 27)
# ===========================================================================
# is_signal : True, p_values[67]: 0.6959099593236775
# FPR: 0.0, TPR: 0.46551724137931033
# is_not_signal: (10, 0)
# is_signal: (58, 27)
# ===========================================================================
# -- h = 6 --
# is_signal : True, p_values[0]: 0.0037112320188383173
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : False, p_values[1]: 0.2426103537654849
# FPR: 0.0, TPR: 1.0
# is_not_signal: (1, 0)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : True, p_values[2]: 0.029154555449124025
# FPR: 0.0, TPR: 1.0
# is_not_signal: (1, 0)
# is_signal: (2, 2)
# ===========================================================================
# is_signal : True, p_values[3]: 0.0019572336769127967
# FPR: 0.0, TPR: 1.0
# is_not_signal: (1, 0)
# is_signal: (3, 3)
# ===========================================================================
# is_signal : True, p_values[4]: 0.0510428734532638
# FPR: 0.0, TPR: 0.75
# is_not_signal: (1, 0)
# is_signal: (4, 3)
# ===========================================================================
# is_signal : True, p_values[5]: 0.2909287422561259
# FPR: 0.0, TPR: 0.6
# is_not_signal: (1, 0)
# is_signal: (5, 3)
# ===========================================================================
# is_signal : True, p_values[6]: 0.05912697996931841
# FPR: 0.0, TPR: 0.5
# is_not_signal: (1, 0)
# is_signal: (6, 3)
# ===========================================================================
# is_signal : True, p_values[7]: 0.011920311461916714
# FPR: 0.0, TPR: 0.5714285714285714
# is_not_signal: (1, 0)
# is_signal: (7, 4)
# ===========================================================================
# is_signal : True, p_values[8]: 0.009333019096587318
# FPR: 0.0, TPR: 0.625
# is_not_signal: (1, 0)
# is_signal: (8, 5)
# ===========================================================================
# is_signal : True, p_values[9]: 0.7114347507969443
# FPR: 0.0, TPR: 0.5555555555555556
# is_not_signal: (1, 0)
# is_signal: (9, 5)
# ===========================================================================
# is_signal : True, p_values[10]: 0.1076171886699356
# FPR: 0.0, TPR: 0.5
# is_not_signal: (1, 0)
# is_signal: (10, 5)
# ===========================================================================
# is_signal : True, p_values[11]: 0.008760345538680804
# FPR: 0.0, TPR: 0.5454545454545454
# is_not_signal: (1, 0)
# is_signal: (11, 6)
# ===========================================================================
# is_signal : True, p_values[12]: 0.9027018038428417
# FPR: 0.0, TPR: 0.5
# is_not_signal: (1, 0)
# is_signal: (12, 6)
# ===========================================================================
# is_signal : True, p_values[13]: 0.14501068429820763
# FPR: 0.0, TPR: 0.46153846153846156
# is_not_signal: (1, 0)
# is_signal: (13, 6)
# ===========================================================================
# is_signal : True, p_values[14]: 0.016381390965066186
# FPR: 0.0, TPR: 0.5
# is_not_signal: (1, 0)
# is_signal: (14, 7)
# ===========================================================================
# is_signal : True, p_values[15]: 0.5219855072932692
# FPR: 0.0, TPR: 0.4666666666666667
# is_not_signal: (1, 0)
# is_signal: (15, 7)
# ===========================================================================
# is_signal : True, p_values[16]: 0.008695173922327985
# FPR: 0.0, TPR: 0.5
# is_not_signal: (1, 0)
# is_signal: (16, 8)
# ===========================================================================
# is_signal : True, p_values[17]: 0.479366094453732
# FPR: 0.0, TPR: 0.47058823529411764
# is_not_signal: (1, 0)
# is_signal: (17, 8)
# ===========================================================================
# is_signal : True, p_values[18]: 0.16231362217834042
# FPR: 0.0, TPR: 0.4444444444444444
# is_not_signal: (1, 0)
# is_signal: (18, 8)
# ===========================================================================
# is_signal : True, p_values[19]: 0.01785878775371945
# FPR: 0.0, TPR: 0.47368421052631576
# is_not_signal: (1, 0)
# is_signal: (19, 9)
# ===========================================================================
# is_signal : False, p_values[20]: 0.0907875210675426
# FPR: 0.0, TPR: 0.47368421052631576
# is_not_signal: (2, 0)
# is_signal: (19, 9)
# ===========================================================================
# is_signal : True, p_values[21]: 0.007634388862799642
# FPR: 0.0, TPR: 0.5
# is_not_signal: (2, 0)
# is_signal: (20, 10)
# ===========================================================================
# is_signal : False, p_values[22]: 0.5855751013453663
# FPR: 0.0, TPR: 0.5
# is_not_signal: (3, 0)
# is_signal: (20, 10)
# ===========================================================================
# is_signal : True, p_values[23]: 0.5777437265203923
# FPR: 0.0, TPR: 0.47619047619047616
# is_not_signal: (3, 0)
# is_signal: (21, 10)
# ===========================================================================
# is_signal : False, p_values[24]: 0.9838003210734556
# FPR: 0.0, TPR: 0.47619047619047616
# is_not_signal: (4, 0)
# is_signal: (21, 10)
# ===========================================================================
# is_signal : True, p_values[25]: 0.10649858859912295
# FPR: 0.0, TPR: 0.45454545454545453
# is_not_signal: (4, 0)
# is_signal: (22, 10)
# ===========================================================================
# is_signal : True, p_values[26]: 0.16132927721129767
# FPR: 0.0, TPR: 0.43478260869565216
# is_not_signal: (4, 0)
# is_signal: (23, 10)
# ===========================================================================
# is_signal : False, p_values[27]: 0.8841559928089673
# FPR: 0.0, TPR: 0.43478260869565216
# is_not_signal: (5, 0)
# is_signal: (23, 10)
# ===========================================================================
# is_signal : False, p_values[28]: 0.5391246943730377
# FPR: 0.0, TPR: 0.43478260869565216
# is_not_signal: (6, 0)
# is_signal: (23, 10)
# ===========================================================================
# is_signal : True, p_values[29]: 0.18653256318444747
# FPR: 0.0, TPR: 0.4166666666666667
# is_not_signal: (6, 0)
# is_signal: (24, 10)
# ===========================================================================
# is_signal : True, p_values[30]: 0.7555916336859301
# FPR: 0.0, TPR: 0.4
# is_not_signal: (6, 0)
# is_signal: (25, 10)
# ===========================================================================
# is_signal : True, p_values[31]: 0.5453879899383073
# FPR: 0.0, TPR: 0.38461538461538464
# is_not_signal: (6, 0)
# is_signal: (26, 10)
# ===========================================================================
# is_signal : True, p_values[32]: 0.28299752610812867
# FPR: 0.0, TPR: 0.37037037037037035
# is_not_signal: (6, 0)
# is_signal: (27, 10)
# ===========================================================================
# is_signal : False, p_values[33]: 0.3871909049726422
# FPR: 0.0, TPR: 0.37037037037037035
# is_not_signal: (7, 0)
# is_signal: (27, 10)
# ===========================================================================
# is_signal : True, p_values[34]: 0.009120648893357506
# FPR: 0.0, TPR: 0.39285714285714285
# is_not_signal: (7, 0)
# is_signal: (28, 11)
# ===========================================================================
# is_signal : True, p_values[35]: 0.0032647542599844644
# FPR: 0.0, TPR: 0.41379310344827586
# is_not_signal: (7, 0)
# is_signal: (29, 12)
# ===========================================================================
# is_signal : True, p_values[36]: 0.05835767862287889
# FPR: 0.0, TPR: 0.4
# is_not_signal: (7, 0)
# is_signal: (30, 12)
# ===========================================================================
# is_signal : True, p_values[37]: 0.005793427031803714
# FPR: 0.0, TPR: 0.41935483870967744
# is_not_signal: (7, 0)
# is_signal: (31, 13)
# ===========================================================================
# is_signal : True, p_values[38]: 0.0275817639633421
# FPR: 0.0, TPR: 0.4375
# is_not_signal: (7, 0)
# is_signal: (32, 14)
# ===========================================================================
# is_signal : True, p_values[39]: 0.699230920435432
# FPR: 0.0, TPR: 0.42424242424242425
# is_not_signal: (7, 0)
# is_signal: (33, 14)
# ===========================================================================
# is_signal : True, p_values[40]: 0.28897815835316065
# FPR: 0.0, TPR: 0.4117647058823529
# is_not_signal: (7, 0)
# is_signal: (34, 14)
# ===========================================================================
# is_signal : False, p_values[41]: 0.8344120346771505
# FPR: 0.0, TPR: 0.4117647058823529
# is_not_signal: (8, 0)
# is_signal: (34, 14)
# ===========================================================================
# is_signal : True, p_values[42]: 0.535743105833679
# FPR: 0.0, TPR: 0.4
# is_not_signal: (8, 0)
# is_signal: (35, 14)
# ===========================================================================
# is_signal : True, p_values[43]: 0.7183443231896915
# FPR: 0.0, TPR: 0.3888888888888889
# is_not_signal: (8, 0)
# is_signal: (36, 14)
# ===========================================================================
# is_signal : True, p_values[44]: 0.06526490235441687
# FPR: 0.0, TPR: 0.3783783783783784
# is_not_signal: (8, 0)
# is_signal: (37, 14)
# ===========================================================================
# is_signal : True, p_values[45]: 0.06188210504965197
# FPR: 0.0, TPR: 0.3684210526315789
# is_not_signal: (8, 0)
# is_signal: (38, 14)
# ===========================================================================
# is_signal : True, p_values[46]: 0.02635775590456187
# FPR: 0.0, TPR: 0.38461538461538464
# is_not_signal: (8, 0)
# is_signal: (39, 15)
# ===========================================================================
# is_signal : False, p_values[47]: 0.03678115186378071
# FPR: 0.1111111111111111, TPR: 0.38461538461538464
# is_not_signal: (9, 1)
# is_signal: (39, 15)
# ===========================================================================
# is_signal : True, p_values[48]: 0.6438117587450566
# FPR: 0.1111111111111111, TPR: 0.375
# is_not_signal: (9, 1)
# is_signal: (40, 15)
# ===========================================================================
# is_signal : True, p_values[49]: 0.23839467734869685
# FPR: 0.1111111111111111, TPR: 0.36585365853658536
# is_not_signal: (9, 1)
# is_signal: (41, 15)
# ===========================================================================
# is_signal : False, p_values[50]: 0.5819747011423697
# FPR: 0.1, TPR: 0.36585365853658536
# is_not_signal: (10, 1)
# is_signal: (41, 15)
# ===========================================================================
# is_signal : True, p_values[51]: 0.17335594658980918
# FPR: 0.1, TPR: 0.35714285714285715
# is_not_signal: (10, 1)
# is_signal: (42, 15)
# ===========================================================================
# is_signal : False, p_values[52]: 0.7746551966257488
# FPR: 0.09090909090909091, TPR: 0.35714285714285715
# is_not_signal: (11, 1)
# is_signal: (42, 15)
# ===========================================================================
# is_signal : False, p_values[53]: 0.47743738167419
# FPR: 0.08333333333333333, TPR: 0.35714285714285715
# is_not_signal: (12, 1)
# is_signal: (42, 15)
# ===========================================================================
# is_signal : False, p_values[54]: 0.5953076963496092
# FPR: 0.07692307692307693, TPR: 0.35714285714285715
# is_not_signal: (13, 1)
# is_signal: (42, 15)
# ===========================================================================
# is_signal : False, p_values[55]: 0.8221516330934009
# FPR: 0.07142857142857142, TPR: 0.35714285714285715
# is_not_signal: (14, 1)
# is_signal: (42, 15)
# ===========================================================================
# is_signal : False, p_values[56]: 0.7912455540484877
# FPR: 0.06666666666666667, TPR: 0.35714285714285715
# is_not_signal: (15, 1)
# is_signal: (42, 15)
# ===========================================================================
# is_signal : True, p_values[57]: 0.04272303759795048
# FPR: 0.06666666666666667, TPR: 0.37209302325581395
# is_not_signal: (15, 1)
# is_signal: (43, 16)
# ===========================================================================
# is_signal : True, p_values[58]: 0.028340051676774062
# FPR: 0.06666666666666667, TPR: 0.38636363636363635
# is_not_signal: (15, 1)
# is_signal: (44, 17)
# ===========================================================================
# is_signal : True, p_values[59]: 0.0569092707961107
# FPR: 0.06666666666666667, TPR: 0.37777777777777777
# is_not_signal: (15, 1)
# is_signal: (45, 17)
# ===========================================================================
# is_signal : True, p_values[60]: 0.5195598131968405
# FPR: 0.06666666666666667, TPR: 0.3695652173913043
# is_not_signal: (15, 1)
# is_signal: (46, 17)
# ===========================================================================
# is_signal : False, p_values[61]: 0.1760905119296231
# FPR: 0.0625, TPR: 0.3695652173913043
# is_not_signal: (16, 1)
# is_signal: (46, 17)
# ===========================================================================
# is_signal : False, p_values[62]: 0.4100431381894507
# FPR: 0.058823529411764705, TPR: 0.3695652173913043
# is_not_signal: (17, 1)
# is_signal: (46, 17)
# ===========================================================================
# is_signal : True, p_values[63]: 0.21051539626914478
# FPR: 0.058823529411764705, TPR: 0.3617021276595745
# is_not_signal: (17, 1)
# is_signal: (47, 17)
# ===========================================================================
# is_signal : True, p_values[64]: 0.05907883394146526
# FPR: 0.058823529411764705, TPR: 0.3541666666666667
# is_not_signal: (17, 1)
# is_signal: (48, 17)
# ===========================================================================
# is_signal : False, p_values[65]: 0.24719543410948383
# FPR: 0.05555555555555555, TPR: 0.3541666666666667
# is_not_signal: (18, 1)
# is_signal: (48, 17)
# ===========================================================================
# is_signal : False, p_values[66]: 0.1962156979949281
# FPR: 0.05263157894736842, TPR: 0.3541666666666667
# is_not_signal: (19, 1)
# is_signal: (48, 17)
# ===========================================================================
# is_signal : True, p_values[67]: 0.9984064004550257
# FPR: 0.05263157894736842, TPR: 0.3469387755102041
# is_not_signal: (19, 1)
# is_signal: (49, 17)
# ===========================================================================
# -- h = 10 --
# is_signal : True, p_values[0]: 0.1396657953606157
# FPR: nan, TPR: 0.0
# is_not_signal: (0, 0)
# is_signal: (1, 0)
# ===========================================================================
# is_signal : False, p_values[1]: 0.29542361642019144
# FPR: 0.0, TPR: 0.0
# is_not_signal: (1, 0)
# is_signal: (1, 0)
# ===========================================================================
# is_signal : True, p_values[2]: 0.005468614503543215
# FPR: 0.0, TPR: 0.5
# is_not_signal: (1, 0)
# is_signal: (2, 1)
# ===========================================================================
# is_signal : True, p_values[3]: 0.38219326845969187
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (1, 0)
# is_signal: (3, 1)
# ===========================================================================
# is_signal : True, p_values[4]: 0.9431724384293868
# FPR: 0.0, TPR: 0.25
# is_not_signal: (1, 0)
# is_signal: (4, 1)
# ===========================================================================
# is_signal : True, p_values[5]: 0.002024823209731168
# FPR: 0.0, TPR: 0.4
# is_not_signal: (1, 0)
# is_signal: (5, 2)
# ===========================================================================
# is_signal : False, p_values[6]: 0.44476832057317345
# FPR: 0.0, TPR: 0.4
# is_not_signal: (2, 0)
# is_signal: (5, 2)
# ===========================================================================
# is_signal : True, p_values[7]: 0.5277047255806064
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (2, 0)
# is_signal: (6, 2)
# ===========================================================================
# is_signal : True, p_values[8]: 0.04374960412852093
# FPR: 0.0, TPR: 0.42857142857142855
# is_not_signal: (2, 0)
# is_signal: (7, 3)
# ===========================================================================
# is_signal : True, p_values[9]: 0.08815000021624164
# FPR: 0.0, TPR: 0.375
# is_not_signal: (2, 0)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : False, p_values[10]: 0.9902889295826633
# FPR: 0.0, TPR: 0.375
# is_not_signal: (3, 0)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : False, p_values[11]: 0.8891891302345672
# FPR: 0.0, TPR: 0.375
# is_not_signal: (4, 0)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : False, p_values[12]: 0.1634385298541135
# FPR: 0.0, TPR: 0.375
# is_not_signal: (5, 0)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : True, p_values[13]: 0.0037487973526235934
# FPR: 0.0, TPR: 0.4444444444444444
# is_not_signal: (5, 0)
# is_signal: (9, 4)
# ===========================================================================
# is_signal : True, p_values[14]: 0.08740213235647445
# FPR: 0.0, TPR: 0.4
# is_not_signal: (5, 0)
# is_signal: (10, 4)
# ===========================================================================
# is_signal : True, p_values[15]: 0.0041964063009797365
# FPR: 0.0, TPR: 0.45454545454545453
# is_not_signal: (5, 0)
# is_signal: (11, 5)
# ===========================================================================
# is_signal : True, p_values[16]: 0.043707054317284076
# FPR: 0.0, TPR: 0.5
# is_not_signal: (5, 0)
# is_signal: (12, 6)
# ===========================================================================
# is_signal : True, p_values[17]: 0.6713675480485722
# FPR: 0.0, TPR: 0.46153846153846156
# is_not_signal: (5, 0)
# is_signal: (13, 6)
# ===========================================================================
# is_signal : False, p_values[18]: 0.6457683965415152
# FPR: 0.0, TPR: 0.46153846153846156
# is_not_signal: (6, 0)
# is_signal: (13, 6)
# ===========================================================================
# is_signal : False, p_values[19]: 0.434052744476436
# FPR: 0.0, TPR: 0.46153846153846156
# is_not_signal: (7, 0)
# is_signal: (13, 6)
# ===========================================================================
# is_signal : True, p_values[20]: 0.0019519066324828601
# FPR: 0.0, TPR: 0.5
# is_not_signal: (7, 0)
# is_signal: (14, 7)
# ===========================================================================
# is_signal : True, p_values[21]: 0.00011809645050492765
# FPR: 0.0, TPR: 0.5333333333333333
# is_not_signal: (7, 0)
# is_signal: (15, 8)
# ===========================================================================
# is_signal : False, p_values[22]: 0.6338927263872338
# FPR: 0.0, TPR: 0.5333333333333333
# is_not_signal: (8, 0)
# is_signal: (15, 8)
# ===========================================================================
# is_signal : True, p_values[23]: 0.12305855380535874
# FPR: 0.0, TPR: 0.5
# is_not_signal: (8, 0)
# is_signal: (16, 8)
# ===========================================================================
# is_signal : True, p_values[24]: 0.011428613176577326
# FPR: 0.0, TPR: 0.5294117647058824
# is_not_signal: (8, 0)
# is_signal: (17, 9)
# ===========================================================================
# is_signal : True, p_values[25]: 0.2162024967701185
# FPR: 0.0, TPR: 0.5
# is_not_signal: (8, 0)
# is_signal: (18, 9)
# ===========================================================================
# is_signal : True, p_values[26]: 0.2424377943368241
# FPR: 0.0, TPR: 0.47368421052631576
# is_not_signal: (8, 0)
# is_signal: (19, 9)
# ===========================================================================
# is_signal : True, p_values[27]: 0.09760143002746582
# FPR: 0.0, TPR: 0.45
# is_not_signal: (8, 0)
# is_signal: (20, 9)
# ===========================================================================
# is_signal : True, p_values[28]: 6.012763674661613e-06
# FPR: 0.0, TPR: 0.47619047619047616
# is_not_signal: (8, 0)
# is_signal: (21, 10)
# ===========================================================================
# is_signal : True, p_values[29]: 0.557917091753228
# FPR: 0.0, TPR: 0.45454545454545453
# is_not_signal: (8, 0)
# is_signal: (22, 10)
# ===========================================================================
# is_signal : True, p_values[30]: 0.1316153468126052
# FPR: 0.0, TPR: 0.43478260869565216
# is_not_signal: (8, 0)
# is_signal: (23, 10)
# ===========================================================================
# is_signal : True, p_values[31]: 0.17860347551314038
# FPR: 0.0, TPR: 0.4166666666666667
# is_not_signal: (8, 0)
# is_signal: (24, 10)
# ===========================================================================
# is_signal : True, p_values[32]: 0.009165601664187978
# FPR: 0.0, TPR: 0.44
# is_not_signal: (8, 0)
# is_signal: (25, 11)
# ===========================================================================
# is_signal : True, p_values[33]: 0.00015624234064408294
# FPR: 0.0, TPR: 0.46153846153846156
# is_not_signal: (8, 0)
# is_signal: (26, 12)
# ===========================================================================
# is_signal : True, p_values[34]: 0.43965499460162316
# FPR: 0.0, TPR: 0.4444444444444444
# is_not_signal: (8, 0)
# is_signal: (27, 12)
# ===========================================================================
# is_signal : True, p_values[35]: 0.0025787120479538483
# FPR: 0.0, TPR: 0.4642857142857143
# is_not_signal: (8, 0)
# is_signal: (28, 13)
# ===========================================================================
# is_signal : True, p_values[36]: 0.13845842270446035
# FPR: 0.0, TPR: 0.4482758620689655
# is_not_signal: (8, 0)
# is_signal: (29, 13)
# ===========================================================================
# is_signal : False, p_values[37]: 0.8825082139366299
# FPR: 0.0, TPR: 0.4482758620689655
# is_not_signal: (9, 0)
# is_signal: (29, 13)
# ===========================================================================
# is_signal : True, p_values[38]: 0.6162989864794813
# FPR: 0.0, TPR: 0.43333333333333335
# is_not_signal: (9, 0)
# is_signal: (30, 13)
# ===========================================================================
# is_signal : True, p_values[39]: 0.18286669803541192
# FPR: 0.0, TPR: 0.41935483870967744
# is_not_signal: (9, 0)
# is_signal: (31, 13)
# ===========================================================================
# is_signal : True, p_values[40]: 0.1373910238933091
# FPR: 0.0, TPR: 0.40625
# is_not_signal: (9, 0)
# is_signal: (32, 13)
# ===========================================================================
# is_signal : True, p_values[41]: 0.1124044678283217
# FPR: 0.0, TPR: 0.3939393939393939
# is_not_signal: (9, 0)
# is_signal: (33, 13)
# ===========================================================================
# is_signal : True, p_values[42]: 0.9745479801136301
# FPR: 0.0, TPR: 0.38235294117647056
# is_not_signal: (9, 0)
# is_signal: (34, 13)
# ===========================================================================
# is_signal : True, p_values[43]: 0.03141542293041736
# FPR: 0.0, TPR: 0.4
# is_not_signal: (9, 0)
# is_signal: (35, 14)
# ===========================================================================
# is_signal : True, p_values[44]: 0.15052349001194953
# FPR: 0.0, TPR: 0.3888888888888889
# is_not_signal: (9, 0)
# is_signal: (36, 14)
# ===========================================================================
# is_signal : True, p_values[45]: 0.018480455626109567
# FPR: 0.0, TPR: 0.40540540540540543
# is_not_signal: (9, 0)
# is_signal: (37, 15)
# ===========================================================================
# is_signal : True, p_values[46]: 0.07074173137985058
# FPR: 0.0, TPR: 0.39473684210526316
# is_not_signal: (9, 0)
# is_signal: (38, 15)
# ===========================================================================
# is_signal : True, p_values[47]: 0.0010618790039615819
# FPR: 0.0, TPR: 0.41025641025641024
# is_not_signal: (9, 0)
# is_signal: (39, 16)
# ===========================================================================
# is_signal : True, p_values[48]: 0.02106144486032671
# FPR: 0.0, TPR: 0.425
# is_not_signal: (9, 0)
# is_signal: (40, 17)
# ===========================================================================
# is_signal : True, p_values[49]: 0.02303996703305589
# FPR: 0.0, TPR: 0.43902439024390244
# is_not_signal: (9, 0)
# is_signal: (41, 18)
# ===========================================================================
# is_signal : False, p_values[50]: 0.30087204857077626
# FPR: 0.0, TPR: 0.43902439024390244
# is_not_signal: (10, 0)
# is_signal: (41, 18)
# ===========================================================================
# is_signal : True, p_values[51]: 0.4197747142891679
# FPR: 0.0, TPR: 0.42857142857142855
# is_not_signal: (10, 0)
# is_signal: (42, 18)
# ===========================================================================
# is_signal : False, p_values[52]: 0.729657480467502
# FPR: 0.0, TPR: 0.42857142857142855
# is_not_signal: (11, 0)
# is_signal: (42, 18)
# ===========================================================================
# is_signal : True, p_values[53]: 0.03763509658845233
# FPR: 0.0, TPR: 0.4418604651162791
# is_not_signal: (11, 0)
# is_signal: (43, 19)
# ===========================================================================
# is_signal : True, p_values[54]: 0.20176297248815775
# FPR: 0.0, TPR: 0.4318181818181818
# is_not_signal: (11, 0)
# is_signal: (44, 19)
# ===========================================================================
# is_signal : True, p_values[55]: 0.009987970073862838
# FPR: 0.0, TPR: 0.4444444444444444
# is_not_signal: (11, 0)
# is_signal: (45, 20)
# ===========================================================================
# is_signal : True, p_values[56]: 0.0053646816250664435
# FPR: 0.0, TPR: 0.45652173913043476
# is_not_signal: (11, 0)
# is_signal: (46, 21)
# ===========================================================================
# is_signal : True, p_values[57]: 0.08786299544872561
# FPR: 0.0, TPR: 0.44680851063829785
# is_not_signal: (11, 0)
# is_signal: (47, 21)
# ===========================================================================
# is_signal : False, p_values[58]: 0.7075318104028094
# FPR: 0.0, TPR: 0.44680851063829785
# is_not_signal: (12, 0)
# is_signal: (47, 21)
# ===========================================================================
# is_signal : True, p_values[59]: 0.08209024068367712
# FPR: 0.0, TPR: 0.4375
# is_not_signal: (12, 0)
# is_signal: (48, 21)
# ===========================================================================
# is_signal : True, p_values[60]: 0.38600991027320736
# FPR: 0.0, TPR: 0.42857142857142855
# is_not_signal: (12, 0)
# is_signal: (49, 21)
# ===========================================================================
# is_signal : True, p_values[61]: 0.023071536968180578
# FPR: 0.0, TPR: 0.44
# is_not_signal: (12, 0)
# is_signal: (50, 22)
# ===========================================================================
# is_signal : True, p_values[62]: 0.23980317292890072
# FPR: 0.0, TPR: 0.43137254901960786
# is_not_signal: (12, 0)
# is_signal: (51, 22)
# ===========================================================================
# is_signal : True, p_values[63]: 0.00028571115239638524
# FPR: 0.0, TPR: 0.4423076923076923
# is_not_signal: (12, 0)
# is_signal: (52, 23)
# ===========================================================================
# is_signal : False, p_values[64]: 0.9920774525737792
# FPR: 0.0, TPR: 0.4423076923076923
# is_not_signal: (13, 0)
# is_signal: (52, 23)
# ===========================================================================
# is_signal : True, p_values[65]: 0.005422603209371837
# FPR: 0.0, TPR: 0.4528301886792453
# is_not_signal: (13, 0)
# is_signal: (53, 24)
# ===========================================================================
# is_signal : True, p_values[66]: 0.0035443067295481702
# FPR: 0.0, TPR: 0.46296296296296297
# is_not_signal: (13, 0)
# is_signal: (54, 25)
# ===========================================================================
# is_signal : True, p_values[67]: 0.9150589026533772
# FPR: 0.0, TPR: 0.45454545454545453
# is_not_signal: (13, 0)
# is_signal: (55, 25)
# ===========================================================================
# -- h = 14 --
# is_signal : True, p_values[0]: 0.007379589459037147
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : True, p_values[1]: 0.007286712691874041
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (2, 2)
# ===========================================================================
# is_signal : True, p_values[2]: 0.03255003558611161
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (3, 3)
# ===========================================================================
# is_signal : True, p_values[3]: 0.0024157317715883544
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (4, 4)
# ===========================================================================
# is_signal : True, p_values[4]: 0.011910989842871126
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (5, 5)
# ===========================================================================
# is_signal : True, p_values[5]: 0.02351669452782866
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (6, 6)
# ===========================================================================
# is_signal : True, p_values[6]: 8.923302699253996e-05
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (7, 7)
# ===========================================================================
# is_signal : True, p_values[7]: 0.8990257764345329
# FPR: nan, TPR: 0.875
# is_not_signal: (0, 0)
# is_signal: (8, 7)
# ===========================================================================
# is_signal : True, p_values[8]: 0.16088786015592163
# FPR: nan, TPR: 0.7777777777777778
# is_not_signal: (0, 0)
# is_signal: (9, 7)
# ===========================================================================
# is_signal : True, p_values[9]: 0.10232620189732868
# FPR: nan, TPR: 0.7
# is_not_signal: (0, 0)
# is_signal: (10, 7)
# ===========================================================================
# is_signal : True, p_values[10]: 0.00030993005751302454
# FPR: nan, TPR: 0.7272727272727273
# is_not_signal: (0, 0)
# is_signal: (11, 8)
# ===========================================================================
# is_signal : True, p_values[11]: 0.46490089361633047
# FPR: nan, TPR: 0.6666666666666666
# is_not_signal: (0, 0)
# is_signal: (12, 8)
# ===========================================================================
# is_signal : True, p_values[12]: 0.03030063408560648
# FPR: nan, TPR: 0.6923076923076923
# is_not_signal: (0, 0)
# is_signal: (13, 9)
# ===========================================================================
# is_signal : True, p_values[13]: 0.008831851187018156
# FPR: nan, TPR: 0.7142857142857143
# is_not_signal: (0, 0)
# is_signal: (14, 10)
# ===========================================================================
# is_signal : True, p_values[14]: 0.004237996446226871
# FPR: nan, TPR: 0.7333333333333333
# is_not_signal: (0, 0)
# is_signal: (15, 11)
# ===========================================================================
# is_signal : True, p_values[15]: 0.007886131725721243
# FPR: nan, TPR: 0.75
# is_not_signal: (0, 0)
# is_signal: (16, 12)
# ===========================================================================
# is_signal : True, p_values[16]: 0.2809899551872281
# FPR: nan, TPR: 0.7058823529411765
# is_not_signal: (0, 0)
# is_signal: (17, 12)
# ===========================================================================
# is_signal : True, p_values[17]: 0.03158204569990008
# FPR: nan, TPR: 0.7222222222222222
# is_not_signal: (0, 0)
# is_signal: (18, 13)
# ===========================================================================
# is_signal : True, p_values[18]: 0.27127905047226364
# FPR: nan, TPR: 0.6842105263157895
# is_not_signal: (0, 0)
# is_signal: (19, 13)
# ===========================================================================
# is_signal : True, p_values[19]: 0.01533006490765932
# FPR: nan, TPR: 0.7
# is_not_signal: (0, 0)
# is_signal: (20, 14)
# ===========================================================================
# is_signal : False, p_values[20]: 0.5368284073587427
# FPR: 0.0, TPR: 0.7
# is_not_signal: (1, 0)
# is_signal: (20, 14)
# ===========================================================================
# is_signal : True, p_values[21]: 0.06032064130941995
# FPR: 0.0, TPR: 0.6666666666666666
# is_not_signal: (1, 0)
# is_signal: (21, 14)
# ===========================================================================
# is_signal : True, p_values[22]: 0.17739809352415192
# FPR: 0.0, TPR: 0.6363636363636364
# is_not_signal: (1, 0)
# is_signal: (22, 14)
# ===========================================================================
# is_signal : True, p_values[23]: 0.5781454304024741
# FPR: 0.0, TPR: 0.6086956521739131
# is_not_signal: (1, 0)
# is_signal: (23, 14)
# ===========================================================================
# is_signal : True, p_values[24]: 8.52066989729202e-05
# FPR: 0.0, TPR: 0.625
# is_not_signal: (1, 0)
# is_signal: (24, 15)
# ===========================================================================
# is_signal : True, p_values[25]: 0.5503103242853895
# FPR: 0.0, TPR: 0.6
# is_not_signal: (1, 0)
# is_signal: (25, 15)
# ===========================================================================
# is_signal : True, p_values[26]: 0.2751539710210585
# FPR: 0.0, TPR: 0.5769230769230769
# is_not_signal: (1, 0)
# is_signal: (26, 15)
# ===========================================================================
# is_signal : True, p_values[27]: 0.0011603392229463287
# FPR: 0.0, TPR: 0.5925925925925926
# is_not_signal: (1, 0)
# is_signal: (27, 16)
# ===========================================================================
# is_signal : True, p_values[28]: 0.40770780504109705
# FPR: 0.0, TPR: 0.5714285714285714
# is_not_signal: (1, 0)
# is_signal: (28, 16)
# ===========================================================================
# is_signal : True, p_values[29]: 0.5375821594186289
# FPR: 0.0, TPR: 0.5517241379310345
# is_not_signal: (1, 0)
# is_signal: (29, 16)
# ===========================================================================
# is_signal : False, p_values[30]: 0.7789139266753282
# FPR: 0.0, TPR: 0.5517241379310345
# is_not_signal: (2, 0)
# is_signal: (29, 16)
# ===========================================================================
# is_signal : True, p_values[31]: 0.0002874755185257699
# FPR: 0.0, TPR: 0.5666666666666667
# is_not_signal: (2, 0)
# is_signal: (30, 17)
# ===========================================================================
# is_signal : True, p_values[32]: 0.7689253716820886
# FPR: 0.0, TPR: 0.5483870967741935
# is_not_signal: (2, 0)
# is_signal: (31, 17)
# ===========================================================================
# is_signal : True, p_values[33]: 0.19232713029753837
# FPR: 0.0, TPR: 0.53125
# is_not_signal: (2, 0)
# is_signal: (32, 17)
# ===========================================================================
# is_signal : False, p_values[34]: 0.28118648099693
# FPR: 0.0, TPR: 0.53125
# is_not_signal: (3, 0)
# is_signal: (32, 17)
# ===========================================================================
# is_signal : True, p_values[35]: 0.010019486342649599
# FPR: 0.0, TPR: 0.5454545454545454
# is_not_signal: (3, 0)
# is_signal: (33, 18)
# ===========================================================================
# is_signal : True, p_values[36]: 0.0039567506206715465
# FPR: 0.0, TPR: 0.5588235294117647
# is_not_signal: (3, 0)
# is_signal: (34, 19)
# ===========================================================================
# is_signal : False, p_values[37]: 0.2613513504248208
# FPR: 0.0, TPR: 0.5588235294117647
# is_not_signal: (4, 0)
# is_signal: (34, 19)
# ===========================================================================
# is_signal : True, p_values[38]: 0.0061540145653751705
# FPR: 0.0, TPR: 0.5714285714285714
# is_not_signal: (4, 0)
# is_signal: (35, 20)
# ===========================================================================
# is_signal : True, p_values[39]: 0.004520364127175993
# FPR: 0.0, TPR: 0.5833333333333334
# is_not_signal: (4, 0)
# is_signal: (36, 21)
# ===========================================================================
# is_signal : True, p_values[40]: 0.09415493328772624
# FPR: 0.0, TPR: 0.5675675675675675
# is_not_signal: (4, 0)
# is_signal: (37, 21)
# ===========================================================================
# is_signal : True, p_values[41]: 0.0019399845228040464
# FPR: 0.0, TPR: 0.5789473684210527
# is_not_signal: (4, 0)
# is_signal: (38, 22)
# ===========================================================================
# is_signal : True, p_values[42]: 0.19430871550511505
# FPR: 0.0, TPR: 0.5641025641025641
# is_not_signal: (4, 0)
# is_signal: (39, 22)
# ===========================================================================
# is_signal : True, p_values[43]: 0.5482015099808426
# FPR: 0.0, TPR: 0.55
# is_not_signal: (4, 0)
# is_signal: (40, 22)
# ===========================================================================
# is_signal : True, p_values[44]: 0.00037997338325706343
# FPR: 0.0, TPR: 0.5609756097560976
# is_not_signal: (4, 0)
# is_signal: (41, 23)
# ===========================================================================
# is_signal : True, p_values[45]: 0.31096174739571814
# FPR: 0.0, TPR: 0.5476190476190477
# is_not_signal: (4, 0)
# is_signal: (42, 23)
# ===========================================================================
# is_signal : True, p_values[46]: 0.8455861630392374
# FPR: 0.0, TPR: 0.5348837209302325
# is_not_signal: (4, 0)
# is_signal: (43, 23)
# ===========================================================================
# is_signal : True, p_values[47]: 0.5143523268879835
# FPR: 0.0, TPR: 0.5227272727272727
# is_not_signal: (4, 0)
# is_signal: (44, 23)
# ===========================================================================
# is_signal : True, p_values[48]: 0.00042920447662155676
# FPR: 0.0, TPR: 0.5333333333333333
# is_not_signal: (4, 0)
# is_signal: (45, 24)
# ===========================================================================
# is_signal : True, p_values[49]: 0.24383044219458322
# FPR: 0.0, TPR: 0.5217391304347826
# is_not_signal: (4, 0)
# is_signal: (46, 24)
# ===========================================================================
# is_signal : False, p_values[50]: 0.7211248574077742
# FPR: 0.0, TPR: 0.5217391304347826
# is_not_signal: (5, 0)
# is_signal: (46, 24)
# ===========================================================================
# is_signal : True, p_values[51]: 0.416747622338369
# FPR: 0.0, TPR: 0.5106382978723404
# is_not_signal: (5, 0)
# is_signal: (47, 24)
# ===========================================================================
# is_signal : True, p_values[52]: 0.41658604983802666
# FPR: 0.0, TPR: 0.5
# is_not_signal: (5, 0)
# is_signal: (48, 24)
# ===========================================================================
# is_signal : False, p_values[53]: 0.6660345834591932
# FPR: 0.0, TPR: 0.5
# is_not_signal: (6, 0)
# is_signal: (48, 24)
# ===========================================================================
# is_signal : True, p_values[54]: 0.7798523548038623
# FPR: 0.0, TPR: 0.4897959183673469
# is_not_signal: (6, 0)
# is_signal: (49, 24)
# ===========================================================================
# is_signal : True, p_values[55]: 0.001112209147532302
# FPR: 0.0, TPR: 0.5
# is_not_signal: (6, 0)
# is_signal: (50, 25)
# ===========================================================================
# is_signal : True, p_values[56]: 0.012437626433519833
# FPR: 0.0, TPR: 0.5098039215686274
# is_not_signal: (6, 0)
# is_signal: (51, 26)
# ===========================================================================
# is_signal : True, p_values[57]: 0.3509682811925224
# FPR: 0.0, TPR: 0.5
# is_not_signal: (6, 0)
# is_signal: (52, 26)
# ===========================================================================
# is_signal : True, p_values[58]: 0.0006353781836036737
# FPR: 0.0, TPR: 0.5094339622641509
# is_not_signal: (6, 0)
# is_signal: (53, 27)
# ===========================================================================
# is_signal : True, p_values[59]: 0.005983658296457297
# FPR: 0.0, TPR: 0.5185185185185185
# is_not_signal: (6, 0)
# is_signal: (54, 28)
# ===========================================================================
# is_signal : True, p_values[60]: 0.0544559457429324
# FPR: 0.0, TPR: 0.509090909090909
# is_not_signal: (6, 0)
# is_signal: (55, 28)
# ===========================================================================
# is_signal : True, p_values[61]: 0.5478930420477074
# FPR: 0.0, TPR: 0.5
# is_not_signal: (6, 0)
# is_signal: (56, 28)
# ===========================================================================
# is_signal : True, p_values[62]: 0.0009310695412535964
# FPR: 0.0, TPR: 0.5087719298245614
# is_not_signal: (6, 0)
# is_signal: (57, 29)
# ===========================================================================
# is_signal : True, p_values[63]: 0.7308669421495129
# FPR: 0.0, TPR: 0.5
# is_not_signal: (6, 0)
# is_signal: (58, 29)
# ===========================================================================
# is_signal : False, p_values[64]: 0.47021242133589586
# FPR: 0.0, TPR: 0.5
# is_not_signal: (7, 0)
# is_signal: (58, 29)
# ===========================================================================
# is_signal : True, p_values[65]: 0.01219645354377405
# FPR: 0.0, TPR: 0.5084745762711864
# is_not_signal: (7, 0)
# is_signal: (59, 30)
# ===========================================================================
# is_signal : True, p_values[66]: 0.10807357038485998
# FPR: 0.0, TPR: 0.5
# is_not_signal: (7, 0)
# is_signal: (60, 30)
# ===========================================================================
# is_signal : True, p_values[67]: 0.0034239998771350626
# FPR: 0.0, TPR: 0.5081967213114754
# is_not_signal: (7, 0)
# is_signal: (61, 31)
# ===========================================================================

# %%
n_target = 40
n_source = 80
p = 200
K = 5
Ka = 3
h = 10
alpha = 0.05
T = 5
s_len = 10
s_vector = [0.0] * s_len

h_list = [2, 6, 10, 14]

iteration = 125

for h in h_list:
    print(f"-- h = {h} --")
    para_results_storage = []
    CoRT_model = CoRT_builder.CoRT()
    cnt1 = 0
    cnt2 = 0
    cnt3 = 0
    cnt4 = 0

    for i in range(iteration):
        target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
        result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, T, s_len)

        if result_dict != None:
            cnt1 += (result_dict['is_signal'] == True)
            cnt2 += (result_dict['is_signal'] == False)
            cnt3 += (result_dict['is_signal'] == True and result_dict['p_value'] <= alpha)
            cnt4 += (result_dict['is_signal'] == False and result_dict['p_value'] <= alpha)
            
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_values[{i}]: {result_dict['p_value']}")
            print(f"FPR: {cnt4 / cnt2}, TPR: {cnt3 / cnt1}")
            print(f"is_not_signal: {int(cnt2), int(cnt4)}")
            print(f"is_signal: {int(cnt1), int(cnt3)}")
            print("===========================================================================")
                
            para_results_storage.append(result_dict)
    is_signal_cases = [r for r in para_results_storage if r['is_signal']]
    not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

    false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
    fpr = false_positives / len(not_signal_cases) if len(not_signal_cases) != 0 else -1
    true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha) 
    tpr = true_positives / len(is_signal_cases) if len(is_signal_cases) != 0 else -1

    configs = {
        "n_source": n_source,
        "p":  p,
        "K": K,
        "Ka": Ka,
        "h": h,
        "alpha": alpha,
        "T":  T,
        "s_len": s_len,
        "s_vector": s_vector,
        "n_target": n_target,
        "iteration": iteration,
    }

    results = {
        "configs": configs,
        "time": datetime.datetime.now().ctime(),
        "fpr": fpr,
        "tpr": tpr,
        "is_signal_cases": len(is_signal_cases),
        "not_signal_cases": len(not_signal_cases),
        "false_positives": false_positives,
        "true_positives": true_positives
    }

    filename = 'records_3/FPR_parametric_vis_records.json'
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            try:
                records = json.load(f)
            except Exception as e:
                print(e)
                records = []
    else:
        records = []

    records.append(results)

    with open(filename, 'w') as f:
        json.dump(records, f, indent=4)

# %%
n_source = 80
p = 200
K = 5
Ka = 3
h = 10
alpha = 0.05
T = 5
s_len = 10
s_vector = [0.5] * s_len
iteration = 125

n_target_list = [40, 50, 60, 70]

for n_target in n_target_list:
    print(f"-- n_target = {n_target} --")
    para_results_storage = []
    CoRT_model = CoRT_builder.CoRT()
    cnt1 = 0
    cnt2 = 0
    cnt3 = 0
    cnt4 = 0

    for i in range(iteration):
        target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
        result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, T, s_len)

        if result_dict != None:
            cnt1 += (result_dict['is_signal'] == True)
            cnt2 += (result_dict['is_signal'] == False)
            cnt3 += (result_dict['is_signal'] == True and result_dict['p_value'] <= alpha)
            cnt4 += (result_dict['is_signal'] == False and result_dict['p_value'] <= alpha)
            
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_values[{i}]: {result_dict['p_value']}")
            print(f"FPR: {cnt4 / cnt2}, TPR: {cnt3 / cnt1}")
            print(f"is_not_signal: {int(cnt2), int(cnt4)}")
            print(f"is_signal: {int(cnt1), int(cnt3)}")
            print("===========================================================================")
                
            para_results_storage.append(result_dict)
    is_signal_cases = [r for r in para_results_storage if r['is_signal']]
    not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

    false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
    fpr = false_positives / len(not_signal_cases) if len(not_signal_cases) != 0 else -1
    true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha) 
    tpr = true_positives / len(is_signal_cases) if len(is_signal_cases) != 0 else -1

    configs = {
        "n_source": n_source,
        "p":  p,
        "K": K,
        "Ka": Ka,
        "h": h,
        "alpha": alpha,
        "T":  T,
        "s_len": s_len,
        "s_vector": s_vector,
        "n_target": n_target,
        "iteration": iteration,
    }

    results = {
        "configs": configs,
        "time": datetime.datetime.now().ctime(),
        "fpr": fpr,
        "tpr": tpr,
        "is_signal_cases": len(is_signal_cases),
        "not_signal_cases": len(not_signal_cases),
        "false_positives": false_positives,
        "true_positives": true_positives
    }

    filename = 'records/TPR_parametric_vis_records.json'
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            try:
                records = json.load(f)
            except Exception as e:
                print(e)
                records = []
    else:
        records = []

    records.append(results)

    with open(filename, 'w') as f:
        json.dump(records, f, indent=4)
# Out:
# -- n_target = 40 --
# is_signal : True, p_values[0]: 0.025216784408720286
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : True, p_values[1]: 0.0005257392710020984
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (2, 2)
# ===========================================================================
# is_signal : True, p_values[2]: 0.9754311824384709
# FPR: nan, TPR: 0.6666666666666666
# is_not_signal: (0, 0)
# is_signal: (3, 2)
# ===========================================================================
# is_signal : True, p_values[3]: 0.8104150162581802
# FPR: nan, TPR: 0.5
# is_not_signal: (0, 0)
# is_signal: (4, 2)
# ===========================================================================
# is_signal : True, p_values[4]: 0.8135991566647497
# FPR: nan, TPR: 0.4
# is_not_signal: (0, 0)
# is_signal: (5, 2)
# ===========================================================================
# is_signal : True, p_values[5]: 0.0008888253547786966
# FPR: nan, TPR: 0.5
# is_not_signal: (0, 0)
# is_signal: (6, 3)
# ===========================================================================
# is_signal : True, p_values[6]: 0.37540965171909074
# FPR: nan, TPR: 0.42857142857142855
# is_not_signal: (0, 0)
# is_signal: (7, 3)
# ===========================================================================
# is_signal : True, p_values[7]: 0.2904178016731907
# FPR: nan, TPR: 0.375
# is_not_signal: (0, 0)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : False, p_values[8]: 0.3375079357037829
# FPR: 0.0, TPR: 0.375
# is_not_signal: (1, 0)
# is_signal: (8, 3)
# ===========================================================================
# is_signal : True, p_values[9]: 0.33862610531118525
# FPR: 0.0, TPR: 0.3333333333333333
# is_not_signal: (1, 0)
# is_signal: (9, 3)
# ===========================================================================
# is_signal : True, p_values[10]: 0.667958815232952
# FPR: 0.0, TPR: 0.3
# is_not_signal: (1, 0)
# is_signal: (10, 3)
# ===========================================================================
# is_signal : True, p_values[11]: 0.44301475482551544
# FPR: 0.0, TPR: 0.2727272727272727
# is_not_signal: (1, 0)
# is_signal: (11, 3)
# ===========================================================================
# is_signal : True, p_values[12]: 0.6367325478617364
# FPR: 0.0, TPR: 0.25
# is_not_signal: (1, 0)
# is_signal: (12, 3)
# ===========================================================================
# is_signal : True, p_values[13]: 0.8351820286906592
# FPR: 0.0, TPR: 0.23076923076923078
# is_not_signal: (1, 0)
# is_signal: (13, 3)
# ===========================================================================
# is_signal : True, p_values[14]: 0.11413058103900943
# FPR: 0.0, TPR: 0.21428571428571427
# is_not_signal: (1, 0)
# is_signal: (14, 3)
# ===========================================================================
# is_signal : True, p_values[15]: 0.5558424757416303
# FPR: 0.0, TPR: 0.2
# is_not_signal: (1, 0)
# is_signal: (15, 3)
# ===========================================================================
# is_signal : True, p_values[16]: 0.5248941465718531
# FPR: 0.0, TPR: 0.1875
# is_not_signal: (1, 0)
# is_signal: (16, 3)
# ===========================================================================
# is_signal : True, p_values[17]: 0.0025104915262972945
# FPR: 0.0, TPR: 0.23529411764705882
# is_not_signal: (1, 0)
# is_signal: (17, 4)
# ===========================================================================
# is_signal : True, p_values[18]: 0.09663134387705874
# FPR: 0.0, TPR: 0.2222222222222222
# is_not_signal: (1, 0)
# is_signal: (18, 4)
# ===========================================================================
# R_aug, z2: 0.09553923815551595, 0.09553933834700927
# is_signal : True, p_values[19]: 0.05965167912810669
# FPR: 0.0, TPR: 0.21052631578947367
# is_not_signal: (1, 0)
# is_signal: (19, 4)
# ===========================================================================
# is_signal : True, p_values[20]: 0.03186618958500664
# FPR: 0.0, TPR: 0.25
# is_not_signal: (1, 0)
# is_signal: (20, 5)
# ===========================================================================
# is_signal : True, p_values[21]: 0.060048615338200446
# FPR: 0.0, TPR: 0.23809523809523808
# is_not_signal: (1, 0)
# is_signal: (21, 5)
# ===========================================================================
# is_signal : True, p_values[22]: 0.03987350442386638
# FPR: 0.0, TPR: 0.2727272727272727
# is_not_signal: (1, 0)
# is_signal: (22, 6)
# ===========================================================================
# is_signal : True, p_values[23]: 0.3590314201574777
# FPR: 0.0, TPR: 0.2608695652173913
# is_not_signal: (1, 0)
# is_signal: (23, 6)
# ===========================================================================
# is_signal : False, p_values[24]: 0.9647099735724256
# FPR: 0.0, TPR: 0.2608695652173913
# is_not_signal: (2, 0)
# is_signal: (23, 6)
# ===========================================================================
# is_signal : True, p_values[25]: 0.06582839463627209
# FPR: 0.0, TPR: 0.25
# is_not_signal: (2, 0)
# is_signal: (24, 6)
# ===========================================================================
# is_signal : True, p_values[26]: 0.005620056909725873
# FPR: 0.0, TPR: 0.28
# is_not_signal: (2, 0)
# is_signal: (25, 7)
# ===========================================================================
# is_signal : True, p_values[27]: 0.34293557645736605
# FPR: 0.0, TPR: 0.2692307692307692
# is_not_signal: (2, 0)
# is_signal: (26, 7)
# ===========================================================================
# is_signal : True, p_values[28]: 0.19436128581955373
# FPR: 0.0, TPR: 0.25925925925925924
# is_not_signal: (2, 0)
# is_signal: (27, 7)
# ===========================================================================
# is_signal : False, p_values[29]: 0.3844449135374161
# FPR: 0.0, TPR: 0.25925925925925924
# is_not_signal: (3, 0)
# is_signal: (27, 7)
# ===========================================================================
# is_signal : True, p_values[30]: 0.5002980151969826
# FPR: 0.0, TPR: 0.25
# is_not_signal: (3, 0)
# is_signal: (28, 7)
# ===========================================================================
# is_signal : True, p_values[31]: 0.007818144016599764
# FPR: 0.0, TPR: 0.27586206896551724
# is_not_signal: (3, 0)
# is_signal: (29, 8)
# ===========================================================================
# is_signal : False, p_values[32]: 0.12525409151296943
# FPR: 0.0, TPR: 0.27586206896551724
# is_not_signal: (4, 0)
# is_signal: (29, 8)
# ===========================================================================
# is_signal : True, p_values[33]: 0.22622101110760628
# FPR: 0.0, TPR: 0.26666666666666666
# is_not_signal: (4, 0)
# is_signal: (30, 8)
# ===========================================================================
# is_signal : True, p_values[34]: 0.0034477964578934284
# FPR: 0.0, TPR: 0.2903225806451613
# is_not_signal: (4, 0)
# is_signal: (31, 9)
# ===========================================================================
# is_signal : True, p_values[35]: 0.0025636556019234093
# FPR: 0.0, TPR: 0.3125
# is_not_signal: (4, 0)
# is_signal: (32, 10)
# ===========================================================================
# is_signal : False, p_values[36]: 0.32508870491257463
# FPR: 0.0, TPR: 0.3125
# is_not_signal: (5, 0)
# is_signal: (32, 10)
# ===========================================================================
# is_signal : False, p_values[37]: 0.04699957402938943
# FPR: 0.16666666666666666, TPR: 0.3125
# is_not_signal: (6, 1)
# is_signal: (32, 10)
# ===========================================================================
# is_signal : True, p_values[38]: 0.005769619389696698
# FPR: 0.16666666666666666, TPR: 0.3333333333333333
# is_not_signal: (6, 1)
# is_signal: (33, 11)
# ===========================================================================
# is_signal : True, p_values[39]: 0.0711291878131245
# FPR: 0.16666666666666666, TPR: 0.3235294117647059
# is_not_signal: (6, 1)
# is_signal: (34, 11)
# ===========================================================================
# is_signal : True, p_values[40]: 0.6972866805572329
# FPR: 0.16666666666666666, TPR: 0.3142857142857143
# is_not_signal: (6, 1)
# is_signal: (35, 11)
# ===========================================================================
# is_signal : True, p_values[41]: 0.5673355141357865
# FPR: 0.16666666666666666, TPR: 0.3055555555555556
# is_not_signal: (6, 1)
# is_signal: (36, 11)
# ===========================================================================
# is_signal : True, p_values[42]: 0.23409159503924204
# FPR: 0.16666666666666666, TPR: 0.2972972972972973
# is_not_signal: (6, 1)
# is_signal: (37, 11)
# ===========================================================================
# is_signal : True, p_values[43]: 0.6793590136730968
# FPR: 0.16666666666666666, TPR: 0.2894736842105263
# is_not_signal: (6, 1)
# is_signal: (38, 11)
# ===========================================================================
# is_signal : True, p_values[44]: 0.00610450221441505
# FPR: 0.16666666666666666, TPR: 0.3076923076923077
# is_not_signal: (6, 1)
# is_signal: (39, 12)
# ===========================================================================
# is_signal : False, p_values[45]: 0.5275722659339049
# FPR: 0.14285714285714285, TPR: 0.3076923076923077
# is_not_signal: (7, 1)
# is_signal: (39, 12)
# ===========================================================================
# is_signal : True, p_values[46]: 0.7100596409104586
# FPR: 0.14285714285714285, TPR: 0.3
# is_not_signal: (7, 1)
# is_signal: (40, 12)
# ===========================================================================
# is_signal : True, p_values[47]: 0.17089448325604528
# FPR: 0.14285714285714285, TPR: 0.2926829268292683
# is_not_signal: (7, 1)
# is_signal: (41, 12)
# ===========================================================================
# is_signal : True, p_values[48]: 0.4543610839605812
# FPR: 0.14285714285714285, TPR: 0.2857142857142857
# is_not_signal: (7, 1)
# is_signal: (42, 12)
# ===========================================================================
# is_signal : True, p_values[49]: 0.01762263290586136
# FPR: 0.14285714285714285, TPR: 0.3023255813953488
# is_not_signal: (7, 1)
# is_signal: (43, 13)
# ===========================================================================
# is_signal : True, p_values[50]: 0.0066074300663663725
# FPR: 0.14285714285714285, TPR: 0.3181818181818182
# is_not_signal: (7, 1)
# is_signal: (44, 14)
# ===========================================================================
# is_signal : True, p_values[51]: 0.007121536034888114
# FPR: 0.14285714285714285, TPR: 0.3333333333333333
# is_not_signal: (7, 1)
# is_signal: (45, 15)
# ===========================================================================
# is_signal : True, p_values[52]: 0.0016487640155469913
# FPR: 0.14285714285714285, TPR: 0.34782608695652173
# is_not_signal: (7, 1)
# is_signal: (46, 16)
# ===========================================================================
# is_signal : True, p_values[53]: 0.10518475273140056
# FPR: 0.14285714285714285, TPR: 0.3404255319148936
# is_not_signal: (7, 1)
# is_signal: (47, 16)
# ===========================================================================
# is_signal : True, p_values[54]: 0.3744992258935173
# FPR: 0.14285714285714285, TPR: 0.3333333333333333
# is_not_signal: (7, 1)
# is_signal: (48, 16)
# ===========================================================================
# is_signal : False, p_values[55]: 0.19927665344737153
# FPR: 0.125, TPR: 0.3333333333333333
# is_not_signal: (8, 1)
# is_signal: (48, 16)
# ===========================================================================
# is_signal : True, p_values[56]: 0.06467281666106782
# FPR: 0.125, TPR: 0.32653061224489793
# is_not_signal: (8, 1)
# is_signal: (49, 16)
# ===========================================================================
# is_signal : True, p_values[57]: 0.10436587822080516
# FPR: 0.125, TPR: 0.32
# is_not_signal: (8, 1)
# is_signal: (50, 16)
# ===========================================================================
# is_signal : True, p_values[58]: 0.00279340447648059
# FPR: 0.125, TPR: 0.3333333333333333
# is_not_signal: (8, 1)
# is_signal: (51, 17)
# ===========================================================================
# is_signal : True, p_values[59]: 0.243730568401517
# FPR: 0.125, TPR: 0.3269230769230769
# is_not_signal: (8, 1)
# is_signal: (52, 17)
# ===========================================================================
# is_signal : True, p_values[60]: 0.010016033533876915
# FPR: 0.125, TPR: 0.33962264150943394
# is_not_signal: (8, 1)
# is_signal: (53, 18)
# ===========================================================================
# is_signal : True, p_values[61]: 0.09548273744513143
# FPR: 0.125, TPR: 0.3333333333333333
# is_not_signal: (8, 1)
# is_signal: (54, 18)
# ===========================================================================
# is_signal : True, p_values[62]: 0.13951325351017516
# FPR: 0.125, TPR: 0.32727272727272727
# is_not_signal: (8, 1)
# is_signal: (55, 18)
# ===========================================================================
# is_signal : False, p_values[63]: 0.3318780576862669
# FPR: 0.1111111111111111, TPR: 0.32727272727272727
# is_not_signal: (9, 1)
# is_signal: (55, 18)
# ===========================================================================
# is_signal : True, p_values[64]: 0.018784463008104383
# FPR: 0.1111111111111111, TPR: 0.3392857142857143
# is_not_signal: (9, 1)
# is_signal: (56, 19)
# ===========================================================================
# is_signal : True, p_values[65]: 0.6356249259577635
# FPR: 0.1111111111111111, TPR: 0.3333333333333333
# is_not_signal: (9, 1)
# is_signal: (57, 19)
# ===========================================================================
# -- n_target = 50 --
# is_signal : True, p_values[0]: 0.013968570940678177
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (1, 1)
# ===========================================================================
# is_signal : True, p_values[1]: 0.0004250819249778864
# FPR: nan, TPR: 1.0
# is_not_signal: (0, 0)
# is_signal: (2, 2)
# ===========================================================================
# is_signal : False, p_values[2]: 0.9677572239013333
# FPR: 0.0, TPR: 1.0
# is_not_signal: (1, 0)
# is_signal: (2, 2)
# ===========================================================================
# is_signal : True, p_values[3]: 0.26640100856646953
# FPR: 0.0, TPR: 0.6666666666666666
# is_not_signal: (1, 0)
# is_signal: (3, 2)
# ===========================================================================
# is_signal : True, p_values[4]: 0.049932689827304616
# FPR: 0.0, TPR: 0.75
# is_not_signal: (1, 0)
# is_signal: (4, 3)
# ===========================================================================
# is_signal : False, p_values[5]: 0.18550359807232747
# FPR: 0.0, TPR: 0.75
# is_not_signal: (2, 0)
# is_signal: (4, 3)
# ===========================================================================
# is_signal : True, p_values[6]: 0.005704263054201872
# FPR: 0.0, TPR: 0.8
# is_not_signal: (2, 0)
# is_signal: (5, 4)
# ===========================================================================
# is_signal : True, p_values[7]: 0.05483624153543658
# FPR: 0.0, TPR: 0.6666666666666666
# is_not_signal: (2, 0)
# is_signal: (6, 4)
# ===========================================================================
# is_signal : True, p_values[8]: 0.620229673945733
# FPR: 0.0, TPR: 0.5714285714285714
# is_not_signal: (2, 0)
# is_signal: (7, 4)
# ===========================================================================
# is_signal : True, p_values[9]: 0.02827946745948469
# FPR: 0.0, TPR: 0.625
# is_not_signal: (2, 0)
# is_signal: (8, 5)
# ===========================================================================
# is_signal : True, p_values[10]: 0.4258226575829079
# FPR: 0.0, TPR: 0.5555555555555556
# is_not_signal: (2, 0)
# is_signal: (9, 5)
# ===========================================================================
# is_signal : True, p_values[11]: 0.0006218056550405146
# FPR: 0.0, TPR: 0.6
# is_not_signal: (2, 0)
# is_signal: (10, 6)
# ===========================================================================
# is_signal : True, p_values[12]: 0.0809122483962886
# FPR: 0.0, TPR: 0.5454545454545454
# is_not_signal: (2, 0)
# is_signal: (11, 6)
# ===========================================================================
# is_signal : True, p_values[13]: 0.015543061988932058
# FPR: 0.0, TPR: 0.5833333333333334
# is_not_signal: (2, 0)
# is_signal: (12, 7)
# ===========================================================================
# is_signal : True, p_values[14]: 7.908594596108135e-05
# FPR: 0.0, TPR: 0.6153846153846154
# is_not_signal: (2, 0)
# is_signal: (13, 8)
# ===========================================================================
# is_signal : True, p_values[15]: 0.08317984193827797
# FPR: 0.0, TPR: 0.5714285714285714
# is_not_signal: (2, 0)
# is_signal: (14, 8)
# ===========================================================================
# is_signal : True, p_values[16]: 0.000334957875292256
# FPR: 0.0, TPR: 0.6
# is_not_signal: (2, 0)
# is_signal: (15, 9)
# ===========================================================================
# is_signal : True, p_values[17]: 0.036196681110585556
# FPR: 0.0, TPR: 0.625
# is_not_signal: (2, 0)
# is_signal: (16, 10)
# ===========================================================================
# is_signal : True, p_values[18]: 0.0012107416818764804
# FPR: 0.0, TPR: 0.6470588235294118
# is_not_signal: (2, 0)
# is_signal: (17, 11)
# ===========================================================================
# is_signal : True, p_values[19]: 0.2040635976773686
# FPR: 0.0, TPR: 0.6111111111111112
# is_not_signal: (2, 0)
# is_signal: (18, 11)
# ===========================================================================
# is_signal : True, p_values[20]: 0.3847282213266104
# FPR: 0.0, TPR: 0.5789473684210527
# is_not_signal: (2, 0)
# is_signal: (19, 11)
# ===========================================================================

# %%
n_source = 80
p = 200
K = 5
Ka = 3
h = 10
alpha = 0.05
T = 5
s_len = 10
s_vector = [0.0] * s_len
iteration = 125

n_target_list = [40, 50, 60, 70]

for n_target in n_target_list:
    print(f"-- n_target = {n_target} --")
    para_results_storage = []
    CoRT_model = CoRT_builder.CoRT()
    cnt1 = 0
    cnt2 = 0
    cnt3 = 0
    cnt4 = 0

    for i in range(iteration):
        target_data, source_data = CoRT_model.gen_data(n_target, n_source, p, K, Ka, h, s_vector, s_len, "AR")
        result_dict = SI_CoRT.SI_parametric(n_target, p, K, target_data, source_data, T, s_len)

        if result_dict != None:
            cnt1 += (result_dict['is_signal'] == True)
            cnt2 += (result_dict['is_signal'] == False)
            cnt3 += (result_dict['is_signal'] == True and result_dict['p_value'] <= alpha)
            cnt4 += (result_dict['is_signal'] == False and result_dict['p_value'] <= alpha)
            
        if i % 1 == 0:
            print(f"is_signal : {result_dict['is_signal']}, p_values[{i}]: {result_dict['p_value']}")
            print(f"FPR: {cnt4 / cnt2}, TPR: {cnt3 / cnt1}")
            print(f"is_not_signal: {int(cnt2), int(cnt4)}")
            print(f"is_signal: {int(cnt1), int(cnt3)}")
            print("===========================================================================")
                
            para_results_storage.append(result_dict)
    is_signal_cases = [r for r in para_results_storage if r['is_signal']]
    not_signal_cases = [r for r in para_results_storage if not r['is_signal']]

    false_positives = sum(1 for c in not_signal_cases if c['p_value'] <= alpha)
    fpr = false_positives / len(not_signal_cases) if len(not_signal_cases) != 0 else -1
    true_positives = sum(1 for r in is_signal_cases if r['p_value'] <= alpha) 
    tpr = true_positives / len(is_signal_cases) if len(is_signal_cases) != 0 else -1

    configs = {
        "n_source": n_source,
        "p":  p,
        "K": K,
        "Ka": Ka,
        "h": h,
        "alpha": alpha,
        "T":  T,
        "s_len": s_len,
        "s_vector": s_vector,
        "n_target": n_target,
        "iteration": iteration,
    }

    results = {
        "configs": configs,
        "time": datetime.datetime.now().ctime(),
        "fpr": fpr,
        "tpr": tpr,
        "is_signal_cases": len(is_signal_cases),
        "not_signal_cases": len(not_signal_cases),
        "false_positives": false_positives,
        "true_positives": true_positives
    }

    filename = 'records/FPR_parametric_vis_records.json'
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            try:
                records = json.load(f)
            except Exception as e:
                print(e)
                records = []
    else:
        records = []

    records.append(results)

    with open(filename, 'w') as f:
        json.dump(records, f, indent=4)
